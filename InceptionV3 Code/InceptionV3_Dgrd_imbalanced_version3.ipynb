# %%
# ==========================================================
# CREATE BALANCED DATASET DIRECTORY
# ==========================================================
print("start")

import os





print("Unalanced dataset ready")
# Out:
# start
# Unalanced dataset ready

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("TensorFlow Version: ", tf.__version__)
# Out:
# Num GPUs Available:  1
# TensorFlow Version:  2.10.0

# %%
# ==========================================================
# IMPORTS
# ==========================================================
print("start")

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall
import tensorflow_addons as tfa
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint,
    Callback
)

print("done1")
# Out:
# start
# done1

# %%
# CONFIGURATION & GENERATORS

print("start")




IMAGE_SIZE = (288, 288)
MODEL_INPUT_SIZE = (288, 288, 3) 
NUM_CLASSES = 3              
BATCH_SIZE = 32
EPOCHS = 150

print("done1")
# Out:
# start
# done1

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.inception_v3 import preprocess_input

# 1. Define the base generator (No validation_split needed here anymore)
datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# 2. Define the paths to your new split folders
train_dir = r"D:\Thesis_folder\Preprocessed_Pipeline\Supervised_Imbalanced\train"
val_dir = r"D:\Thesis_folder\Preprocessed_Pipeline\Supervised_Imbalanced\val"
test_dir = r"D:\Thesis_folder\Preprocessed_Pipeline\Supervised_Imbalanced\test"

# 3. Create the Train Generator
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(288, 288),
    batch_size=32,
    class_mode='categorical',
    shuffle=True # Shuffle training data
)

# 4. Create the Validation Generator
val_generator = datagen.flow_from_directory(
    val_dir,
    target_size=(288, 288),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# 5. Create the Test Generator (CRITICAL: shuffle=False for evaluation)
test_generator = datagen.flow_from_directory(
    test_dir,
    target_size=(288, 288),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 13787 images belonging to 3 classes.
# Found 2942 images belonging to 3 classes.
# Found 3002 images belonging to 3 classes.

# %%
print("start")

from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.optimizers import Adam

f1_metric = tfa.metrics.F1Score(num_classes=NUM_CLASSES, average='macro', name='f1_score')
precision_metric = Precision(name='precision')
recall_metric = Recall(name='recall')

def get_InceptionV3():
    base_model = InceptionV3(
        input_shape=MODEL_INPUT_SIZE,
        weights='imagenet',
        include_top=False
    )

    base_model.trainable = False

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(NUM_CLASSES, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=outputs)

    optimizer = Adam(learning_rate=0.0001)

    model.compile(
        loss="categorical_crossentropy",
        metrics=["accuracy", f1_metric, precision_metric, recall_metric],
        optimizer=optimizer
    )

    return model

model = get_InceptionV3()
model.summary()

print("done1")
# Out:
# start
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 288, 288, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 143, 143, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 143, 143, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 143, 143, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 141, 141, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 141, 141, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 141, 141, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 141, 141, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 141, 141, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 141, 141, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 70, 70, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 70, 70, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 70, 70, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 70, 70, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 68, 68, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 68, 68, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 68, 68, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 33, 33, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 33, 33, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 33, 33, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 33, 33, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 33, 33, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 33, 33, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 33, 33, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 33, 33, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 33, 33, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 33, 33, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 33, 33, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 33, 33, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 33, 33, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 33, 33, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 33, 33, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 33, 33, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 33, 33, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 33, 33, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 33, 33, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 33, 33, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 33, 33, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 33, 33, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 33, 33, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 33, 33, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 33, 33, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 33, 33, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 33, 33, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 33, 33, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 33, 33, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 33, 33, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 33, 33, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 33, 33, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 33, 33, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 33, 33, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 33, 33, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 33, 33, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 33, 33, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 33, 33, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 33, 33, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 33, 33, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 33, 33, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 33, 33, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 33, 33, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 33, 33, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 33, 33, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 33, 33, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 33, 33, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 33, 33, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 33, 33, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 33, 33, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 33, 33, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 33, 33, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 33, 33, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 33, 33, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 33, 33, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 33, 33, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 33, 33, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_19 (Conv2D)             (None, 33, 33, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 33, 33, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 33, 33, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 33, 33, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 33, 33, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 33, 33, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 33, 33, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 33, 33, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 33, 33, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 33, 33, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 33, 33, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 33, 33, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 33, 33, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 33, 33, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 33, 33, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 33, 33, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 33, 33, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 33, 33, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 33, 33, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 16, 16, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 16, 16, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 16, 16, 384)  1152       ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 96)  288         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 16, 16, 384)  0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 16, 16, 96)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 16, 16, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 16, 16, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 16, 16, 128)  384        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 16, 16, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 16, 16, 128)  384        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 16, 16, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 16, 16, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 16, 16, 128)  384        ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 16, 16, 128)  384        ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 16, 16, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 16, 16, 128)  384        ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 16, 16, 128)  384        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 16, 16, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_30 (Conv2D)             (None, 16, 16, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 16, 16, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 16, 16, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 16, 16, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 16, 16, 192)  576        ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 16, 16, 192)  576        ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 16, 16, 192)  576        ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 16, 16, 192)  576        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 16, 16, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 16, 16, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 16, 16, 160)  480        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 16, 16, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 16, 16, 160)  480        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 16, 16, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 16, 16, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 16, 16, 160)  480        ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 16, 16, 160)  480        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 16, 16, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 16, 16, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 16, 16, 160)  480        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 16, 16, 160)  480        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 16, 16, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_40 (Conv2D)             (None, 16, 16, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 16, 16, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 16, 16, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 16, 16, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 16, 16, 192)  576        ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 16, 16, 192)  576        ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 16, 16, 192)  576        ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 16, 16, 192)  576        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 16, 16, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 16, 16, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 16, 16, 160)  480        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 16, 16, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 16, 16, 160)  480        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 16, 16, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 16, 16, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 16, 16, 160)  480        ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 16, 16, 160)  480        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 16, 16, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 16, 16, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 16, 16, 160)  480        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 16, 16, 160)  480        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 16, 16, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_50 (Conv2D)             (None, 16, 16, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 16, 16, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 16, 16, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 16, 16, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 16, 16, 192)  576        ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 16, 16, 192)  576        ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 16, 16, 192)  576        ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 16, 16, 192)  576        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_58[0][0]']
#
#  activation_59 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_59[0][0]']
# ...
#  batch_normalization_80 (BatchN  (None, 7, 7, 448)   1344        ['conv2d_80[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 7, 7, 448)    0           ['batch_normalization_80[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 7, 7, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 7, 7, 384)    1548288     ['activation_80[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 7, 7, 384)   1152        ['conv2d_77[0][0]']
#  ormalization)
#
#  batch_normalization_81 (BatchN  (None, 7, 7, 384)   1152        ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 7, 7, 384)    0           ['batch_normalization_77[0][0]']
#
#  activation_81 (Activation)     (None, 7, 7, 384)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 7, 7, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 7, 7, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 7, 7, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 7, 7, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 7, 7, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_76 (Conv2D)             (None, 7, 7, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 7, 7, 384)   1152        ['conv2d_78[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 7, 7, 384)   1152        ['conv2d_79[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 7, 7, 384)   1152        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 7, 7, 384)   1152        ['conv2d_83[0][0]']
#  ormalization)
#
#  conv2d_84 (Conv2D)             (None, 7, 7, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 7, 7, 320)   960         ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 7, 7, 384)    0           ['batch_normalization_78[0][0]']
#
#  activation_79 (Activation)     (None, 7, 7, 384)    0           ['batch_normalization_79[0][0]']
#
#  activation_82 (Activation)     (None, 7, 7, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_83 (Activation)     (None, 7, 7, 384)    0           ['batch_normalization_83[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 7, 7, 192)   576         ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 7, 7, 320)    0           ['batch_normalization_76[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 7, 7, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 7, 7, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 7, 7, 192)    0           ['batch_normalization_84[0][0]']
#
#  mixed9 (Concatenate)           (None, 7, 7, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 7, 7, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 7, 7, 448)   1344        ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 7, 7, 448)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 7, 7, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 7, 7, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 7, 7, 384)   1152        ['conv2d_86[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 7, 7, 384)   1152        ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 7, 7, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 7, 7, 384)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 7, 7, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 7, 7, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 7, 7, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 7, 7, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 7, 7, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_85 (Conv2D)             (None, 7, 7, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 7, 7, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 7, 7, 384)   1152        ['conv2d_88[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 7, 7, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 7, 7, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  conv2d_93 (Conv2D)             (None, 7, 7, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 7, 7, 320)   960         ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 7, 7, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 7, 7, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 7, 7, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 7, 7, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 7, 7, 192)   576         ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 7, 7, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 7, 7, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 7, 7, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 7, 7, 192)    0           ['batch_normalization_93[0][0]']
#
#  mixed10 (Concatenate)          (None, 7, 7, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['mixed10[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 3)            6147        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 21,808,931
# Trainable params: 6,147
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# done1

# %%
# ==========================================================
# CALLBACKS (Monitor set to 'val_f1_score')
# ==========================================================
print("start")

early_stop = EarlyStopping(
    monitor='val_f1_score',
    mode='max',
    patience=11,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.3,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

checkpoint = ModelCheckpoint(
"InceptionV3_Imbalanced_model_V3.h5",
    monitor='val_f1_score',
    save_best_only=True,
    mode='max',
    verbose=1
)

print("done")
# Out:
# start
# done

# %%
# ==========================================================
# SHOW LEARNING RATE
# ==========================================================
print("start")

class PrintLearningRate(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate.numpy()
        print(f"\nEpoch {epoch+1} Learning Rate : {lr}")

lr_callback = PrintLearningRate()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# TRAINING
# ==========================================================
print("start")

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[
        early_stop,
        reduce_lr,
        checkpoint,
        lr_callback
    ]
)
print("done")
# Out:
# start
# Epoch 1/150
# 431/431 [==============================] - ETA: 0s - loss: 0.9994 - accuracy: 0.4906 - f1_score: 0.4626 - precision: 0.6008 - recall: 0.2508
# Epoch 1: val_f1_score improved from -inf to 0.55075, saving model to InceptionV3_Imbalanced_model_V3.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 184s 417ms/step - loss: 0.9994 - accuracy: 0.4906 - f1_score: 0.4626 - precision: 0.6008 - recall: 0.2508 - val_loss: 0.9050 - val_accuracy: 0.5704 - val_f1_score: 0.5507 - val_precision: 0.6816 - val_recall: 0.3521 - lr: 1.0000e-04
# Epoch 2/150
# 431/431 [==============================] - ETA: 0s - loss: 0.8905 - accuracy: 0.5744 - f1_score: 0.5617 - precision: 0.6743 - recall: 0.3944
# Epoch 2: val_f1_score improved from 0.55075 to 0.58556, saving model to InceptionV3_Imbalanced_model_V3.h5
#
# Epoch 2 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 139s 322ms/step - loss: 0.8905 - accuracy: 0.5744 - f1_score: 0.5617 - precision: 0.6743 - recall: 0.3944 - val_loss: 0.8551 - val_accuracy: 0.6050 - val_f1_score: 0.5856 - val_precision: 0.6983 - val_recall: 0.4232 - lr: 1.0000e-04
# Epoch 3/150
# 431/431 [==============================] - ETA: 0s - loss: 0.8478 - accuracy: 0.6027 - f1_score: 0.5897 - precision: 0.6925 - recall: 0.4457
# Epoch 3: val_f1_score improved from 0.58556 to 0.62687, saving model to InceptionV3_Imbalanced_model_V3.h5
#
# Epoch 3 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 136s 314ms/step - loss: 0.8478 - accuracy: 0.6027 - f1_score: 0.5897 - precision: 0.6925 - recall: 0.4457 - val_loss: 0.8262 - val_accuracy: 0.6312 - val_f1_score: 0.6269 - val_precision: 0.7238 - val_recall: 0.4711 - lr: 1.0000e-04
# Epoch 4/150
# 431/431 [==============================] - ETA: 0s - loss: 0.8224 - accuracy: 0.6159 - f1_score: 0.6044 - precision: 0.6984 - recall: 0.4720
# Epoch 4: val_f1_score did not improve from 0.62687
#
# Epoch 4 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 132s 305ms/step - loss: 0.8224 - accuracy: 0.6159 - f1_score: 0.6044 - precision: 0.6984 - recall: 0.4720 - val_loss: 0.8102 - val_accuracy: 0.6336 - val_f1_score: 0.6217 - val_precision: 0.7190 - val_recall: 0.4871 - lr: 1.0000e-04
# Epoch 5/150
# 431/431 [==============================] - ETA: 0s - loss: 0.8050 - accuracy: 0.6246 - f1_score: 0.6121 - precision: 0.7060 - recall: 0.4915
# Epoch 5: val_f1_score did not improve from 0.62687
#
# Epoch 5 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 130s 302ms/step - loss: 0.8050 - accuracy: 0.6246 - f1_score: 0.6121 - precision: 0.7060 - recall: 0.4915 - val_loss: 0.8053 - val_accuracy: 0.6281 - val_f1_score: 0.6168 - val_precision: 0.7077 - val_recall: 0.4922 - lr: 1.0000e-04
# Epoch 6/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7909 - accuracy: 0.6288 - f1_score: 0.6173 - precision: 0.7151 - recall: 0.5108
# Epoch 6: val_f1_score did not improve from 0.62687
#
# Epoch 6 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 132s 306ms/step - loss: 0.7909 - accuracy: 0.6288 - f1_score: 0.6173 - precision: 0.7151 - recall: 0.5108 - val_loss: 0.7930 - val_accuracy: 0.6353 - val_f1_score: 0.6223 - val_precision: 0.7108 - val_recall: 0.5071 - lr: 1.0000e-04
# Epoch 7/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7824 - accuracy: 0.6328 - f1_score: 0.6217 - precision: 0.7138 - recall: 0.5172
# Epoch 7: val_f1_score improved from 0.62687 to 0.63238, saving model to InceptionV3_Imbalanced_model_V3.h5
#
# Epoch 7 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 138s 321ms/step - loss: 0.7824 - accuracy: 0.6328 - f1_score: 0.6217 - precision: 0.7138 - recall: 0.5172 - val_loss: 0.7882 - val_accuracy: 0.6431 - val_f1_score: 0.6324 - val_precision: 0.7171 - val_recall: 0.5153 - lr: 1.0000e-04
# Epoch 8/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7729 - accuracy: 0.6402 - f1_score: 0.6288 - precision: 0.7173 - recall: 0.5233
# Epoch 8: val_f1_score did not improve from 0.63238
#
# Epoch 8 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 132s 306ms/step - loss: 0.7729 - accuracy: 0.6402 - f1_score: 0.6288 - precision: 0.7173 - recall: 0.5233 - val_loss: 0.7834 - val_accuracy: 0.6448 - val_f1_score: 0.6275 - val_precision: 0.7112 - val_recall: 0.5214 - lr: 1.0000e-04
# Epoch 9/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7653 - accuracy: 0.6441 - f1_score: 0.6336 - precision: 0.7192 - recall: 0.5314
# Epoch 9: val_f1_score improved from 0.63238 to 0.63864, saving model to InceptionV3_Imbalanced_model_V3.h5
#
# Epoch 9 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 136s 316ms/step - loss: 0.7653 - accuracy: 0.6441 - f1_score: 0.6336 - precision: 0.7192 - recall: 0.5314 - val_loss: 0.7735 - val_accuracy: 0.6492 - val_f1_score: 0.6386 - val_precision: 0.7215 - val_recall: 0.5292 - lr: 1.0000e-04
# Epoch 10/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7595 - accuracy: 0.6487 - f1_score: 0.6382 - precision: 0.7233 - recall: 0.5395
# Epoch 10: val_f1_score improved from 0.63864 to 0.63889, saving model to InceptionV3_Imbalanced_model_V3.h5
#
# Epoch 10 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 136s 315ms/step - loss: 0.7595 - accuracy: 0.6487 - f1_score: 0.6382 - precision: 0.7233 - recall: 0.5395 - val_loss: 0.7707 - val_accuracy: 0.6472 - val_f1_score: 0.6389 - val_precision: 0.7222 - val_recall: 0.5330 - lr: 1.0000e-04
# Epoch 11/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7535 - accuracy: 0.6483 - f1_score: 0.6375 - precision: 0.7258 - recall: 0.5444
# Epoch 11: val_f1_score did not improve from 0.63889
#
# Epoch 11 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 129s 298ms/step - loss: 0.7535 - accuracy: 0.6483 - f1_score: 0.6375 - precision: 0.7258 - recall: 0.5444 - val_loss: 0.7726 - val_accuracy: 0.6475 - val_f1_score: 0.6284 - val_precision: 0.7086 - val_recall: 0.5364 - lr: 1.0000e-04
# Epoch 12/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7478 - accuracy: 0.6536 - f1_score: 0.6429 - precision: 0.7285 - recall: 0.5496
# Epoch 12: val_f1_score improved from 0.63889 to 0.64668, saving model to InceptionV3_Imbalanced_model_V3.h5
#
# Epoch 12 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 137s 317ms/step - loss: 0.7478 - accuracy: 0.6536 - f1_score: 0.6429 - precision: 0.7285 - recall: 0.5496 - val_loss: 0.7661 - val_accuracy: 0.6489 - val_f1_score: 0.6467 - val_precision: 0.7228 - val_recall: 0.5442 - lr: 1.0000e-04
# Epoch 13/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7444 - accuracy: 0.6567 - f1_score: 0.6467 - precision: 0.7302 - recall: 0.5537
# Epoch 13: val_f1_score did not improve from 0.64668
#
# Epoch 13 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 132s 307ms/step - loss: 0.7444 - accuracy: 0.6567 - f1_score: 0.6467 - precision: 0.7302 - recall: 0.5537 - val_loss: 0.7619 - val_accuracy: 0.6513 - val_f1_score: 0.6419 - val_precision: 0.7183 - val_recall: 0.5486 - lr: 1.0000e-04
# Epoch 14/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7394 - accuracy: 0.6597 - f1_score: 0.6500 - precision: 0.7305 - recall: 0.5598
# Epoch 14: val_f1_score did not improve from 0.64668
#
# Epoch 14 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 129s 300ms/step - loss: 0.7394 - accuracy: 0.6597 - f1_score: 0.6500 - precision: 0.7305 - recall: 0.5598 - val_loss: 0.7660 - val_accuracy: 0.6485 - val_f1_score: 0.6330 - val_precision: 0.7128 - val_recall: 0.5408 - lr: 1.0000e-04
# Epoch 15/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7357 - accuracy: 0.6598 - f1_score: 0.6497 - precision: 0.7318 - recall: 0.5591
# Epoch 15: val_f1_score did not improve from 0.64668
#
# Epoch 15 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 129s 299ms/step - loss: 0.7357 - accuracy: 0.6598 - f1_score: 0.6497 - precision: 0.7318 - recall: 0.5591 - val_loss: 0.7649 - val_accuracy: 0.6492 - val_f1_score: 0.6398 - val_precision: 0.7159 - val_recall: 0.5466 - lr: 1.0000e-04
# Epoch 16/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7328 - accuracy: 0.6655 - f1_score: 0.6558 - precision: 0.7331 - recall: 0.5644
# Epoch 16: val_f1_score did not improve from 0.64668
#
# Epoch 16 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 130s 301ms/step - loss: 0.7328 - accuracy: 0.6655 - f1_score: 0.6558 - precision: 0.7331 - recall: 0.5644 - val_loss: 0.7595 - val_accuracy: 0.6489 - val_f1_score: 0.6428 - val_precision: 0.7176 - val_recall: 0.5459 - lr: 1.0000e-04
# Epoch 17/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7287 - accuracy: 0.6653 - f1_score: 0.6555 - precision: 0.7341 - recall: 0.5651
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 17: val_f1_score did not improve from 0.64668
#
# Epoch 17 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 130s 301ms/step - loss: 0.7287 - accuracy: 0.6653 - f1_score: 0.6555 - precision: 0.7341 - recall: 0.5651 - val_loss: 0.7646 - val_accuracy: 0.6438 - val_f1_score: 0.6240 - val_precision: 0.7043 - val_recall: 0.5455 - lr: 1.0000e-04
# Epoch 18/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7226 - accuracy: 0.6680 - f1_score: 0.6579 - precision: 0.7379 - recall: 0.5704
# Epoch 18: val_f1_score did not improve from 0.64668
#
# Epoch 18 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 131s 303ms/step - loss: 0.7226 - accuracy: 0.6680 - f1_score: 0.6579 - precision: 0.7379 - recall: 0.5704 - val_loss: 0.7551 - val_accuracy: 0.6502 - val_f1_score: 0.6412 - val_precision: 0.7152 - val_recall: 0.5472 - lr: 3.0000e-05
# Epoch 19/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7214 - accuracy: 0.6713 - f1_score: 0.6617 - precision: 0.7378 - recall: 0.5710
# Epoch 19: val_f1_score did not improve from 0.64668
#
# Epoch 19 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 132s 305ms/step - loss: 0.7214 - accuracy: 0.6713 - f1_score: 0.6617 - precision: 0.7378 - recall: 0.5710 - val_loss: 0.7581 - val_accuracy: 0.6530 - val_f1_score: 0.6374 - val_precision: 0.7130 - val_recall: 0.5489 - lr: 3.0000e-05
# Epoch 20/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7205 - accuracy: 0.6703 - f1_score: 0.6601 - precision: 0.7374 - recall: 0.5716
# Epoch 20: val_f1_score did not improve from 0.64668
#
# Epoch 20 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 130s 303ms/step - loss: 0.7205 - accuracy: 0.6703 - f1_score: 0.6601 - precision: 0.7374 - recall: 0.5716 - val_loss: 0.7549 - val_accuracy: 0.6499 - val_f1_score: 0.6394 - val_precision: 0.7132 - val_recall: 0.5486 - lr: 3.0000e-05
# Epoch 21/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7191 - accuracy: 0.6710 - f1_score: 0.6608 - precision: 0.7390 - recall: 0.5743
# Epoch 21: val_f1_score did not improve from 0.64668
#
# Epoch 21 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 130s 303ms/step - loss: 0.7191 - accuracy: 0.6710 - f1_score: 0.6608 - precision: 0.7390 - recall: 0.5743 - val_loss: 0.7541 - val_accuracy: 0.6513 - val_f1_score: 0.6450 - val_precision: 0.7208 - val_recall: 0.5547 - lr: 3.0000e-05
# Epoch 22/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7187 - accuracy: 0.6709 - f1_score: 0.6615 - precision: 0.7400 - recall: 0.5731
# Epoch 22: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 22: val_f1_score did not improve from 0.64668
#
# Epoch 22 Learning Rate : 8.999999408842996e-06
# 431/431 [==============================] - 131s 304ms/step - loss: 0.7187 - accuracy: 0.6709 - f1_score: 0.6615 - precision: 0.7400 - recall: 0.5731 - val_loss: 0.7549 - val_accuracy: 0.6543 - val_f1_score: 0.6428 - val_precision: 0.7127 - val_recall: 0.5472 - lr: 3.0000e-05
# Epoch 23/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7169 - accuracy: 0.6753 - f1_score: 0.6654 - precision: 0.7431 - recall: 0.5744Restoring model weights from the end of the best epoch: 12.
#
# Epoch 23: val_f1_score did not improve from 0.64668
#
# Epoch 23 Learning Rate : 8.999999408842996e-06
# 431/431 [==============================] - 130s 303ms/step - loss: 0.7169 - accuracy: 0.6753 - f1_score: 0.6654 - precision: 0.7431 - recall: 0.5744 - val_loss: 0.7538 - val_accuracy: 0.6509 - val_f1_score: 0.6412 - val_precision: 0.7122 - val_recall: 0.5493 - lr: 9.0000e-06
# Epoch 23: early stopping
# done

# %%
model = get_InceptionV3()

# 2. Load the weights directly into the blueprint
# Note: .load_weights() does not require a custom_objects dictionary!
model.load_weights("InceptionV3_Imbalanced_model_V3.h5")

# %%
# ==========================================================
# PLOT LEARNING CURVES (Loss, F1-Score, Precision)
# ==========================================================
print("start")

# 1. Loss Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Train Loss', color='red')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig("InceptionV3_unbalanced_Loss_Curve3.pdf", format='pdf', bbox_inches='tight')
plt.show()

# 2. F1 Score Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['f1_score'], label='Train F1-Score', color='blue')
plt.plot(history.history['val_f1_score'], label='Validation F1-Score', color='cyan')
plt.xlabel('Epochs')
plt.ylabel('F1-Score')
plt.legend()
plt.tight_layout()
plt.savefig("InceptionV3_Unbalanced_F1_Curve3.pdf", format='pdf', bbox_inches='tight')
plt.show()

# 3. Precision Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['precision'], label='Train Precision', color='green')
plt.plot(history.history['val_precision'], label='Validation Precision', color='lightgreen')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.tight_layout()
plt.savefig("InceptionV3_Unbalanced_Precision_Curve3.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# EVALUATION (Training, Validation & Testing)
# ==========================================================
print("Evaluating on Training Set...")
train_results = model.evaluate(train_generator)

print("\nEvaluating on Validation Set...")
val_results = model.evaluate(val_generator)

print("\nEvaluating on Testing Set (Truly Unseen)...")
test_results = model.evaluate(test_generator)

# Unpacking 5 values based on the compile metrics order
# Order: [loss, accuracy, f1_score, precision, recall]
train_loss = train_results[0]
train_acc = train_results[1]
train_f1 = train_results[2]
train_precision = train_results[3]
train_recall = train_results[4]

val_loss = val_results[0]
val_acc = val_results[1]
val_f1 = val_results[2]
val_precision = val_results[3]
val_recall = val_results[4]

test_loss = test_results[0]
test_acc = test_results[1]
test_f1 = test_results[2]
test_precision = test_results[3]
test_recall = test_results[4]

print("\n" + "="*40)
print("TRAINING METRICS")
print("="*40)
print(f"Training Loss      : {train_loss:.4f}")
print(f"Training Accuracy  : {train_acc*100:.2f}%")
print(f"Training F1-Score  : {train_f1*100:.2f}%")
print(f"Training Precision : {train_precision*100:.2f}%")
print(f"Training Recall    : {train_recall*100:.2f}%")

print("\n" + "="*40)
print("VALIDATION METRICS")
print("="*40)
print(f"Validation Loss      : {val_loss:.4f}")
print(f"Validation Accuracy  : {val_acc*100:.2f}%")
print(f"Validation F1-Score  : {val_f1*100:.2f}%")
print(f"Validation Precision : {val_precision*100:.2f}%")
print(f"Validation Recall    : {val_recall*100:.2f}%")

print("\n" + "="*40)
print("TESTING METRICS (UNSEEN DATA)")
print("="*40)
print(f"Testing Loss      : {test_loss:.4f}")
print(f"Testing Accuracy  : {test_acc*100:.2f}%")
print(f"Testing F1-Score  : {test_f1*100:.2f}%")
print(f"Testing Precision : {test_precision*100:.2f}%")
print(f"Testing Recall    : {test_recall*100:.2f}%")
# Out:
# Evaluating on Training Set...
# 431/431 [==============================] - 108s 248ms/step - loss: 0.7458 - accuracy: 0.6565 - f1_score: 0.6532 - precision: 0.7268 - recall: 0.5507
#
# Evaluating on Validation Set...
# 92/92 [==============================] - 22s 240ms/step - loss: 0.7661 - accuracy: 0.6489 - f1_score: 0.6467 - precision: 0.7228 - recall: 0.5442
#
# Evaluating on Testing Set (Truly Unseen)...
# 94/94 [==============================] - 29s 311ms/step - loss: 0.7998 - accuracy: 0.6262 - f1_score: 0.6245 - precision: 0.6982 - recall: 0.5233
#
# ========================================
# TRAINING METRICS
# ========================================
# Training Loss      : 0.7458
# Training Accuracy  : 65.65%
# Training F1-Score  : 65.32%
# Training Precision : 72.68%
# Training Recall    : 55.07%
#
# ========================================
# VALIDATION METRICS
# ========================================
# Validation Loss      : 0.7661
# Validation Accuracy  : 64.89%
# Validation F1-Score  : 64.67%
# Validation Precision : 72.28%
# Validation Recall    : 54.42%
#
# ========================================
# TESTING METRICS (UNSEEN DATA)
# ========================================
# Testing Loss      : 0.7998
# Testing Accuracy  : 62.62%
# Testing F1-Score  : 62.45%
# Testing Precision : 69.82%
# Testing Recall    : 52.33%

# %%
# ==========================================================
# PRECISION, RECALL, F1-SCORE (Test Set - Unseen Data)
# ==========================================================
print("\nCalculating Precision, Recall, F1-score on Test Set...")

predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

true_classes = test_generator.classes
class_names = list(test_generator.class_indices.keys())

print("\nClassification Report (Test Set):\n")
print(
    classification_report(
        true_classes,
        predicted_classes,
        target_names=class_names
    )
)

print("done1")
# Out:
# Calculating Precision, Recall, F1-score on Test Set...
# 94/94 [==============================] - 22s 232ms/step
#
# Classification Report (Test Set):
#
#               precision    recall  f1-score   support
#
#       Benign       0.51      0.53      0.52       924
#    Malignant       0.68      0.66      0.67      1309
#       Normal       0.68      0.68      0.68       769
#
#     accuracy                           0.63      3002
#    macro avg       0.62      0.63      0.62      3002
# weighted avg       0.63      0.63      0.63      3002
#
# done1

# %%
# ==========================================================
# CONFUSION MATRIX (Test Set)
# ==========================================================
print("Generating Confusion Matrix...")

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(true_classes, predicted_classes)

# Plot the confusion matrix using Seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,       # Show the actual numbers inside the squares
    fmt='d',          # Format as whole numbers (integers)
    cmap='Blues',     # Color scheme
    xticklabels=class_names,
    yticklabels=class_names
)

plt.ylabel('True Label', fontsize=14)
plt.xlabel('Predicted Label', fontsize=14)
plt.xticks(rotation=45) # Rotate x-axis labels so they are easier to read
plt.yticks(rotation=0)

plt.tight_layout()
plt.savefig("InceptionV3 unbalanced confusion_matrix_test_V3.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# Generating Confusion Matrix...
# done1
