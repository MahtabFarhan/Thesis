# %% [markdown]
# # Fused Pipeline v2: Semi-Supervised ResNet-50 + Wavelet Hybrid — Breast Cancer Classification
#
# **Changes from v1**, based on comparing v1's test results against the plain (non-semi-supervised)
# ResNet50+Wavelet hybrid — v1 scored *worse* (70.6% macro F1) than the plain model (72.2% macro F1),
# with training F1 hitting 99.9% while validation F1 sat around 70%. That gap is classic overfitting,
# made worse by feeding the fine-tuned backbone a training set that includes noisy self-training
# pseudo-labels with zero data augmentation to counteract it.
#
# 1. **Data augmentation added to the generator — flip only.** Random rotation/zoom/brightness were
#    dropped: the upstream preprocessing pipeline already balances classes with synthetic augmented
#    copies mixed indistinguishably into `labeled_train`/`unlabeled_train`, so any resampling-based
#    augmentation (rotate, zoom) applied here again would compound blur on top of those copies and hit
#    the balanced (weakest) class hardest. A horizontal flip needs no resampling, so it adds diversity
#    every epoch without that compounding risk.
# 2. **Lighter fine-tuning**: unfreeze fewer ResNet-50 layers (15 instead of 30), fewer epochs (25
#    instead of 40), plus L2 weight decay and higher dropout in the fusion head.
# 3. **Early stopping inside each self-training iteration** (not just a checkpoint) so a bad iteration
#    can't push the model further into memorizing noisy pseudo-labels.
# 4. **Per-class pseudo-label logging** every self-training iteration, so you can see directly whether
#    acceptance is skewed away from Benign (the weakest class in both v1 and the plain baseline) rather
#    than guessing from the aggregate accept/reject count.
# 5. **Confidence threshold left at 0.90, not lowered.** In the v1 run, 0.90 already accepted a
#    substantial fraction of the unlabeled pool each iteration (2,666 / 12,857 in iteration 1 alone) —
#    volume was not the bottleneck. Lowering it would only let in *more* low-confidence, more likely
#    mislabeled examples, which cuts against fixing the overfitting/noise problem. If you want to test
#    this empirically rather than take my word for it, the per-class logging in Phase 2 below (see
#    `iteration_class_counts`) will show you if the accepted labels are trustworthy-looking before you
#    decide to tune the threshold further.
#
# ### Pipeline phases (unchanged)
# - **Phase 1** — train the frozen-backbone hybrid model on `labeled_train` only (now augmented).
# - **Phase 2** — iterative self-training with early stopping per iteration + per-class pseudo-label logging.
# - **Phase 3** — lighter fine-tuning of the ResNet-50 backbone on the final combined set.
# - **Phase 4** — evaluate on train/val/test, classification report, confusion matrix.
#
# ### Expected data layout (unchanged)
# ```
# Semi_Supervised_Balanced/
#     labeled_train/<class>/*.jpg
#     unlabeled_train/<class or single dummy folder>/*.jpg
#     val/<class>/*.jpg
#     test/<class>/*.jpg
# ```

# %%
# ==========================================================
# GPU CHECK
# ==========================================================
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("TensorFlow Version: ", tf.__version__)
# Out:
# Num GPUs Available:  1
# TensorFlow Version:  2.10.0

# %%
# ==========================================================
# IMPORTS
# ==========================================================
print("start")

import os
import shutil
import random
import numpy as np
import cv2
import pywt
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix

from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Dense, GlobalAveragePooling2D, Dropout, Concatenate, BatchNormalization
)
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import Sequence
from tensorflow.keras.metrics import Precision, Recall
import tensorflow_addons as tfa
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint,
    Callback
)

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# SEMI-SUPERVISED DATASET DIRECTORY (BALANCED)
# ==========================================================
# Same directory the semi-supervised EfficientNetB3 notebook uses --
# labeled_train / unlabeled_train / val / test, built by the preprocessing
# pipeline (P3_fixed_final_Pipeline_v11). labeled_train/unlabeled_train/val
# come from the augmented, balanced pool; test is the raw, untouched,
# held-out set shared across all your models so results stay comparable.
print("start")

base_path = r"D:\Thesis_folder\Preprocessed_Pipeline\Semi_Supervised_Balanced"

labeled_dir = os.path.join(base_path, "labeled_train")
unlabeled_dir = os.path.join(base_path, "unlabeled_train")
val_dir = os.path.join(base_path, "val")
test_dir = os.path.join(base_path, "test")
train_combined_dir = os.path.join(base_path, "train_combined")

for split_dir in [labeled_dir, unlabeled_dir, val_dir, test_dir]:
    if not os.path.isdir(split_dir):
        raise FileNotFoundError(
            f"'{split_dir}' not found. Run the preprocessing pipeline "
            "(P3_fixed_final_Pipeline_v11) through the semi-supervised split step first."
        )
    classes_found = [d for d in os.listdir(split_dir) if os.path.isdir(os.path.join(split_dir, d))]
    counts = {cls: len(os.listdir(os.path.join(split_dir, cls))) for cls in classes_found}
    print(f"{os.path.basename(split_dir)}: {counts}")

print("done1")
# Out:
# start
# labeled_train: {'Benign': 1714, 'Malignant': 1714, 'Normal': 1715}
# unlabeled_train: {'Benign': 4286, 'Malignant': 4286, 'Normal': 4285}
# val: {'Benign': 931, 'Malignant': 1239, 'Normal': 795}
# test: {'Benign': 888, 'Malignant': 1266, 'Normal': 789}
# done1

# %%
# ==========================================================
# CONFIGURATION & PARAMETERS  (v2)
# ==========================================================
print("start")

IMAGE_SIZE = (288, 288)
MODEL_INPUT_SIZE = (288, 288, 3)
NUM_CLASSES = 3
BATCH_SIZE = 32
EPOCHS_PHASE1 = 150

WAVELET_NAME = "db1"
WAVELET_LEVEL = 2

# --- Semi-supervised self-training schedule ---
NUM_ITERATIONS = 5
EPOCHS_PER_ITERATION = 7
CONFIDENCE_THRESHOLD = 0.90   # left as-is on purpose -- see markdown note above.
                               # v1 already accepted plenty of volume at this threshold;
                               # the problem was label QUALITY + overfitting downstream,
                               # not too little data getting through.
SELFTRAIN_EARLYSTOP_PATIENCE = 3   # NEW: stop an iteration's fit early if val_f1 stalls,
                                    # instead of always burning all EPOCHS_PER_ITERATION.

# --- Fine-tuning schedule (v2: lighter than v1) ---
EPOCHS_FINETUNE = 25              # was 40
FINETUNE_UNFREEZE_LAST_N = 15     # was 30 -- unfreeze less of the backbone

# --- Regularization (v2: new) ---
DROPOUT_RATE = 0.4                # was 0.3 throughout
L2_REG = 1e-4                     # new L2 weight decay on the fusion head's Dense layers

# --- Data augmentation (v2: new) ---
AUGMENT_TRAIN = True   # applied only to train_labeled_generator / train_combined_generator,
                        # NEVER to val_generator, test_generator, or the unlabeled scoring generator

# NOTE: class weighting / Malignant boost stays removed, per prior decision -- all classes
# are treated equally in the loss. CLASS_WEIGHT_MODE is left here as an easy lever if Benign
# (the weakest class in both v1 and the plain baseline) still needs it after these changes.
CLASS_WEIGHT_MODE = None   # set to 'balanced' to try sklearn-style inverse-frequency weights

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# WAVELET FEATURE EXTRACTION
# ==========================================================
# 2D Discrete Wavelet Transform on the grayscale image; every sub-band
# (approximation + horizontal/vertical/diagonal detail, at every decomposition
# level) is summarised with mean, std and normalised energy. This gives a
# compact, complementary texture descriptor that is concatenated with the
# ResNet-50 deep features.
print("start")

def extract_wavelet_features(image_rgb, wavelet=WAVELET_NAME, level=WAVELET_LEVEL):
    '''
    image_rgb: HxWx3 uint8 or float array (0-255 range)
    Returns: 1D float32 feature vector
    '''
    gray = cv2.cvtColor(image_rgb.astype(np.uint8), cv2.COLOR_RGB2GRAY)
    coeffs = pywt.wavedec2(gray, wavelet=wavelet, level=level)

    features = []
    for idx, c in enumerate(coeffs):
        if idx == 0:
            sub_bands = [c]                 # approximation coefficients
        else:
            sub_bands = list(c)             # (cH, cV, cD) detail coefficients

        for sub in sub_bands:
            features.append(sub.mean())
            features.append(sub.std())
            features.append(np.sum(sub.astype(np.float64) ** 2) / sub.size)

    return np.array(features, dtype=np.float32)


def get_wavelet_feature_dim():
    dummy = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 3), dtype=np.uint8)
    return extract_wavelet_features(dummy).shape[0]


WAVELET_FEATURE_DIM = get_wavelet_feature_dim()
print(f"Wavelet feature vector length: {WAVELET_FEATURE_DIM}")
print("done1")
# Out:
# start
# Wavelet feature vector length: 21
# done1

# %%
# ==========================================================
# AUGMENTATION (v2b, REVISED)
# ==========================================================
# IMPORTANT: the upstream preprocessing pipeline already balances classes by
# inserting synthetic augmented copies (~10% of images) directly into
# labeled_train / unlabeled_train, with no way to tell those apart from
# genuine originals at this stage. Rotation/zoom/jitter are resampling
# operations -- applying them AGAIN on top of an already-augmented image
# compounds interpolation blur and washes out the fine texture detail the
# wavelet branch depends on, and it lands hardest on whichever class was
# balanced with the most synthetic copies (almost certainly Benign, the
# weakest class in every run so far) -- the opposite of what we want.
#
# So this version restricts on-the-fly augmentation to a horizontal flip
# only. A flip is a pure pixel re-index, not a resampling operation, so it
# never compounds blur even when applied to an already-augmented image. It
# still doubles the effective diversity of every epoch (each image can be
# seen in either orientation) without the double-degradation risk that
# rotation/zoom/brightness jitter would carry here.
print("start")

def augment_image(img_rgb):
    if random.random() < 0.5:
        return np.ascontiguousarray(np.fliplr(img_rgb))
    return img_rgb

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# DUAL-INPUT DATA GENERATOR (ResNet-50 image branch + wavelet branch)  (v2)
# ==========================================================
# Same as v1, with one addition: an `augment` flag. When True (train_labeled_
# generator / train_combined_generator only), each image is put through
# augment_image() BEFORE the wavelet features are computed and BEFORE
# preprocess_input, so both branches always see the same (possibly augmented)
# pixels. val_generator, test_generator, and the unlabeled scoring generator
# always use augment=False -- augmenting evaluation or pseudo-label scoring
# would make results non-reproducible and would bias pseudo-label confidence.
class ResNetWaveletGenerator(Sequence):
    def __init__(self, directory, image_size=IMAGE_SIZE, batch_size=BATCH_SIZE,
                 num_classes=NUM_CLASSES, shuffle=True, labeled=True,
                 class_indices=None, exclude_filepaths=None, augment=False):
        self.directory = directory
        self.image_size = image_size
        self.batch_size = batch_size
        self.num_classes = num_classes
        self.shuffle = shuffle
        self.labeled = labeled
        self.augment = augment

        self.class_names = sorted(
            d for d in os.listdir(directory)
            if os.path.isdir(os.path.join(directory, d))
        )
        self.class_indices = class_indices or {name: i for i, name in enumerate(self.class_names)}

        exclude_filepaths = exclude_filepaths or set()

        self.filepaths = []
        self.labels = []
        for cls in self.class_names:
            cls_dir = os.path.join(directory, cls)
            for fname in os.listdir(cls_dir):
                if fname.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tif", ".tiff")):
                    fpath = os.path.join(cls_dir, fname)
                    if fpath in exclude_filepaths:
                        continue
                    self.filepaths.append(fpath)
                    self.labels.append(self.class_indices.get(cls, 0))

        self.labels = np.array(self.labels)
        self.indices = np.arange(len(self.filepaths))
        self.on_epoch_end()

    def __len__(self):
        return max(1, int(np.ceil(len(self.filepaths) / self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

    def __getitem__(self, idx):
        batch_idx = self.indices[idx * self.batch_size:(idx + 1) * self.batch_size]

        batch_images = np.zeros((len(batch_idx), *self.image_size, 3), dtype=np.float32)
        batch_wavelets = np.zeros((len(batch_idx), WAVELET_FEATURE_DIM), dtype=np.float32)
        batch_labels = np.zeros((len(batch_idx), self.num_classes), dtype=np.float32)

        for i, fi in enumerate(batch_idx):
            img_bgr = cv2.imread(self.filepaths[fi])
            img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
            img_rgb = cv2.resize(img_rgb, self.image_size)

            if self.augment:
                img_rgb = augment_image(img_rgb)

            # Wavelet branch computed on the (possibly augmented) raw 0-255 image,
            # BEFORE ResNet's preprocess_input rescales/centres it.
            batch_wavelets[i] = extract_wavelet_features(img_rgb)
            batch_images[i] = preprocess_input(img_rgb.astype(np.float32))

            if self.labeled:
                batch_labels[i, self.labels[fi]] = 1.0

        if self.labeled:
            return [batch_images, batch_wavelets], batch_labels
        # NOTE (kept from v1): must stay a 2-tuple (x, None), not a bare list --
        # Keras's Sequence protocol would otherwise silently drop the wavelet input.
        return [batch_images, batch_wavelets], None

    def filepaths_for_batch(self, idx):
        batch_idx = self.indices[idx * self.batch_size:(idx + 1) * self.batch_size]
        return [self.filepaths[i] for i in batch_idx]

print("ResNetWaveletGenerator (v2, with augmentation) ready")
# Out:
# ResNetWaveletGenerator (v2, with augmentation) ready

# %%
# ==========================================================
# BUILD LABELED / VAL / TEST GENERATORS  (v2: train generator is augmented)
# ==========================================================
print("start")

train_labeled_generator = ResNetWaveletGenerator(
    labeled_dir, shuffle=True, labeled=True, augment=AUGMENT_TRAIN
)

# Val/test must share the exact same class_indices mapping as train_labeled,
# and are NEVER augmented.
val_generator = ResNetWaveletGenerator(
    val_dir, shuffle=False, labeled=True, augment=False,
    class_indices=train_labeled_generator.class_indices
)

test_generator = ResNetWaveletGenerator(
    test_dir, shuffle=False, labeled=True, augment=False,
    class_indices=train_labeled_generator.class_indices
)

class_names = train_labeled_generator.class_names
print("Class indices:", train_labeled_generator.class_indices)

assert len(class_names) == NUM_CLASSES, (
    f"Expected {NUM_CLASSES} classes, found {len(class_names)}. "
    "Rerun the preprocessing pipeline from a clean state."
)
assert set(val_generator.filepaths).isdisjoint(set(test_generator.filepaths)), (
    "val_generator and test_generator appear to overlap."
)

print("done1")
# Out:
# start
# Class indices: {'Benign': 0, 'Malignant': 1, 'Normal': 2}
# done1

# %%
# ==========================================================
# CLASS WEIGHTS -- still disabled by default (v2 keeps the prior decision)
# ==========================================================
if CLASS_WEIGHT_MODE == 'balanced':
    from sklearn.utils.class_weight import compute_class_weight
    classes_arr = np.arange(NUM_CLASSES)
    weights = compute_class_weight('balanced', classes=classes_arr, y=train_labeled_generator.labels)
    class_weight = {i: w for i, w in enumerate(weights)}
    print("Class weighting: balanced ->", class_weight)
else:
    class_weight = None
    print("Class weighting: disabled (class_weight=None)")

print("Class names:", class_names)
# Out:
# Class weighting: disabled (class_weight=None)
# Class names: ['Benign', 'Malignant', 'Normal']

# %%
# ==========================================================
# MODEL DEFINITION: ResNet-50 (image branch) + Wavelet MLP (feature branch)  (v2)
# ==========================================================
# Same dual-branch architecture as v1. NEW: L2 weight decay on the fusion
# head's Dense layers, and dropout raised from 0.3 -> DROPOUT_RATE (0.4) --
# both aimed directly at the 99.9%-train / 70%-val overfitting gap seen in v1.
print("start")

f1_metric = tfa.metrics.F1Score(num_classes=NUM_CLASSES, average='macro', name='f1_score')
precision_metric = Precision(name='precision')
recall_metric = Recall(name='recall')

def get_ResNet50_Wavelet_Hybrid(learning_rate=1e-4):
    # ---- Image branch: ResNet-50 (frozen, ImageNet weights) ----
    image_input = Input(shape=MODEL_INPUT_SIZE, name="image_input")
    base_model = ResNet50(
        input_tensor=image_input,
        weights='imagenet',
        include_top=False
    )
    base_model.trainable = False

    x_img = GlobalAveragePooling2D()(base_model.output)
    x_img = Dropout(DROPOUT_RATE)(x_img)

    # ---- Wavelet branch: small MLP over handcrafted features ----
    wavelet_input = Input(shape=(WAVELET_FEATURE_DIM,), name="wavelet_input")
    x_wav = BatchNormalization()(wavelet_input)
    x_wav = Dense(64, activation='relu', kernel_regularizer=regularizers.l2(L2_REG))(x_wav)
    x_wav = Dropout(DROPOUT_RATE)(x_wav)

    # ---- Fusion + classifier head ----
    fused = Concatenate()([x_img, x_wav])
    fused = Dense(128, activation='relu', kernel_regularizer=regularizers.l2(L2_REG))(fused)
    fused = Dropout(DROPOUT_RATE)(fused)
    output = Dense(NUM_CLASSES, activation='softmax', kernel_regularizer=regularizers.l2(L2_REG))(fused)

    model = Model(inputs=[image_input, wavelet_input], outputs=output)

    optimizer = Adam(learning_rate=learning_rate)
    model.compile(
        loss="categorical_crossentropy",
        metrics=["accuracy", f1_metric, precision_metric, recall_metric],
        optimizer=optimizer
    )

    return model, base_model

model, base_model = get_ResNet50_Wavelet_Hybrid()
model.summary()

print("done1")
# Out:
# start
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image_input (InputLayer)       [(None, 288, 288, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 294, 294, 3)  0           ['image_input[0][0]']
#
#  conv1_conv (Conv2D)            (None, 144, 144, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 144, 144, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 144, 144, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 146, 146, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 72, 72, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 72, 72, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 72, 72, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 72, 72, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 72, 72, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 72, 72, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 72, 72, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 72, 72, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 72, 72, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 72, 72, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 72, 72, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 72, 72, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 72, 72, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 72, 72, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 72, 72, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 72, 72, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 72, 72, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 72, 72, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 72, 72, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 72, 72, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 72, 72, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 36, 36, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 36, 36, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 36, 36, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 36, 36, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 36, 36, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 36, 36, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 36, 36, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 36, 36, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 36, 36, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 36, 36, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 36, 36, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 36, 36, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 36, 36, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 36, 36, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 36, 36, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 36, 36, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 36, 36, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 36, 36, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 36, 36, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 36, 36, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 36, 36, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 36, 36, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 36, 36, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 36, 36, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 36, 36, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 36, 36, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 18, 18, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 18, 18, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 18, 18, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 18, 18, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 18, 18, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 18, 18, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 18, 18, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 18, 18, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 9, 9, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 9, 9, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 9, 9, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 9, 9, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 9, 9, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 9, 9, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 9, 9, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 9, 9, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 9, 9, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 9, 9, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 9, 9, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 9, 9, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 9, 9, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 9, 9, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 9, 9, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 9, 9, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 9, 9, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 9, 9, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 9, 9, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  wavelet_input (InputLayer)     [(None, 21)]         0           []
#
#  conv5_block3_out (Activation)  (None, 9, 9, 2048)   0           ['conv5_block3_add[0][0]']
#
#  batch_normalization (BatchNorm  (None, 21)          84          ['wavelet_input[0][0]']
#  alization)
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 64)           1408        ['batch_normalization[0][0]']
#
#  dropout (Dropout)              (None, 2048)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout_1 (Dropout)            (None, 64)           0           ['dense[0][0]']
#
#  concatenate (Concatenate)      (None, 2112)         0           ['dropout[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  dense_1 (Dense)                (None, 128)          270464      ['concatenate[0][0]']
#
#  dropout_2 (Dropout)            (None, 128)          0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 3)            387         ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 23,860,055
# Trainable params: 272,301
# Non-trainable params: 23,587,754
# __________________________________________________________________________________________________
# done1

# %%
# ==========================================================
# CALLBACKS -- PHASE 1 (frozen backbone, labeled-only training)
# ==========================================================
print("start")

early_stop = EarlyStopping(
    monitor='val_f1_score',
    mode='max',
    patience=11,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.3,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

checkpoint_initial = ModelCheckpoint(
    "ResNet50_Wavelet_SemiSupervised_Initial_v2.h5",
    monitor='val_f1_score',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

class PrintLearningRate(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate.numpy()
        print(f"\nEpoch {epoch+1} Learning Rate : {lr}")

lr_callback = PrintLearningRate()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# PHASE 1: INITIAL MODEL TRAINING (labeled subset only, frozen backbone, augmented)
# ==========================================================
print("start")

history_initial = model.fit(
    train_labeled_generator,
    validation_data=val_generator,
    epochs=EPOCHS_PHASE1,
    callbacks=[early_stop, reduce_lr, checkpoint_initial, lr_callback]
)

print("Initial baseline model training complete")
# Out:
# start
# Epoch 1/150
# 161/161 [==============================] - ETA: 0s - loss: 1.2203 - accuracy: 0.4492 - f1_score: 0.4492 - precision: 0.4679 - recall: 0.3385
# Epoch 1: val_f1_score improved from -inf to 0.56075, saving model to ResNet50_Wavelet_SemiSupervised_Initial_v2.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 108s 651ms/step - loss: 1.2203 - accuracy: 0.4492 - f1_score: 0.4492 - precision: 0.4679 - recall: 0.3385 - val_loss: 0.9213 - val_accuracy: 0.5872 - val_f1_score: 0.5608 - val_precision: 0.7183 - val_recall: 0.3551 - lr: 1.0000e-04
# Epoch 2/150
# 161/161 [==============================] - ETA: 0s - loss: 0.9765 - accuracy: 0.5534 - f1_score: 0.5505 - precision: 0.6074 - recall: 0.4042
# Epoch 2: val_f1_score improved from 0.56075 to 0.57501, saving model to ResNet50_Wavelet_SemiSupervised_Initial_v2.h5
#
# Epoch 2 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 106s 660ms/step - loss: 0.9765 - accuracy: 0.5534 - f1_score: 0.5505 - precision: 0.6074 - recall: 0.4042 - val_loss: 0.8911 - val_accuracy: 0.5919 - val_f1_score: 0.5750 - val_precision: 0.7046 - val_recall: 0.3629 - lr: 1.0000e-04
# Epoch 3/150
# 161/161 [==============================] - ETA: 0s - loss: 0.9130 - accuracy: 0.5742 - f1_score: 0.5692 - precision: 0.6376 - recall: 0.4455
# Epoch 3: val_f1_score improved from 0.57501 to 0.59840, saving model to ResNet50_Wavelet_SemiSupervised_Initial_v2.h5
#
# Epoch 3 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 107s 663ms/step - loss: 0.9130 - accuracy: 0.5742 - f1_score: 0.5692 - precision: 0.6376 - recall: 0.4455 - val_loss: 0.8494 - val_accuracy: 0.6138 - val_f1_score: 0.5984 - val_precision: 0.7244 - val_recall: 0.4334 - lr: 1.0000e-04
# Epoch 4/150
# 161/161 [==============================] - ETA: 0s - loss: 0.8789 - accuracy: 0.5950 - f1_score: 0.5905 - precision: 0.6649 - recall: 0.4830
# Epoch 4: val_f1_score improved from 0.59840 to 0.62040, saving model to ResNet50_Wavelet_SemiSupervised_Initial_v2.h5
#
# Epoch 4 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 109s 675ms/step - loss: 0.8789 - accuracy: 0.5950 - f1_score: 0.5905 - precision: 0.6649 - recall: 0.4830 - val_loss: 0.8156 - val_accuracy: 0.6351 - val_f1_score: 0.6204 - val_precision: 0.7540 - val_recall: 0.4806 - lr: 1.0000e-04
# Epoch 5/150
# 161/161 [==============================] - ETA: 0s - loss: 0.8415 - accuracy: 0.6201 - f1_score: 0.6157 - precision: 0.6804 - recall: 0.5092
# Epoch 5: val_f1_score improved from 0.62040 to 0.62439, saving model to ResNet50_Wavelet_SemiSupervised_Initial_v2.h5
#
# Epoch 5 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 106s 658ms/step - loss: 0.8415 - accuracy: 0.6201 - f1_score: 0.6157 - precision: 0.6804 - recall: 0.5092 - val_loss: 0.7884 - val_accuracy: 0.6371 - val_f1_score: 0.6244 - val_precision: 0.7405 - val_recall: 0.5062 - lr: 1.0000e-04
# Epoch 6/150
# 161/161 [==============================] - ETA: 0s - loss: 0.8202 - accuracy: 0.6181 - f1_score: 0.6133 - precision: 0.6753 - recall: 0.5201
# Epoch 6: val_f1_score improved from 0.62439 to 0.64392, saving model to ResNet50_Wavelet_SemiSupervised_Initial_v2.h5
#
# Epoch 6 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 113s 699ms/step - loss: 0.8202 - accuracy: 0.6181 - f1_score: 0.6133 - precision: 0.6753 - recall: 0.5201 - val_loss: 0.7878 - val_accuracy: 0.6405 - val_f1_score: 0.6439 - val_precision: 0.7264 - val_recall: 0.4880 - lr: 1.0000e-04
# Epoch 7/150
# 161/161 [==============================] - ETA: 0s - loss: 0.8207 - accuracy: 0.6236 - f1_score: 0.6195 - precision: 0.6895 - recall: 0.5225
# Epoch 7: val_f1_score improved from 0.64392 to 0.64629, saving model to ResNet50_Wavelet_SemiSupervised_Initial_v2.h5
#
# Epoch 7 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 107s 664ms/step - loss: 0.8207 - accuracy: 0.6236 - f1_score: 0.6195 - precision: 0.6895 - recall: 0.5225 - val_loss: 0.7796 - val_accuracy: 0.6516 - val_f1_score: 0.6463 - val_precision: 0.7485 - val_recall: 0.4998 - lr: 1.0000e-04
# Epoch 8/150
# 161/161 [==============================] - ETA: 0s - loss: 0.8049 - accuracy: 0.6280 - f1_score: 0.6238 - precision: 0.6935 - recall: 0.5359
# Epoch 8: val_f1_score did not improve from 0.64629
#
# Epoch 8 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 102s 633ms/step - loss: 0.8049 - accuracy: 0.6280 - f1_score: 0.6238 - precision: 0.6935 - recall: 0.5359 - val_loss: 0.7706 - val_accuracy: 0.6455 - val_f1_score: 0.6410 - val_precision: 0.7380 - val_recall: 0.5130 - lr: 1.0000e-04
# Epoch 9/150
# 161/161 [==============================] - ETA: 0s - loss: 0.8001 - accuracy: 0.6346 - f1_score: 0.6299 - precision: 0.6975 - recall: 0.5398
# Epoch 9: val_f1_score did not improve from 0.64629
#
# Epoch 9 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 101s 628ms/step - loss: 0.8001 - accuracy: 0.6346 - f1_score: 0.6299 - precision: 0.6975 - recall: 0.5398 - val_loss: 0.7637 - val_accuracy: 0.6523 - val_f1_score: 0.6447 - val_precision: 0.7469 - val_recall: 0.5157 - lr: 1.0000e-04
# Epoch 10/150
# 161/161 [==============================] - ETA: 0s - loss: 0.7854 - accuracy: 0.6346 - f1_score: 0.6300 - precision: 0.6974 - recall: 0.5390
# Epoch 10: val_f1_score improved from 0.64629 to 0.65467, saving model to ResNet50_Wavelet_SemiSupervised_Initial_v2.h5
#
# Epoch 10 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 105s 654ms/step - loss: 0.7854 - accuracy: 0.6346 - f1_score: 0.6300 - precision: 0.6974 - recall: 0.5390 - val_loss: 0.7594 - val_accuracy: 0.6563 - val_f1_score: 0.6547 - val_precision: 0.7567 - val_recall: 0.5234 - lr: 1.0000e-04
# Epoch 11/150
# 161/161 [==============================] - ETA: 0s - loss: 0.7680 - accuracy: 0.6498 - f1_score: 0.6464 - precision: 0.7145 - recall: 0.5551
# Epoch 11: val_f1_score did not improve from 0.65467
#
# Epoch 11 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 101s 628ms/step - loss: 0.7680 - accuracy: 0.6498 - f1_score: 0.6464 - precision: 0.7145 - recall: 0.5551 - val_loss: 0.7438 - val_accuracy: 0.6597 - val_f1_score: 0.6475 - val_precision: 0.7409 - val_recall: 0.5440 - lr: 1.0000e-04
# Epoch 12/150
# 161/161 [==============================] - ETA: 0s - loss: 0.7550 - accuracy: 0.6599 - f1_score: 0.6559 - precision: 0.7172 - recall: 0.5670
# Epoch 12: val_f1_score improved from 0.65467 to 0.65515, saving model to ResNet50_Wavelet_SemiSupervised_Initial_v2.h5
#
# Epoch 12 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 108s 672ms/step - loss: 0.7550 - accuracy: 0.6599 - f1_score: 0.6559 - precision: 0.7172 - recall: 0.5670 - val_loss: 0.7412 - val_accuracy: 0.6597 - val_f1_score: 0.6552 - val_precision: 0.7445 - val_recall: 0.5494 - lr: 1.0000e-04
# Epoch 13/150
# 161/161 [==============================] - ETA: 0s - loss: 0.7441 - accuracy: 0.6597 - f1_score: 0.6562 - precision: 0.7161 - recall: 0.5748
# Epoch 13: val_f1_score improved from 0.65515 to 0.65882, saving model to ResNet50_Wavelet_SemiSupervised_Initial_v2.h5
#
# Epoch 13 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 111s 691ms/step - loss: 0.7441 - accuracy: 0.6597 - f1_score: 0.6562 - precision: 0.7161 - recall: 0.5748 - val_loss: 0.7363 - val_accuracy: 0.6607 - val_f1_score: 0.6588 - val_precision: 0.7460 - val_recall: 0.5467 - lr: 1.0000e-04
# Epoch 14/150
# 161/161 [==============================] - ETA: 0s - loss: 0.7345 - accuracy: 0.6568 - f1_score: 0.6528 - precision: 0.7155 - recall: 0.5771
# Epoch 14: val_f1_score improved from 0.65882 to 0.66104, saving model to ResNet50_Wavelet_SemiSupervised_Initial_v2.h5
#
# Epoch 14 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 109s 680ms/step - loss: 0.7345 - accuracy: 0.6568 - f1_score: 0.6528 - precision: 0.7155 - recall: 0.5771 - val_loss: 0.7286 - val_accuracy: 0.6678 - val_f1_score: 0.6610 - val_precision: 0.7538 - val_recall: 0.5565 - lr: 1.0000e-04
# Epoch 15/150
# 161/161 [==============================] - ETA: 0s - loss: 0.7333 - accuracy: 0.6625 - f1_score: 0.6587 - precision: 0.7250 - recall: 0.5740
# Epoch 15: val_f1_score improved from 0.66104 to 0.66327, saving model to ResNet50_Wavelet_SemiSupervised_Initial_v2.h5
#
# Epoch 15 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 111s 690ms/step - loss: 0.7333 - accuracy: 0.6625 - f1_score: 0.6587 - precision: 0.7250 - recall: 0.5740 - val_loss: 0.7288 - val_accuracy: 0.6631 - val_f1_score: 0.6633 - val_precision: 0.7415 - val_recall: 0.5494 - lr: 1.0000e-04
# Epoch 16/150
# 161/161 [==============================] - ETA: 0s - loss: 0.7258 - accuracy: 0.6685 - f1_score: 0.6650 - precision: 0.7252 - recall: 0.5870
# Epoch 16: val_f1_score improved from 0.66327 to 0.66398, saving model to ResNet50_Wavelet_SemiSupervised_Initial_v2.h5
#
# Epoch 16 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 106s 658ms/step - loss: 0.7258 - accuracy: 0.6685 - f1_score: 0.6650 - precision: 0.7252 - recall: 0.5870 - val_loss: 0.7214 - val_accuracy: 0.6715 - val_f1_score: 0.6640 - val_precision: 0.7526 - val_recall: 0.5632 - lr: 1.0000e-04
# Epoch 17/150
# 161/161 [==============================] - ETA: 0s - loss: 0.7229 - accuracy: 0.6693 - f1_score: 0.6664 - precision: 0.7266 - recall: 0.5866
# Epoch 17: val_f1_score did not improve from 0.66398
#
# Epoch 17 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 99s 612ms/step - loss: 0.7229 - accuracy: 0.6693 - f1_score: 0.6664 - precision: 0.7266 - recall: 0.5866 - val_loss: 0.7294 - val_accuracy: 0.6634 - val_f1_score: 0.6590 - val_precision: 0.7337 - val_recall: 0.5565 - lr: 1.0000e-04
# Epoch 18/150
# 161/161 [==============================] - ETA: 0s - loss: 0.7225 - accuracy: 0.6687 - f1_score: 0.6653 - precision: 0.7295 - recall: 0.5874
# Epoch 18: val_f1_score did not improve from 0.66398
#
# Epoch 18 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 101s 627ms/step - loss: 0.7225 - accuracy: 0.6687 - f1_score: 0.6653 - precision: 0.7295 - recall: 0.5874 - val_loss: 0.7192 - val_accuracy: 0.6695 - val_f1_score: 0.6602 - val_precision: 0.7466 - val_recall: 0.5585 - lr: 1.0000e-04
# Epoch 19/150
# 161/161 [==============================] - ETA: 0s - loss: 0.7099 - accuracy: 0.6730 - f1_score: 0.6699 - precision: 0.7259 - recall: 0.5880
# Epoch 19: val_f1_score improved from 0.66398 to 0.67708, saving model to ResNet50_Wavelet_SemiSupervised_Initial_v2.h5
#
# Epoch 19 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 105s 652ms/step - loss: 0.7099 - accuracy: 0.6730 - f1_score: 0.6699 - precision: 0.7259 - recall: 0.5880 - val_loss: 0.7153 - val_accuracy: 0.6772 - val_f1_score: 0.6771 - val_precision: 0.7589 - val_recall: 0.5700 - lr: 1.0000e-04
# Epoch 20/150
# 161/161 [==============================] - ETA: 0s - loss: 0.7079 - accuracy: 0.6747 - f1_score: 0.6719 - precision: 0.7332 - recall: 0.5925
# Epoch 20: val_f1_score did not improve from 0.67708
#
# Epoch 20 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 103s 638ms/step - loss: 0.7079 - accuracy: 0.6747 - f1_score: 0.6719 - precision: 0.7332 - recall: 0.5925 - val_loss: 0.7115 - val_accuracy: 0.6766 - val_f1_score: 0.6668 - val_precision: 0.7567 - val_recall: 0.5676 - lr: 1.0000e-04
# Epoch 21/150
# 161/161 [==============================] - ETA: 0s - loss: 0.7040 - accuracy: 0.6836 - f1_score: 0.6810 - precision: 0.7390 - recall: 0.6018
# Epoch 21: val_f1_score did not improve from 0.67708
#
# Epoch 21 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 105s 651ms/step - loss: 0.7040 - accuracy: 0.6836 - f1_score: 0.6810 - precision: 0.7390 - recall: 0.6018 - val_loss: 0.7098 - val_accuracy: 0.6718 - val_f1_score: 0.6697 - val_precision: 0.7604 - val_recall: 0.5683 - lr: 1.0000e-04
# Epoch 22/150
# 161/161 [==============================] - ETA: 0s - loss: 0.6959 - accuracy: 0.6784 - f1_score: 0.6761 - precision: 0.7379 - recall: 0.5971
# Epoch 22: val_f1_score did not improve from 0.67708
#
# Epoch 22 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 103s 640ms/step - loss: 0.6959 - accuracy: 0.6784 - f1_score: 0.6761 - precision: 0.7379 - recall: 0.5971 - val_loss: 0.7106 - val_accuracy: 0.6793 - val_f1_score: 0.6768 - val_precision: 0.7599 - val_recall: 0.5744 - lr: 1.0000e-04
# Epoch 23/150
# 161/161 [==============================] - ETA: 0s - loss: 0.6911 - accuracy: 0.6811 - f1_score: 0.6782 - precision: 0.7442 - recall: 0.6031
# Epoch 23: val_f1_score did not improve from 0.67708
#
# Epoch 23 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 102s 631ms/step - loss: 0.6911 - accuracy: 0.6811 - f1_score: 0.6782 - precision: 0.7442 - recall: 0.6031 - val_loss: 0.7041 - val_accuracy: 0.6796 - val_f1_score: 0.6729 - val_precision: 0.7509 - val_recall: 0.5794 - lr: 1.0000e-04
# Epoch 24/150
# 161/161 [==============================] - ETA: 0s - loss: 0.6787 - accuracy: 0.6912 - f1_score: 0.6882 - precision: 0.7409 - recall: 0.6129
# Epoch 24: val_f1_score improved from 0.67708 to 0.67804, saving model to ResNet50_Wavelet_SemiSupervised_Initial_v2.h5
#
# Epoch 24 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 107s 665ms/step - loss: 0.6787 - accuracy: 0.6912 - f1_score: 0.6882 - precision: 0.7409 - recall: 0.6129 - val_loss: 0.7028 - val_accuracy: 0.6813 - val_f1_score: 0.6780 - val_precision: 0.7521 - val_recall: 0.5781 - lr: 1.0000e-04
# Epoch 25/150
# 161/161 [==============================] - ETA: 0s - loss: 0.6792 - accuracy: 0.6922 - f1_score: 0.6891 - precision: 0.7475 - recall: 0.6181
# Epoch 25: val_f1_score did not improve from 0.67804
#
# Epoch 25 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 99s 614ms/step - loss: 0.6792 - accuracy: 0.6922 - f1_score: 0.6891 - precision: 0.7475 - recall: 0.6181 - val_loss: 0.7092 - val_accuracy: 0.6725 - val_f1_score: 0.6675 - val_precision: 0.7347 - val_recall: 0.5696 - lr: 1.0000e-04
# Epoch 26/150
# 161/161 [==============================] - ETA: 0s - loss: 0.6708 - accuracy: 0.6988 - f1_score: 0.6961 - precision: 0.7520 - recall: 0.6292
# Epoch 26: val_f1_score did not improve from 0.67804
#
# Epoch 26 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 99s 617ms/step - loss: 0.6708 - accuracy: 0.6988 - f1_score: 0.6961 - precision: 0.7520 - recall: 0.6292 - val_loss: 0.7032 - val_accuracy: 0.6752 - val_f1_score: 0.6716 - val_precision: 0.7475 - val_recall: 0.5781 - lr: 1.0000e-04
# Epoch 27/150
# 161/161 [==============================] - ETA: 0s - loss: 0.6760 - accuracy: 0.6918 - f1_score: 0.6882 - precision: 0.7468 - recall: 0.6199
# Epoch 27: val_f1_score did not improve from 0.67804
#
# Epoch 27 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 103s 638ms/step - loss: 0.6760 - accuracy: 0.6918 - f1_score: 0.6882 - precision: 0.7468 - recall: 0.6199 - val_loss: 0.6928 - val_accuracy: 0.6766 - val_f1_score: 0.6722 - val_precision: 0.7524 - val_recall: 0.5882 - lr: 1.0000e-04
# Epoch 28/150
# 161/161 [==============================] - ETA: 0s - loss: 0.6767 - accuracy: 0.6889 - f1_score: 0.6860 - precision: 0.7435 - recall: 0.6181
# Epoch 28: val_f1_score improved from 0.67804 to 0.68884, saving model to ResNet50_Wavelet_SemiSupervised_Initial_v2.h5
#
# Epoch 28 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 111s 689ms/step - loss: 0.6767 - accuracy: 0.6889 - f1_score: 0.6860 - precision: 0.7435 - recall: 0.6181 - val_loss: 0.6926 - val_accuracy: 0.6894 - val_f1_score: 0.6888 - val_precision: 0.7568 - val_recall: 0.5973 - lr: 1.0000e-04
# Epoch 29/150
# 161/161 [==============================] - ETA: 0s - loss: 0.6745 - accuracy: 0.6961 - f1_score: 0.6934 - precision: 0.7484 - recall: 0.6234
# Epoch 29: val_f1_score did not improve from 0.68884
#
# Epoch 29 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 106s 658ms/step - loss: 0.6745 - accuracy: 0.6961 - f1_score: 0.6934 - precision: 0.7484 - recall: 0.6234 - val_loss: 0.6911 - val_accuracy: 0.6884 - val_f1_score: 0.6836 - val_precision: 0.7564 - val_recall: 0.6000 - lr: 1.0000e-04
# Epoch 30/150
# 161/161 [==============================] - ETA: 0s - loss: 0.6710 - accuracy: 0.7002 - f1_score: 0.6975 - precision: 0.7553 - recall: 0.6236
# Epoch 30: val_f1_score did not improve from 0.68884
#
# Epoch 30 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 103s 639ms/step - loss: 0.6710 - accuracy: 0.7002 - f1_score: 0.6975 - precision: 0.7553 - recall: 0.6236 - val_loss: 0.6905 - val_accuracy: 0.6823 - val_f1_score: 0.6758 - val_precision: 0.7575 - val_recall: 0.5922 - lr: 1.0000e-04
# Epoch 31/150
# 161/161 [==============================] - ETA: 0s - loss: 0.6565 - accuracy: 0.7087 - f1_score: 0.7056 - precision: 0.7614 - recall: 0.6378
# Epoch 31: val_f1_score did not improve from 0.68884
#
# Epoch 31 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 99s 617ms/step - loss: 0.6565 - accuracy: 0.7087 - f1_score: 0.7056 - precision: 0.7614 - recall: 0.6378 - val_loss: 0.6856 - val_accuracy: 0.6897 - val_f1_score: 0.6853 - val_precision: 0.7612 - val_recall: 0.5966 - lr: 1.0000e-04
# Epoch 32/150
# 161/161 [==============================] - ETA: 0s - loss: 0.6608 - accuracy: 0.7033 - f1_score: 0.7004 - precision: 0.7451 - recall: 0.6257
# Epoch 32: val_f1_score did not improve from 0.68884
#
# Epoch 32 Learning Rate : 9.999999747378752e-05
# 161/161 [==============================] - 100s 622ms/step - loss: 0.6608 - accuracy: 0.7033 - f1_score: 0.7004 - precision: 0.7451 - recall: 0.6257 - val_loss: 0.6905 - val_accuracy: 0.6904 - val_f1_score: 0.6835 - val_precision: 0.7613 - val_recall: 0.5906 - lr: 1.0000e-04
# Epoch 33/150
# 161/161 [==============================] - ETA: 0s - loss: 0.6565 - accuracy: 0.6992 - f1_score: 0.6968 - precision: 0.7502 - recall: 0.6271
# Epoch 33: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 33: val_f1_score did not improve from 0.68884
#
# Epoch 33 Learning Rate : 2.9999999242136255e-05
# 161/161 [==============================] - 99s 615ms/step - loss: 0.6565 - accuracy: 0.6992 - f1_score: 0.6968 - precision: 0.7502 - recall: 0.6271 - val_loss: 0.6867 - val_accuracy: 0.6887 - val_f1_score: 0.6814 - val_precision: 0.7584 - val_recall: 0.6034 - lr: 1.0000e-04
# Epoch 34/150
# 161/161 [==============================] - ETA: 0s - loss: 0.6511 - accuracy: 0.7043 - f1_score: 0.7013 - precision: 0.7554 - recall: 0.6343
# Epoch 34: val_f1_score did not improve from 0.68884
#
# Epoch 34 Learning Rate : 2.9999999242136255e-05
# 161/161 [==============================] - 101s 628ms/step - loss: 0.6511 - accuracy: 0.7043 - f1_score: 0.7013 - precision: 0.7554 - recall: 0.6343 - val_loss: 0.6859 - val_accuracy: 0.6884 - val_f1_score: 0.6856 - val_precision: 0.7539 - val_recall: 0.5919 - lr: 3.0000e-05
# Epoch 35/150
# 161/161 [==============================] - ETA: 0s - loss: 0.6403 - accuracy: 0.7138 - f1_score: 0.7111 - precision: 0.7596 - recall: 0.6434
# Epoch 35: val_f1_score did not improve from 0.68884
#
# Epoch 35 Learning Rate : 2.9999999242136255e-05
# 161/161 [==============================] - 102s 636ms/step - loss: 0.6403 - accuracy: 0.7138 - f1_score: 0.7111 - precision: 0.7596 - recall: 0.6434 - val_loss: 0.6868 - val_accuracy: 0.6907 - val_f1_score: 0.6842 - val_precision: 0.7535 - val_recall: 0.5939 - lr: 3.0000e-05
# Epoch 36/150
# 161/161 [==============================] - ETA: 0s - loss: 0.6476 - accuracy: 0.7140 - f1_score: 0.7113 - precision: 0.7627 - recall: 0.6442
# Epoch 36: val_f1_score did not improve from 0.68884
#
# Epoch 36 Learning Rate : 2.9999999242136255e-05
# 161/161 [==============================] - 104s 650ms/step - loss: 0.6476 - accuracy: 0.7140 - f1_score: 0.7113 - precision: 0.7627 - recall: 0.6442 - val_loss: 0.6854 - val_accuracy: 0.6911 - val_f1_score: 0.6865 - val_precision: 0.7544 - val_recall: 0.5936 - lr: 3.0000e-05
# Epoch 37/150
# 161/161 [==============================] - ETA: 0s - loss: 0.6457 - accuracy: 0.7157 - f1_score: 0.7130 - precision: 0.7658 - recall: 0.6434
# Epoch 37: val_f1_score did not improve from 0.68884
#
# Epoch 37 Learning Rate : 2.9999999242136255e-05
# 161/161 [==============================] - 105s 653ms/step - loss: 0.6457 - accuracy: 0.7157 - f1_score: 0.7130 - precision: 0.7658 - recall: 0.6434 - val_loss: 0.6844 - val_accuracy: 0.6911 - val_f1_score: 0.6872 - val_precision: 0.7551 - val_recall: 0.5949 - lr: 3.0000e-05
# Epoch 38/150
# 161/161 [==============================] - ETA: 0s - loss: 0.6429 - accuracy: 0.7185 - f1_score: 0.7156 - precision: 0.7697 - recall: 0.6467
# Epoch 38: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 38: val_f1_score did not improve from 0.68884
#
# Epoch 38 Learning Rate : 8.999999408842996e-06
# 161/161 [==============================] - 105s 655ms/step - loss: 0.6429 - accuracy: 0.7185 - f1_score: 0.7156 - precision: 0.7697 - recall: 0.6467 - val_loss: 0.6852 - val_accuracy: 0.6887 - val_f1_score: 0.6828 - val_precision: 0.7571 - val_recall: 0.5960 - lr: 3.0000e-05
# Epoch 39/150
# 161/161 [==============================] - ETA: 0s - loss: 0.6335 - accuracy: 0.7081 - f1_score: 0.7044 - precision: 0.7623 - recall: 0.6422Restoring model weights from the end of the best epoch: 28.
#
# Epoch 39: val_f1_score did not improve from 0.68884
#
# Epoch 39 Learning Rate : 8.999999408842996e-06
# 161/161 [==============================] - 102s 632ms/step - loss: 0.6335 - accuracy: 0.7081 - f1_score: 0.7044 - precision: 0.7623 - recall: 0.6422 - val_loss: 0.6826 - val_accuracy: 0.6897 - val_f1_score: 0.6853 - val_precision: 0.7565 - val_recall: 0.5963 - lr: 9.0000e-06
# Epoch 39: early stopping
# Initial baseline model training complete

# %%
# ==========================================================
# RELOAD PHASE 1 BEST WEIGHTS BEFORE STARTING SELF-TRAINING
# ==========================================================
model, base_model = get_ResNet50_Wavelet_Hybrid()
model.load_weights("ResNet50_Wavelet_SemiSupervised_Initial_v2.h5")
print("Phase 1 (frozen backbone) weights loaded successfully!")
# Out:
# Phase 1 (frozen backbone) weights loaded successfully!

# %%
# ==========================================================
# PHASE 2: ITERATIVE SEMI-SUPERVISED SELF-TRAINING LOOP  (v2)
# ==========================================================
# Same copy-not-move / exclude_filepaths bookkeeping as v1. NEW in v2:
#   - Each iteration's fit() now has its own EarlyStopping (patience =
#     SELFTRAIN_EARLYSTOP_PATIENCE), so a stalling iteration doesn't burn
#     all EPOCHS_PER_ITERATION memorizing the current combined set.
#   - iteration_class_counts logs how many pseudo-labels were accepted PER
#     CLASS each iteration -- use this to check whether acceptance is
#     skewed away from Benign (the weakest class in both prior notebooks)
#     before deciding to touch CONFIDENCE_THRESHOLD further.
#   - train_combined_generator is built with augment=AUGMENT_TRAIN; the
#     unlabeled_generator used for SCORING is never augmented.
print("start")

class CombinedHistory:
    def __init__(self):
        self.history = {
            'loss': [], 'val_loss': [],
            'f1_score': [], 'val_f1_score': [],
            'precision': [], 'val_precision': [],
            'recall': [], 'val_recall': [],
            'accuracy': [], 'val_accuracy': []
        }
    def extend(self, keras_history):
        for k, v in keras_history.history.items():
            if k in self.history:
                self.history[k].extend(v)

history_final = CombinedHistory()
iteration_class_counts = []   # NEW: per-iteration, per-class accepted pseudo-label counts

print("Refreshing combined training directory from baseline labeled data...")
if os.path.exists(train_combined_dir):
    shutil.rmtree(train_combined_dir)
os.makedirs(train_combined_dir, exist_ok=True)

for class_name in os.listdir(labeled_dir):
    src_class_dir = os.path.join(labeled_dir, class_name)
    dst_class_dir = os.path.join(train_combined_dir, class_name)
    if os.path.isdir(src_class_dir):
        shutil.copytree(src_class_dir, dst_class_dir)

class_indices = train_labeled_generator.class_indices
idx_to_class = {v: k for k, v in class_indices.items()}
used_filepaths = set()

for iteration in range(NUM_ITERATIONS):
    print(f"\n==================================================")
    print(f" STARTING ITERATION {iteration + 1} / {NUM_ITERATIONS}")
    print(f"==================================================")

    unlabeled_generator = ResNetWaveletGenerator(
        unlabeled_dir, shuffle=False, labeled=False, class_indices=class_indices,
        exclude_filepaths=used_filepaths, augment=False   # never augment scoring
    )

    if len(unlabeled_generator.filepaths) == 0:
        print("No unlabeled images left to score -- stopping self-training loop early.")
        break

    predictions = []
    for b in range(len(unlabeled_generator)):
        batch_x, _ = unlabeled_generator[b]
        predictions.append(model.predict_on_batch(batch_x))
        if b % 10 == 0 or b == len(unlabeled_generator) - 1:
            print(f"  predicting batch {b + 1}/{len(unlabeled_generator)}", end="\r")
    print()
    predictions = np.concatenate(predictions, axis=0)
    confidences = predictions.max(axis=1)
    pseudo_labels = predictions.argmax(axis=1)

    high_conf_positions = np.where(confidences >= CONFIDENCE_THRESHOLD)[0]
    print(f"High-confidence pseudo-labels this iteration: "
          f"{len(high_conf_positions)} / {len(unlabeled_generator.filepaths)}")

    if len(high_conf_positions) == 0:
        print("No samples cleared the confidence threshold -- stopping self-training loop early.")
        break

    # NEW: per-class breakdown of what's about to be accepted, BEFORE copying files
    accepted_labels = pseudo_labels[high_conf_positions]
    counts_this_iter = {idx_to_class[c]: int((accepted_labels == c).sum()) for c in range(NUM_CLASSES)}
    iteration_class_counts.append(counts_this_iter)
    print("Accepted pseudo-labels by class this iteration:", counts_this_iter)

    for pos in high_conf_positions:
        src_path = unlabeled_generator.filepaths[pos]
        pred_class = idx_to_class[pseudo_labels[pos]]
        dst_dir = os.path.join(train_combined_dir, pred_class)
        os.makedirs(dst_dir, exist_ok=True)
        dst_path = os.path.join(dst_dir, os.path.basename(src_path))
        shutil.copy2(src_path, dst_path)
        used_filepaths.add(src_path)

    train_combined_generator = ResNetWaveletGenerator(
        train_combined_dir, shuffle=True, labeled=True, class_indices=class_indices,
        augment=AUGMENT_TRAIN
    )
    print("Combined training set size:", len(train_combined_generator.filepaths))

    checkpoint_iter = ModelCheckpoint(
        "ResNet50_Wavelet_SemiSupervised_Final_v2.h5",
        monitor='val_f1_score',
        save_best_only=True,
        save_weights_only=True,
        mode='max',
        verbose=1
    )
    earlystop_iter = EarlyStopping(   # NEW in v2
        monitor='val_f1_score', mode='max',
        patience=SELFTRAIN_EARLYSTOP_PATIENCE,
        restore_best_weights=True, verbose=1
    )

    history_iter = model.fit(
        train_combined_generator,
        validation_data=val_generator,
        epochs=EPOCHS_PER_ITERATION,
        callbacks=[reduce_lr, checkpoint_iter, earlystop_iter, lr_callback]
    )
    history_final.extend(history_iter)

print("\nPer-iteration accepted pseudo-label class breakdown:")
for i, counts in enumerate(iteration_class_counts):
    print(f"  Iteration {i+1}: {counts}")

print("Semi-supervised self-training loop complete")
print("done1")
# Out:
# start
# Refreshing combined training directory from baseline labeled data...
#
# ==================================================
#  STARTING ITERATION 1 / 5
# ==================================================
#   predicting batch 402/402
# High-confidence pseudo-labels this iteration: 2197 / 12857
# Accepted pseudo-labels by class this iteration: {'Benign': 267, 'Malignant': 32, 'Normal': 1898}
# Combined training set size: 7340
# Epoch 1/7
# 230/230 [==============================] - ETA: 0s - loss: 0.5022 - accuracy: 0.7858 - f1_score: 0.7335 - precision: 0.8075 - recall: 0.6973
# Epoch 1: val_f1_score improved from -inf to 0.67705, saving model to ResNet50_Wavelet_SemiSupervised_Final_v2.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-05
# 230/230 [==============================] - 145s 627ms/step - loss: 0.5022 - accuracy: 0.7858 - f1_score: 0.7335 - precision: 0.8075 - recall: 0.6973 - val_loss: 0.6932 - val_accuracy: 0.6793 - val_f1_score: 0.6770 - val_precision: 0.7462 - val_recall: 0.6000 - lr: 1.0000e-04
# Epoch 2/7
# 230/230 [==============================] - ETA: 0s - loss: 0.4926 - accuracy: 0.7911 - f1_score: 0.7518 - precision: 0.8296 - recall: 0.7429
# Epoch 2: val_f1_score improved from 0.67705 to 0.67856, saving model to ResNet50_Wavelet_SemiSupervised_Final_v2.h5
#
# Epoch 2 Learning Rate : 9.999999747378752e-05
# 230/230 [==============================] - 137s 597ms/step - loss: 0.4926 - accuracy: 0.7911 - f1_score: 0.7518 - precision: 0.8296 - recall: 0.7429 - val_loss: 0.6930 - val_accuracy: 0.6853 - val_f1_score: 0.6786 - val_precision: 0.7466 - val_recall: 0.5993 - lr: 1.0000e-04
# Epoch 3/7
# 230/230 [==============================] - ETA: 0s - loss: 0.4871 - accuracy: 0.7902 - f1_score: 0.7503 - precision: 0.8322 - recall: 0.7431
# Epoch 3: val_f1_score improved from 0.67856 to 0.68159, saving model to ResNet50_Wavelet_SemiSupervised_Final_v2.h5
#
# Epoch 3 Learning Rate : 9.999999747378752e-05
# 230/230 [==============================] - 133s 577ms/step - loss: 0.4871 - accuracy: 0.7902 - f1_score: 0.7503 - precision: 0.8322 - recall: 0.7431 - val_loss: 0.6896 - val_accuracy: 0.6813 - val_f1_score: 0.6816 - val_precision: 0.7485 - val_recall: 0.5993 - lr: 1.0000e-04
# Epoch 4/7
# 230/230 [==============================] - ETA: 0s - loss: 0.4931 - accuracy: 0.7861 - f1_score: 0.7460 - precision: 0.8276 - recall: 0.7383
# Epoch 4: val_f1_score did not improve from 0.68159
#
# Epoch 4 Learning Rate : 9.999999747378752e-05
# 230/230 [==============================] - 126s 548ms/step - loss: 0.4931 - accuracy: 0.7861 - f1_score: 0.7460 - precision: 0.8276 - recall: 0.7383 - val_loss: 0.6863 - val_accuracy: 0.6826 - val_f1_score: 0.6793 - val_precision: 0.7560 - val_recall: 0.5946 - lr: 1.0000e-04
# Epoch 5/7
# 230/230 [==============================] - ETA: 0s - loss: 0.4879 - accuracy: 0.7932 - f1_score: 0.7552 - precision: 0.8317 - recall: 0.7478
# Epoch 5: val_f1_score did not improve from 0.68159
#
# Epoch 5 Learning Rate : 9.999999747378752e-05
# 230/230 [==============================] - 133s 577ms/step - loss: 0.4879 - accuracy: 0.7932 - f1_score: 0.7552 - precision: 0.8317 - recall: 0.7478 - val_loss: 0.7065 - val_accuracy: 0.6735 - val_f1_score: 0.6635 - val_precision: 0.7392 - val_recall: 0.5831 - lr: 1.0000e-04
# Epoch 6/7
# 230/230 [==============================] - ETA: 0s - loss: 0.4744 - accuracy: 0.7929 - f1_score: 0.7534 - precision: 0.8364 - recall: 0.7493
# Epoch 6: val_f1_score did not improve from 0.68159
# Restoring model weights from the end of the best epoch: 3.
#
# Epoch 6 Learning Rate : 9.999999747378752e-05
# 230/230 [==============================] - 132s 573ms/step - loss: 0.4744 - accuracy: 0.7929 - f1_score: 0.7534 - precision: 0.8364 - recall: 0.7493 - val_loss: 0.6969 - val_accuracy: 0.6776 - val_f1_score: 0.6772 - val_precision: 0.7423 - val_recall: 0.5916 - lr: 1.0000e-04
# Epoch 6: early stopping
#
# ==================================================
#  STARTING ITERATION 2 / 5
# ==================================================
#   predicting batch 334/334
# High-confidence pseudo-labels this iteration: 460 / 10660
# Accepted pseudo-labels by class this iteration: {'Benign': 154, 'Malignant': 14, 'Normal': 292}
# Combined training set size: 7800
# Epoch 1/7
# 244/244 [==============================] - ETA: 0s - loss: 0.4641 - accuracy: 0.8058 - f1_score: 0.7646 - precision: 0.8426 - recall: 0.7626
# Epoch 1: val_f1_score improved from -inf to 0.68803, saving model to ResNet50_Wavelet_SemiSupervised_Final_v2.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-05
# 244/244 [==============================] - 140s 576ms/step - loss: 0.4641 - accuracy: 0.8058 - f1_score: 0.7646 - precision: 0.8426 - recall: 0.7626 - val_loss: 0.6935 - val_accuracy: 0.6880 - val_f1_score: 0.6880 - val_precision: 0.7445 - val_recall: 0.6105 - lr: 1.0000e-04
# Epoch 2/7
# 244/244 [==============================] - ETA: 0s - loss: 0.4660 - accuracy: 0.8021 - f1_score: 0.7619 - precision: 0.8416 - recall: 0.7610
# Epoch 2: val_f1_score did not improve from 0.68803
#
# Epoch 2 Learning Rate : 9.999999747378752e-05
# 244/244 [==============================] - 138s 566ms/step - loss: 0.4660 - accuracy: 0.8021 - f1_score: 0.7619 - precision: 0.8416 - recall: 0.7610 - val_loss: 0.6910 - val_accuracy: 0.6809 - val_f1_score: 0.6670 - val_precision: 0.7466 - val_recall: 0.5953 - lr: 1.0000e-04
# Epoch 3/7
# 244/244 [==============================] - ETA: 0s - loss: 0.4559 - accuracy: 0.8051 - f1_score: 0.7633 - precision: 0.8471 - recall: 0.7671
# Epoch 3: val_f1_score did not improve from 0.68803
#
# Epoch 3 Learning Rate : 9.999999747378752e-05
# 244/244 [==============================] - 139s 572ms/step - loss: 0.4559 - accuracy: 0.8051 - f1_score: 0.7633 - precision: 0.8471 - recall: 0.7671 - val_loss: 0.6842 - val_accuracy: 0.6850 - val_f1_score: 0.6798 - val_precision: 0.7470 - val_recall: 0.6094 - lr: 1.0000e-04
# Epoch 4/7
# 244/244 [==============================] - ETA: 0s - loss: 0.4620 - accuracy: 0.8049 - f1_score: 0.7644 - precision: 0.8429 - recall: 0.7582
# Epoch 4: val_f1_score did not improve from 0.68803
# Restoring model weights from the end of the best epoch: 1.
#
# Epoch 4 Learning Rate : 9.999999747378752e-05
# 244/244 [==============================] - 139s 569ms/step - loss: 0.4620 - accuracy: 0.8049 - f1_score: 0.7644 - precision: 0.8429 - recall: 0.7582 - val_loss: 0.6855 - val_accuracy: 0.6907 - val_f1_score: 0.6828 - val_precision: 0.7529 - val_recall: 0.6044 - lr: 1.0000e-04
# Epoch 4: early stopping
#
# ==================================================
#  STARTING ITERATION 3 / 5
# ==================================================
#   predicting batch 319/319
# High-confidence pseudo-labels this iteration: 306 / 10200
# Accepted pseudo-labels by class this iteration: {'Benign': 37, 'Malignant': 16, 'Normal': 253}
# Combined training set size: 8106
# Epoch 1/7
# 254/254 [==============================] - ETA: 0s - loss: 0.4482 - accuracy: 0.8077 - f1_score: 0.7619 - precision: 0.8452 - recall: 0.7677
# Epoch 1: val_f1_score improved from -inf to 0.67693, saving model to ResNet50_Wavelet_SemiSupervised_Final_v2.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-05
# 254/254 [==============================] - 144s 567ms/step - loss: 0.4482 - accuracy: 0.8077 - f1_score: 0.7619 - precision: 0.8452 - recall: 0.7677 - val_loss: 0.6892 - val_accuracy: 0.6762 - val_f1_score: 0.6769 - val_precision: 0.7370 - val_recall: 0.5983 - lr: 1.0000e-04
# Epoch 2/7
# 254/254 [==============================] - ETA: 0s - loss: 0.4522 - accuracy: 0.8093 - f1_score: 0.7658 - precision: 0.8484 - recall: 0.7699
# Epoch 2: val_f1_score improved from 0.67693 to 0.68193, saving model to ResNet50_Wavelet_SemiSupervised_Final_v2.h5
#
# Epoch 2 Learning Rate : 9.999999747378752e-05
# 254/254 [==============================] - 139s 547ms/step - loss: 0.4522 - accuracy: 0.8093 - f1_score: 0.7658 - precision: 0.8484 - recall: 0.7699 - val_loss: 0.6868 - val_accuracy: 0.6867 - val_f1_score: 0.6819 - val_precision: 0.7472 - val_recall: 0.6101 - lr: 1.0000e-04
# Epoch 3/7
# 254/254 [==============================] - ETA: 0s - loss: 0.4454 - accuracy: 0.8131 - f1_score: 0.7686 - precision: 0.8505 - recall: 0.7730
# Epoch 3: val_f1_score improved from 0.68193 to 0.68485, saving model to ResNet50_Wavelet_SemiSupervised_Final_v2.h5
#
# Epoch 3 Learning Rate : 9.999999747378752e-05
# 254/254 [==============================] - 142s 556ms/step - loss: 0.4454 - accuracy: 0.8131 - f1_score: 0.7686 - precision: 0.8505 - recall: 0.7730 - val_loss: 0.6868 - val_accuracy: 0.6857 - val_f1_score: 0.6848 - val_precision: 0.7482 - val_recall: 0.6152 - lr: 1.0000e-04
# Epoch 4/7
# 254/254 [==============================] - ETA: 0s - loss: 0.4431 - accuracy: 0.8135 - f1_score: 0.7708 - precision: 0.8490 - recall: 0.7767
# Epoch 4: val_f1_score did not improve from 0.68485
#
# Epoch 4 Learning Rate : 9.999999747378752e-05
# 254/254 [==============================] - 136s 535ms/step - loss: 0.4431 - accuracy: 0.8135 - f1_score: 0.7708 - precision: 0.8490 - recall: 0.7767 - val_loss: 0.6952 - val_accuracy: 0.6833 - val_f1_score: 0.6767 - val_precision: 0.7431 - val_recall: 0.6010 - lr: 1.0000e-04
# Epoch 5/7
# 254/254 [==============================] - ETA: 0s - loss: 0.4363 - accuracy: 0.8168 - f1_score: 0.7737 - precision: 0.8550 - recall: 0.7755
# Epoch 5: val_f1_score did not improve from 0.68485
#
# Epoch 5 Learning Rate : 9.999999747378752e-05
# 254/254 [==============================] - 139s 547ms/step - loss: 0.4363 - accuracy: 0.8168 - f1_score: 0.7737 - precision: 0.8550 - recall: 0.7755 - val_loss: 0.6852 - val_accuracy: 0.6833 - val_f1_score: 0.6810 - val_precision: 0.7423 - val_recall: 0.6054 - lr: 1.0000e-04
# Epoch 6/7
# 254/254 [==============================] - ETA: 0s - loss: 0.4356 - accuracy: 0.8170 - f1_score: 0.7734 - precision: 0.8544 - recall: 0.7772
# Epoch 6: val_f1_score did not improve from 0.68485
# Restoring model weights from the end of the best epoch: 3.
#
# Epoch 6 Learning Rate : 9.999999747378752e-05
# 254/254 [==============================] - 139s 549ms/step - loss: 0.4356 - accuracy: 0.8170 - f1_score: 0.7734 - precision: 0.8544 - recall: 0.7772 - val_loss: 0.6901 - val_accuracy: 0.6877 - val_f1_score: 0.6842 - val_precision: 0.7468 - val_recall: 0.6037 - lr: 1.0000e-04
# Epoch 6: early stopping
#
# ==================================================
#  STARTING ITERATION 4 / 5
# ==================================================
#   predicting batch 310/310
# High-confidence pseudo-labels this iteration: 101 / 9894
# Accepted pseudo-labels by class this iteration: {'Benign': 75, 'Malignant': 6, 'Normal': 20}
# Combined training set size: 8207
# Epoch 1/7
# 257/257 [==============================] - ETA: 0s - loss: 0.4349 - accuracy: 0.8184 - f1_score: 0.7781 - precision: 0.8554 - recall: 0.7791
# Epoch 1: val_f1_score improved from -inf to 0.67861, saving model to ResNet50_Wavelet_SemiSupervised_Final_v2.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-05
# 257/257 [==============================] - 156s 608ms/step - loss: 0.4349 - accuracy: 0.8184 - f1_score: 0.7781 - precision: 0.8554 - recall: 0.7791 - val_loss: 0.6894 - val_accuracy: 0.6843 - val_f1_score: 0.6786 - val_precision: 0.7483 - val_recall: 0.6078 - lr: 1.0000e-04
# Epoch 2/7
# 257/257 [==============================] - ETA: 0s - loss: 0.4324 - accuracy: 0.8232 - f1_score: 0.7842 - precision: 0.8564 - recall: 0.7847
# Epoch 2: val_f1_score improved from 0.67861 to 0.68421, saving model to ResNet50_Wavelet_SemiSupervised_Final_v2.h5
#
# Epoch 2 Learning Rate : 9.999999747378752e-05
# 257/257 [==============================] - 156s 608ms/step - loss: 0.4324 - accuracy: 0.8232 - f1_score: 0.7842 - precision: 0.8564 - recall: 0.7847 - val_loss: 0.6853 - val_accuracy: 0.6887 - val_f1_score: 0.6842 - val_precision: 0.7471 - val_recall: 0.6148 - lr: 1.0000e-04
# Epoch 3/7
# 257/257 [==============================] - ETA: 0s - loss: 0.4394 - accuracy: 0.8152 - f1_score: 0.7730 - precision: 0.8513 - recall: 0.7749
# Epoch 3: val_f1_score improved from 0.68421 to 0.68509, saving model to ResNet50_Wavelet_SemiSupervised_Final_v2.h5
#
# Epoch 3 Learning Rate : 9.999999747378752e-05
# 257/257 [==============================] - 140s 543ms/step - loss: 0.4394 - accuracy: 0.8152 - f1_score: 0.7730 - precision: 0.8513 - recall: 0.7749 - val_loss: 0.6916 - val_accuracy: 0.6843 - val_f1_score: 0.6851 - val_precision: 0.7358 - val_recall: 0.6067 - lr: 1.0000e-04
# Epoch 4/7
# 257/257 [==============================] - ETA: 0s - loss: 0.4294 - accuracy: 0.8200 - f1_score: 0.7794 - precision: 0.8547 - recall: 0.7808
# Epoch 4: val_f1_score did not improve from 0.68509
#
# Epoch 4 Learning Rate : 9.999999747378752e-05
# 257/257 [==============================] - 135s 526ms/step - loss: 0.4294 - accuracy: 0.8200 - f1_score: 0.7794 - precision: 0.8547 - recall: 0.7808 - val_loss: 0.6948 - val_accuracy: 0.6847 - val_f1_score: 0.6796 - val_precision: 0.7488 - val_recall: 0.5963 - lr: 1.0000e-04
# Epoch 5/7
# 257/257 [==============================] - ETA: 0s - loss: 0.4312 - accuracy: 0.8169 - f1_score: 0.7755 - precision: 0.8560 - recall: 0.7774
# Epoch 5: val_f1_score improved from 0.68509 to 0.68532, saving model to ResNet50_Wavelet_SemiSupervised_Final_v2.h5
#
# Epoch 5 Learning Rate : 9.999999747378752e-05
# 257/257 [==============================] - 144s 559ms/step - loss: 0.4312 - accuracy: 0.8169 - f1_score: 0.7755 - precision: 0.8560 - recall: 0.7774 - val_loss: 0.6835 - val_accuracy: 0.6890 - val_f1_score: 0.6853 - val_precision: 0.7536 - val_recall: 0.6108 - lr: 1.0000e-04
# Epoch 6/7
# 257/257 [==============================] - ETA: 0s - loss: 0.4238 - accuracy: 0.8232 - f1_score: 0.7827 - precision: 0.8591 - recall: 0.7847
# Epoch 6: val_f1_score did not improve from 0.68532
#
# Epoch 6 Learning Rate : 9.999999747378752e-05
# 257/257 [==============================] - 139s 540ms/step - loss: 0.4238 - accuracy: 0.8232 - f1_score: 0.7827 - precision: 0.8591 - recall: 0.7847 - val_loss: 0.6819 - val_accuracy: 0.6904 - val_f1_score: 0.6850 - val_precision: 0.7529 - val_recall: 0.6145 - lr: 1.0000e-04
# Epoch 7/7
# 257/257 [==============================] - ETA: 0s - loss: 0.4259 - accuracy: 0.8221 - f1_score: 0.7816 - precision: 0.8567 - recall: 0.7808
# Epoch 7: val_f1_score did not improve from 0.68532
#
# Epoch 7 Learning Rate : 9.999999747378752e-05
# 257/257 [==============================] - 141s 551ms/step - loss: 0.4259 - accuracy: 0.8221 - f1_score: 0.7816 - precision: 0.8567 - recall: 0.7808 - val_loss: 0.6913 - val_accuracy: 0.6897 - val_f1_score: 0.6835 - val_precision: 0.7437 - val_recall: 0.6108 - lr: 1.0000e-04
#
# ==================================================
#  STARTING ITERATION 5 / 5
# ==================================================
#   predicting batch 307/307
# High-confidence pseudo-labels this iteration: 257 / 9793
# Accepted pseudo-labels by class this iteration: {'Benign': 70, 'Malignant': 50, 'Normal': 137}
# Combined training set size: 8464
# Epoch 1/7
# 265/265 [==============================] - ETA: 0s - loss: 0.4157 - accuracy: 0.8266 - f1_score: 0.7870 - precision: 0.8607 - recall: 0.7922
# Epoch 1: val_f1_score improved from -inf to 0.67851, saving model to ResNet50_Wavelet_SemiSupervised_Final_v2.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-05
# 265/265 [==============================] - 145s 548ms/step - loss: 0.4157 - accuracy: 0.8266 - f1_score: 0.7870 - precision: 0.8607 - recall: 0.7922 - val_loss: 0.6968 - val_accuracy: 0.6806 - val_f1_score: 0.6785 - val_precision: 0.7344 - val_recall: 0.6024 - lr: 1.0000e-04
# Epoch 2/7
# 265/265 [==============================] - ETA: 0s - loss: 0.4127 - accuracy: 0.8287 - f1_score: 0.7902 - precision: 0.8630 - recall: 0.7918
# Epoch 2: val_f1_score improved from 0.67851 to 0.68497, saving model to ResNet50_Wavelet_SemiSupervised_Final_v2.h5
#
# Epoch 2 Learning Rate : 9.999999747378752e-05
# 265/265 [==============================] - 148s 559ms/step - loss: 0.4127 - accuracy: 0.8287 - f1_score: 0.7902 - precision: 0.8630 - recall: 0.7918 - val_loss: 0.6850 - val_accuracy: 0.6917 - val_f1_score: 0.6850 - val_precision: 0.7443 - val_recall: 0.6216 - lr: 1.0000e-04
# Epoch 3/7
# 265/265 [==============================] - ETA: 0s - loss: 0.4036 - accuracy: 0.8314 - f1_score: 0.7923 - precision: 0.8626 - recall: 0.7951
# Epoch 3: val_f1_score improved from 0.68497 to 0.68767, saving model to ResNet50_Wavelet_SemiSupervised_Final_v2.h5
#
# Epoch 3 Learning Rate : 9.999999747378752e-05
# 265/265 [==============================] - 149s 561ms/step - loss: 0.4036 - accuracy: 0.8314 - f1_score: 0.7923 - precision: 0.8626 - recall: 0.7951 - val_loss: 0.6792 - val_accuracy: 0.6904 - val_f1_score: 0.6877 - val_precision: 0.7485 - val_recall: 0.6182 - lr: 1.0000e-04
# Epoch 4/7
# 265/265 [==============================] - ETA: 0s - loss: 0.4043 - accuracy: 0.8332 - f1_score: 0.7955 - precision: 0.8643 - recall: 0.7996
# Epoch 4: val_f1_score improved from 0.68767 to 0.69091, saving model to ResNet50_Wavelet_SemiSupervised_Final_v2.h5
#
# Epoch 4 Learning Rate : 9.999999747378752e-05
# 265/265 [==============================] - 149s 562ms/step - loss: 0.4043 - accuracy: 0.8332 - f1_score: 0.7955 - precision: 0.8643 - recall: 0.7996 - val_loss: 0.6835 - val_accuracy: 0.6948 - val_f1_score: 0.6909 - val_precision: 0.7483 - val_recall: 0.6196 - lr: 1.0000e-04
# Epoch 5/7
# 265/265 [==============================] - ETA: 0s - loss: 0.4110 - accuracy: 0.8300 - f1_score: 0.7915 - precision: 0.8676 - recall: 0.7932
# Epoch 5: val_f1_score did not improve from 0.69091
#
# Epoch 5 Learning Rate : 9.999999747378752e-05
# 265/265 [==============================] - 136s 512ms/step - loss: 0.4110 - accuracy: 0.8300 - f1_score: 0.7915 - precision: 0.8676 - recall: 0.7932 - val_loss: 0.6846 - val_accuracy: 0.6870 - val_f1_score: 0.6805 - val_precision: 0.7413 - val_recall: 0.6128 - lr: 1.0000e-04
# Epoch 6/7
# 265/265 [==============================] - ETA: 0s - loss: 0.4024 - accuracy: 0.8345 - f1_score: 0.7963 - precision: 0.8673 - recall: 0.7960
# Epoch 6: val_f1_score did not improve from 0.69091
#
# Epoch 6 Learning Rate : 9.999999747378752e-05
# 265/265 [==============================] - 137s 515ms/step - loss: 0.4024 - accuracy: 0.8345 - f1_score: 0.7963 - precision: 0.8673 - recall: 0.7960 - val_loss: 0.6830 - val_accuracy: 0.6816 - val_f1_score: 0.6791 - val_precision: 0.7382 - val_recall: 0.6030 - lr: 1.0000e-04
# Epoch 7/7
# 265/265 [==============================] - ETA: 0s - loss: 0.4032 - accuracy: 0.8329 - f1_score: 0.7946 - precision: 0.8685 - recall: 0.7970
# Epoch 7: val_f1_score did not improve from 0.69091
# Restoring model weights from the end of the best epoch: 4.
#
# Epoch 7 Learning Rate : 9.999999747378752e-05
# 265/265 [==============================] - 137s 516ms/step - loss: 0.4032 - accuracy: 0.8329 - f1_score: 0.7946 - precision: 0.8685 - recall: 0.7970 - val_loss: 0.6865 - val_accuracy: 0.6897 - val_f1_score: 0.6874 - val_precision: 0.7414 - val_recall: 0.6111 - lr: 1.0000e-04
# Epoch 7: early stopping
#
# Per-iteration accepted pseudo-label class breakdown:
#   Iteration 1: {'Benign': 267, 'Malignant': 32, 'Normal': 1898}
#   Iteration 2: {'Benign': 154, 'Malignant': 14, 'Normal': 292}
#   Iteration 3: {'Benign': 37, 'Malignant': 16, 'Normal': 253}
#   Iteration 4: {'Benign': 75, 'Malignant': 6, 'Normal': 20}
#   Iteration 5: {'Benign': 70, 'Malignant': 50, 'Normal': 137}
# Semi-supervised self-training loop complete
# done1

# %%
# ==========================================================
# RELOAD BEST WEIGHTS FROM THE SELF-TRAINING LOOP + REBUILD COMBINED GENERATOR
# ==========================================================
model, base_model = get_ResNet50_Wavelet_Hybrid()
model.load_weights("ResNet50_Wavelet_SemiSupervised_Final_v2.h5")

train_combined_generator = ResNetWaveletGenerator(
    train_combined_dir, shuffle=True, labeled=True,
    class_indices=train_labeled_generator.class_indices, augment=AUGMENT_TRAIN
)

print("Self-trained model weights loaded successfully!")
print("Final combined training set size:", len(train_combined_generator.filepaths))
# Out:
# Self-trained model weights loaded successfully!
# Final combined training set size: 8464

# %%
# ==========================================================
# PHASE 3: FINE-TUNE THE RESNET-50 BACKBONE  (v2: lighter than v1)
# ==========================================================
# v1 unfroze the last 30 layers for up to 40 epochs and ended with train F1
# 99.9% vs val F1 ~70% -- severe overfitting. v2 unfreezes fewer layers
# (FINETUNE_UNFREEZE_LAST_N = 15), runs fewer epochs (EPOCHS_FINETUNE = 25),
# and relies on the augmentation + L2 + dropout added above to keep the
# train/val gap from blowing up again.
print("start")

base_model.trainable = True
for layer in base_model.layers[:-FINETUNE_UNFREEZE_LAST_N]:
    layer.trainable = False
for layer in base_model.layers:
    if isinstance(layer, BatchNormalization):
        layer.trainable = False

optimizer_ft = Adam(learning_rate=1e-5)
model.compile(
    loss="categorical_crossentropy",
    metrics=["accuracy", f1_metric, precision_metric, recall_metric],
    optimizer=optimizer_ft
)

early_stop_ft = EarlyStopping(
    monitor='val_f1_score', mode='max', patience=8,   # tightened from 10
    restore_best_weights=True, verbose=1
)
reduce_lr_ft = ReduceLROnPlateau(
    monitor='val_f1_score', mode='max', factor=0.3, patience=4,
    min_lr=1e-8, verbose=1
)
checkpoint_ft = ModelCheckpoint(
    "ResNet50_Wavelet_SemiSupervised_FineTuned_v2.h5",
    monitor='val_f1_score', save_best_only=True, save_weights_only=True,
    mode='max', verbose=1
)

history_finetune = model.fit(
    train_combined_generator,
    validation_data=val_generator,
    epochs=EPOCHS_FINETUNE,
    callbacks=[early_stop_ft, reduce_lr_ft, checkpoint_ft, lr_callback]
)

print("done")
# Out:
# start
# Epoch 1/25
# 265/265 [==============================] - ETA: 0s - loss: 0.4036 - accuracy: 0.8352 - f1_score: 0.7718 - precision: 0.8365 - recall: 0.7491
# Epoch 1: val_f1_score improved from -inf to 0.68685, saving model to ResNet50_Wavelet_SemiSupervised_FineTuned_v2.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-06
# 265/265 [==============================] - 145s 540ms/step - loss: 0.4036 - accuracy: 0.8352 - f1_score: 0.7718 - precision: 0.8365 - recall: 0.7491 - val_loss: 0.6796 - val_accuracy: 0.6897 - val_f1_score: 0.6869 - val_precision: 0.7425 - val_recall: 0.6155 - lr: 1.0000e-05
# Epoch 2/25
# 265/265 [==============================] - ETA: 0s - loss: 0.3876 - accuracy: 0.8418 - f1_score: 0.8055 - precision: 0.8718 - recall: 0.8064
# Epoch 2: val_f1_score improved from 0.68685 to 0.69943, saving model to ResNet50_Wavelet_SemiSupervised_FineTuned_v2.h5
#
# Epoch 2 Learning Rate : 9.999999747378752e-06
# 265/265 [==============================] - 147s 556ms/step - loss: 0.3876 - accuracy: 0.8418 - f1_score: 0.8055 - precision: 0.8718 - recall: 0.8064 - val_loss: 0.6706 - val_accuracy: 0.7022 - val_f1_score: 0.6994 - val_precision: 0.7576 - val_recall: 0.6263 - lr: 1.0000e-05
# Epoch 3/25
# 265/265 [==============================] - ETA: 0s - loss: 0.3737 - accuracy: 0.8502 - f1_score: 0.8152 - precision: 0.8800 - recall: 0.8208
# Epoch 3: val_f1_score improved from 0.69943 to 0.70242, saving model to ResNet50_Wavelet_SemiSupervised_FineTuned_v2.h5
#
# Epoch 3 Learning Rate : 9.999999747378752e-06
# 265/265 [==============================] - 145s 545ms/step - loss: 0.3737 - accuracy: 0.8502 - f1_score: 0.8152 - precision: 0.8800 - recall: 0.8208 - val_loss: 0.6730 - val_accuracy: 0.7039 - val_f1_score: 0.7024 - val_precision: 0.7546 - val_recall: 0.6317 - lr: 1.0000e-05
# Epoch 4/25
# 265/265 [==============================] - ETA: 0s - loss: 0.3569 - accuracy: 0.8523 - f1_score: 0.8168 - precision: 0.8817 - recall: 0.8235
# Epoch 4: val_f1_score improved from 0.70242 to 0.70411, saving model to ResNet50_Wavelet_SemiSupervised_FineTuned_v2.h5
#
# Epoch 4 Learning Rate : 9.999999747378752e-06
# 265/265 [==============================] - 143s 539ms/step - loss: 0.3569 - accuracy: 0.8523 - f1_score: 0.8168 - precision: 0.8817 - recall: 0.8235 - val_loss: 0.6828 - val_accuracy: 0.7035 - val_f1_score: 0.7041 - val_precision: 0.7446 - val_recall: 0.6401 - lr: 1.0000e-05
# Epoch 5/25
# 265/265 [==============================] - ETA: 0s - loss: 0.3449 - accuracy: 0.8591 - f1_score: 0.8254 - precision: 0.8841 - recall: 0.8308
# Epoch 5: val_f1_score did not improve from 0.70411
#
# Epoch 5 Learning Rate : 9.999999747378752e-06
# 265/265 [==============================] - 136s 511ms/step - loss: 0.3449 - accuracy: 0.8591 - f1_score: 0.8254 - precision: 0.8841 - recall: 0.8308 - val_loss: 0.6788 - val_accuracy: 0.6995 - val_f1_score: 0.6949 - val_precision: 0.7484 - val_recall: 0.6472 - lr: 1.0000e-05
# Epoch 6/25
# 265/265 [==============================] - ETA: 0s - loss: 0.3355 - accuracy: 0.8658 - f1_score: 0.8344 - precision: 0.8899 - recall: 0.8412
# Epoch 6: val_f1_score did not improve from 0.70411
#
# Epoch 6 Learning Rate : 9.999999747378752e-06
# 265/265 [==============================] - 139s 525ms/step - loss: 0.3355 - accuracy: 0.8658 - f1_score: 0.8344 - precision: 0.8899 - recall: 0.8412 - val_loss: 0.7071 - val_accuracy: 0.7035 - val_f1_score: 0.6952 - val_precision: 0.7436 - val_recall: 0.6513 - lr: 1.0000e-05
# Epoch 7/25
# 265/265 [==============================] - ETA: 0s - loss: 0.3217 - accuracy: 0.8716 - f1_score: 0.8409 - precision: 0.8957 - recall: 0.8472
# Epoch 7: val_f1_score did not improve from 0.70411
#
# Epoch 7 Learning Rate : 9.999999747378752e-06
# 265/265 [==============================] - 142s 536ms/step - loss: 0.3217 - accuracy: 0.8716 - f1_score: 0.8409 - precision: 0.8957 - recall: 0.8472 - val_loss: 0.7137 - val_accuracy: 0.6988 - val_f1_score: 0.6992 - val_precision: 0.7317 - val_recall: 0.6523 - lr: 1.0000e-05
# Epoch 8/25
# 265/265 [==============================] - ETA: 0s - loss: 0.3037 - accuracy: 0.8771 - f1_score: 0.8470 - precision: 0.8986 - recall: 0.8547
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
#
# Epoch 8: val_f1_score did not improve from 0.70411
#
# Epoch 8 Learning Rate : 2.9999998787388904e-06
# 265/265 [==============================] - 142s 537ms/step - loss: 0.3037 - accuracy: 0.8771 - f1_score: 0.8470 - precision: 0.8986 - recall: 0.8547 - val_loss: 0.7050 - val_accuracy: 0.6911 - val_f1_score: 0.6904 - val_precision: 0.7302 - val_recall: 0.6509 - lr: 1.0000e-05
# Epoch 9/25
# 265/265 [==============================] - ETA: 0s - loss: 0.2964 - accuracy: 0.8811 - f1_score: 0.8516 - precision: 0.9009 - recall: 0.8621
# Epoch 9: val_f1_score did not improve from 0.70411
#
# Epoch 9 Learning Rate : 2.9999998787388904e-06
# 265/265 [==============================] - 143s 540ms/step - loss: 0.2964 - accuracy: 0.8811 - f1_score: 0.8516 - precision: 0.9009 - recall: 0.8621 - val_loss: 0.7064 - val_accuracy: 0.7008 - val_f1_score: 0.7010 - val_precision: 0.7291 - val_recall: 0.6573 - lr: 3.0000e-06
# Epoch 10/25
# 265/265 [==============================] - ETA: 0s - loss: 0.2839 - accuracy: 0.8882 - f1_score: 0.8608 - precision: 0.9058 - recall: 0.8711
# Epoch 10: val_f1_score did not improve from 0.70411
#
# Epoch 10 Learning Rate : 2.9999998787388904e-06
# 265/265 [==============================] - 139s 526ms/step - loss: 0.2839 - accuracy: 0.8882 - f1_score: 0.8608 - precision: 0.9058 - recall: 0.8711 - val_loss: 0.7213 - val_accuracy: 0.6877 - val_f1_score: 0.6894 - val_precision: 0.7224 - val_recall: 0.6513 - lr: 3.0000e-06
# Epoch 11/25
# 265/265 [==============================] - ETA: 0s - loss: 0.2791 - accuracy: 0.8900 - f1_score: 0.8629 - precision: 0.9056 - recall: 0.8713
# Epoch 11: val_f1_score did not improve from 0.70411
#
# Epoch 11 Learning Rate : 2.9999998787388904e-06
# 265/265 [==============================] - 143s 539ms/step - loss: 0.2791 - accuracy: 0.8900 - f1_score: 0.8629 - precision: 0.9056 - recall: 0.8713 - val_loss: 0.7313 - val_accuracy: 0.6904 - val_f1_score: 0.6854 - val_precision: 0.7219 - val_recall: 0.6567 - lr: 3.0000e-06
# Epoch 12/25
# 265/265 [==============================] - ETA: 0s - loss: 0.2838 - accuracy: 0.8872 - f1_score: 0.8597 - precision: 0.9070 - recall: 0.8696Restoring model weights from the end of the best epoch: 4.
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 8.999999636216671e-07.
#
# Epoch 12: val_f1_score did not improve from 0.70411
#
# Epoch 12 Learning Rate : 8.999999749903509e-07
# 265/265 [==============================] - 136s 514ms/step - loss: 0.2838 - accuracy: 0.8872 - f1_score: 0.8597 - precision: 0.9070 - recall: 0.8696 - val_loss: 0.7248 - val_accuracy: 0.6988 - val_f1_score: 0.6953 - val_precision: 0.7306 - val_recall: 0.6621 - lr: 3.0000e-06
# Epoch 12: early stopping
# done

# %%
# ==========================================================
# LOAD FINE-TUNED BEST WEIGHTS -- use this for final evaluation
# ==========================================================
model, base_model = get_ResNet50_Wavelet_Hybrid()
base_model.trainable = True
for layer in base_model.layers[:-FINETUNE_UNFREEZE_LAST_N]:
    layer.trainable = False
for layer in base_model.layers:
    if isinstance(layer, BatchNormalization):
        layer.trainable = False

model.compile(
    loss="categorical_crossentropy",
    metrics=["accuracy", f1_metric, precision_metric, recall_metric],
    optimizer=Adam(learning_rate=1e-5)
)
model.load_weights("ResNet50_Wavelet_SemiSupervised_FineTuned_v2.h5")

print("Fine-tuned model weights loaded successfully!")
# Out:
# Fine-tuned model weights loaded successfully!

# %%
# ==========================================================
# PLOT LEARNING CURVES: PHASE 1 (INITIAL, LABELED-ONLY TRAINING)
# ==========================================================
print("start")

if 'history_initial' in globals():
    epochs_range = range(1, len(history_initial.history['loss']) + 1)
    plt.figure(figsize=(20, 5))

    plt.subplot(1, 3, 1)
    plt.plot(epochs_range, history_initial.history['loss'], label='Train Loss', color='crimson')
    plt.plot(epochs_range, history_initial.history['val_loss'], label='Val Loss', color='darkorange')
    plt.xlabel('Epochs'); plt.ylabel('Loss'); plt.legend(); plt.grid(True, linestyle='--', alpha=0.6)

    plt.subplot(1, 3, 2)
    plt.plot(epochs_range, history_initial.history['f1_score'], label='Train F1', color='crimson')
    plt.plot(epochs_range, history_initial.history['val_f1_score'], label='Val F1', color='darkorange')
    plt.xlabel('Epochs'); plt.ylabel('F1-Score'); plt.legend(); plt.grid(True, linestyle='--', alpha=0.6)

    plt.subplot(1, 3, 3)
    plt.plot(epochs_range, history_initial.history['precision'], label='Train Precision', color='crimson')
    plt.plot(epochs_range, history_initial.history['val_precision'], label='Val Precision', color='darkorange')
    plt.xlabel('Epochs'); plt.ylabel('Precision'); plt.legend(); plt.grid(True, linestyle='--', alpha=0.6)

    plt.tight_layout()
    plt.savefig("ResNet50_Wavelet_SemiSupervised_Initial_Learning_Curves_v2.pdf", format='pdf', bbox_inches='tight')
    plt.show()
else:
    print("Warning: history_initial not found. Did Phase 1 execute?")

print("done")
# Out:
# start
# done

# %%
# ==========================================================
# PLOT LEARNING CURVES: PHASE 2 (ITERATIVE SELF-TRAINING) + PHASE 3 (FINE-TUNE)
# ==========================================================
print("start")

def concat_history(h1_dict, h2_keras, key):
    return h1_dict.history[key] + h2_keras.history[key]

if 'history_final' in globals() and 'history_finetune' in globals():
    self_train_end = len(history_final.history['loss'])

    plt.figure(figsize=(20, 5))

    plt.subplot(1, 3, 1)
    plt.plot(concat_history(history_final, history_finetune, 'loss'), label='Train Loss', color='crimson')
    plt.plot(concat_history(history_final, history_finetune, 'val_loss'), label='Val Loss', color='darkorange')
    plt.axvline(self_train_end, linestyle='--', color='gray', label='Fine-tuning starts')
    plt.xlabel('Epochs'); plt.ylabel('Loss'); plt.legend(); plt.grid(True, linestyle='--', alpha=0.6)

    plt.subplot(1, 3, 2)
    plt.plot(concat_history(history_final, history_finetune, 'f1_score'), label='Train F1', color='crimson')
    plt.plot(concat_history(history_final, history_finetune, 'val_f1_score'), label='Val F1', color='darkorange')
    plt.axvline(self_train_end, linestyle='--', color='gray', label='Fine-tuning starts')
    plt.xlabel('Epochs'); plt.ylabel('F1-Score'); plt.legend(); plt.grid(True, linestyle='--', alpha=0.6)

    plt.subplot(1, 3, 3)
    plt.plot(concat_history(history_final, history_finetune, 'precision'), label='Train Precision', color='crimson')
    plt.plot(concat_history(history_final, history_finetune, 'val_precision'), label='Val Precision', color='darkorange')
    plt.axvline(self_train_end, linestyle='--', color='gray', label='Fine-tuning starts')
    plt.xlabel('Epochs'); plt.ylabel('Precision'); plt.legend(); plt.grid(True, linestyle='--', alpha=0.6)

    plt.tight_layout()
    plt.savefig("ResNet50_Wavelet_SemiSupervised_Final_Learning_Curves_v2.pdf", format='pdf', bbox_inches='tight')
    plt.show()
else:
    print("Warning: history_final / history_finetune not found.")

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# FINAL EVALUATION: TRAINING, VALIDATION, AND TEST SETS  (v2)
# ==========================================================
# NEW: a separate, non-augmented generator for evaluating the training set,
# so "training metrics" reflect the real images rather than an augmented
# view of them (train_combined_generator itself still has augment=True,
# which is correct for actual training, just not for this metrics readout).
print("start")

train_eval_generator = ResNetWaveletGenerator(
    train_combined_dir, shuffle=False, labeled=True, augment=False,
    class_indices=train_labeled_generator.class_indices
)

print("\n--- Evaluating Training Dataset (labeled + pseudo-labeled, unaugmented view) ---")
train_results = model.evaluate(train_eval_generator, verbose=1)

print("\n--- Evaluating Validation Dataset ---")
val_results = model.evaluate(val_generator, verbose=1)

print("\n--- Evaluating Test Dataset (unseen) ---")
test_results = model.evaluate(test_generator, verbose=1)

train_loss, train_acc, train_f1, train_precision, train_recall = train_results
val_loss, val_acc, val_f1, val_precision, val_recall = val_results
test_loss, test_acc, test_f1, test_precision, test_recall = test_results

for name, (loss, acc, f1, prec, rec) in [
    ("TRAINING", (train_loss, train_acc, train_f1, train_precision, train_recall)),
    ("VALIDATION", (val_loss, val_acc, val_f1, val_precision, val_recall)),
    ("TESTING (UNSEEN DATA)", (test_loss, test_acc, test_f1, test_precision, test_recall)),
]:
    print("\n" + "=" * 40)
    print(f"{name} METRICS")
    print("=" * 40)
    print(f"Loss      : {loss:.4f}")
    print(f"Accuracy  : {acc*100:.2f}%")
    print(f"F1-Score  : {f1*100:.2f}%")
    print(f"Precision : {prec*100:.2f}%")
    print(f"Recall    : {rec*100:.2f}%")

print("done1")
# Out:
# start
#
# --- Evaluating Training Dataset (labeled + pseudo-labeled, unaugmented view) ---
# 265/265 [==============================] - 98s 367ms/step - loss: 0.2982 - accuracy: 0.8897 - f1_score: 0.8192 - precision: 0.8713 - recall: 0.8041
#
# --- Evaluating Validation Dataset ---
# 93/93 [==============================] - 40s 425ms/step - loss: 0.6828 - accuracy: 0.7035 - f1_score: 0.7041 - precision: 0.7446 - recall: 0.6401
#
# --- Evaluating Test Dataset (unseen) ---
# 92/92 [==============================] - 44s 472ms/step - loss: 0.6932 - accuracy: 0.6952 - f1_score: 0.6941 - precision: 0.7367 - recall: 0.6340
#
# ========================================
# TRAINING METRICS
# ========================================
# Loss      : 0.2982
# Accuracy  : 88.97%
# F1-Score  : 81.92%
# Precision : 87.13%
# Recall    : 80.41%
#
# ========================================
# VALIDATION METRICS
# ========================================
# Loss      : 0.6828
# Accuracy  : 70.35%
# F1-Score  : 70.41%
# Precision : 74.46%
# Recall    : 64.01%
#
# ========================================
# TESTING (UNSEEN DATA) METRICS
# ========================================
# Loss      : 0.6932
# Accuracy  : 69.52%
# F1-Score  : 69.41%
# Precision : 73.67%
# Recall    : 63.40%
# done1

# %%
# ==========================================================
# INFERENCE & CLASSIFICATION REPORT (Test Set)
# ==========================================================
print("start")

predictions_test = model.predict(test_generator, verbose=1)
predicted_classes_test = np.argmax(predictions_test, axis=1)
true_classes_test = test_generator.labels

print("\nClassification Report:")
print(classification_report(true_classes_test, predicted_classes_test, target_names=class_names))

print("done1")
# Out:
# start
# 92/92 [==============================] - 37s 394ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.57      0.57      0.57       888
#    Malignant       0.75      0.68      0.72      1266
#       Normal       0.74      0.85      0.79       789
#
#     accuracy                           0.70      2943
#    macro avg       0.69      0.70      0.69      2943
# weighted avg       0.70      0.70      0.69      2943
#
# done1

# %%
# ==========================================================
# CONFUSION MATRIX PLOT (Test Set)
# ==========================================================
print("start")

cm = confusion_matrix(true_classes_test, predicted_classes_test)

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm, annot=True, fmt='d', cmap='Blues',
    xticklabels=class_names, yticklabels=class_names
)
plt.ylabel('True Label', fontsize=14)
plt.xlabel('Predicted Label', fontsize=14)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.savefig("ResNet50_Wavelet_SemiSupervised_confusion_matrix_test_v2.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# start
# done1

# %% [markdown]
# ## Notes & tunable hyperparameters (v2)
#
# - **`AUGMENT_TRAIN`** -- currently flip-only, on purpose (see intro note on the mixed-in balancing
#   copies). If train/val gap is still large after this run, resist the urge to add rotation/zoom back
#   in wholesale -- it will double-augment the ~10% of images that are already synthetic balancing
#   copies. Safer next steps if flip alone isn't enough: mild additive Gaussian noise (not resampling-
#   based, so it doesn't compound), or fixing the upstream pipeline to tag augmented files so this
#   generator can skip them specifically.
# - **`DROPOUT_RATE` / `L2_REG`** -- if v2 now *underfits* (train and val F1 both mediocre and close
#   together), ease these back down slightly before touching architecture.
# - **`FINETUNE_UNFREEZE_LAST_N` (15)** -- if val F1 still plateaus far below train F1 during Phase 3,
#   drop this further (e.g. 5-10) or skip backbone fine-tuning entirely and only fine-tune the fusion
#   head.
# - **`CONFIDENCE_THRESHOLD` (0.90, unchanged)** -- use `iteration_class_counts` (printed at the end
#   of Phase 2) to check per-class acceptance before adjusting this. If Benign is consistently
#   under-represented in accepted pseudo-labels relative to its share of `unlabeled_train`, that's a
#   labeling-bias problem a threshold tweak alone won't fix -- consider a per-class threshold instead
#   of a single global one.
# - **`SELFTRAIN_EARLYSTOP_PATIENCE` (3)** -- raise if iterations are stopping before they've had a
#   chance to actually fit the newly added pseudo-labeled data; lower if individual iterations are
#   still overfitting to the current combined set.
# - **`CLASS_WEIGHT_MODE`** -- set to `'balanced'` if Benign precision/recall is still the weakest
#   class after the above changes.
# - Wavelet settings (`WAVELET_NAME`, `WAVELET_LEVEL`) unchanged from v1.
# - All checkpoints now save with a `_v2` suffix so they never overwrite your v1 `.h5` files -- you
#   can compare both side by side.
