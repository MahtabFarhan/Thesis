# %%
# ==========================================================
# CREATE BALANCED DATASET DIRECTORY
# ==========================================================
print("start")

import os


balanced_dataset = r"/mnt/d/Thesis_folder/Preprocessed_Pipeline/Supervised_Imbalanced"



print("Imbalanced dataset ready")
# Out:
# start
# Imbalanced dataset ready

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("TensorFlow Version: ", tf.__version__)
# Out:
# Num GPUs Available:  1
# TensorFlow Version:  2.21.0

# %%
# ==========================================================
# IMPORTS
# ==========================================================
print("start")

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ConvNeXtSmall
from tensorflow.keras.applications.convnext import preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint,
    Callback
)

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# CONFIGURATION & GENERATORS
# ==========================================================
print("start")

# Pointing to the Balanced Dataset
DATASET_PATH = r"/mnt/d/Thesis_folder/Preprocessed_Pipeline/Supervised_Imbalanced"

IMAGE_SIZE = (288, 288)
MODEL_INPUT_SIZE = (288, 288, 3)
NUM_CLASSES = 3
BATCH_SIZE = 32
EPOCHS = 150

print("done1")
# Out:
# start
# done1

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.convnext import preprocess_input

# 1. Define the base generator
datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# 2. Define the paths to your new split folders
train_dir = r"/mnt/d/Thesis_folder/Preprocessed_Pipeline/Supervised_Imbalanced/train"
val_dir = r"/mnt/d/Thesis_folder/Preprocessed_Pipeline/Supervised_Imbalanced/val"
test_dir = r"/mnt/d/Thesis_folder/Preprocessed_Pipeline/Supervised_Imbalanced/test"

# 3. Create the Train Generator
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True # Shuffle training data
)

# 4. Create the Validation Generator
val_generator = datagen.flow_from_directory(
    val_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# 5. Create the Test Generator (CRITICAL: shuffle=False for evaluation)
test_generator = datagen.flow_from_directory(
    test_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 13787 images belonging to 3 classes.
# Found 2942 images belonging to 3 classes.
# Found 3002 images belonging to 3 classes.

# %%
import tensorflow as tf

print("start")

# Initializing the metrics, now including Recall
f1_metric = tf.keras.metrics.F1Score(average='macro', name='f1_score')
precision_metric = tf.keras.metrics.Precision(name='precision')
recall_metric = tf.keras.metrics.Recall(name='recall') # <-- Added Recall metric

def get_ConvNeXtSmall():

    base_model = ConvNeXtSmall(
        input_shape=MODEL_INPUT_SIZE,
        weights='imagenet',
        include_top=False
    )

    base_model.trainable = False

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),                
        tf.keras.layers.Dropout(0.3),            
        Dense(NUM_CLASSES, activation='softmax') 
    ])

    # Keep your original optimizer configuration
    optimizer = Adam(learning_rate=0.0001)

    # Compiling with your requested metrics (now including recall)
    model.compile(
        loss="categorical_crossentropy",
        metrics=["accuracy", f1_metric, precision_metric, recall_metric], # <-- Added to compile
        optimizer=optimizer
    )

    return model

model = get_ConvNeXtSmall()
model.summary()

print("done1")
# Out:
# start
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ convnext_small (Functional)     │ (None, 9, 9, 768)      │    49,454,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 768)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 768)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 3)              │         2,307 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 49,456,995 (188.66 MB)
#  Trainable params: 2,307 (9.01 KB)
#  Non-trainable params: 49,454,688 (188.65 MB)
# done1

# %%
# ==========================================================
# CALLBACKS (Monitor set to 'val_f1_score')
# ==========================================================
print("start")

early_stop = EarlyStopping(
    monitor='val_f1_score',
    mode='max',
    patience=11,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.3,
    patience=5,
    min_lr=5e-8,
    verbose=1
)

checkpoint = ModelCheckpoint(
"ConvNeXtSmall_Imbalanced_model_V1.weights.h5",
    monitor='val_f1_score',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

print("done")
# Out:
# start
# done

# %%
# ==========================================================
# SHOW LEARNING RATE
# ==========================================================
print("start")

class PrintLearningRate(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate.numpy()
        print(f"\nEpoch {epoch+1} Learning Rate : {lr}")

lr_callback = PrintLearningRate()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# TRAINING
# ==========================================================
print("start")

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[
        early_stop,
        reduce_lr,
        checkpoint,
        lr_callback
    ]
)
print("done")
# Out:
# start
# Epoch 1/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.4463 - f1_score: 0.4068 - loss: 1.0926 - precision: 0.4926 - recall: 0.2567
# Epoch 1: val_f1_score improved from None to 0.51619, saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 1: finished saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 204s 438ms/step - accuracy: 0.4463 - f1_score: 0.4068 - loss: 1.0926 - precision: 0.4926 - recall: 0.2567 - val_accuracy: 0.5411 - val_f1_score: 0.5162 - val_loss: 0.9621 - val_precision: 0.6822 - val_recall: 0.2787 - learning_rate: 1.0000e-04
# Epoch 2/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.5314 - f1_score: 0.5143 - loss: 0.9769 - precision: 0.6023 - recall: 0.3271
# Epoch 2: val_f1_score improved from 0.51619 to 0.58342, saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 2: finished saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 2 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 180s 418ms/step - accuracy: 0.5314 - f1_score: 0.5143 - loss: 0.9769 - precision: 0.6023 - recall: 0.3271 - val_accuracy: 0.5945 - val_f1_score: 0.5834 - val_loss: 0.8961 - val_precision: 0.7418 - val_recall: 0.3848 - learning_rate: 1.0000e-04
# Epoch 3/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.5717 - f1_score: 0.5574 - loss: 0.9195 - precision: 0.6524 - recall: 0.3883
# Epoch 3: val_f1_score improved from 0.58342 to 0.60731, saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 3: finished saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 3 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 195s 453ms/step - accuracy: 0.5717 - f1_score: 0.5574 - loss: 0.9195 - precision: 0.6524 - recall: 0.3883 - val_accuracy: 0.6169 - val_f1_score: 0.6073 - val_loss: 0.8603 - val_precision: 0.7465 - val_recall: 0.4303 - learning_rate: 1.0000e-04
# Epoch 4/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.5964 - f1_score: 0.5842 - loss: 0.8858 - precision: 0.6754 - recall: 0.4316
# Epoch 4: val_f1_score improved from 0.60731 to 0.60842, saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 4: finished saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 4 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 181s 418ms/step - accuracy: 0.5964 - f1_score: 0.5842 - loss: 0.8858 - precision: 0.6754 - recall: 0.4316 - val_accuracy: 0.6213 - val_f1_score: 0.6084 - val_loss: 0.8397 - val_precision: 0.7381 - val_recall: 0.4579 - learning_rate: 1.0000e-04
# Epoch 5/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.6104 - f1_score: 0.5978 - loss: 0.8589 - precision: 0.6937 - recall: 0.4641
# Epoch 5: val_f1_score improved from 0.60842 to 0.62578, saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 5: finished saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 5 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 181s 419ms/step - accuracy: 0.6104 - f1_score: 0.5978 - loss: 0.8589 - precision: 0.6937 - recall: 0.4641 - val_accuracy: 0.6356 - val_f1_score: 0.6258 - val_loss: 0.8237 - val_precision: 0.7384 - val_recall: 0.4769 - learning_rate: 1.0000e-04
# Epoch 6/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.6207 - f1_score: 0.6079 - loss: 0.8491 - precision: 0.6926 - recall: 0.4789
# Epoch 6: val_f1_score improved from 0.62578 to 0.63044, saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 6: finished saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 6 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 174s 402ms/step - accuracy: 0.6207 - f1_score: 0.6079 - loss: 0.8491 - precision: 0.6926 - recall: 0.4789 - val_accuracy: 0.6400 - val_f1_score: 0.6304 - val_loss: 0.8108 - val_precision: 0.7383 - val_recall: 0.4986 - learning_rate: 1.0000e-04
# Epoch 7/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.6205 - f1_score: 0.6078 - loss: 0.8363 - precision: 0.6941 - recall: 0.4956
# Epoch 7: val_f1_score did not improve from 0.63044
#
# Epoch 7 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 166s 386ms/step - accuracy: 0.6205 - f1_score: 0.6078 - loss: 0.8363 - precision: 0.6941 - recall: 0.4956 - val_accuracy: 0.6411 - val_f1_score: 0.6285 - val_loss: 0.8034 - val_precision: 0.7372 - val_recall: 0.5071 - learning_rate: 1.0000e-04
# Epoch 8/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.6270 - f1_score: 0.6146 - loss: 0.8221 - precision: 0.6997 - recall: 0.5030
# Epoch 8: val_f1_score improved from 0.63044 to 0.63854, saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 8: finished saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 8 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 182s 423ms/step - accuracy: 0.6270 - f1_score: 0.6146 - loss: 0.8221 - precision: 0.6997 - recall: 0.5030 - val_accuracy: 0.6513 - val_f1_score: 0.6385 - val_loss: 0.7943 - val_precision: 0.7388 - val_recall: 0.5173 - learning_rate: 1.0000e-04
# Epoch 9/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.6291 - f1_score: 0.6168 - loss: 0.8187 - precision: 0.7009 - recall: 0.5118
# Epoch 9: val_f1_score did not improve from 0.63854
#
# Epoch 9 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 179s 414ms/step - accuracy: 0.6291 - f1_score: 0.6168 - loss: 0.8187 - precision: 0.7009 - recall: 0.5118 - val_accuracy: 0.6431 - val_f1_score: 0.6292 - val_loss: 0.7901 - val_precision: 0.7368 - val_recall: 0.5272 - learning_rate: 1.0000e-04
# Epoch 10/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.6336 - f1_score: 0.6208 - loss: 0.8096 - precision: 0.7051 - recall: 0.5224
# Epoch 10: val_f1_score improved from 0.63854 to 0.64587, saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 10: finished saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 10 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 181s 418ms/step - accuracy: 0.6336 - f1_score: 0.6208 - loss: 0.8096 - precision: 0.7051 - recall: 0.5224 - val_accuracy: 0.6526 - val_f1_score: 0.6459 - val_loss: 0.7830 - val_precision: 0.7422 - val_recall: 0.5343 - learning_rate: 1.0000e-04
# Epoch 11/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.6324 - f1_score: 0.6202 - loss: 0.8031 - precision: 0.7010 - recall: 0.5222
# Epoch 11: val_f1_score did not improve from 0.64587
#
# Epoch 11 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 182s 421ms/step - accuracy: 0.6324 - f1_score: 0.6202 - loss: 0.8031 - precision: 0.7010 - recall: 0.5222 - val_accuracy: 0.6540 - val_f1_score: 0.6439 - val_loss: 0.7776 - val_precision: 0.7380 - val_recall: 0.5418 - learning_rate: 1.0000e-04
# Epoch 12/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.6389 - f1_score: 0.6274 - loss: 0.7992 - precision: 0.7035 - recall: 0.5349
# Epoch 12: val_f1_score did not improve from 0.64587
#
# Epoch 12 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 165s 382ms/step - accuracy: 0.6389 - f1_score: 0.6274 - loss: 0.7992 - precision: 0.7035 - recall: 0.5349 - val_accuracy: 0.6458 - val_f1_score: 0.6308 - val_loss: 0.7788 - val_precision: 0.7302 - val_recall: 0.5401 - learning_rate: 1.0000e-04
# Epoch 13/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.6416 - f1_score: 0.6300 - loss: 0.7916 - precision: 0.7074 - recall: 0.5381
# Epoch 13: val_f1_score did not improve from 0.64587
#
# Epoch 13 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 166s 385ms/step - accuracy: 0.6416 - f1_score: 0.6300 - loss: 0.7916 - precision: 0.7074 - recall: 0.5381 - val_accuracy: 0.6526 - val_f1_score: 0.6391 - val_loss: 0.7733 - val_precision: 0.7335 - val_recall: 0.5435 - learning_rate: 1.0000e-04
# Epoch 14/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.6420 - f1_score: 0.6293 - loss: 0.7895 - precision: 0.7105 - recall: 0.5425
# Epoch 14: val_f1_score improved from 0.64587 to 0.64769, saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 14: finished saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 14 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 181s 420ms/step - accuracy: 0.6420 - f1_score: 0.6293 - loss: 0.7895 - precision: 0.7105 - recall: 0.5425 - val_accuracy: 0.6581 - val_f1_score: 0.6477 - val_loss: 0.7672 - val_precision: 0.7370 - val_recall: 0.5476 - learning_rate: 1.0000e-04
# Epoch 15/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.6388 - f1_score: 0.6269 - loss: 0.7879 - precision: 0.7065 - recall: 0.5438
# Epoch 15: val_f1_score did not improve from 0.64769
#
# Epoch 15 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 171s 395ms/step - accuracy: 0.6388 - f1_score: 0.6269 - loss: 0.7879 - precision: 0.7065 - recall: 0.5438 - val_accuracy: 0.6587 - val_f1_score: 0.6467 - val_loss: 0.7666 - val_precision: 0.7342 - val_recall: 0.5466 - learning_rate: 1.0000e-04
# Epoch 16/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.6439 - f1_score: 0.6308 - loss: 0.7862 - precision: 0.7085 - recall: 0.5494
# Epoch 16: val_f1_score improved from 0.64769 to 0.65416, saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 16: finished saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 16 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 193s 448ms/step - accuracy: 0.6439 - f1_score: 0.6308 - loss: 0.7862 - precision: 0.7085 - recall: 0.5494 - val_accuracy: 0.6615 - val_f1_score: 0.6542 - val_loss: 0.7629 - val_precision: 0.7417 - val_recall: 0.5554 - learning_rate: 1.0000e-04
# Epoch 17/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.6482 - f1_score: 0.6362 - loss: 0.7789 - precision: 0.7144 - recall: 0.5511
# Epoch 17: val_f1_score did not improve from 0.65416
#
# Epoch 17 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 168s 388ms/step - accuracy: 0.6482 - f1_score: 0.6362 - loss: 0.7789 - precision: 0.7144 - recall: 0.5511 - val_accuracy: 0.6584 - val_f1_score: 0.6477 - val_loss: 0.7625 - val_precision: 0.7358 - val_recall: 0.5557 - learning_rate: 1.0000e-04
# Epoch 18/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.6487 - f1_score: 0.6367 - loss: 0.7764 - precision: 0.7118 - recall: 0.5555
# Epoch 18: val_f1_score did not improve from 0.65416
#
# Epoch 18 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 183s 424ms/step - accuracy: 0.6487 - f1_score: 0.6367 - loss: 0.7764 - precision: 0.7118 - recall: 0.5555 - val_accuracy: 0.6611 - val_f1_score: 0.6513 - val_loss: 0.7594 - val_precision: 0.7368 - val_recall: 0.5595 - learning_rate: 1.0000e-04
# Epoch 19/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.6539 - f1_score: 0.6430 - loss: 0.7713 - precision: 0.7188 - recall: 0.5617
# Epoch 19: val_f1_score did not improve from 0.65416
#
# Epoch 19 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 168s 388ms/step - accuracy: 0.6539 - f1_score: 0.6430 - loss: 0.7713 - precision: 0.7188 - recall: 0.5617 - val_accuracy: 0.6584 - val_f1_score: 0.6452 - val_loss: 0.7587 - val_precision: 0.7334 - val_recall: 0.5602 - learning_rate: 1.0000e-04
# Epoch 20/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.6503 - f1_score: 0.6385 - loss: 0.7705 - precision: 0.7170 - recall: 0.5558
# Epoch 20: val_f1_score improved from 0.65416 to 0.65442, saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 20: finished saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 20 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 175s 406ms/step - accuracy: 0.6503 - f1_score: 0.6385 - loss: 0.7705 - precision: 0.7170 - recall: 0.5558 - val_accuracy: 0.6638 - val_f1_score: 0.6544 - val_loss: 0.7561 - val_precision: 0.7393 - val_recall: 0.5639 - learning_rate: 1.0000e-04
# Epoch 21/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.6550 - f1_score: 0.6434 - loss: 0.7702 - precision: 0.7131 - recall: 0.5619
# Epoch 21: val_f1_score did not improve from 0.65442
#
# Epoch 21 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 182s 423ms/step - accuracy: 0.6550 - f1_score: 0.6434 - loss: 0.7702 - precision: 0.7131 - recall: 0.5619 - val_accuracy: 0.6608 - val_f1_score: 0.6477 - val_loss: 0.7538 - val_precision: 0.7339 - val_recall: 0.5663 - learning_rate: 1.0000e-04
# Epoch 22/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.6499 - f1_score: 0.6371 - loss: 0.7688 - precision: 0.7149 - recall: 0.5621
# Epoch 22: val_f1_score improved from 0.65442 to 0.66164, saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 22: finished saving model to ConvNeXtSmall_Imbalanced_model_V1.weights.h5
#
# Epoch 22 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 184s 426ms/step - accuracy: 0.6499 - f1_score: 0.6371 - loss: 0.7688 - precision: 0.7149 - recall: 0.5621 - val_accuracy: 0.6689 - val_f1_score: 0.6616 - val_loss: 0.7532 - val_precision: 0.7396 - val_recall: 0.5707 - learning_rate: 1.0000e-04
# Epoch 23/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.6521 - f1_score: 0.6402 - loss: 0.7671 - precision: 0.7127 - recall: 0.5658
# Epoch 23: val_f1_score did not improve from 0.66164
#
# Epoch 23 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 168s 389ms/step - accuracy: 0.6521 - f1_score: 0.6402 - loss: 0.7671 - precision: 0.7127 - recall: 0.5658 - val_accuracy: 0.6659 - val_f1_score: 0.6562 - val_loss: 0.7509 - val_precision: 0.7393 - val_recall: 0.5659 - learning_rate: 1.0000e-04
# Epoch 24/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.6505 - f1_score: 0.6389 - loss: 0.7660 - precision: 0.7138 - recall: 0.5655
# Epoch 24: val_f1_score did not improve from 0.66164
#
# Epoch 24 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 182s 422ms/step - accuracy: 0.6505 - f1_score: 0.6389 - loss: 0.7660 - precision: 0.7138 - recall: 0.5655 - val_accuracy: 0.6604 - val_f1_score: 0.6498 - val_loss: 0.7515 - val_precision: 0.7376 - val_recall: 0.5666 - learning_rate: 1.0000e-04
# Epoch 25/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.6536 - f1_score: 0.6418 - loss: 0.7627 - precision: 0.7157 - recall: 0.5667
# Epoch 25: val_f1_score did not improve from 0.66164
#
# Epoch 25 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 168s 389ms/step - accuracy: 0.6536 - f1_score: 0.6418 - loss: 0.7627 - precision: 0.7157 - recall: 0.5667 - val_accuracy: 0.6604 - val_f1_score: 0.6473 - val_loss: 0.7521 - val_precision: 0.7336 - val_recall: 0.5673 - learning_rate: 1.0000e-04
# Epoch 26/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.6568 - f1_score: 0.6439 - loss: 0.7624 - precision: 0.7170 - recall: 0.5666
# Epoch 26: val_f1_score did not improve from 0.66164
#
# Epoch 26 Learning Rate : 9.999999747378752e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 170s 394ms/step - accuracy: 0.6568 - f1_score: 0.6439 - loss: 0.7624 - precision: 0.7170 - recall: 0.5666 - val_accuracy: 0.6676 - val_f1_score: 0.6581 - val_loss: 0.7475 - val_precision: 0.7427 - val_recall: 0.5741 - learning_rate: 1.0000e-04
# Epoch 27/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.6550 - f1_score: 0.6436 - loss: 0.7614 - precision: 0.7133 - recall: 0.5639
# Epoch 27: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 27: val_f1_score did not improve from 0.66164
#
# Epoch 27 Learning Rate : 2.9999999242136255e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 183s 425ms/step - accuracy: 0.6550 - f1_score: 0.6436 - loss: 0.7614 - precision: 0.7133 - recall: 0.5639 - val_accuracy: 0.6655 - val_f1_score: 0.6552 - val_loss: 0.7468 - val_precision: 0.7404 - val_recall: 0.5738 - learning_rate: 1.0000e-04
# Epoch 28/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.6580 - f1_score: 0.6463 - loss: 0.7565 - precision: 0.7184 - recall: 0.5724
# Epoch 28: val_f1_score did not improve from 0.66164
#
# Epoch 28 Learning Rate : 2.9999999242136255e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 169s 391ms/step - accuracy: 0.6580 - f1_score: 0.6463 - loss: 0.7565 - precision: 0.7184 - recall: 0.5724 - val_accuracy: 0.6652 - val_f1_score: 0.6549 - val_loss: 0.7463 - val_precision: 0.7400 - val_recall: 0.5738 - learning_rate: 3.0000e-05
# Epoch 29/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.6544 - f1_score: 0.6423 - loss: 0.7589 - precision: 0.7145 - recall: 0.5678
# Epoch 29: val_f1_score did not improve from 0.66164
#
# Epoch 29 Learning Rate : 2.9999999242136255e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 166s 385ms/step - accuracy: 0.6544 - f1_score: 0.6423 - loss: 0.7589 - precision: 0.7145 - recall: 0.5678 - val_accuracy: 0.6611 - val_f1_score: 0.6500 - val_loss: 0.7470 - val_precision: 0.7397 - val_recall: 0.5738 - learning_rate: 3.0000e-05
# Epoch 30/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.6557 - f1_score: 0.6444 - loss: 0.7569 - precision: 0.7151 - recall: 0.5687
# Epoch 30: val_f1_score did not improve from 0.66164
#
# Epoch 30 Learning Rate : 2.9999999242136255e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 169s 391ms/step - accuracy: 0.6557 - f1_score: 0.6444 - loss: 0.7569 - precision: 0.7151 - recall: 0.5687 - val_accuracy: 0.6638 - val_f1_score: 0.6535 - val_loss: 0.7461 - val_precision: 0.7401 - val_recall: 0.5731 - learning_rate: 3.0000e-05
# Epoch 31/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.6593 - f1_score: 0.6476 - loss: 0.7582 - precision: 0.7218 - recall: 0.5727
# Epoch 31: val_f1_score did not improve from 0.66164
#
# Epoch 31 Learning Rate : 2.9999999242136255e-05
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 166s 386ms/step - accuracy: 0.6593 - f1_score: 0.6476 - loss: 0.7582 - precision: 0.7218 - recall: 0.5727 - val_accuracy: 0.6611 - val_f1_score: 0.6496 - val_loss: 0.7465 - val_precision: 0.7387 - val_recall: 0.5727 - learning_rate: 3.0000e-05
# Epoch 32/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.6612 - f1_score: 0.6491 - loss: 0.7537 - precision: 0.7207 - recall: 0.5743
# Epoch 32: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 32: val_f1_score did not improve from 0.66164
#
# Epoch 32 Learning Rate : 8.999999408842996e-06
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 173s 400ms/step - accuracy: 0.6612 - f1_score: 0.6491 - loss: 0.7537 - precision: 0.7207 - recall: 0.5743 - val_accuracy: 0.6618 - val_f1_score: 0.6514 - val_loss: 0.7456 - val_precision: 0.7413 - val_recall: 0.5748 - learning_rate: 3.0000e-05
# Epoch 33/150
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.6583 - f1_score: 0.6482 - loss: 0.7596 - precision: 0.7210 - recall: 0.5737
# Epoch 33: val_f1_score did not improve from 0.66164
#
# Epoch 33 Learning Rate : 8.999999408842996e-06
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 168s 390ms/step - accuracy: 0.6583 - f1_score: 0.6482 - loss: 0.7596 - precision: 0.7210 - recall: 0.5737 - val_accuracy: 0.6635 - val_f1_score: 0.6525 - val_loss: 0.7453 - val_precision: 0.7397 - val_recall: 0.5748 - learning_rate: 9.0000e-06
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 22.
# done

# %%
# 1. Rebuild the model architecture blueprint first
model = get_ConvNeXtSmall()

# 2. Load the weights directly into the blueprint
# Note: .load_weights() does not require a custom_objects dictionary!
model.load_weights("ConvNeXtSmall_Imbalanced_model_V1.weights.h5")

print("Model weights loaded successfully!")
# Out:
# Model weights loaded successfully!
# /home/user7/miniconda3/envs/tf_new/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:869: UserWarning: Skipping variable loading for optimizer 'adam_1', because it has 2 variables whereas the saved optimizer has 6 variables.
#   saveable.load_own_variables(store)

# %%
# ==========================================================
# PLOT LEARNING CURVES (Loss, F1-Score, Precision)
# ==========================================================
print("start")

# 1. Loss Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Train Loss', color='red')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig("ConvNeXtSmall_Imbalanced_Loss_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

# 2. F1 Score Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['f1_score'], label='Train F1-Score', color='blue')
plt.plot(history.history['val_f1_score'], label='Validation F1-Score', color='cyan')

plt.xlabel('Epochs')
plt.ylabel('F1-Score')
plt.legend()
plt.tight_layout()
plt.savefig("ConvNeXtSmall_Imbalanced_F1_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

# 3. Precision Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['precision'], label='Train Precision', color='green')
plt.plot(history.history['val_precision'], label='Validation Precision', color='lightgreen')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.tight_layout()
plt.savefig("ConvNeXtSmall_Imbalanced_Precision_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# EVALUATION (Training, Validation & Testing)
# ==========================================================
print("Evaluating on Training Set...")
train_results = model.evaluate(train_generator)

print("\nEvaluating on Validation Set...")
val_results = model.evaluate(val_generator)

print("\nEvaluating on Testing Set (Truly Unseen)...")
test_results = model.evaluate(test_generator)

# Unpacking 5 values based on the compile metrics order
# Order: [loss, accuracy, f1_score, precision, recall]
train_loss = train_results[0]
train_acc = train_results[1]
train_f1 = train_results[2]
train_precision = train_results[3]
train_recall = train_results[4]

val_loss = val_results[0]
val_acc = val_results[1]
val_f1 = val_results[2]
val_precision = val_results[3]
val_recall = val_results[4]

test_loss = test_results[0]
test_acc = test_results[1]
test_f1 = test_results[2]
test_precision = test_results[3]
test_recall = test_results[4]

print("\n" + "="*40)
print("TRAINING METRICS")
print("="*40)
print(f"Training Loss      : {train_loss:.4f}")
print(f"Training Accuracy  : {train_acc*100:.2f}%")
print(f"Training F1-Score  : {train_f1*100:.2f}%")
print(f"Training Precision : {train_precision*100:.2f}%")
print(f"Training Recall    : {train_recall*100:.2f}%")

print("\n" + "="*40)
print("VALIDATION METRICS")
print("="*40)
print(f"Validation Loss      : {val_loss:.4f}")
print(f"Validation Accuracy  : {val_acc*100:.2f}%")
print(f"Validation F1-Score  : {val_f1*100:.2f}%")
print(f"Validation Precision : {val_precision*100:.2f}%")
print(f"Validation Recall    : {val_recall*100:.2f}%")

print("\n" + "="*40)
print("TESTING METRICS (UNSEEN DATA)")
print("="*40)
print(f"Testing Loss      : {test_loss:.4f}")
print(f"Testing Accuracy  : {test_acc*100:.2f}%")
print(f"Testing F1-Score  : {test_f1*100:.2f}%")
print(f"Testing Precision : {test_precision*100:.2f}%")
print(f"Testing Recall    : {test_recall*100:.2f}%")
# Out:
# Evaluating on Training Set...
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 146s 327ms/step - accuracy: 0.6696 - f1_score: 0.6609 - loss: 0.7399 - precision: 0.7410 - recall: 0.5688
#
# Evaluating on Validation Set...
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 30s 330ms/step - accuracy: 0.6689 - f1_score: 0.6616 - loss: 0.7532 - precision: 0.7396 - recall: 0.5707
#
# Evaluating on Testing Set (Truly Unseen)...
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 37s 380ms/step - accuracy: 0.6592 - f1_score: 0.6531 - loss: 0.7591 - precision: 0.7269 - recall: 0.5640
#
# ========================================
# TRAINING METRICS
# ========================================
# Training Loss      : 0.7399
# Training Accuracy  : 66.96%
# Training F1-Score  : 66.09%
# Training Precision : 74.10%
# Training Recall    : 56.88%
#
# ========================================
# VALIDATION METRICS
# ========================================
# Validation Loss      : 0.7532
# Validation Accuracy  : 66.89%
# Validation F1-Score  : 66.16%
# Validation Precision : 73.96%
# Validation Recall    : 57.07%
#
# ========================================
# TESTING METRICS (UNSEEN DATA)
# ========================================
# Testing Loss      : 0.7591
# Testing Accuracy  : 65.92%
# Testing F1-Score  : 65.31%
# Testing Precision : 72.69%
# Testing Recall    : 56.40%

# %%
# ==========================================================
# PRECISION, RECALL, F1-SCORE (Test Set - Unseen Data)
# ==========================================================
print("\nCalculating Precision, Recall, F1-score on Test Set...")

predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

true_classes = test_generator.classes
class_names = list(test_generator.class_indices.keys())

print("\nClassification Report (Test Set):\n")
print(
    classification_report(
        true_classes,
        predicted_classes,
        target_names=class_names
    )
)

print("done1")
# Out:
# Calculating Precision, Recall, F1-score on Test Set...
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 37s 358ms/step
#
# Classification Report (Test Set):
#
#               precision    recall  f1-score   support
#
#       Benign       0.55      0.49      0.52       924
#    Malignant       0.70      0.71      0.71      1309
#       Normal       0.70      0.77      0.73       769
#
#     accuracy                           0.66      3002
#    macro avg       0.65      0.66      0.65      3002
# weighted avg       0.65      0.66      0.66      3002
#
# done1

# %%
# ==========================================================
# CONFUSION MATRIX (Test Set)
# ==========================================================
print("Generating Confusion Matrix...")

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(true_classes, predicted_classes)

# Plot the confusion matrix using Seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,       # Show the actual numbers inside the squares
    fmt='d',          # Format as whole numbers (integers)
    cmap='Blues',     # Color scheme
    xticklabels=class_names,
    yticklabels=class_names
)


plt.ylabel('True Label', fontsize=14)
plt.xlabel('Predicted Label', fontsize=14)
plt.xticks(rotation=45) # Rotate x-axis labels so they are easier to read
plt.yticks(rotation=0)

plt.tight_layout()
plt.savefig("ConvNeXtSmall_Imbalanced_confusion_matrix_test.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# Generating Confusion Matrix...
# done1
