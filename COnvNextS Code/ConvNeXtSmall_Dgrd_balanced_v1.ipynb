# %%
# ==========================================================
# CREATE BALANCED DATASET DIRECTORY
# ==========================================================
print("start")

import os


balanced_dataset = r"/mnt/d/Thesis_folder/Preprocessed_Pipeline/Supervised_Balanced"



print("Balanced dataset ready")
# Out:
# start
# Balanced dataset ready

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("TensorFlow Version: ", tf.__version__)
# Out:
# Num GPUs Available:  1
# TensorFlow Version:  2.21.0

# %%
# ==========================================================
# IMPORTS
# ==========================================================
print("start")

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ConvNeXtSmall
from tensorflow.keras.applications.convnext import preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint,
    Callback
)

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# CONFIGURATION & GENERATORS
# ==========================================================
print("start")

# Pointing to the Balanced Dataset
DATASET_PATH = r"/mnt/d/Thesis_folder/Preprocessed_Pipeline/Supervised_Balanced"

IMAGE_SIZE = (288, 288)
MODEL_INPUT_SIZE = (288, 288, 3)
NUM_CLASSES = 3
BATCH_SIZE = 32
EPOCHS = 150

print("done1")
# Out:
# start
# done1

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.convnext import preprocess_input

# 1. Define the base generator
datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# 2. Define the paths to your new split folders
train_dir = r"/mnt/d/Thesis_folder/Supervised_Balanced/train"
val_dir = r"/mnt/d/Thesis_folder/Supervised_Balanced/val"
test_dir = r"/mnt/d/Thesis_folder/Supervised_Balanced/test"

# 3. Create the Train Generator
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True # Shuffle training data
)

# 4. Create the Validation Generator
val_generator = datagen.flow_from_directory(
    val_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# 5. Create the Test Generator (CRITICAL: shuffle=False for evaluation)
test_generator = datagen.flow_from_directory(
    test_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 18000 images belonging to 3 classes.
# Found 2960 images belonging to 3 classes.
# Found 2960 images belonging to 3 classes.

# %%
import tensorflow as tf

print("start")

# Initializing the metrics, now including Recall
f1_metric = tf.keras.metrics.F1Score(average='macro', name='f1_score')
precision_metric = tf.keras.metrics.Precision(name='precision')
recall_metric = tf.keras.metrics.Recall(name='recall') # <-- Added Recall metric

def get_ConvNeXtSmall():

    base_model = ConvNeXtSmall(
        input_shape=MODEL_INPUT_SIZE,
        weights='imagenet',
        include_top=False
    )

    base_model.trainable = False

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),                
        tf.keras.layers.Dropout(0.3),            
        Dense(NUM_CLASSES, activation='softmax') 
    ])

    # Keep your original optimizer configuration
    optimizer = Adam(learning_rate=0.0001)

    # Compiling with your requested metrics (now including recall)
    model.compile(
        loss="categorical_crossentropy",
        metrics=["accuracy", f1_metric, precision_metric, recall_metric], # <-- Added to compile
        optimizer=optimizer
    )

    return model

model = get_ConvNeXtSmall()
model.summary()

print("done1")
# Out:
# start
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ convnext_small (Functional)     │ (None, 9, 9, 768)      │    49,454,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 768)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 768)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 3)              │         2,307 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 49,456,995 (188.66 MB)
#  Trainable params: 2,307 (9.01 KB)
#  Non-trainable params: 49,454,688 (188.65 MB)
# done1

# %%
# ==========================================================
# CALLBACKS (Monitor set to 'val_f1_score')
# ==========================================================
print("start")

early_stop = EarlyStopping(
    monitor='val_f1_score',
    mode='max',
    patience=11,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.3,
    patience=5,
    min_lr=5e-8,
    verbose=1
)

checkpoint = ModelCheckpoint(
"ConvNeXtSmall_balanced_model_V1.weights.h5",
    monitor='val_f1_score',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

print("done")
# Out:
# start
# done

# %%
# ==========================================================
# SHOW LEARNING RATE
# ==========================================================
print("start")

class PrintLearningRate(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate.numpy()
        print(f"\nEpoch {epoch+1} Learning Rate : {lr}")

lr_callback = PrintLearningRate()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# TRAINING
# ==========================================================
print("start")

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[
        early_stop,
        reduce_lr,
        checkpoint,
        lr_callback
    ]
)
print("done")
# Out:
# start
# Epoch 1/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 947ms/step - accuracy: 0.4391 - f1_score: 0.4389 - loss: 1.0909 - precision: 0.4866 - recall: 0.2467
# Epoch 1: val_f1_score improved from None to 0.55805, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 1: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 614s 1s/step - accuracy: 0.4391 - f1_score: 0.4389 - loss: 1.0909 - precision: 0.4866 - recall: 0.2467 - val_accuracy: 0.5608 - val_f1_score: 0.5581 - val_loss: 0.9568 - val_precision: 0.6766 - val_recall: 0.2686 - learning_rate: 1.0000e-04
# Epoch 2/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.5417 - f1_score: 0.5395 - loss: 0.9471 - precision: 0.6152 - recall: 0.3587
# Epoch 2: val_f1_score improved from 0.55805 to 0.58642, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 2: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 2 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 207s 367ms/step - accuracy: 0.5417 - f1_score: 0.5395 - loss: 0.9471 - precision: 0.6152 - recall: 0.3587 - val_accuracy: 0.5929 - val_f1_score: 0.5864 - val_loss: 0.8948 - val_precision: 0.6995 - val_recall: 0.3892 - learning_rate: 1.0000e-04
# Epoch 3/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.5844 - f1_score: 0.5809 - loss: 0.8884 - precision: 0.6621 - recall: 0.4187
# Epoch 3: val_f1_score improved from 0.58642 to 0.60869, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 3: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 3 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 207s 367ms/step - accuracy: 0.5844 - f1_score: 0.5809 - loss: 0.8884 - precision: 0.6621 - recall: 0.4187 - val_accuracy: 0.6152 - val_f1_score: 0.6087 - val_loss: 0.8668 - val_precision: 0.7007 - val_recall: 0.4247 - learning_rate: 1.0000e-04
# Epoch 4/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.6054 - f1_score: 0.6011 - loss: 0.8533 - precision: 0.6819 - recall: 0.4507
# Epoch 4: val_f1_score improved from 0.60869 to 0.61910, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 4: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 4 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 205s 364ms/step - accuracy: 0.6054 - f1_score: 0.6011 - loss: 0.8533 - precision: 0.6819 - recall: 0.4507 - val_accuracy: 0.6287 - val_f1_score: 0.6191 - val_loss: 0.8486 - val_precision: 0.7088 - val_recall: 0.4588 - learning_rate: 1.0000e-04
# Epoch 5/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.6154 - f1_score: 0.6107 - loss: 0.8362 - precision: 0.6865 - recall: 0.4794
# Epoch 5: val_f1_score improved from 0.61910 to 0.62521, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 5: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 5 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 205s 363ms/step - accuracy: 0.6154 - f1_score: 0.6107 - loss: 0.8362 - precision: 0.6865 - recall: 0.4794 - val_accuracy: 0.6311 - val_f1_score: 0.6252 - val_loss: 0.8370 - val_precision: 0.7056 - val_recall: 0.4770 - learning_rate: 1.0000e-04
# Epoch 6/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.6237 - f1_score: 0.6190 - loss: 0.8216 - precision: 0.6886 - recall: 0.4978
# Epoch 6: val_f1_score improved from 0.62521 to 0.63289, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 6: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 6 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 207s 367ms/step - accuracy: 0.6237 - f1_score: 0.6190 - loss: 0.8216 - precision: 0.6886 - recall: 0.4978 - val_accuracy: 0.6382 - val_f1_score: 0.6329 - val_loss: 0.8253 - val_precision: 0.7098 - val_recall: 0.4892 - learning_rate: 1.0000e-04
# Epoch 7/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.6333 - f1_score: 0.6282 - loss: 0.8061 - precision: 0.6996 - recall: 0.5099
# Epoch 7: val_f1_score improved from 0.63289 to 0.63604, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 7: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 7 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 207s 366ms/step - accuracy: 0.6333 - f1_score: 0.6282 - loss: 0.8061 - precision: 0.6996 - recall: 0.5099 - val_accuracy: 0.6446 - val_f1_score: 0.6360 - val_loss: 0.8125 - val_precision: 0.7119 - val_recall: 0.5159 - learning_rate: 1.0000e-04
# Epoch 8/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.6355 - f1_score: 0.6305 - loss: 0.7978 - precision: 0.6981 - recall: 0.5191
# Epoch 8: val_f1_score improved from 0.63604 to 0.63743, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 8: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 8 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 203s 360ms/step - accuracy: 0.6355 - f1_score: 0.6305 - loss: 0.7978 - precision: 0.6981 - recall: 0.5191 - val_accuracy: 0.6419 - val_f1_score: 0.6374 - val_loss: 0.8075 - val_precision: 0.7150 - val_recall: 0.5095 - learning_rate: 1.0000e-04
# Epoch 9/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.6393 - f1_score: 0.6343 - loss: 0.7916 - precision: 0.7011 - recall: 0.5258
# Epoch 9: val_f1_score improved from 0.63743 to 0.63916, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 9: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 9 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 208s 368ms/step - accuracy: 0.6393 - f1_score: 0.6343 - loss: 0.7916 - precision: 0.7011 - recall: 0.5258 - val_accuracy: 0.6470 - val_f1_score: 0.6392 - val_loss: 0.7983 - val_precision: 0.7144 - val_recall: 0.5274 - learning_rate: 1.0000e-04
# Epoch 10/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.6417 - f1_score: 0.6367 - loss: 0.7860 - precision: 0.7005 - recall: 0.5329
# Epoch 10: val_f1_score improved from 0.63916 to 0.64180, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 10: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 10 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 206s 366ms/step - accuracy: 0.6417 - f1_score: 0.6367 - loss: 0.7860 - precision: 0.7005 - recall: 0.5329 - val_accuracy: 0.6486 - val_f1_score: 0.6418 - val_loss: 0.7937 - val_precision: 0.7140 - val_recall: 0.5314 - learning_rate: 1.0000e-04
# Epoch 11/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.6456 - f1_score: 0.6402 - loss: 0.7813 - precision: 0.7068 - recall: 0.5381
# Epoch 11: val_f1_score improved from 0.64180 to 0.64252, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 11: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 11 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 203s 360ms/step - accuracy: 0.6456 - f1_score: 0.6402 - loss: 0.7813 - precision: 0.7068 - recall: 0.5381 - val_accuracy: 0.6493 - val_f1_score: 0.6425 - val_loss: 0.7905 - val_precision: 0.7140 - val_recall: 0.5382 - learning_rate: 1.0000e-04
# Epoch 12/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.6446 - f1_score: 0.6392 - loss: 0.7747 - precision: 0.7074 - recall: 0.5454
# Epoch 12: val_f1_score improved from 0.64252 to 0.64599, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 12: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 12 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 217s 385ms/step - accuracy: 0.6446 - f1_score: 0.6392 - loss: 0.7747 - precision: 0.7074 - recall: 0.5454 - val_accuracy: 0.6537 - val_f1_score: 0.6460 - val_loss: 0.7870 - val_precision: 0.7165 - val_recall: 0.5389 - learning_rate: 1.0000e-04
# Epoch 13/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.6488 - f1_score: 0.6433 - loss: 0.7713 - precision: 0.7057 - recall: 0.5481
# Epoch 13: val_f1_score did not improve from 0.64599
#
# Epoch 13 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 233s 413ms/step - accuracy: 0.6488 - f1_score: 0.6433 - loss: 0.7713 - precision: 0.7057 - recall: 0.5481 - val_accuracy: 0.6520 - val_f1_score: 0.6457 - val_loss: 0.7849 - val_precision: 0.7140 - val_recall: 0.5422 - learning_rate: 1.0000e-04
# Epoch 14/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.6509 - f1_score: 0.6459 - loss: 0.7659 - precision: 0.7118 - recall: 0.5540
# Epoch 14: val_f1_score improved from 0.64599 to 0.64768, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 14: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 14 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 214s 380ms/step - accuracy: 0.6509 - f1_score: 0.6459 - loss: 0.7659 - precision: 0.7118 - recall: 0.5540 - val_accuracy: 0.6571 - val_f1_score: 0.6477 - val_loss: 0.7757 - val_precision: 0.7163 - val_recall: 0.5476 - learning_rate: 1.0000e-04
# Epoch 15/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.6518 - f1_score: 0.6463 - loss: 0.7638 - precision: 0.7084 - recall: 0.5542
# Epoch 15: val_f1_score improved from 0.64768 to 0.64815, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 15: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 15 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 200s 355ms/step - accuracy: 0.6518 - f1_score: 0.6463 - loss: 0.7638 - precision: 0.7084 - recall: 0.5542 - val_accuracy: 0.6541 - val_f1_score: 0.6482 - val_loss: 0.7772 - val_precision: 0.7160 - val_recall: 0.5503 - learning_rate: 1.0000e-04
# Epoch 16/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.6529 - f1_score: 0.6477 - loss: 0.7610 - precision: 0.7088 - recall: 0.5566
# Epoch 16: val_f1_score improved from 0.64815 to 0.64984, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 16: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 16 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 200s 354ms/step - accuracy: 0.6529 - f1_score: 0.6477 - loss: 0.7610 - precision: 0.7088 - recall: 0.5566 - val_accuracy: 0.6591 - val_f1_score: 0.6498 - val_loss: 0.7720 - val_precision: 0.7155 - val_recall: 0.5480 - learning_rate: 1.0000e-04
# Epoch 17/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.6534 - f1_score: 0.6479 - loss: 0.7581 - precision: 0.7095 - recall: 0.5605
# Epoch 17: val_f1_score improved from 0.64984 to 0.65222, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 17: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 17 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 197s 349ms/step - accuracy: 0.6534 - f1_score: 0.6479 - loss: 0.7581 - precision: 0.7095 - recall: 0.5605 - val_accuracy: 0.6595 - val_f1_score: 0.6522 - val_loss: 0.7691 - val_precision: 0.7202 - val_recall: 0.5557 - learning_rate: 1.0000e-04
# Epoch 18/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.6561 - f1_score: 0.6511 - loss: 0.7585 - precision: 0.7105 - recall: 0.5659
# Epoch 18: val_f1_score did not improve from 0.65222
#
# Epoch 18 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 191s 338ms/step - accuracy: 0.6561 - f1_score: 0.6511 - loss: 0.7585 - precision: 0.7105 - recall: 0.5659 - val_accuracy: 0.6605 - val_f1_score: 0.6518 - val_loss: 0.7668 - val_precision: 0.7196 - val_recall: 0.5591 - learning_rate: 1.0000e-04
# Epoch 19/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.6564 - f1_score: 0.6516 - loss: 0.7528 - precision: 0.7123 - recall: 0.5676
# Epoch 19: val_f1_score did not improve from 0.65222
#
# Epoch 19 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 188s 333ms/step - accuracy: 0.6564 - f1_score: 0.6516 - loss: 0.7528 - precision: 0.7123 - recall: 0.5676 - val_accuracy: 0.6561 - val_f1_score: 0.6510 - val_loss: 0.7677 - val_precision: 0.7165 - val_recall: 0.5574 - learning_rate: 1.0000e-04
# Epoch 20/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.6580 - f1_score: 0.6529 - loss: 0.7556 - precision: 0.7140 - recall: 0.5686
# Epoch 20: val_f1_score did not improve from 0.65222
#
# Epoch 20 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 188s 334ms/step - accuracy: 0.6580 - f1_score: 0.6529 - loss: 0.7556 - precision: 0.7140 - recall: 0.5686 - val_accuracy: 0.6541 - val_f1_score: 0.6492 - val_loss: 0.7671 - val_precision: 0.7182 - val_recall: 0.5554 - learning_rate: 1.0000e-04
# Epoch 21/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.6589 - f1_score: 0.6541 - loss: 0.7494 - precision: 0.7166 - recall: 0.5690
# Epoch 21: val_f1_score did not improve from 0.65222
#
# Epoch 21 Learning Rate : 9.999999747378752e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 191s 338ms/step - accuracy: 0.6589 - f1_score: 0.6541 - loss: 0.7494 - precision: 0.7166 - recall: 0.5690 - val_accuracy: 0.6571 - val_f1_score: 0.6504 - val_loss: 0.7629 - val_precision: 0.7190 - val_recall: 0.5618 - learning_rate: 1.0000e-04
# Epoch 22/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.6586 - f1_score: 0.6539 - loss: 0.7485 - precision: 0.7136 - recall: 0.5692
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 22: val_f1_score improved from 0.65222 to 0.65225, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 22: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 22 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 199s 353ms/step - accuracy: 0.6586 - f1_score: 0.6539 - loss: 0.7485 - precision: 0.7136 - recall: 0.5692 - val_accuracy: 0.6578 - val_f1_score: 0.6523 - val_loss: 0.7620 - val_precision: 0.7181 - val_recall: 0.5611 - learning_rate: 1.0000e-04
# Epoch 23/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.6612 - f1_score: 0.6566 - loss: 0.7468 - precision: 0.7150 - recall: 0.5724
# Epoch 23: val_f1_score did not improve from 0.65225
#
# Epoch 23 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 186s 329ms/step - accuracy: 0.6612 - f1_score: 0.6566 - loss: 0.7468 - precision: 0.7150 - recall: 0.5724 - val_accuracy: 0.6584 - val_f1_score: 0.6511 - val_loss: 0.7618 - val_precision: 0.7219 - val_recall: 0.5622 - learning_rate: 3.0000e-05
# Epoch 24/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.6636 - f1_score: 0.6585 - loss: 0.7445 - precision: 0.7129 - recall: 0.5741
# Epoch 24: val_f1_score improved from 0.65225 to 0.65300, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 24: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 24 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 202s 359ms/step - accuracy: 0.6636 - f1_score: 0.6585 - loss: 0.7445 - precision: 0.7129 - recall: 0.5741 - val_accuracy: 0.6584 - val_f1_score: 0.6530 - val_loss: 0.7619 - val_precision: 0.7177 - val_recall: 0.5618 - learning_rate: 3.0000e-05
# Epoch 25/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.6584 - f1_score: 0.6534 - loss: 0.7467 - precision: 0.7133 - recall: 0.5711
# Epoch 25: val_f1_score improved from 0.65300 to 0.65306, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 25: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 25 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 217s 385ms/step - accuracy: 0.6584 - f1_score: 0.6534 - loss: 0.7467 - precision: 0.7133 - recall: 0.5711 - val_accuracy: 0.6588 - val_f1_score: 0.6531 - val_loss: 0.7609 - val_precision: 0.7204 - val_recall: 0.5632 - learning_rate: 3.0000e-05
# Epoch 26/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.6629 - f1_score: 0.6581 - loss: 0.7455 - precision: 0.7141 - recall: 0.5734
# Epoch 26: val_f1_score did not improve from 0.65306
#
# Epoch 26 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 187s 332ms/step - accuracy: 0.6629 - f1_score: 0.6581 - loss: 0.7455 - precision: 0.7141 - recall: 0.5734 - val_accuracy: 0.6598 - val_f1_score: 0.6528 - val_loss: 0.7602 - val_precision: 0.7205 - val_recall: 0.5625 - learning_rate: 3.0000e-05
# Epoch 27/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.6633 - f1_score: 0.6586 - loss: 0.7450 - precision: 0.7171 - recall: 0.5751
# Epoch 27: val_f1_score did not improve from 0.65306
#
# Epoch 27 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 188s 334ms/step - accuracy: 0.6633 - f1_score: 0.6586 - loss: 0.7450 - precision: 0.7171 - recall: 0.5751 - val_accuracy: 0.6574 - val_f1_score: 0.6512 - val_loss: 0.7613 - val_precision: 0.7206 - val_recall: 0.5628 - learning_rate: 3.0000e-05
# Epoch 28/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.6596 - f1_score: 0.6548 - loss: 0.7457 - precision: 0.7125 - recall: 0.5721
# Epoch 28: val_f1_score improved from 0.65306 to 0.65489, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 28: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 28 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 201s 358ms/step - accuracy: 0.6596 - f1_score: 0.6548 - loss: 0.7457 - precision: 0.7125 - recall: 0.5721 - val_accuracy: 0.6632 - val_f1_score: 0.6549 - val_loss: 0.7584 - val_precision: 0.7210 - val_recall: 0.5639 - learning_rate: 3.0000e-05
# Epoch 29/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.6614 - f1_score: 0.6564 - loss: 0.7443 - precision: 0.7164 - recall: 0.5709
# Epoch 29: val_f1_score did not improve from 0.65489
#
# Epoch 29 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 188s 334ms/step - accuracy: 0.6614 - f1_score: 0.6564 - loss: 0.7443 - precision: 0.7164 - recall: 0.5709 - val_accuracy: 0.6591 - val_f1_score: 0.6536 - val_loss: 0.7601 - val_precision: 0.7197 - val_recall: 0.5622 - learning_rate: 3.0000e-05
# Epoch 30/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.6634 - f1_score: 0.6588 - loss: 0.7415 - precision: 0.7156 - recall: 0.5756
# Epoch 30: val_f1_score improved from 0.65489 to 0.65516, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 30: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 30 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 200s 355ms/step - accuracy: 0.6634 - f1_score: 0.6588 - loss: 0.7415 - precision: 0.7156 - recall: 0.5756 - val_accuracy: 0.6608 - val_f1_score: 0.6552 - val_loss: 0.7591 - val_precision: 0.7215 - val_recall: 0.5635 - learning_rate: 3.0000e-05
# Epoch 31/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.6633 - f1_score: 0.6587 - loss: 0.7428 - precision: 0.7155 - recall: 0.5753
# Epoch 31: val_f1_score did not improve from 0.65516
#
# Epoch 31 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 186s 331ms/step - accuracy: 0.6633 - f1_score: 0.6587 - loss: 0.7428 - precision: 0.7155 - recall: 0.5753 - val_accuracy: 0.6551 - val_f1_score: 0.6507 - val_loss: 0.7605 - val_precision: 0.7182 - val_recall: 0.5632 - learning_rate: 3.0000e-05
# Epoch 32/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.6606 - f1_score: 0.6559 - loss: 0.7422 - precision: 0.7148 - recall: 0.5769
# Epoch 32: val_f1_score did not improve from 0.65516
#
# Epoch 32 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 202s 359ms/step - accuracy: 0.6606 - f1_score: 0.6559 - loss: 0.7422 - precision: 0.7148 - recall: 0.5769 - val_accuracy: 0.6618 - val_f1_score: 0.6551 - val_loss: 0.7576 - val_precision: 0.7206 - val_recall: 0.5645 - learning_rate: 3.0000e-05
# Epoch 33/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.6638 - f1_score: 0.6590 - loss: 0.7394 - precision: 0.7172 - recall: 0.5808
# Epoch 33: val_f1_score improved from 0.65516 to 0.65564, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 33: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 33 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 203s 360ms/step - accuracy: 0.6638 - f1_score: 0.6590 - loss: 0.7394 - precision: 0.7172 - recall: 0.5808 - val_accuracy: 0.6618 - val_f1_score: 0.6556 - val_loss: 0.7570 - val_precision: 0.7218 - val_recall: 0.5645 - learning_rate: 3.0000e-05
# Epoch 34/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.6631 - f1_score: 0.6586 - loss: 0.7414 - precision: 0.7186 - recall: 0.5791
# Epoch 34: val_f1_score improved from 0.65564 to 0.65723, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 34: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 34 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 216s 382ms/step - accuracy: 0.6631 - f1_score: 0.6586 - loss: 0.7414 - precision: 0.7186 - recall: 0.5791 - val_accuracy: 0.6628 - val_f1_score: 0.6572 - val_loss: 0.7571 - val_precision: 0.7206 - val_recall: 0.5645 - learning_rate: 3.0000e-05
# Epoch 35/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.6623 - f1_score: 0.6576 - loss: 0.7418 - precision: 0.7137 - recall: 0.5741
# Epoch 35: val_f1_score did not improve from 0.65723
#
# Epoch 35 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 202s 358ms/step - accuracy: 0.6623 - f1_score: 0.6576 - loss: 0.7418 - precision: 0.7137 - recall: 0.5741 - val_accuracy: 0.6628 - val_f1_score: 0.6563 - val_loss: 0.7562 - val_precision: 0.7225 - val_recall: 0.5639 - learning_rate: 3.0000e-05
# Epoch 36/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.6616 - f1_score: 0.6566 - loss: 0.7406 - precision: 0.7193 - recall: 0.5757
# Epoch 36: val_f1_score did not improve from 0.65723
#
# Epoch 36 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 202s 359ms/step - accuracy: 0.6616 - f1_score: 0.6566 - loss: 0.7406 - precision: 0.7193 - recall: 0.5757 - val_accuracy: 0.6584 - val_f1_score: 0.6542 - val_loss: 0.7580 - val_precision: 0.7179 - val_recall: 0.5632 - learning_rate: 3.0000e-05
# Epoch 37/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.6623 - f1_score: 0.6577 - loss: 0.7430 - precision: 0.7165 - recall: 0.5773
# Epoch 37: val_f1_score did not improve from 0.65723
#
# Epoch 37 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 188s 334ms/step - accuracy: 0.6623 - f1_score: 0.6577 - loss: 0.7430 - precision: 0.7165 - recall: 0.5773 - val_accuracy: 0.6584 - val_f1_score: 0.6547 - val_loss: 0.7574 - val_precision: 0.7174 - val_recall: 0.5625 - learning_rate: 3.0000e-05
# Epoch 38/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.6661 - f1_score: 0.6613 - loss: 0.7383 - precision: 0.7190 - recall: 0.5797
# Epoch 38: val_f1_score improved from 0.65723 to 0.65781, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 38: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 38 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 195s 347ms/step - accuracy: 0.6661 - f1_score: 0.6613 - loss: 0.7383 - precision: 0.7190 - recall: 0.5797 - val_accuracy: 0.6625 - val_f1_score: 0.6578 - val_loss: 0.7560 - val_precision: 0.7207 - val_recall: 0.5659 - learning_rate: 3.0000e-05
# Epoch 39/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.6611 - f1_score: 0.6564 - loss: 0.7401 - precision: 0.7177 - recall: 0.5766
# Epoch 39: val_f1_score improved from 0.65781 to 0.65842, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 39: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 39 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 203s 359ms/step - accuracy: 0.6611 - f1_score: 0.6564 - loss: 0.7401 - precision: 0.7177 - recall: 0.5766 - val_accuracy: 0.6639 - val_f1_score: 0.6584 - val_loss: 0.7551 - val_precision: 0.7196 - val_recall: 0.5652 - learning_rate: 3.0000e-05
# Epoch 40/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.6594 - f1_score: 0.6549 - loss: 0.7405 - precision: 0.7143 - recall: 0.5767
# Epoch 40: val_f1_score did not improve from 0.65842
#
# Epoch 40 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 190s 337ms/step - accuracy: 0.6594 - f1_score: 0.6549 - loss: 0.7405 - precision: 0.7143 - recall: 0.5767 - val_accuracy: 0.6652 - val_f1_score: 0.6579 - val_loss: 0.7540 - val_precision: 0.7205 - val_recall: 0.5652 - learning_rate: 3.0000e-05
# Epoch 41/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.6661 - f1_score: 0.6613 - loss: 0.7411 - precision: 0.7150 - recall: 0.5789
# Epoch 41: val_f1_score did not improve from 0.65842
#
# Epoch 41 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 192s 342ms/step - accuracy: 0.6661 - f1_score: 0.6613 - loss: 0.7411 - precision: 0.7150 - recall: 0.5789 - val_accuracy: 0.6649 - val_f1_score: 0.6570 - val_loss: 0.7534 - val_precision: 0.7208 - val_recall: 0.5679 - learning_rate: 3.0000e-05
# Epoch 42/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.6644 - f1_score: 0.6590 - loss: 0.7411 - precision: 0.7185 - recall: 0.5809
# Epoch 42: val_f1_score improved from 0.65842 to 0.65961, saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 42: finished saving model to ConvNeXtSmall_balanced_model_V1.weights.h5
#
# Epoch 42 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 201s 357ms/step - accuracy: 0.6644 - f1_score: 0.6590 - loss: 0.7411 - precision: 0.7185 - recall: 0.5809 - val_accuracy: 0.6632 - val_f1_score: 0.6596 - val_loss: 0.7570 - val_precision: 0.7177 - val_recall: 0.5652 - learning_rate: 3.0000e-05
# Epoch 43/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.6659 - f1_score: 0.6614 - loss: 0.7398 - precision: 0.7166 - recall: 0.5794
# Epoch 43: val_f1_score did not improve from 0.65961
#
# Epoch 43 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 190s 336ms/step - accuracy: 0.6659 - f1_score: 0.6614 - loss: 0.7398 - precision: 0.7166 - recall: 0.5794 - val_accuracy: 0.6649 - val_f1_score: 0.6582 - val_loss: 0.7539 - val_precision: 0.7209 - val_recall: 0.5655 - learning_rate: 3.0000e-05
# Epoch 44/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.6664 - f1_score: 0.6616 - loss: 0.7374 - precision: 0.7151 - recall: 0.5795
# Epoch 44: val_f1_score did not improve from 0.65961
#
# Epoch 44 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 192s 341ms/step - accuracy: 0.6664 - f1_score: 0.6616 - loss: 0.7374 - precision: 0.7151 - recall: 0.5795 - val_accuracy: 0.6625 - val_f1_score: 0.6577 - val_loss: 0.7544 - val_precision: 0.7191 - val_recall: 0.5649 - learning_rate: 3.0000e-05
# Epoch 45/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.6666 - f1_score: 0.6622 - loss: 0.7345 - precision: 0.7216 - recall: 0.5800
# Epoch 45: val_f1_score did not improve from 0.65961
#
# Epoch 45 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 192s 341ms/step - accuracy: 0.6666 - f1_score: 0.6622 - loss: 0.7345 - precision: 0.7216 - recall: 0.5800 - val_accuracy: 0.6645 - val_f1_score: 0.6587 - val_loss: 0.7539 - val_precision: 0.7198 - val_recall: 0.5686 - learning_rate: 3.0000e-05
# Epoch 46/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.6617 - f1_score: 0.6570 - loss: 0.7402 - precision: 0.7169 - recall: 0.5811
# Epoch 46: val_f1_score did not improve from 0.65961
#
# Epoch 46 Learning Rate : 2.9999999242136255e-05
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 192s 341ms/step - accuracy: 0.6617 - f1_score: 0.6570 - loss: 0.7402 - precision: 0.7169 - recall: 0.5811 - val_accuracy: 0.6649 - val_f1_score: 0.6586 - val_loss: 0.7528 - val_precision: 0.7194 - val_recall: 0.5655 - learning_rate: 3.0000e-05
# Epoch 47/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.6660 - f1_score: 0.6612 - loss: 0.7339 - precision: 0.7196 - recall: 0.5847
# Epoch 47: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 47: val_f1_score did not improve from 0.65961
#
# Epoch 47 Learning Rate : 8.999999408842996e-06
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 189s 335ms/step - accuracy: 0.6660 - f1_score: 0.6612 - loss: 0.7339 - precision: 0.7196 - recall: 0.5847 - val_accuracy: 0.6639 - val_f1_score: 0.6580 - val_loss: 0.7524 - val_precision: 0.7209 - val_recall: 0.5672 - learning_rate: 3.0000e-05
# Epoch 48/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.6662 - f1_score: 0.6615 - loss: 0.7375 - precision: 0.7195 - recall: 0.5821
# Epoch 48: val_f1_score did not improve from 0.65961
#
# Epoch 48 Learning Rate : 8.999999408842996e-06
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 191s 339ms/step - accuracy: 0.6662 - f1_score: 0.6615 - loss: 0.7375 - precision: 0.7195 - recall: 0.5821 - val_accuracy: 0.6622 - val_f1_score: 0.6572 - val_loss: 0.7535 - val_precision: 0.7195 - val_recall: 0.5676 - learning_rate: 9.0000e-06
# Epoch 49/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.6670 - f1_score: 0.6622 - loss: 0.7363 - precision: 0.7209 - recall: 0.5844
# Epoch 49: val_f1_score did not improve from 0.65961
#
# Epoch 49 Learning Rate : 8.999999408842996e-06
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 189s 336ms/step - accuracy: 0.6670 - f1_score: 0.6622 - loss: 0.7363 - precision: 0.7209 - recall: 0.5844 - val_accuracy: 0.6639 - val_f1_score: 0.6586 - val_loss: 0.7531 - val_precision: 0.7200 - val_recall: 0.5672 - learning_rate: 9.0000e-06
# Epoch 50/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.6632 - f1_score: 0.6583 - loss: 0.7409 - precision: 0.7145 - recall: 0.5792
# Epoch 50: val_f1_score did not improve from 0.65961
#
# Epoch 50 Learning Rate : 8.999999408842996e-06
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 189s 336ms/step - accuracy: 0.6632 - f1_score: 0.6583 - loss: 0.7409 - precision: 0.7145 - recall: 0.5792 - val_accuracy: 0.6625 - val_f1_score: 0.6574 - val_loss: 0.7533 - val_precision: 0.7206 - val_recall: 0.5689 - learning_rate: 9.0000e-06
# Epoch 51/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.6631 - f1_score: 0.6584 - loss: 0.7387 - precision: 0.7118 - recall: 0.5762
# Epoch 51: val_f1_score did not improve from 0.65961
#
# Epoch 51 Learning Rate : 8.999999408842996e-06
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 188s 334ms/step - accuracy: 0.6631 - f1_score: 0.6584 - loss: 0.7387 - precision: 0.7118 - recall: 0.5762 - val_accuracy: 0.6632 - val_f1_score: 0.6580 - val_loss: 0.7531 - val_precision: 0.7202 - val_recall: 0.5686 - learning_rate: 9.0000e-06
# Epoch 52/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.6657 - f1_score: 0.6611 - loss: 0.7387 - precision: 0.7155 - recall: 0.5784
# Epoch 52: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
#
# Epoch 52: val_f1_score did not improve from 0.65961
#
# Epoch 52 Learning Rate : 2.699999868127634e-06
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 191s 339ms/step - accuracy: 0.6657 - f1_score: 0.6611 - loss: 0.7387 - precision: 0.7155 - recall: 0.5784 - val_accuracy: 0.6645 - val_f1_score: 0.6591 - val_loss: 0.7527 - val_precision: 0.7211 - val_recall: 0.5679 - learning_rate: 9.0000e-06
# Epoch 53/150
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.6623 - f1_score: 0.6576 - loss: 0.7399 - precision: 0.7136 - recall: 0.5792
# Epoch 53: val_f1_score did not improve from 0.65961
#
# Epoch 53 Learning Rate : 2.699999868127634e-06
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 207s 367ms/step - accuracy: 0.6623 - f1_score: 0.6576 - loss: 0.7399 - precision: 0.7136 - recall: 0.5792 - val_accuracy: 0.6645 - val_f1_score: 0.6591 - val_loss: 0.7527 - val_precision: 0.7222 - val_recall: 0.5682 - learning_rate: 2.7000e-06
# Epoch 53: early stopping
# Restoring model weights from the end of the best epoch: 42.
# done

# %%
# 1. Rebuild the model architecture blueprint first
model = get_ConvNeXtSmall()

# 2. Load the weights directly into the blueprint
# Note: .load_weights() does not require a custom_objects dictionary!
model.load_weights("ConvNeXtSmall_balanced_model_V1.weights.h5")

print("Model weights loaded successfully!")
# Out:
# Model weights loaded successfully!
# /home/user7/miniconda3/envs/tf_new/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:869: UserWarning: Skipping variable loading for optimizer 'adam_1', because it has 2 variables whereas the saved optimizer has 6 variables.
#   saveable.load_own_variables(store)

# %%
# ==========================================================
# PLOT LEARNING CURVES (Loss, F1-Score, Precision)
# ==========================================================
print("start")

# 1. Loss Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Train Loss', color='red')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig("ConvNeXtSmall_balanced_Loss_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

# 2. F1 Score Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['f1_score'], label='Train F1-Score', color='blue')
plt.plot(history.history['val_f1_score'], label='Validation F1-Score', color='cyan')

plt.xlabel('Epochs')
plt.ylabel('F1-Score')
plt.legend()
plt.tight_layout()
plt.savefig("ConvNeXtSmall_balanced_F1_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

# 3. Precision Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['precision'], label='Train Precision', color='green')
plt.plot(history.history['val_precision'], label='Validation Precision', color='lightgreen')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.tight_layout()
plt.savefig("ConvNeXtSmall_balanced_Precision_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# EVALUATION (Training, Validation & Testing)
# ==========================================================
print("Evaluating on Training Set...")
train_results = model.evaluate(train_generator)

print("\nEvaluating on Validation Set...")
val_results = model.evaluate(val_generator)

print("\nEvaluating on Testing Set (Truly Unseen)...")
test_results = model.evaluate(test_generator)

# Unpacking 5 values based on the compile metrics order
# Order: [loss, accuracy, f1_score, precision, recall]
train_loss = train_results[0]
train_acc = train_results[1]
train_f1 = train_results[2]
train_precision = train_results[3]
train_recall = train_results[4]

val_loss = val_results[0]
val_acc = val_results[1]
val_f1 = val_results[2]
val_precision = val_results[3]
val_recall = val_results[4]

test_loss = test_results[0]
test_acc = test_results[1]
test_f1 = test_results[2]
test_precision = test_results[3]
test_recall = test_results[4]

print("\n" + "="*40)
print("TRAINING METRICS")
print("="*40)
print(f"Training Loss      : {train_loss:.4f}")
print(f"Training Accuracy  : {train_acc*100:.2f}%")
print(f"Training F1-Score  : {train_f1*100:.2f}%")
print(f"Training Precision : {train_precision*100:.2f}%")
print(f"Training Recall    : {train_recall*100:.2f}%")

print("\n" + "="*40)
print("VALIDATION METRICS")
print("="*40)
print(f"Validation Loss      : {val_loss:.4f}")
print(f"Validation Accuracy  : {val_acc*100:.2f}%")
print(f"Validation F1-Score  : {val_f1*100:.2f}%")
print(f"Validation Precision : {val_precision*100:.2f}%")
print(f"Validation Recall    : {val_recall*100:.2f}%")

print("\n" + "="*40)
print("TESTING METRICS (UNSEEN DATA)")
print("="*40)
print(f"Testing Loss      : {test_loss:.4f}")
print(f"Testing Accuracy  : {test_acc*100:.2f}%")
print(f"Testing F1-Score  : {test_f1*100:.2f}%")
print(f"Testing Precision : {test_precision*100:.2f}%")
print(f"Testing Recall    : {test_recall*100:.2f}%")
# Out:
# Evaluating on Training Set...
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 170s 294ms/step - accuracy: 0.6824 - f1_score: 0.6758 - loss: 0.7075 - precision: 0.7381 - recall: 0.5861
#
# Evaluating on Validation Set...
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 28s 295ms/step - accuracy: 0.6632 - f1_score: 0.6596 - loss: 0.7570 - precision: 0.7177 - recall: 0.5652
#
# Evaluating on Testing Set (Truly Unseen)...
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 66s 713ms/step - accuracy: 0.6520 - f1_score: 0.6501 - loss: 0.7694 - precision: 0.7108 - recall: 0.5588
#
# ========================================
# TRAINING METRICS
# ========================================
# Training Loss      : 0.7075
# Training Accuracy  : 68.24%
# Training F1-Score  : 67.58%
# Training Precision : 73.81%
# Training Recall    : 58.61%
#
# ========================================
# VALIDATION METRICS
# ========================================
# Validation Loss      : 0.7570
# Validation Accuracy  : 66.32%
# Validation F1-Score  : 65.96%
# Validation Precision : 71.77%
# Validation Recall    : 56.52%
#
# ========================================
# TESTING METRICS (UNSEEN DATA)
# ========================================
# Testing Loss      : 0.7694
# Testing Accuracy  : 65.20%
# Testing F1-Score  : 65.01%
# Testing Precision : 71.08%
# Testing Recall    : 55.88%

# %%
# ==========================================================
# PRECISION, RECALL, F1-SCORE (Test Set - Unseen Data)
# ==========================================================
print("\nCalculating Precision, Recall, F1-score on Test Set...")

predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

true_classes = test_generator.classes
class_names = list(test_generator.class_indices.keys())

print("\nClassification Report (Test Set):\n")
print(
    classification_report(
        true_classes,
        predicted_classes,
        target_names=class_names
    )
)

print("done1")
# Out:
# Calculating Precision, Recall, F1-score on Test Set...
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 331ms/step
#
# Classification Report (Test Set):
#
#               precision    recall  f1-score   support
#
#       Benign       0.55      0.54      0.54       910
#    Malignant       0.71      0.64      0.68      1263
#       Normal       0.67      0.80      0.73       787
#
#     accuracy                           0.65      2960
#    macro avg       0.65      0.66      0.65      2960
# weighted avg       0.65      0.65      0.65      2960
#
# done1

# %%
# ==========================================================
# CONFUSION MATRIX (Test Set)
# ==========================================================
print("Generating Confusion Matrix...")

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(true_classes, predicted_classes)

# Plot the confusion matrix using Seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,       # Show the actual numbers inside the squares
    fmt='d',          # Format as whole numbers (integers)
    cmap='Blues',     # Color scheme
    xticklabels=class_names,
    yticklabels=class_names
)


plt.ylabel('True Label', fontsize=14)
plt.xlabel('Predicted Label', fontsize=14)
plt.xticks(rotation=45) # Rotate x-axis labels so they are easier to read
plt.yticks(rotation=0)

plt.tight_layout()
plt.savefig("ConvNeXtSmall_Balanced_confusion_matrix_test.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# Generating Confusion Matrix...
# done1
