# %%
# ==========================================================
# CREATE BALANCED DATASET DIRECTORY
# ==========================================================
print("start")

import os


balanced_dataset = r"D:/Thesis_folder/Preprocessed_Pipeline/Supervised_Imbalanced"



print("Balanced dataset ready")
# Out:
# start
# Balanced dataset ready

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("TensorFlow Version: ", tf.__version__)
# Out:
# Num GPUs Available:  1
# TensorFlow Version:  2.10.0

# %%
# ==========================================================
# IMPORTS
# ==========================================================
print("start")

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetV2S
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint,
    Callback
)

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# CONFIGURATION & GENERATORS
# ==========================================================
print("start")

# Pointing to the Balanced Dataset
DATASET_PATH = r"D:/Thesis_folder/Preprocessed_Pipeline/Supervised_Imbalanced"

IMAGE_SIZE = (288, 288)
MODEL_INPUT_SIZE = (288, 288, 3)
NUM_CLASSES = 3
BATCH_SIZE = 32
EPOCHS = 150

print("done1")
# Out:
# start
# done1

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input

# 1. Define the base generator
datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# 2. Define the paths to your new split folders
train_dir = r"D:/Thesis_folder/Preprocessed_Pipeline/Supervised_Imbalanced/train"
val_dir = r"D:/Thesis_folder/Preprocessed_Pipeline/Supervised_Imbalanced/val"
test_dir = r"D:/Thesis_folder/Preprocessed_Pipeline/Supervised_Imbalanced/test"

# 3. Create the Train Generator
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True # Shuffle training data
)

# 4. Create the Validation Generator
val_generator = datagen.flow_from_directory(
    val_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# 5. Create the Test Generator (CRITICAL: shuffle=False for evaluation)
test_generator = datagen.flow_from_directory(
    test_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 13787 images belonging to 3 classes.
# Found 2942 images belonging to 3 classes.
# Found 3002 images belonging to 3 classes.

# %%
import tensorflow as tf
import tensorflow_addons as tfa
print("start")

# Initializing the metrics, now including Recall
f1_metric = tfa.metrics.F1Score(num_classes=3, average='macro', name='f1_score')
precision_metric = tf.keras.metrics.Precision(name='precision')
recall_metric = tf.keras.metrics.Recall(name='recall') # <-- Added Recall metric

def get_EfficientNetV2S():

    base_model = EfficientNetV2S(
        input_shape=MODEL_INPUT_SIZE,
        weights='imagenet',
        include_top=False
    )

    base_model.trainable = False

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),                
        tf.keras.layers.Dropout(0.3),            
        Dense(NUM_CLASSES, activation='softmax') 
    ])

    # Keep your original optimizer configuration
    optimizer = Adam(learning_rate=0.0001)

    # Compiling with your requested metrics (now including recall)
    model.compile(
        loss="categorical_crossentropy",
        metrics=["accuracy", f1_metric, precision_metric, recall_metric], # <-- Added to compile
        optimizer=optimizer
    )

    return model

model = get_EfficientNetV2S()
model.summary()

print("done1")
# Out:
# start
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetv2-s (Functiona  (None, 9, 9, 1280)       20331360
#  l)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 3)                 3843
#
# =================================================================
# Total params: 20,335,203
# Trainable params: 3,843
# Non-trainable params: 20,331,360
# _________________________________________________________________
# done1

# %%
# ==========================================================
# CALLBACKS (Monitor set to 'val_f1_score')
# ==========================================================
print("start")

early_stop = EarlyStopping(
    monitor='val_f1_score',
    mode='max',
    patience=11,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.3,
    patience=5,
    min_lr=5e-8,
    verbose=1
)

checkpoint = ModelCheckpoint(
"EfficientNetV2S_Imbalanced_model_V1.h5",
    monitor='val_f1_score',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

print("done")
# Out:
# start
# done

# %%
# ==========================================================
# SHOW LEARNING RATE
# ==========================================================
print("start")

class PrintLearningRate(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate.numpy()
        print(f"\nEpoch {epoch+1} Learning Rate : {lr}")

lr_callback = PrintLearningRate()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# TRAINING
# ==========================================================
print("start")

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[
        early_stop,
        reduce_lr,
        checkpoint,
        lr_callback
    ]
)
print("done")
# Out:
# start
# Epoch 1/150
# 431/431 [==============================] - ETA: 0s - loss: 1.0040 - accuracy: 0.4969 - f1_score: 0.4701 - precision: 0.5833 - recall: 0.2688
# Epoch 1: val_f1_score improved from -inf to 0.59308, saving model to EfficientNetV2S_Imbalanced_model_V1.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 135s 297ms/step - loss: 1.0040 - accuracy: 0.4969 - f1_score: 0.4701 - precision: 0.5833 - recall: 0.2688 - val_loss: 0.9027 - val_accuracy: 0.6037 - val_f1_score: 0.5931 - val_precision: 0.7345 - val_recall: 0.3620 - lr: 1.0000e-04
# Epoch 2/150
# 431/431 [==============================] - ETA: 0s - loss: 0.9031 - accuracy: 0.5837 - f1_score: 0.5730 - precision: 0.6732 - recall: 0.3998
# Epoch 2: val_f1_score improved from 0.59308 to 0.60741, saving model to EfficientNetV2S_Imbalanced_model_V1.h5
#
# Epoch 2 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 140s 325ms/step - loss: 0.9031 - accuracy: 0.5837 - f1_score: 0.5730 - precision: 0.6732 - recall: 0.3998 - val_loss: 0.8529 - val_accuracy: 0.6207 - val_f1_score: 0.6074 - val_precision: 0.7237 - val_recall: 0.4415 - lr: 1.0000e-04
# Epoch 3/150
# 431/431 [==============================] - ETA: 0s - loss: 0.8641 - accuracy: 0.5988 - f1_score: 0.5882 - precision: 0.6825 - recall: 0.4529
# Epoch 3: val_f1_score improved from 0.60741 to 0.61644, saving model to EfficientNetV2S_Imbalanced_model_V1.h5
#
# Epoch 3 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 136s 316ms/step - loss: 0.8641 - accuracy: 0.5988 - f1_score: 0.5882 - precision: 0.6825 - recall: 0.4529 - val_loss: 0.8289 - val_accuracy: 0.6339 - val_f1_score: 0.6164 - val_precision: 0.7276 - val_recall: 0.4786 - lr: 1.0000e-04
# Epoch 4/150
# 431/431 [==============================] - ETA: 0s - loss: 0.8385 - accuracy: 0.6135 - f1_score: 0.6019 - precision: 0.6916 - recall: 0.4754
# Epoch 4: val_f1_score improved from 0.61644 to 0.62151, saving model to EfficientNetV2S_Imbalanced_model_V1.h5
#
# Epoch 4 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 136s 316ms/step - loss: 0.8385 - accuracy: 0.6135 - f1_score: 0.6019 - precision: 0.6916 - recall: 0.4754 - val_loss: 0.8093 - val_accuracy: 0.6353 - val_f1_score: 0.6215 - val_precision: 0.7305 - val_recall: 0.5085 - lr: 1.0000e-04
# Epoch 5/150
# 431/431 [==============================] - ETA: 0s - loss: 0.8280 - accuracy: 0.6170 - f1_score: 0.6067 - precision: 0.6926 - recall: 0.4929
# Epoch 5: val_f1_score improved from 0.62151 to 0.62769, saving model to EfficientNetV2S_Imbalanced_model_V1.h5
#
# Epoch 5 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 140s 324ms/step - loss: 0.8280 - accuracy: 0.6170 - f1_score: 0.6067 - precision: 0.6926 - recall: 0.4929 - val_loss: 0.7957 - val_accuracy: 0.6404 - val_f1_score: 0.6277 - val_precision: 0.7337 - val_recall: 0.5170 - lr: 1.0000e-04
# Epoch 6/150
# 431/431 [==============================] - ETA: 0s - loss: 0.8145 - accuracy: 0.6202 - f1_score: 0.6095 - precision: 0.6943 - recall: 0.5060
# Epoch 6: val_f1_score did not improve from 0.62769
#
# Epoch 6 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 129s 299ms/step - loss: 0.8145 - accuracy: 0.6202 - f1_score: 0.6095 - precision: 0.6943 - recall: 0.5060 - val_loss: 0.7930 - val_accuracy: 0.6404 - val_f1_score: 0.6215 - val_precision: 0.7206 - val_recall: 0.5330 - lr: 1.0000e-04
# Epoch 7/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7998 - accuracy: 0.6314 - f1_score: 0.6211 - precision: 0.7048 - recall: 0.5172
# Epoch 7: val_f1_score did not improve from 0.62769
#
# Epoch 7 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 127s 294ms/step - loss: 0.7998 - accuracy: 0.6314 - f1_score: 0.6211 - precision: 0.7048 - recall: 0.5172 - val_loss: 0.7842 - val_accuracy: 0.6390 - val_f1_score: 0.6203 - val_precision: 0.7210 - val_recall: 0.5401 - lr: 1.0000e-04
# Epoch 8/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7971 - accuracy: 0.6299 - f1_score: 0.6187 - precision: 0.7004 - recall: 0.5181
# Epoch 8: val_f1_score improved from 0.62769 to 0.63632, saving model to EfficientNetV2S_Imbalanced_model_V1.h5
#
# Epoch 8 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 137s 318ms/step - loss: 0.7971 - accuracy: 0.6299 - f1_score: 0.6187 - precision: 0.7004 - recall: 0.5181 - val_loss: 0.7746 - val_accuracy: 0.6506 - val_f1_score: 0.6363 - val_precision: 0.7323 - val_recall: 0.5476 - lr: 1.0000e-04
# Epoch 9/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7901 - accuracy: 0.6313 - f1_score: 0.6207 - precision: 0.7043 - recall: 0.5274
# Epoch 9: val_f1_score improved from 0.63632 to 0.64845, saving model to EfficientNetV2S_Imbalanced_model_V1.h5
#
# Epoch 9 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 136s 316ms/step - loss: 0.7901 - accuracy: 0.6313 - f1_score: 0.6207 - precision: 0.7043 - recall: 0.5274 - val_loss: 0.7708 - val_accuracy: 0.6560 - val_f1_score: 0.6484 - val_precision: 0.7385 - val_recall: 0.5557 - lr: 1.0000e-04
# Epoch 10/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7875 - accuracy: 0.6336 - f1_score: 0.6232 - precision: 0.7049 - recall: 0.5318
# Epoch 10: val_f1_score did not improve from 0.64845
#
# Epoch 10 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 128s 297ms/step - loss: 0.7875 - accuracy: 0.6336 - f1_score: 0.6232 - precision: 0.7049 - recall: 0.5318 - val_loss: 0.7652 - val_accuracy: 0.6553 - val_f1_score: 0.6446 - val_precision: 0.7381 - val_recall: 0.5564 - lr: 1.0000e-04
# Epoch 11/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7816 - accuracy: 0.6376 - f1_score: 0.6271 - precision: 0.7063 - recall: 0.5384
# Epoch 11: val_f1_score did not improve from 0.64845
#
# Epoch 11 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 126s 291ms/step - loss: 0.7816 - accuracy: 0.6376 - f1_score: 0.6271 - precision: 0.7063 - recall: 0.5384 - val_loss: 0.7635 - val_accuracy: 0.6496 - val_f1_score: 0.6352 - val_precision: 0.7280 - val_recall: 0.5578 - lr: 1.0000e-04
# Epoch 12/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7785 - accuracy: 0.6366 - f1_score: 0.6259 - precision: 0.7050 - recall: 0.5369
# Epoch 12: val_f1_score did not improve from 0.64845
#
# Epoch 12 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 127s 295ms/step - loss: 0.7785 - accuracy: 0.6366 - f1_score: 0.6259 - precision: 0.7050 - recall: 0.5369 - val_loss: 0.7590 - val_accuracy: 0.6509 - val_f1_score: 0.6381 - val_precision: 0.7344 - val_recall: 0.5602 - lr: 1.0000e-04
# Epoch 13/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7718 - accuracy: 0.6413 - f1_score: 0.6308 - precision: 0.7124 - recall: 0.5441
# Epoch 13: val_f1_score did not improve from 0.64845
#
# Epoch 13 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 129s 300ms/step - loss: 0.7718 - accuracy: 0.6413 - f1_score: 0.6308 - precision: 0.7124 - recall: 0.5441 - val_loss: 0.7545 - val_accuracy: 0.6536 - val_f1_score: 0.6428 - val_precision: 0.7379 - val_recall: 0.5646 - lr: 1.0000e-04
# Epoch 14/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7677 - accuracy: 0.6448 - f1_score: 0.6345 - precision: 0.7091 - recall: 0.5441
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 14: val_f1_score did not improve from 0.64845
#
# Epoch 14 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 131s 304ms/step - loss: 0.7677 - accuracy: 0.6448 - f1_score: 0.6345 - precision: 0.7091 - recall: 0.5441 - val_loss: 0.7533 - val_accuracy: 0.6536 - val_f1_score: 0.6431 - val_precision: 0.7378 - val_recall: 0.5632 - lr: 1.0000e-04
# Epoch 15/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7726 - accuracy: 0.6432 - f1_score: 0.6331 - precision: 0.7099 - recall: 0.5436
# Epoch 15: val_f1_score did not improve from 0.64845
#
# Epoch 15 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 129s 299ms/step - loss: 0.7726 - accuracy: 0.6432 - f1_score: 0.6331 - precision: 0.7099 - recall: 0.5436 - val_loss: 0.7521 - val_accuracy: 0.6526 - val_f1_score: 0.6397 - val_precision: 0.7364 - val_recall: 0.5659 - lr: 3.0000e-05
# Epoch 16/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7696 - accuracy: 0.6420 - f1_score: 0.6311 - precision: 0.7102 - recall: 0.5445
# Epoch 16: val_f1_score did not improve from 0.64845
#
# Epoch 16 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 128s 296ms/step - loss: 0.7696 - accuracy: 0.6420 - f1_score: 0.6311 - precision: 0.7102 - recall: 0.5445 - val_loss: 0.7517 - val_accuracy: 0.6547 - val_f1_score: 0.6422 - val_precision: 0.7346 - val_recall: 0.5683 - lr: 3.0000e-05
# Epoch 17/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7642 - accuracy: 0.6478 - f1_score: 0.6368 - precision: 0.7108 - recall: 0.5475
# Epoch 17: val_f1_score did not improve from 0.64845
#
# Epoch 17 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 131s 303ms/step - loss: 0.7642 - accuracy: 0.6478 - f1_score: 0.6368 - precision: 0.7108 - recall: 0.5475 - val_loss: 0.7500 - val_accuracy: 0.6540 - val_f1_score: 0.6421 - val_precision: 0.7373 - val_recall: 0.5676 - lr: 3.0000e-05
# Epoch 18/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7674 - accuracy: 0.6423 - f1_score: 0.6325 - precision: 0.7106 - recall: 0.5478
# Epoch 18: val_f1_score did not improve from 0.64845
#
# Epoch 18 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 131s 305ms/step - loss: 0.7674 - accuracy: 0.6423 - f1_score: 0.6325 - precision: 0.7106 - recall: 0.5478 - val_loss: 0.7501 - val_accuracy: 0.6540 - val_f1_score: 0.6405 - val_precision: 0.7366 - val_recall: 0.5693 - lr: 3.0000e-05
# Epoch 19/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7673 - accuracy: 0.6423 - f1_score: 0.6315 - precision: 0.7085 - recall: 0.5486
# Epoch 19: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 19: val_f1_score did not improve from 0.64845
#
# Epoch 19 Learning Rate : 8.999999408842996e-06
# 431/431 [==============================] - 130s 302ms/step - loss: 0.7673 - accuracy: 0.6423 - f1_score: 0.6315 - precision: 0.7085 - recall: 0.5486 - val_loss: 0.7495 - val_accuracy: 0.6553 - val_f1_score: 0.6428 - val_precision: 0.7334 - val_recall: 0.5704 - lr: 3.0000e-05
# Epoch 20/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7629 - accuracy: 0.6444 - f1_score: 0.6347 - precision: 0.7167 - recall: 0.5476Restoring model weights from the end of the best epoch: 9.
#
# Epoch 20: val_f1_score did not improve from 0.64845
#
# Epoch 20 Learning Rate : 8.999999408842996e-06
# 431/431 [==============================] - 130s 301ms/step - loss: 0.7629 - accuracy: 0.6444 - f1_score: 0.6347 - precision: 0.7167 - recall: 0.5476 - val_loss: 0.7491 - val_accuracy: 0.6557 - val_f1_score: 0.6432 - val_precision: 0.7351 - val_recall: 0.5717 - lr: 9.0000e-06
# Epoch 20: early stopping
# done

# %%
# 1. Rebuild the model architecture blueprint first
model = get_EfficientNetV2S()

# 2. Load the weights directly into the blueprint
# Note: .load_weights() does not require a custom_objects dictionary!
model.load_weights("EfficientNetV2S_Imbalanced_model_V1.h5")

print("Model weights loaded successfully!")
# Out:
# Model weights loaded successfully!

# %%
# ==========================================================
# PLOT LEARNING CURVES (Loss, F1-Score, Precision)
# ==========================================================
print("start")

# 1. Loss Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Train Loss', color='red')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig("EfficientNetV2S_Imbalanced_Loss_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

# 2. F1 Score Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['f1_score'], label='Train F1-Score', color='blue')
plt.plot(history.history['val_f1_score'], label='Validation F1-Score', color='cyan')

plt.xlabel('Epochs')
plt.ylabel('F1-Score')
plt.legend()
plt.tight_layout()
plt.savefig("EfficientNetV2S_Imbalanced_F1_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

# 3. Precision Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['precision'], label='Train Precision', color='green')
plt.plot(history.history['val_precision'], label='Validation Precision', color='lightgreen')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.tight_layout()
plt.savefig("EfficientNetV2S_Imbalanced_Precision_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# EVALUATION (Training, Validation & Testing)
# ==========================================================
print("Evaluating on Training Set...")
train_results = model.evaluate(train_generator)

print("\nEvaluating on Validation Set...")
val_results = model.evaluate(val_generator)

print("\nEvaluating on Testing Set (Truly Unseen)...")
test_results = model.evaluate(test_generator)

# Unpacking 5 values based on the compile metrics order
# Order: [loss, accuracy, f1_score, precision, recall]
train_loss = train_results[0]
train_acc = train_results[1]
train_f1 = train_results[2]
train_precision = train_results[3]
train_recall = train_results[4]

val_loss = val_results[0]
val_acc = val_results[1]
val_f1 = val_results[2]
val_precision = val_results[3]
val_recall = val_results[4]

test_loss = test_results[0]
test_acc = test_results[1]
test_f1 = test_results[2]
test_precision = test_results[3]
test_recall = test_results[4]

print("\n" + "="*40)
print("TRAINING METRICS")
print("="*40)
print(f"Training Loss      : {train_loss:.4f}")
print(f"Training Accuracy  : {train_acc*100:.2f}%")
print(f"Training F1-Score  : {train_f1*100:.2f}%")
print(f"Training Precision : {train_precision*100:.2f}%")
print(f"Training Recall    : {train_recall*100:.2f}%")

print("\n" + "="*40)
print("VALIDATION METRICS")
print("="*40)
print(f"Validation Loss      : {val_loss:.4f}")
print(f"Validation Accuracy  : {val_acc*100:.2f}%")
print(f"Validation F1-Score  : {val_f1*100:.2f}%")
print(f"Validation Precision : {val_precision*100:.2f}%")
print(f"Validation Recall    : {val_recall*100:.2f}%")

print("\n" + "="*40)
print("TESTING METRICS (UNSEEN DATA)")
print("="*40)
print(f"Testing Loss      : {test_loss:.4f}")
print(f"Testing Accuracy  : {test_acc*100:.2f}%")
print(f"Testing F1-Score  : {test_f1*100:.2f}%")
print(f"Testing Precision : {test_precision*100:.2f}%")
print(f"Testing Recall    : {test_recall*100:.2f}%")
# Out:
# Evaluating on Training Set...
# 431/431 [==============================] - 107s 244ms/step - loss: 0.7540 - accuracy: 0.6595 - f1_score: 0.6527 - precision: 0.7352 - recall: 0.5496
#
# Evaluating on Validation Set...
# 92/92 [==============================] - 22s 238ms/step - loss: 0.7708 - accuracy: 0.6560 - f1_score: 0.6484 - precision: 0.7385 - recall: 0.5557
#
# Evaluating on Testing Set (Truly Unseen)...
# 94/94 [==============================] - 37s 395ms/step - loss: 0.7871 - accuracy: 0.6309 - f1_score: 0.6250 - precision: 0.7019 - recall: 0.5303
#
# ========================================
# TRAINING METRICS
# ========================================
# Training Loss      : 0.7540
# Training Accuracy  : 65.95%
# Training F1-Score  : 65.27%
# Training Precision : 73.52%
# Training Recall    : 54.96%
#
# ========================================
# VALIDATION METRICS
# ========================================
# Validation Loss      : 0.7708
# Validation Accuracy  : 65.60%
# Validation F1-Score  : 64.84%
# Validation Precision : 73.85%
# Validation Recall    : 55.57%
#
# ========================================
# TESTING METRICS (UNSEEN DATA)
# ========================================
# Testing Loss      : 0.7871
# Testing Accuracy  : 63.09%
# Testing F1-Score  : 62.50%
# Testing Precision : 70.19%
# Testing Recall    : 53.03%

# %%
# ==========================================================
# PRECISION, RECALL, F1-SCORE (Test Set - Unseen Data)
# ==========================================================
print("\nCalculating Precision, Recall, F1-score on Test Set...")

predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

true_classes = test_generator.classes
class_names = list(test_generator.class_indices.keys())

print("\nClassification Report (Test Set):\n")
print(
    classification_report(
        true_classes,
        predicted_classes,
        target_names=class_names
    )
)

print("done1")
# Out:
# Calculating Precision, Recall, F1-score on Test Set...
# 94/94 [==============================] - 23s 236ms/step
#
# Classification Report (Test Set):
#
#               precision    recall  f1-score   support
#
#       Benign       0.52      0.49      0.50       924
#    Malignant       0.65      0.72      0.68      1309
#       Normal       0.72      0.66      0.69       769
#
#     accuracy                           0.63      3002
#    macro avg       0.63      0.62      0.63      3002
# weighted avg       0.63      0.63      0.63      3002
#
# done1

# %%
# ==========================================================
# CONFUSION MATRIX (Test Set)
# ==========================================================
print("Generating Confusion Matrix...")

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(true_classes, predicted_classes)

# Plot the confusion matrix using Seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,       # Show the actual numbers inside the squares
    fmt='d',          # Format as whole numbers (integers)
    cmap='Blues',     # Color scheme
    xticklabels=class_names,
    yticklabels=class_names
)


plt.ylabel('True Label', fontsize=14)
plt.xlabel('Predicted Label', fontsize=14)
plt.xticks(rotation=45) # Rotate x-axis labels so they are easier to read
plt.yticks(rotation=0)

plt.tight_layout()
plt.savefig("EfficientNetV2S_Imbalanced_confusion_matrix_test.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# Generating Confusion Matrix...
# done1
