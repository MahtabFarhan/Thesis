# %%
# ==========================================================
# CREATE BALANCED DATASET DIRECTORY
# ==========================================================
print("start")

import os


balanced_dataset = r"D:/Thesis_folder/Preprocessed_Pipeline/Supervised_Balanced"



print("Balanced dataset ready")
# Out:
# start
# Balanced dataset ready

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("TensorFlow Version: ", tf.__version__)
# Out:
# Num GPUs Available:  1
# TensorFlow Version:  2.10.0

# %%
# ==========================================================
# IMPORTS
# ==========================================================
print("start")

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetV2S
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint,
    Callback
)

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# CONFIGURATION & GENERATORS
# ==========================================================
print("start")

# Pointing to the Balanced Dataset
DATASET_PATH = r"D:/Thesis_folder/Preprocessed_Pipeline/Supervised_Balanced"

IMAGE_SIZE = (288, 288)
MODEL_INPUT_SIZE = (288, 288, 3)
NUM_CLASSES = 3
BATCH_SIZE = 32
EPOCHS = 150

print("done1")
# Out:
# start
# done1

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input

# 1. Define the base generator
datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# 2. Define the paths to your new split folders
train_dir = r"D:/Thesis_folder/Preprocessed_Pipeline/Supervised_Balanced/train"
val_dir = r"D:/Thesis_folder/Preprocessed_Pipeline/Supervised_Balanced/val"
test_dir = r"D:/Thesis_folder/Preprocessed_Pipeline/Supervised_Balanced/test"

# 3. Create the Train Generator
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True # Shuffle training data
)

# 4. Create the Validation Generator
val_generator = datagen.flow_from_directory(
    val_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# 5. Create the Test Generator (CRITICAL: shuffle=False for evaluation)
test_generator = datagen.flow_from_directory(
    test_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 18000 images belonging to 3 classes.
# Found 2965 images belonging to 3 classes.
# Found 2943 images belonging to 3 classes.

# %%
import tensorflow as tf
import tensorflow_addons as tfa
print("start")

# Initializing the metrics, now including Recall
f1_metric = tfa.metrics.F1Score(num_classes=3, average='macro', name='f1_score')
precision_metric = tf.keras.metrics.Precision(name='precision')
recall_metric = tf.keras.metrics.Recall(name='recall') # <-- Added Recall metric

def get_EfficientNetV2S():

    base_model = EfficientNetV2S(
        input_shape=MODEL_INPUT_SIZE,
        weights='imagenet',
        include_top=False
    )

    base_model.trainable = False

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),                
        tf.keras.layers.Dropout(0.3),            
        Dense(NUM_CLASSES, activation='softmax') 
    ])

    # Keep your original optimizer configuration
    optimizer = Adam(learning_rate=0.0001)

    # Compiling with your requested metrics (now including recall)
    model.compile(
        loss="categorical_crossentropy",
        metrics=["accuracy", f1_metric, precision_metric, recall_metric], # <-- Added to compile
        optimizer=optimizer
    )

    return model

model = get_EfficientNetV2S()
model.summary()

print("done1")
# Out:
# start
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetv2-s (Functiona  (None, 9, 9, 1280)       20331360
#  l)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 3)                 3843
#
# =================================================================
# Total params: 20,335,203
# Trainable params: 3,843
# Non-trainable params: 20,331,360
# _________________________________________________________________
# done1

# %%
# ==========================================================
# CALLBACKS (Monitor set to 'val_f1_score')
# ==========================================================
print("start")

early_stop = EarlyStopping(
    monitor='val_f1_score',
    mode='max',
    patience=11,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.3,
    patience=5,
    min_lr=5e-8,
    verbose=1
)

checkpoint = ModelCheckpoint(
"EfficientNetV2S_balanced_model_V1.h5",
    monitor='val_f1_score',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

print("done")
# Out:
# start
# done

# %%
# ==========================================================
# SHOW LEARNING RATE
# ==========================================================
print("start")

class PrintLearningRate(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate.numpy()
        print(f"\nEpoch {epoch+1} Learning Rate : {lr}")

lr_callback = PrintLearningRate()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# TRAINING
# ==========================================================
print("start")

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[
        early_stop,
        reduce_lr,
        checkpoint,
        lr_callback
    ]
)
print("done")
# Out:
# start
# Epoch 1/150
# 563/563 [==============================] - ETA: 0s - loss: 1.0303 - accuracy: 0.4709 - f1_score: 0.4703 - precision: 0.5669 - recall: 0.2219
# Epoch 1: val_f1_score improved from -inf to 0.58994, saving model to EfficientNetV2S_balanced_model_V1.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 457s 799ms/step - loss: 1.0303 - accuracy: 0.4709 - f1_score: 0.4703 - precision: 0.5669 - recall: 0.2219 - val_loss: 0.8989 - val_accuracy: 0.5936 - val_f1_score: 0.5899 - val_precision: 0.7184 - val_recall: 0.3777 - lr: 1.0000e-04
# Epoch 2/150
# 563/563 [==============================] - ETA: 0s - loss: 0.9111 - accuracy: 0.5687 - f1_score: 0.5646 - precision: 0.6537 - recall: 0.3882
# Epoch 2: val_f1_score improved from 0.58994 to 0.61499, saving model to EfficientNetV2S_balanced_model_V1.h5
#
# Epoch 2 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 168s 299ms/step - loss: 0.9111 - accuracy: 0.5687 - f1_score: 0.5646 - precision: 0.6537 - recall: 0.3882 - val_loss: 0.8501 - val_accuracy: 0.6185 - val_f1_score: 0.6150 - val_precision: 0.7080 - val_recall: 0.4540 - lr: 1.0000e-04
# Epoch 3/150
# 563/563 [==============================] - ETA: 0s - loss: 0.8625 - accuracy: 0.5967 - f1_score: 0.5921 - precision: 0.6782 - recall: 0.4456
# Epoch 3: val_f1_score improved from 0.61499 to 0.62231, saving model to EfficientNetV2S_balanced_model_V1.h5
#
# Epoch 3 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 169s 299ms/step - loss: 0.8625 - accuracy: 0.5967 - f1_score: 0.5921 - precision: 0.6782 - recall: 0.4456 - val_loss: 0.8231 - val_accuracy: 0.6270 - val_f1_score: 0.6223 - val_precision: 0.7087 - val_recall: 0.4833 - lr: 1.0000e-04
# Epoch 4/150
# 563/563 [==============================] - ETA: 0s - loss: 0.8410 - accuracy: 0.6047 - f1_score: 0.5999 - precision: 0.6791 - recall: 0.4724
# Epoch 4: val_f1_score improved from 0.62231 to 0.63290, saving model to EfficientNetV2S_balanced_model_V1.h5
#
# Epoch 4 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 195s 347ms/step - loss: 0.8410 - accuracy: 0.6047 - f1_score: 0.5999 - precision: 0.6791 - recall: 0.4724 - val_loss: 0.7976 - val_accuracy: 0.6371 - val_f1_score: 0.6329 - val_precision: 0.7204 - val_recall: 0.5022 - lr: 1.0000e-04
# Epoch 5/150
# 563/563 [==============================] - ETA: 0s - loss: 0.8259 - accuracy: 0.6117 - f1_score: 0.6074 - precision: 0.6809 - recall: 0.4887
# Epoch 5: val_f1_score improved from 0.63290 to 0.63518, saving model to EfficientNetV2S_balanced_model_V1.h5
#
# Epoch 5 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 187s 332ms/step - loss: 0.8259 - accuracy: 0.6117 - f1_score: 0.6074 - precision: 0.6809 - recall: 0.4887 - val_loss: 0.7890 - val_accuracy: 0.6398 - val_f1_score: 0.6352 - val_precision: 0.7174 - val_recall: 0.5147 - lr: 1.0000e-04
# Epoch 6/150
# 563/563 [==============================] - ETA: 0s - loss: 0.8117 - accuracy: 0.6190 - f1_score: 0.6148 - precision: 0.6870 - recall: 0.5010
# Epoch 6: val_f1_score improved from 0.63518 to 0.63641, saving model to EfficientNetV2S_balanced_model_V1.h5
#
# Epoch 6 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 168s 298ms/step - loss: 0.8117 - accuracy: 0.6190 - f1_score: 0.6148 - precision: 0.6870 - recall: 0.5010 - val_loss: 0.7789 - val_accuracy: 0.6455 - val_f1_score: 0.6364 - val_precision: 0.7269 - val_recall: 0.5251 - lr: 1.0000e-04
# Epoch 7/150
# 563/563 [==============================] - ETA: 0s - loss: 0.8009 - accuracy: 0.6247 - f1_score: 0.6200 - precision: 0.6948 - recall: 0.5117
# Epoch 7: val_f1_score improved from 0.63641 to 0.64105, saving model to EfficientNetV2S_balanced_model_V1.h5
#
# Epoch 7 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 164s 291ms/step - loss: 0.8009 - accuracy: 0.6247 - f1_score: 0.6200 - precision: 0.6948 - recall: 0.5117 - val_loss: 0.7785 - val_accuracy: 0.6449 - val_f1_score: 0.6411 - val_precision: 0.7134 - val_recall: 0.5214 - lr: 1.0000e-04
# Epoch 8/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7943 - accuracy: 0.6267 - f1_score: 0.6225 - precision: 0.6934 - recall: 0.5194
# Epoch 8: val_f1_score improved from 0.64105 to 0.64305, saving model to EfficientNetV2S_balanced_model_V1.h5
#
# Epoch 8 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 169s 300ms/step - loss: 0.7943 - accuracy: 0.6267 - f1_score: 0.6225 - precision: 0.6934 - recall: 0.5194 - val_loss: 0.7749 - val_accuracy: 0.6449 - val_f1_score: 0.6431 - val_precision: 0.7117 - val_recall: 0.5278 - lr: 1.0000e-04
# Epoch 9/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7881 - accuracy: 0.6307 - f1_score: 0.6269 - precision: 0.6949 - recall: 0.5256
# Epoch 9: val_f1_score did not improve from 0.64305
#
# Epoch 9 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 154s 272ms/step - loss: 0.7881 - accuracy: 0.6307 - f1_score: 0.6269 - precision: 0.6949 - recall: 0.5256 - val_loss: 0.7649 - val_accuracy: 0.6476 - val_f1_score: 0.6396 - val_precision: 0.7221 - val_recall: 0.5356 - lr: 1.0000e-04
# Epoch 10/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7825 - accuracy: 0.6326 - f1_score: 0.6286 - precision: 0.6981 - recall: 0.5298
# Epoch 10: val_f1_score improved from 0.64305 to 0.64567, saving model to EfficientNetV2S_balanced_model_V1.h5
#
# Epoch 10 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 163s 289ms/step - loss: 0.7825 - accuracy: 0.6326 - f1_score: 0.6286 - precision: 0.6981 - recall: 0.5298 - val_loss: 0.7625 - val_accuracy: 0.6503 - val_f1_score: 0.6457 - val_precision: 0.7204 - val_recall: 0.5336 - lr: 1.0000e-04
# Epoch 11/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7768 - accuracy: 0.6386 - f1_score: 0.6346 - precision: 0.7027 - recall: 0.5362
# Epoch 11: val_f1_score improved from 0.64567 to 0.64575, saving model to EfficientNetV2S_balanced_model_V1.h5
#
# Epoch 11 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 164s 291ms/step - loss: 0.7768 - accuracy: 0.6386 - f1_score: 0.6346 - precision: 0.7027 - recall: 0.5362 - val_loss: 0.7562 - val_accuracy: 0.6516 - val_f1_score: 0.6457 - val_precision: 0.7252 - val_recall: 0.5474 - lr: 1.0000e-04
# Epoch 12/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7763 - accuracy: 0.6356 - f1_score: 0.6317 - precision: 0.6981 - recall: 0.5353
# Epoch 12: val_f1_score did not improve from 0.64575
#
# Epoch 12 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 154s 274ms/step - loss: 0.7763 - accuracy: 0.6356 - f1_score: 0.6317 - precision: 0.6981 - recall: 0.5353 - val_loss: 0.7519 - val_accuracy: 0.6526 - val_f1_score: 0.6426 - val_precision: 0.7261 - val_recall: 0.5508 - lr: 1.0000e-04
# Epoch 13/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7719 - accuracy: 0.6376 - f1_score: 0.6336 - precision: 0.7011 - recall: 0.5424
# Epoch 13: val_f1_score improved from 0.64575 to 0.65410, saving model to EfficientNetV2S_balanced_model_V1.h5
#
# Epoch 13 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 163s 289ms/step - loss: 0.7719 - accuracy: 0.6376 - f1_score: 0.6336 - precision: 0.7011 - recall: 0.5424 - val_loss: 0.7542 - val_accuracy: 0.6563 - val_f1_score: 0.6541 - val_precision: 0.7247 - val_recall: 0.5450 - lr: 1.0000e-04
# Epoch 14/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7637 - accuracy: 0.6433 - f1_score: 0.6398 - precision: 0.7071 - recall: 0.5504
# Epoch 14: val_f1_score did not improve from 0.65410
#
# Epoch 14 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 155s 274ms/step - loss: 0.7637 - accuracy: 0.6433 - f1_score: 0.6398 - precision: 0.7071 - recall: 0.5504 - val_loss: 0.7511 - val_accuracy: 0.6526 - val_f1_score: 0.6463 - val_precision: 0.7254 - val_recall: 0.5487 - lr: 1.0000e-04
# Epoch 15/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7625 - accuracy: 0.6447 - f1_score: 0.6413 - precision: 0.7075 - recall: 0.5493
# Epoch 15: val_f1_score did not improve from 0.65410
#
# Epoch 15 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 155s 275ms/step - loss: 0.7625 - accuracy: 0.6447 - f1_score: 0.6413 - precision: 0.7075 - recall: 0.5493 - val_loss: 0.7528 - val_accuracy: 0.6530 - val_f1_score: 0.6467 - val_precision: 0.7231 - val_recall: 0.5433 - lr: 1.0000e-04
# Epoch 16/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7612 - accuracy: 0.6451 - f1_score: 0.6411 - precision: 0.7057 - recall: 0.5502
# Epoch 16: val_f1_score did not improve from 0.65410
#
# Epoch 16 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 152s 270ms/step - loss: 0.7612 - accuracy: 0.6451 - f1_score: 0.6411 - precision: 0.7057 - recall: 0.5502 - val_loss: 0.7494 - val_accuracy: 0.6556 - val_f1_score: 0.6517 - val_precision: 0.7219 - val_recall: 0.5551 - lr: 1.0000e-04
# Epoch 17/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7657 - accuracy: 0.6426 - f1_score: 0.6391 - precision: 0.7005 - recall: 0.5461
# Epoch 17: val_f1_score did not improve from 0.65410
#
# Epoch 17 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 154s 273ms/step - loss: 0.7657 - accuracy: 0.6426 - f1_score: 0.6391 - precision: 0.7005 - recall: 0.5461 - val_loss: 0.7479 - val_accuracy: 0.6556 - val_f1_score: 0.6517 - val_precision: 0.7222 - val_recall: 0.5470 - lr: 1.0000e-04
# Epoch 18/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7576 - accuracy: 0.6493 - f1_score: 0.6455 - precision: 0.7092 - recall: 0.5535
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 18: val_f1_score did not improve from 0.65410
#
# Epoch 18 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 153s 272ms/step - loss: 0.7576 - accuracy: 0.6493 - f1_score: 0.6455 - precision: 0.7092 - recall: 0.5535 - val_loss: 0.7423 - val_accuracy: 0.6587 - val_f1_score: 0.6492 - val_precision: 0.7308 - val_recall: 0.5585 - lr: 1.0000e-04
# Epoch 19/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7572 - accuracy: 0.6501 - f1_score: 0.6463 - precision: 0.7065 - recall: 0.5555
# Epoch 19: val_f1_score did not improve from 0.65410
#
# Epoch 19 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 153s 271ms/step - loss: 0.7572 - accuracy: 0.6501 - f1_score: 0.6463 - precision: 0.7065 - recall: 0.5555 - val_loss: 0.7447 - val_accuracy: 0.6570 - val_f1_score: 0.6531 - val_precision: 0.7237 - val_recall: 0.5548 - lr: 3.0000e-05
# Epoch 20/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7593 - accuracy: 0.6407 - f1_score: 0.6371 - precision: 0.7007 - recall: 0.5504
# Epoch 20: val_f1_score did not improve from 0.65410
#
# Epoch 20 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 153s 271ms/step - loss: 0.7593 - accuracy: 0.6407 - f1_score: 0.6371 - precision: 0.7007 - recall: 0.5504 - val_loss: 0.7426 - val_accuracy: 0.6573 - val_f1_score: 0.6520 - val_precision: 0.7270 - val_recall: 0.5551 - lr: 3.0000e-05
# Epoch 21/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7551 - accuracy: 0.6479 - f1_score: 0.6447 - precision: 0.7079 - recall: 0.5553
# Epoch 21: val_f1_score did not improve from 0.65410
#
# Epoch 21 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 155s 276ms/step - loss: 0.7551 - accuracy: 0.6479 - f1_score: 0.6447 - precision: 0.7079 - recall: 0.5553 - val_loss: 0.7426 - val_accuracy: 0.6587 - val_f1_score: 0.6519 - val_precision: 0.7261 - val_recall: 0.5562 - lr: 3.0000e-05
# Epoch 22/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7586 - accuracy: 0.6483 - f1_score: 0.6447 - precision: 0.7079 - recall: 0.5537
# Epoch 22: val_f1_score did not improve from 0.65410
#
# Epoch 22 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 154s 274ms/step - loss: 0.7586 - accuracy: 0.6483 - f1_score: 0.6447 - precision: 0.7079 - recall: 0.5537 - val_loss: 0.7420 - val_accuracy: 0.6583 - val_f1_score: 0.6513 - val_precision: 0.7280 - val_recall: 0.5589 - lr: 3.0000e-05
# Epoch 23/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7521 - accuracy: 0.6502 - f1_score: 0.6464 - precision: 0.7085 - recall: 0.5551
# Epoch 23: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 23: val_f1_score did not improve from 0.65410
#
# Epoch 23 Learning Rate : 8.999999408842996e-06
# 563/563 [==============================] - 159s 282ms/step - loss: 0.7521 - accuracy: 0.6502 - f1_score: 0.6464 - precision: 0.7085 - recall: 0.5551 - val_loss: 0.7433 - val_accuracy: 0.6570 - val_f1_score: 0.6506 - val_precision: 0.7254 - val_recall: 0.5541 - lr: 3.0000e-05
# Epoch 24/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7567 - accuracy: 0.6505 - f1_score: 0.6468 - precision: 0.7090 - recall: 0.5578Restoring model weights from the end of the best epoch: 13.
#
# Epoch 24: val_f1_score did not improve from 0.65410
#
# Epoch 24 Learning Rate : 8.999999408842996e-06
# 563/563 [==============================] - 158s 280ms/step - loss: 0.7567 - accuracy: 0.6505 - f1_score: 0.6468 - precision: 0.7090 - recall: 0.5578 - val_loss: 0.7422 - val_accuracy: 0.6587 - val_f1_score: 0.6531 - val_precision: 0.7285 - val_recall: 0.5565 - lr: 9.0000e-06
# Epoch 24: early stopping
# done

# %%
# 1. Rebuild the model architecture blueprint first
model = get_EfficientNetV2S()

# 2. Load the weights directly into the blueprint
# Note: .load_weights() does not require a custom_objects dictionary!
model.load_weights("EfficientNetV2S_balanced_model_V1.h5")

print("Model weights loaded successfully!")
# Out:
# Model weights loaded successfully!

# %%
# ==========================================================
# PLOT LEARNING CURVES (Loss, F1-Score, Precision)
# ==========================================================
print("start")

# 1. Loss Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Train Loss', color='red')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig("EfficientNetV2S_balanced_Loss_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

# 2. F1 Score Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['f1_score'], label='Train F1-Score', color='blue')
plt.plot(history.history['val_f1_score'], label='Validation F1-Score', color='cyan')

plt.xlabel('Epochs')
plt.ylabel('F1-Score')
plt.legend()
plt.tight_layout()
plt.savefig("EfficientNetV2S_balanced_F1_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

# 3. Precision Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['precision'], label='Train Precision', color='green')
plt.plot(history.history['val_precision'], label='Validation Precision', color='lightgreen')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.tight_layout()
plt.savefig("EfficientNetV2S_balanced_Precision_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# EVALUATION (Training, Validation & Testing)
# ==========================================================
print("Evaluating on Training Set...")
train_results = model.evaluate(train_generator)

print("\nEvaluating on Validation Set...")
val_results = model.evaluate(val_generator)

print("\nEvaluating on Testing Set (Truly Unseen)...")
test_results = model.evaluate(test_generator)

# Unpacking 5 values based on the compile metrics order
# Order: [loss, accuracy, f1_score, precision, recall]
train_loss = train_results[0]
train_acc = train_results[1]
train_f1 = train_results[2]
train_precision = train_results[3]
train_recall = train_results[4]

val_loss = val_results[0]
val_acc = val_results[1]
val_f1 = val_results[2]
val_precision = val_results[3]
val_recall = val_results[4]

test_loss = test_results[0]
test_acc = test_results[1]
test_f1 = test_results[2]
test_precision = test_results[3]
test_recall = test_results[4]

print("\n" + "="*40)
print("TRAINING METRICS")
print("="*40)
print(f"Training Loss      : {train_loss:.4f}")
print(f"Training Accuracy  : {train_acc*100:.2f}%")
print(f"Training F1-Score  : {train_f1*100:.2f}%")
print(f"Training Precision : {train_precision*100:.2f}%")
print(f"Training Recall    : {train_recall*100:.2f}%")

print("\n" + "="*40)
print("VALIDATION METRICS")
print("="*40)
print(f"Validation Loss      : {val_loss:.4f}")
print(f"Validation Accuracy  : {val_acc*100:.2f}%")
print(f"Validation F1-Score  : {val_f1*100:.2f}%")
print(f"Validation Precision : {val_precision*100:.2f}%")
print(f"Validation Recall    : {val_recall*100:.2f}%")

print("\n" + "="*40)
print("TESTING METRICS (UNSEEN DATA)")
print("="*40)
print(f"Testing Loss      : {test_loss:.4f}")
print(f"Testing Accuracy  : {test_acc*100:.2f}%")
print(f"Testing F1-Score  : {test_f1*100:.2f}%")
print(f"Testing Precision : {test_precision*100:.2f}%")
print(f"Testing Recall    : {test_recall*100:.2f}%")
# Out:
# Evaluating on Training Set...
# 563/563 [==============================] - 131s 230ms/step - loss: 0.7285 - accuracy: 0.6642 - f1_score: 0.6617 - precision: 0.7355 - recall: 0.5588
#
# Evaluating on Validation Set...
# 93/93 [==============================] - 22s 233ms/step - loss: 0.7542 - accuracy: 0.6563 - f1_score: 0.6541 - precision: 0.7247 - recall: 0.5450
#
# Evaluating on Testing Set (Truly Unseen)...
# 92/92 [==============================] - 36s 392ms/step - loss: 0.7761 - accuracy: 0.6256 - f1_score: 0.6210 - precision: 0.7020 - recall: 0.5202
#
# ========================================
# TRAINING METRICS
# ========================================
# Training Loss      : 0.7285
# Training Accuracy  : 66.42%
# Training F1-Score  : 66.17%
# Training Precision : 73.55%
# Training Recall    : 55.88%
#
# ========================================
# VALIDATION METRICS
# ========================================
# Validation Loss      : 0.7542
# Validation Accuracy  : 65.63%
# Validation F1-Score  : 65.41%
# Validation Precision : 72.47%
# Validation Recall    : 54.50%
#
# ========================================
# TESTING METRICS (UNSEEN DATA)
# ========================================
# Testing Loss      : 0.7761
# Testing Accuracy  : 62.56%
# Testing F1-Score  : 62.10%
# Testing Precision : 70.20%
# Testing Recall    : 52.02%

# %%
# ==========================================================
# PRECISION, RECALL, F1-SCORE (Test Set - Unseen Data)
# ==========================================================
print("\nCalculating Precision, Recall, F1-score on Test Set...")

predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

true_classes = test_generator.classes
class_names = list(test_generator.class_indices.keys())

print("\nClassification Report (Test Set):\n")
print(
    classification_report(
        true_classes,
        predicted_classes,
        target_names=class_names
    )
)

print("done1")
# Out:
# Calculating Precision, Recall, F1-score on Test Set...
# 92/92 [==============================] - 22s 229ms/step
#
# Classification Report (Test Set):
#
#               precision    recall  f1-score   support
#
#       Benign       0.50      0.49      0.49       888
#    Malignant       0.69      0.65      0.67      1266
#       Normal       0.66      0.74      0.70       789
#
#     accuracy                           0.63      2943
#    macro avg       0.62      0.63      0.62      2943
# weighted avg       0.63      0.63      0.62      2943
#
# done1

# %%
# ==========================================================
# CONFUSION MATRIX (Test Set)
# ==========================================================
print("Generating Confusion Matrix...")

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(true_classes, predicted_classes)

# Plot the confusion matrix using Seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,       # Show the actual numbers inside the squares
    fmt='d',          # Format as whole numbers (integers)
    cmap='Blues',     # Color scheme
    xticklabels=class_names,
    yticklabels=class_names
)


plt.ylabel('True Label', fontsize=14)
plt.xlabel('Predicted Label', fontsize=14)
plt.xticks(rotation=45) # Rotate x-axis labels so they are easier to read
plt.yticks(rotation=0)

plt.tight_layout()
plt.savefig("EfficientNetV2S_balanced_confusion_matrix_test.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# Generating Confusion Matrix...
# done1
