# %%
# ==========================================================
# CREATE BALANCED DATASET DIRECTORY
# ==========================================================
print("start")

import os





print("Balanced dataset ready")
# Out:
# start
# Balanced dataset ready

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("TensorFlow Version: ", tf.__version__)
# Out:
# Num GPUs Available:  1
# TensorFlow Version:  2.10.0

# %%
# ==========================================================
# IMPORTS
# ==========================================================
print("start")

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall
import tensorflow_addons as tfa
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint,
    Callback
)

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# CONFIGURATION & GENERATORS
# ==========================================================
print("start")

# Pointing to the Balanced Dataset
DATASET_PATH = r"D:\Thesis_folder\Preprocessed_Pipeline\Supervised_Balanced"

IMAGE_SIZE = (288, 288)
MODEL_INPUT_SIZE = (288, 288, 3)
NUM_CLASSES = 3
BATCH_SIZE = 32
EPOCHS = 150

print("done1")
# Out:
# start
# done1

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import preprocess_input

# 1. Define the base generator
datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# 2. Define the paths to your new split folders
train_dir = r"D:\Thesis_folder\Preprocessed_Pipeline\Supervised_Balanced\train"
val_dir = r"D:\Thesis_folder\Preprocessed_Pipeline\Supervised_Balanced\val"
test_dir = r"D:\Thesis_folder\Preprocessed_Pipeline\Supervised_Balanced\test"

# 3. Create the Train Generator
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True # Shuffle training data
)

# 4. Create the Validation Generator
val_generator = datagen.flow_from_directory(
    val_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# 5. Create the Test Generator (CRITICAL: shuffle=False for evaluation)
test_generator = datagen.flow_from_directory(
    test_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 18000 images belonging to 3 classes.
# Found 2965 images belonging to 3 classes.
# Found 2943 images belonging to 3 classes.

# %%
import tensorflow as tf

print("start")

# Initializing the metrics, now including Recall
f1_metric = tfa.metrics.F1Score(num_classes=3, average='macro', name='f1_score')
precision_metric = tf.keras.metrics.Precision(name='precision')
recall_metric = tf.keras.metrics.Recall(name='recall') # <-- Added Recall metric

def get_EfficientNetB3():

    base_model = EfficientNetB3(
        input_shape=MODEL_INPUT_SIZE,
        weights='imagenet',
        include_top=False
    )
    
    base_model.trainable = False

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),                
        tf.keras.layers.Dropout(0.3),            
        Dense(NUM_CLASSES, activation='softmax') 
    ])

    # Keep your original optimizer configuration
    optimizer = Adam(learning_rate=0.0001)

    # Compiling with your requested metrics (now including recall)
    model.compile(
        loss="categorical_crossentropy",
        metrics=["accuracy", f1_metric, precision_metric, recall_metric], # <-- Added to compile
        optimizer=optimizer
    )

    return model

model = get_EfficientNetB3()
model.summary()

print("done1")
# Out:
# start
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb3 (Functional)  (None, 9, 9, 1536)       10783535
#
#  global_average_pooling2d (G  (None, 1536)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1536)              0
#
#  dense (Dense)               (None, 3)                 4611
#
# =================================================================
# Total params: 10,788,146
# Trainable params: 4,611
# Non-trainable params: 10,783,535
# _________________________________________________________________
# done1

# %%
# ==========================================================
# CALLBACKS (Monitor set to 'val_f1_score')
# ==========================================================
print("start")

early_stop = EarlyStopping(
    monitor='val_f1_score',
    mode='max',
    patience=11,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.3,
    patience=5,
    min_lr=5e-8,
    verbose=1
)

checkpoint = ModelCheckpoint(
"EfficientnetB3_balanced_model_V2.h5",
    monitor='val_f1_score',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

print("done")
# Out:
# start
# done

# %%
# ==========================================================
# SHOW LEARNING RATE
# ==========================================================
print("start")

class PrintLearningRate(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate.numpy()
        print(f"\nEpoch {epoch+1} Learning Rate : {lr}")

lr_callback = PrintLearningRate()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# TRAINING
# ==========================================================
print("start")

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[
        early_stop,
        reduce_lr,
        checkpoint,
        lr_callback
    ]
)
print("done")
# Out:
# start
# Epoch 1/150
# 563/563 [==============================] - ETA: 0s - loss: 1.0082 - accuracy: 0.4889 - f1_score: 0.4866 - precision: 0.5749 - recall: 0.2642
# Epoch 1: val_f1_score improved from -inf to 0.58709, saving model to EfficientnetB3_balanced_model_V2.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 503s 884ms/step - loss: 1.0082 - accuracy: 0.4889 - f1_score: 0.4866 - precision: 0.5749 - recall: 0.2642 - val_loss: 0.8972 - val_accuracy: 0.5895 - val_f1_score: 0.5871 - val_precision: 0.6931 - val_recall: 0.4074 - lr: 1.0000e-04
# Epoch 2/150
# 563/563 [==============================] - ETA: 0s - loss: 0.8820 - accuracy: 0.5812 - f1_score: 0.5756 - precision: 0.6588 - recall: 0.4261
# Epoch 2: val_f1_score improved from 0.58709 to 0.61697, saving model to EfficientnetB3_balanced_model_V2.h5
#
# Epoch 2 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 160s 284ms/step - loss: 0.8820 - accuracy: 0.5812 - f1_score: 0.5756 - precision: 0.6588 - recall: 0.4261 - val_loss: 0.8385 - val_accuracy: 0.6219 - val_f1_score: 0.6170 - val_precision: 0.7090 - val_recall: 0.4708 - lr: 1.0000e-04
# Epoch 3/150
# 563/563 [==============================] - ETA: 0s - loss: 0.8395 - accuracy: 0.6037 - f1_score: 0.5978 - precision: 0.6722 - recall: 0.4752
# Epoch 3: val_f1_score improved from 0.61697 to 0.62676, saving model to EfficientnetB3_balanced_model_V2.h5
#
# Epoch 3 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 160s 283ms/step - loss: 0.8395 - accuracy: 0.6037 - f1_score: 0.5978 - precision: 0.6722 - recall: 0.4752 - val_loss: 0.8109 - val_accuracy: 0.6354 - val_f1_score: 0.6268 - val_precision: 0.7109 - val_recall: 0.5025 - lr: 1.0000e-04
# Epoch 4/150
# 563/563 [==============================] - ETA: 0s - loss: 0.8127 - accuracy: 0.6183 - f1_score: 0.6126 - precision: 0.6824 - recall: 0.5002
# Epoch 4: val_f1_score did not improve from 0.62676
#
# Epoch 4 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 156s 276ms/step - loss: 0.8127 - accuracy: 0.6183 - f1_score: 0.6126 - precision: 0.6824 - recall: 0.5002 - val_loss: 0.7896 - val_accuracy: 0.6368 - val_f1_score: 0.6229 - val_precision: 0.7136 - val_recall: 0.5184 - lr: 1.0000e-04
# Epoch 5/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7955 - accuracy: 0.6311 - f1_score: 0.6258 - precision: 0.6949 - recall: 0.5208
# Epoch 5: val_f1_score improved from 0.62676 to 0.63575, saving model to EfficientnetB3_balanced_model_V2.h5
#
# Epoch 5 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 162s 287ms/step - loss: 0.7955 - accuracy: 0.6311 - f1_score: 0.6258 - precision: 0.6949 - recall: 0.5208 - val_loss: 0.7763 - val_accuracy: 0.6438 - val_f1_score: 0.6357 - val_precision: 0.7178 - val_recall: 0.5352 - lr: 1.0000e-04
# Epoch 6/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7813 - accuracy: 0.6345 - f1_score: 0.6291 - precision: 0.7005 - recall: 0.5342
# Epoch 6: val_f1_score improved from 0.63575 to 0.63864, saving model to EfficientnetB3_balanced_model_V2.h5
#
# Epoch 6 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 159s 281ms/step - loss: 0.7813 - accuracy: 0.6345 - f1_score: 0.6291 - precision: 0.7005 - recall: 0.5342 - val_loss: 0.7661 - val_accuracy: 0.6452 - val_f1_score: 0.6386 - val_precision: 0.7213 - val_recall: 0.5369 - lr: 1.0000e-04
# Epoch 7/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7701 - accuracy: 0.6405 - f1_score: 0.6354 - precision: 0.7043 - recall: 0.5351
# Epoch 7: val_f1_score did not improve from 0.63864
#
# Epoch 7 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 151s 268ms/step - loss: 0.7701 - accuracy: 0.6405 - f1_score: 0.6354 - precision: 0.7043 - recall: 0.5351 - val_loss: 0.7575 - val_accuracy: 0.6438 - val_f1_score: 0.6325 - val_precision: 0.7246 - val_recall: 0.5474 - lr: 1.0000e-04
# Epoch 8/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7650 - accuracy: 0.6420 - f1_score: 0.6371 - precision: 0.7044 - recall: 0.5449
# Epoch 8: val_f1_score did not improve from 0.63864
#
# Epoch 8 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 153s 272ms/step - loss: 0.7650 - accuracy: 0.6420 - f1_score: 0.6371 - precision: 0.7044 - recall: 0.5449 - val_loss: 0.7523 - val_accuracy: 0.6472 - val_f1_score: 0.6371 - val_precision: 0.7215 - val_recall: 0.5487 - lr: 1.0000e-04
# Epoch 9/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7574 - accuracy: 0.6490 - f1_score: 0.6443 - precision: 0.7082 - recall: 0.5547
# Epoch 9: val_f1_score improved from 0.63864 to 0.64551, saving model to EfficientnetB3_balanced_model_V2.h5
#
# Epoch 9 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 159s 282ms/step - loss: 0.7574 - accuracy: 0.6490 - f1_score: 0.6443 - precision: 0.7082 - recall: 0.5547 - val_loss: 0.7468 - val_accuracy: 0.6499 - val_f1_score: 0.6455 - val_precision: 0.7244 - val_recall: 0.5531 - lr: 1.0000e-04
# Epoch 10/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7535 - accuracy: 0.6449 - f1_score: 0.6401 - precision: 0.7079 - recall: 0.5505
# Epoch 10: val_f1_score improved from 0.64551 to 0.64764, saving model to EfficientnetB3_balanced_model_V2.h5
#
# Epoch 10 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 159s 281ms/step - loss: 0.7535 - accuracy: 0.6449 - f1_score: 0.6401 - precision: 0.7079 - recall: 0.5505 - val_loss: 0.7474 - val_accuracy: 0.6516 - val_f1_score: 0.6476 - val_precision: 0.7155 - val_recall: 0.5599 - lr: 1.0000e-04
# Epoch 11/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7448 - accuracy: 0.6560 - f1_score: 0.6511 - precision: 0.7157 - recall: 0.5627
# Epoch 11: val_f1_score improved from 0.64764 to 0.64850, saving model to EfficientnetB3_balanced_model_V2.h5
#
# Epoch 11 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 162s 286ms/step - loss: 0.7448 - accuracy: 0.6560 - f1_score: 0.6511 - precision: 0.7157 - recall: 0.5627 - val_loss: 0.7447 - val_accuracy: 0.6519 - val_f1_score: 0.6485 - val_precision: 0.7134 - val_recall: 0.5582 - lr: 1.0000e-04
# Epoch 12/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7437 - accuracy: 0.6562 - f1_score: 0.6514 - precision: 0.7170 - recall: 0.5643
# Epoch 12: val_f1_score improved from 0.64850 to 0.64935, saving model to EfficientnetB3_balanced_model_V2.h5
#
# Epoch 12 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 160s 283ms/step - loss: 0.7437 - accuracy: 0.6562 - f1_score: 0.6514 - precision: 0.7170 - recall: 0.5643 - val_loss: 0.7360 - val_accuracy: 0.6556 - val_f1_score: 0.6494 - val_precision: 0.7234 - val_recall: 0.5609 - lr: 1.0000e-04
# Epoch 13/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7363 - accuracy: 0.6600 - f1_score: 0.6551 - precision: 0.7176 - recall: 0.5677
# Epoch 13: val_f1_score did not improve from 0.64935
#
# Epoch 13 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 158s 280ms/step - loss: 0.7363 - accuracy: 0.6600 - f1_score: 0.6551 - precision: 0.7176 - recall: 0.5677 - val_loss: 0.7357 - val_accuracy: 0.6533 - val_f1_score: 0.6457 - val_precision: 0.7195 - val_recall: 0.5605 - lr: 1.0000e-04
# Epoch 14/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7343 - accuracy: 0.6592 - f1_score: 0.6550 - precision: 0.7174 - recall: 0.5703
# Epoch 14: val_f1_score did not improve from 0.64935
#
# Epoch 14 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 153s 271ms/step - loss: 0.7343 - accuracy: 0.6592 - f1_score: 0.6550 - precision: 0.7174 - recall: 0.5703 - val_loss: 0.7340 - val_accuracy: 0.6506 - val_f1_score: 0.6422 - val_precision: 0.7173 - val_recall: 0.5683 - lr: 1.0000e-04
# Epoch 15/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7305 - accuracy: 0.6618 - f1_score: 0.6573 - precision: 0.7194 - recall: 0.5716
# Epoch 15: val_f1_score did not improve from 0.64935
#
# Epoch 15 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 155s 276ms/step - loss: 0.7305 - accuracy: 0.6618 - f1_score: 0.6573 - precision: 0.7194 - recall: 0.5716 - val_loss: 0.7318 - val_accuracy: 0.6526 - val_f1_score: 0.6472 - val_precision: 0.7166 - val_recall: 0.5680 - lr: 1.0000e-04
# Epoch 16/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7279 - accuracy: 0.6616 - f1_score: 0.6573 - precision: 0.7225 - recall: 0.5763
# Epoch 16: val_f1_score improved from 0.64935 to 0.65858, saving model to EfficientnetB3_balanced_model_V2.h5
#
# Epoch 16 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 162s 288ms/step - loss: 0.7279 - accuracy: 0.6616 - f1_score: 0.6573 - precision: 0.7225 - recall: 0.5763 - val_loss: 0.7279 - val_accuracy: 0.6607 - val_f1_score: 0.6586 - val_precision: 0.7251 - val_recall: 0.5666 - lr: 1.0000e-04
# Epoch 17/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7235 - accuracy: 0.6659 - f1_score: 0.6615 - precision: 0.7231 - recall: 0.5793
# Epoch 17: val_f1_score did not improve from 0.65858
#
# Epoch 17 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 153s 271ms/step - loss: 0.7235 - accuracy: 0.6659 - f1_score: 0.6615 - precision: 0.7231 - recall: 0.5793 - val_loss: 0.7326 - val_accuracy: 0.6509 - val_f1_score: 0.6510 - val_precision: 0.7104 - val_recall: 0.5619 - lr: 1.0000e-04
# Epoch 18/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7217 - accuracy: 0.6636 - f1_score: 0.6596 - precision: 0.7207 - recall: 0.5778
# Epoch 18: val_f1_score did not improve from 0.65858
#
# Epoch 18 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 152s 270ms/step - loss: 0.7217 - accuracy: 0.6636 - f1_score: 0.6596 - precision: 0.7207 - recall: 0.5778 - val_loss: 0.7262 - val_accuracy: 0.6556 - val_f1_score: 0.6492 - val_precision: 0.7175 - val_recall: 0.5723 - lr: 1.0000e-04
# Epoch 19/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7216 - accuracy: 0.6679 - f1_score: 0.6635 - precision: 0.7237 - recall: 0.5822
# Epoch 19: val_f1_score did not improve from 0.65858
#
# Epoch 19 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 151s 268ms/step - loss: 0.7216 - accuracy: 0.6679 - f1_score: 0.6635 - precision: 0.7237 - recall: 0.5822 - val_loss: 0.7245 - val_accuracy: 0.6577 - val_f1_score: 0.6519 - val_precision: 0.7191 - val_recall: 0.5723 - lr: 1.0000e-04
# Epoch 20/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7168 - accuracy: 0.6660 - f1_score: 0.6616 - precision: 0.7237 - recall: 0.5855
# Epoch 20: val_f1_score did not improve from 0.65858
#
# Epoch 20 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 152s 271ms/step - loss: 0.7168 - accuracy: 0.6660 - f1_score: 0.6616 - precision: 0.7237 - recall: 0.5855 - val_loss: 0.7210 - val_accuracy: 0.6597 - val_f1_score: 0.6533 - val_precision: 0.7206 - val_recall: 0.5723 - lr: 1.0000e-04
# Epoch 21/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7149 - accuracy: 0.6711 - f1_score: 0.6667 - precision: 0.7232 - recall: 0.5846
# Epoch 21: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 21: val_f1_score did not improve from 0.65858
#
# Epoch 21 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 151s 268ms/step - loss: 0.7149 - accuracy: 0.6711 - f1_score: 0.6667 - precision: 0.7232 - recall: 0.5846 - val_loss: 0.7202 - val_accuracy: 0.6624 - val_f1_score: 0.6576 - val_precision: 0.7250 - val_recall: 0.5727 - lr: 1.0000e-04
# Epoch 22/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7125 - accuracy: 0.6749 - f1_score: 0.6713 - precision: 0.7306 - recall: 0.5903
# Epoch 22: val_f1_score did not improve from 0.65858
#
# Epoch 22 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 152s 271ms/step - loss: 0.7125 - accuracy: 0.6749 - f1_score: 0.6713 - precision: 0.7306 - recall: 0.5903 - val_loss: 0.7186 - val_accuracy: 0.6594 - val_f1_score: 0.6525 - val_precision: 0.7251 - val_recall: 0.5747 - lr: 3.0000e-05
# Epoch 23/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7106 - accuracy: 0.6708 - f1_score: 0.6664 - precision: 0.7278 - recall: 0.5892
# Epoch 23: val_f1_score did not improve from 0.65858
#
# Epoch 23 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 152s 269ms/step - loss: 0.7106 - accuracy: 0.6708 - f1_score: 0.6664 - precision: 0.7278 - recall: 0.5892 - val_loss: 0.7163 - val_accuracy: 0.6641 - val_f1_score: 0.6575 - val_precision: 0.7297 - val_recall: 0.5764 - lr: 3.0000e-05
# Epoch 24/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7161 - accuracy: 0.6718 - f1_score: 0.6682 - precision: 0.7243 - recall: 0.5878
# Epoch 24: val_f1_score did not improve from 0.65858
#
# Epoch 24 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 152s 270ms/step - loss: 0.7161 - accuracy: 0.6718 - f1_score: 0.6682 - precision: 0.7243 - recall: 0.5878 - val_loss: 0.7190 - val_accuracy: 0.6570 - val_f1_score: 0.6500 - val_precision: 0.7242 - val_recall: 0.5720 - lr: 3.0000e-05
# Epoch 25/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7129 - accuracy: 0.6703 - f1_score: 0.6661 - precision: 0.7274 - recall: 0.5875
# Epoch 25: val_f1_score did not improve from 0.65858
#
# Epoch 25 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 148s 263ms/step - loss: 0.7129 - accuracy: 0.6703 - f1_score: 0.6661 - precision: 0.7274 - recall: 0.5875 - val_loss: 0.7174 - val_accuracy: 0.6590 - val_f1_score: 0.6526 - val_precision: 0.7243 - val_recall: 0.5761 - lr: 3.0000e-05
# Epoch 26/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7100 - accuracy: 0.6748 - f1_score: 0.6711 - precision: 0.7273 - recall: 0.5913
# Epoch 26: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 26: val_f1_score did not improve from 0.65858
#
# Epoch 26 Learning Rate : 8.999999408842996e-06
# 563/563 [==============================] - 184s 327ms/step - loss: 0.7100 - accuracy: 0.6748 - f1_score: 0.6711 - precision: 0.7273 - recall: 0.5913 - val_loss: 0.7179 - val_accuracy: 0.6607 - val_f1_score: 0.6522 - val_precision: 0.7233 - val_recall: 0.5740 - lr: 3.0000e-05
# Epoch 27/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7094 - accuracy: 0.6738 - f1_score: 0.6695 - precision: 0.7307 - recall: 0.5897Restoring model weights from the end of the best epoch: 16.
#
# Epoch 27: val_f1_score did not improve from 0.65858
#
# Epoch 27 Learning Rate : 8.999999408842996e-06
# 563/563 [==============================] - 176s 312ms/step - loss: 0.7094 - accuracy: 0.6738 - f1_score: 0.6695 - precision: 0.7307 - recall: 0.5897 - val_loss: 0.7176 - val_accuracy: 0.6607 - val_f1_score: 0.6529 - val_precision: 0.7266 - val_recall: 0.5764 - lr: 9.0000e-06
# Epoch 27: early stopping
# done

# %%
# 1. Rebuild the model architecture blueprint first
model = get_EfficientNetB3()

# 2. Load the weights directly into the blueprint
# Note: .load_weights() does not require a custom_objects dictionary!
model.load_weights("EfficientNetB3_balanced_model_V2.h5")

print("Model weights loaded successfully!")
# Out:
# Model weights loaded successfully!

# %%
# ==========================================================
# PLOT LEARNING CURVES (Loss, F1-Score, Precision)
# ==========================================================
print("start")

# 1. Loss Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Train Loss', color='red')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig("EfficientNetB3_balanced_Loss_Curve3.pdf", format='pdf', bbox_inches='tight')
plt.show()

# 2. F1 Score Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['f1_score'], label='Train F1-Score', color='blue')
plt.plot(history.history['val_f1_score'], label='Validation F1-Score', color='cyan')

plt.xlabel('Epochs')
plt.ylabel('F1-Score')
plt.legend()
plt.tight_layout()
plt.savefig("EfficientNetB3_balanced_F1_Curve3.pdf", format='pdf', bbox_inches='tight')
plt.show()

# 3. Precision Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['precision'], label='Train Precision', color='green')
plt.plot(history.history['val_precision'], label='Validation Precision', color='lightgreen')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.tight_layout()
plt.savefig("EfficientNetB3_balanced_Precision_Curve3.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# EVALUATION (Training, Validation & Testing)
# ==========================================================
print("Evaluating on Training Set...")
train_results = model.evaluate(train_generator)

print("\nEvaluating on Validation Set...")
val_results = model.evaluate(val_generator)

print("\nEvaluating on Testing Set (Truly Unseen)...")
test_results = model.evaluate(test_generator)

# Unpacking 5 values based on the compile metrics order
# Order: [loss, accuracy, f1_score, precision, recall]
train_loss = train_results[0]
train_acc = train_results[1]
train_f1 = train_results[2]
train_precision = train_results[3]
train_recall = train_results[4]

val_loss = val_results[0]
val_acc = val_results[1]
val_f1 = val_results[2]
val_precision = val_results[3]
val_recall = val_results[4]

test_loss = test_results[0]
test_acc = test_results[1]
test_f1 = test_results[2]
test_precision = test_results[3]
test_recall = test_results[4]

print("\n" + "="*40)
print("TRAINING METRICS")
print("="*40)
print(f"Training Loss      : {train_loss:.4f}")
print(f"Training Accuracy  : {train_acc*100:.2f}%")
print(f"Training F1-Score  : {train_f1*100:.2f}%")
print(f"Training Precision : {train_precision*100:.2f}%")
print(f"Training Recall    : {train_recall*100:.2f}%")

print("\n" + "="*40)
print("VALIDATION METRICS")
print("="*40)
print(f"Validation Loss      : {val_loss:.4f}")
print(f"Validation Accuracy  : {val_acc*100:.2f}%")
print(f"Validation F1-Score  : {val_f1*100:.2f}%")
print(f"Validation Precision : {val_precision*100:.2f}%")
print(f"Validation Recall    : {val_recall*100:.2f}%")

print("\n" + "="*40)
print("TESTING METRICS (UNSEEN DATA)")
print("="*40)
print(f"Testing Loss      : {test_loss:.4f}")
print(f"Testing Accuracy  : {test_acc*100:.2f}%")
print(f"Testing F1-Score  : {test_f1*100:.2f}%")
print(f"Testing Precision : {test_precision*100:.2f}%")
print(f"Testing Recall    : {test_recall*100:.2f}%")
# Out:
# Evaluating on Training Set...
# 563/563 [==============================] - 128s 225ms/step - loss: 0.6852 - accuracy: 0.6911 - f1_score: 0.6847 - precision: 0.7532 - recall: 0.5896
#
# Evaluating on Validation Set...
# 93/93 [==============================] - 22s 231ms/step - loss: 0.7279 - accuracy: 0.6607 - f1_score: 0.6586 - precision: 0.7251 - recall: 0.5666
#
# Evaluating on Testing Set (Truly Unseen)...
# 92/92 [==============================] - 37s 395ms/step - loss: 0.7454 - accuracy: 0.6385 - f1_score: 0.6329 - precision: 0.7152 - recall: 0.5545
#
# ========================================
# TRAINING METRICS
# ========================================
# Training Loss      : 0.6852
# Training Accuracy  : 69.11%
# Training F1-Score  : 68.47%
# Training Precision : 75.32%
# Training Recall    : 58.96%
#
# ========================================
# VALIDATION METRICS
# ========================================
# Validation Loss      : 0.7279
# Validation Accuracy  : 66.07%
# Validation F1-Score  : 65.86%
# Validation Precision : 72.51%
# Validation Recall    : 56.66%
#
# ========================================
# TESTING METRICS (UNSEEN DATA)
# ========================================
# Testing Loss      : 0.7454
# Testing Accuracy  : 63.85%
# Testing F1-Score  : 63.29%
# Testing Precision : 71.52%
# Testing Recall    : 55.45%

# %%
# ==========================================================
# PRECISION, RECALL, F1-SCORE (Test Set - Unseen Data)
# ==========================================================
print("\nCalculating Precision, Recall, F1-score on Test Set...")

predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

true_classes = test_generator.classes
class_names = list(test_generator.class_indices.keys())

print("\nClassification Report (Test Set):\n")
print(
    classification_report(
        true_classes,
        predicted_classes,
        target_names=class_names
    )
)

print("done1")
# Out:
# Calculating Precision, Recall, F1-score on Test Set...
# 92/92 [==============================] - 23s 235ms/step
#
# Classification Report (Test Set):
#
#               precision    recall  f1-score   support
#
#       Benign       0.53      0.49      0.51       888
#    Malignant       0.69      0.67      0.68      1266
#       Normal       0.67      0.76      0.71       789
#
#     accuracy                           0.64      2943
#    macro avg       0.63      0.64      0.63      2943
# weighted avg       0.64      0.64      0.64      2943
#
# done1

# %%
# ==========================================================
# CONFUSION MATRIX (Test Set)
# ==========================================================
print("Generating Confusion Matrix...")

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(true_classes, predicted_classes)

# Plot the confusion matrix using Seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,       # Show the actual numbers inside the squares
    fmt='d',          # Format as whole numbers (integers)
    cmap='Blues',     # Color scheme
    xticklabels=class_names,
    yticklabels=class_names
)


plt.ylabel('True Label', fontsize=14)
plt.xlabel('Predicted Label', fontsize=14)
plt.xticks(rotation=45) # Rotate x-axis labels so they are easier to read
plt.yticks(rotation=0)

plt.tight_layout()
plt.savefig("EfficientNetB3_Balanced confusion_matrix_test_V3.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# Generating Confusion Matrix...
# done1
