# %% [markdown]
# # ResNet-50 + Wavelet Features (Hybrid) — Breast Cancer Classification
# Based on: Mohanty & Das (2025), *ResNet-50 backbone + wavelet features for complementary information*.
#
# Pipeline structure mirrors the EfficientNetB3 baseline notebook: frozen ImageNet backbone → pooled deep features,
# fused with handcrafted wavelet features → dense classifier head. Same callbacks, same metrics (F1/Precision/Recall),
# same evaluation + classification report + confusion matrix flow.

# %%
# ==========================================================
# INSTALL WAVELET LIBRARY (only needed once per environment)
# ==========================================================
# !pip install PyWavelets

print("start")

import os



print("Imbalanced dataset ready")
# Out:
# start
# Imbalanced dataset ready

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("TensorFlow Version: ", tf.__version__)
# Out:
# Num GPUs Available:  1
# TensorFlow Version:  2.10.0

# %%
# ==========================================================
# IMPORTS
# ==========================================================
print("start")

import os
import numpy as np
import cv2
import pywt
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report, confusion_matrix

from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Dense, GlobalAveragePooling2D, Dropout, Concatenate, BatchNormalization
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import Sequence, to_categorical
import tensorflow_addons as tfa
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint,
    Callback
)

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# CONFIGURATION
# ==========================================================
print("start")

DATASET_PATH = r"D:\Thesis_folder\Preprocessed_Pipeline\Supervised_Imbalanced"

IMAGE_SIZE = (288, 288)          # native ResNet-50 input size
MODEL_INPUT_SIZE = (288, 288, 3)
NUM_CLASSES = 3
BATCH_SIZE = 32
EPOCHS = 150

WAVELET_NAME = "db1"             # Daubechies-1 (Haar), matches common breast-cancer wavelet studies
WAVELET_LEVEL = 2                # decomposition depth -> richer complementary features

train_dir = os.path.join(DATASET_PATH, "train")
val_dir = os.path.join(DATASET_PATH, "val")
test_dir = os.path.join(DATASET_PATH, "test")

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# WAVELET FEATURE EXTRACTION
# ==========================================================
# For each image we take a 2D Discrete Wavelet Transform (DWT) of the grayscale
# version, then summarise every sub-band (approximation + horizontal/vertical/
# diagonal detail) with mean, std and energy. This gives a compact, complementary
# texture descriptor that is concatenated with the ResNet-50 deep features,
# following the "ResNet-50 backbone + wavelet features for complementary
# information" design in Mohanty & Das (2025).

def extract_wavelet_features(image_rgb, wavelet=WAVELET_NAME, level=WAVELET_LEVEL):
    """
    image_rgb: HxWx3 uint8 or float array (0-255 range)
    Returns: 1D float32 feature vector
    """
    gray = cv2.cvtColor(image_rgb.astype(np.uint8), cv2.COLOR_RGB2GRAY)
    coeffs = pywt.wavedec2(gray, wavelet=wavelet, level=level)

    features = []
    for idx, c in enumerate(coeffs):
        if idx == 0:
            # approximation coefficients (single array)
            sub_bands = [c]
        else:
            # detail coefficients: tuple of (cH, cV, cD)
            sub_bands = list(c)

        for sub in sub_bands:
            features.append(sub.mean())
            features.append(sub.std())
            features.append(np.sum(sub.astype(np.float64) ** 2) / sub.size)  # normalised energy

    return np.array(features, dtype=np.float32)


def get_wavelet_feature_dim():
    """Run once on a dummy image to determine the wavelet feature vector length."""
    dummy = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 3), dtype=np.uint8)
    return extract_wavelet_features(dummy).shape[0]


WAVELET_FEATURE_DIM = get_wavelet_feature_dim()
print(f"Wavelet feature vector length: {WAVELET_FEATURE_DIM}")
# Out:
# Wavelet feature vector length: 21

# %%
# ==========================================================
# DUAL-INPUT DATA GENERATOR (ResNet-50 image branch + wavelet branch)
# ==========================================================
# ImageDataGenerator.flow_from_directory only yields (image, label) pairs, so a
# custom Sequence is used here to additionally compute the wavelet feature
# vector for every image in the batch. Directory layout is identical to the
# EfficientNetB3 notebook: DATASET_PATH/{train,val,test}/<class_name>/*.jpg

class ResNetWaveletGenerator(Sequence):
    def __init__(self, directory, image_size=IMAGE_SIZE, batch_size=BATCH_SIZE,
                 num_classes=NUM_CLASSES, shuffle=True):
        self.directory = directory
        self.image_size = image_size
        self.batch_size = batch_size
        self.num_classes = num_classes
        self.shuffle = shuffle

        self.class_names = sorted(
            d for d in os.listdir(directory)
            if os.path.isdir(os.path.join(directory, d))
        )
        self.class_indices = {name: i for i, name in enumerate(self.class_names)}

        self.filepaths = []
        self.labels = []
        for cls in self.class_names:
            cls_dir = os.path.join(directory, cls)
            for fname in os.listdir(cls_dir):
                if fname.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tif", ".tiff")):
                    self.filepaths.append(os.path.join(cls_dir, fname))
                    self.labels.append(self.class_indices[cls])

        self.labels = np.array(self.labels)
        self.indices = np.arange(len(self.filepaths))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.filepaths) / self.batch_size))

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

    def __getitem__(self, idx):
        batch_idx = self.indices[idx * self.batch_size:(idx + 1) * self.batch_size]

        batch_images = np.zeros((len(batch_idx), *self.image_size, 3), dtype=np.float32)
        batch_wavelets = np.zeros((len(batch_idx), WAVELET_FEATURE_DIM), dtype=np.float32)
        batch_labels = np.zeros((len(batch_idx), self.num_classes), dtype=np.float32)

        for i, fi in enumerate(batch_idx):
            img_bgr = cv2.imread(self.filepaths[fi])
            img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
            img_rgb = cv2.resize(img_rgb, self.image_size)

            # Wavelet branch computed on the raw (0-255) resized image
            batch_wavelets[i] = extract_wavelet_features(img_rgb)

            # ResNet-50 branch uses its own preprocessing (caffe-style mean subtraction)
            batch_images[i] = preprocess_input(img_rgb.astype(np.float32).copy())

            batch_labels[i] = to_categorical(self.labels[fi], num_classes=self.num_classes)

        return (batch_images, batch_wavelets), batch_labels

    # Convenience properties to mirror ImageDataGenerator API used later in the notebook
    @property
    def classes(self):
        return self.labels

    @property
    def class_indices_(self):
        return self.class_indices


train_generator = ResNetWaveletGenerator(train_dir, shuffle=True)
val_generator = ResNetWaveletGenerator(val_dir, shuffle=False)
test_generator = ResNetWaveletGenerator(test_dir, shuffle=False)

print("Classes found:", train_generator.class_names)
print("Train / Val / Test sizes:",
      len(train_generator.filepaths), len(val_generator.filepaths), len(test_generator.filepaths))
# Out:
# Classes found: ['Benign', 'Malignant', 'Normal']
# Train / Val / Test sizes: 13787 2942 3002

# %%
# ==========================================================
# MODEL DEFINITION: ResNet-50 (image branch) + Wavelet MLP (feature branch)
# ==========================================================
print("start")

f1_metric = tfa.metrics.F1Score(num_classes=NUM_CLASSES, average='macro', name='f1_score')
precision_metric = tf.keras.metrics.Precision(name='precision')
recall_metric = tf.keras.metrics.Recall(name='recall')

def get_ResNet50_Wavelet_Hybrid():
    # ---- Image branch: ResNet-50 (frozen, ImageNet weights) ----
    image_input = Input(shape=MODEL_INPUT_SIZE, name="image_input")
    base_model = ResNet50(
        input_tensor=image_input,
        weights='imagenet',
        include_top=False
    )
    base_model.trainable = False

    x_img = GlobalAveragePooling2D()(base_model.output)
    x_img = Dropout(0.3)(x_img)

    # ---- Wavelet branch: small MLP over handcrafted features ----
    wavelet_input = Input(shape=(WAVELET_FEATURE_DIM,), name="wavelet_input")
    x_wav = BatchNormalization()(wavelet_input)
    x_wav = Dense(64, activation='relu')(x_wav)
    x_wav = Dropout(0.3)(x_wav)

    # ---- Fusion + classifier head ----
    fused = Concatenate()([x_img, x_wav])
    fused = Dense(128, activation='relu')(fused)
    fused = Dropout(0.3)(fused)
    output = Dense(NUM_CLASSES, activation='softmax')(fused)

    model = Model(inputs=[image_input, wavelet_input], outputs=output)

    optimizer = Adam(learning_rate=0.0001)
    model.compile(
        loss="categorical_crossentropy",
        metrics=["accuracy", f1_metric, precision_metric, recall_metric],
        optimizer=optimizer
    )

    return model

model = get_ResNet50_Wavelet_Hybrid()
model.summary()

print("done1")
# Out:
# start
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image_input (InputLayer)       [(None, 288, 288, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 294, 294, 3)  0           ['image_input[0][0]']
#
#  conv1_conv (Conv2D)            (None, 144, 144, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 144, 144, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 144, 144, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 146, 146, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 72, 72, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 72, 72, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 72, 72, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 72, 72, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 72, 72, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 72, 72, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 72, 72, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 72, 72, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 72, 72, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 72, 72, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 72, 72, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 72, 72, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 72, 72, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 72, 72, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 72, 72, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 72, 72, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 72, 72, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 72, 72, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 72, 72, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 72, 72, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 72, 72, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 36, 36, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 36, 36, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 36, 36, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 36, 36, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 36, 36, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 36, 36, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 36, 36, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 36, 36, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 36, 36, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 36, 36, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 36, 36, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 36, 36, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 36, 36, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 36, 36, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 36, 36, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 36, 36, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 36, 36, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 36, 36, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 36, 36, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 36, 36, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 36, 36, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 36, 36, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 36, 36, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 36, 36, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 36, 36, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 36, 36, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 18, 18, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 18, 18, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 18, 18, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 18, 18, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 18, 18, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 18, 18, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 18, 18, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 18, 18, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 9, 9, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 9, 9, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 9, 9, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 9, 9, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 9, 9, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 9, 9, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 9, 9, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 9, 9, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 9, 9, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 9, 9, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 9, 9, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 9, 9, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 9, 9, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 9, 9, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 9, 9, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 9, 9, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 9, 9, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 9, 9, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 9, 9, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  wavelet_input (InputLayer)     [(None, 21)]         0           []
#
#  conv5_block3_out (Activation)  (None, 9, 9, 2048)   0           ['conv5_block3_add[0][0]']
#
#  batch_normalization (BatchNorm  (None, 21)          84          ['wavelet_input[0][0]']
#  alization)
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 64)           1408        ['batch_normalization[0][0]']
#
#  dropout (Dropout)              (None, 2048)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout_1 (Dropout)            (None, 64)           0           ['dense[0][0]']
#
#  concatenate (Concatenate)      (None, 2112)         0           ['dropout[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  dense_1 (Dense)                (None, 128)          270464      ['concatenate[0][0]']
#
#  dropout_2 (Dropout)            (None, 128)          0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 3)            387         ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 23,860,055
# Trainable params: 272,301
# Non-trainable params: 23,587,754
# __________________________________________________________________________________________________
# done1

# %%
# ==========================================================
# CALLBACKS (Monitor set to 'val_f1_score')
# ==========================================================
print("start")

early_stop = EarlyStopping(
    monitor='val_f1_score',
    mode='max',
    patience=11,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.3,
    patience=5,
    min_lr=5e-8,
    verbose=1
)

checkpoint = ModelCheckpoint(
    "ResNet50_Wavelet_Hybrid_Imbalanced_model.h5",
    monitor='val_f1_score',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

print("done")
# Out:
# start
# done

# %%
# ==========================================================
# SHOW LEARNING RATE
# ==========================================================
print("start")

class PrintLearningRate(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate.numpy()
        print(f"\nEpoch {epoch+1} Learning Rate : {lr}")

lr_callback = PrintLearningRate()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# TRAINING
# ==========================================================
print("start")

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[
        early_stop,
        reduce_lr,
        checkpoint,
        lr_callback
    ]
)
print("done")
# Out:
# start
# Epoch 1/150
# 431/431 [==============================] - ETA: 0s - loss: 0.9749 - accuracy: 0.5330 - f1_score: 0.5213 - precision: 0.5847 - recall: 0.4155
# Epoch 1: val_f1_score improved from -inf to 0.66984, saving model to ResNet50_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 238s 543ms/step - loss: 0.9749 - accuracy: 0.5330 - f1_score: 0.5213 - precision: 0.5847 - recall: 0.4155 - val_loss: 0.7561 - val_accuracy: 0.6723 - val_f1_score: 0.6698 - val_precision: 0.7667 - val_recall: 0.5394 - lr: 1.0000e-04
# Epoch 2/150
# 431/431 [==============================] - ETA: 0s - loss: 0.8004 - accuracy: 0.6230 - f1_score: 0.6139 - precision: 0.6870 - recall: 0.5154
# Epoch 2: val_f1_score improved from 0.66984 to 0.68681, saving model to ResNet50_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 2 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 241s 558ms/step - loss: 0.8004 - accuracy: 0.6230 - f1_score: 0.6139 - precision: 0.6870 - recall: 0.5154 - val_loss: 0.7099 - val_accuracy: 0.6948 - val_f1_score: 0.6868 - val_precision: 0.7855 - val_recall: 0.5639 - lr: 1.0000e-04
# Epoch 3/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7483 - accuracy: 0.6484 - f1_score: 0.6400 - precision: 0.7133 - recall: 0.5514
# Epoch 3: val_f1_score did not improve from 0.68681
#
# Epoch 3 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 236s 547ms/step - loss: 0.7483 - accuracy: 0.6484 - f1_score: 0.6400 - precision: 0.7133 - recall: 0.5514 - val_loss: 0.6923 - val_accuracy: 0.6846 - val_f1_score: 0.6722 - val_precision: 0.7654 - val_recall: 0.5656 - lr: 1.0000e-04
# Epoch 4/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7269 - accuracy: 0.6566 - f1_score: 0.6499 - precision: 0.7199 - recall: 0.5673
# Epoch 4: val_f1_score improved from 0.68681 to 0.69454, saving model to ResNet50_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 4 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 247s 574ms/step - loss: 0.7269 - accuracy: 0.6566 - f1_score: 0.6499 - precision: 0.7199 - recall: 0.5673 - val_loss: 0.6659 - val_accuracy: 0.7060 - val_f1_score: 0.6945 - val_precision: 0.7784 - val_recall: 0.5897 - lr: 1.0000e-04
# Epoch 5/150
# 431/431 [==============================] - ETA: 0s - loss: 0.7035 - accuracy: 0.6706 - f1_score: 0.6639 - precision: 0.7291 - recall: 0.5842
# Epoch 5: val_f1_score improved from 0.69454 to 0.70623, saving model to ResNet50_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 5 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 248s 574ms/step - loss: 0.7035 - accuracy: 0.6706 - f1_score: 0.6639 - precision: 0.7291 - recall: 0.5842 - val_loss: 0.6524 - val_accuracy: 0.7118 - val_f1_score: 0.7062 - val_precision: 0.7815 - val_recall: 0.5982 - lr: 1.0000e-04
# Epoch 6/150
# 431/431 [==============================] - ETA: 0s - loss: 0.6854 - accuracy: 0.6795 - f1_score: 0.6729 - precision: 0.7391 - recall: 0.5978
# Epoch 6: val_f1_score did not improve from 0.70623
#
# Epoch 6 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 240s 555ms/step - loss: 0.6854 - accuracy: 0.6795 - f1_score: 0.6729 - precision: 0.7391 - recall: 0.5978 - val_loss: 0.6459 - val_accuracy: 0.7080 - val_f1_score: 0.6977 - val_precision: 0.7789 - val_recall: 0.5986 - lr: 1.0000e-04
# Epoch 7/150
# 431/431 [==============================] - ETA: 0s - loss: 0.6704 - accuracy: 0.6896 - f1_score: 0.6842 - precision: 0.7481 - recall: 0.6098
# Epoch 7: val_f1_score improved from 0.70623 to 0.71450, saving model to ResNet50_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 7 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 241s 560ms/step - loss: 0.6704 - accuracy: 0.6896 - f1_score: 0.6842 - precision: 0.7481 - recall: 0.6098 - val_loss: 0.6348 - val_accuracy: 0.7179 - val_f1_score: 0.7145 - val_precision: 0.7924 - val_recall: 0.6125 - lr: 1.0000e-04
# Epoch 8/150
# 431/431 [==============================] - ETA: 0s - loss: 0.6595 - accuracy: 0.6936 - f1_score: 0.6882 - precision: 0.7519 - recall: 0.6183
# Epoch 8: val_f1_score did not improve from 0.71450
#
# Epoch 8 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 239s 555ms/step - loss: 0.6595 - accuracy: 0.6936 - f1_score: 0.6882 - precision: 0.7519 - recall: 0.6183 - val_loss: 0.6265 - val_accuracy: 0.7128 - val_f1_score: 0.7069 - val_precision: 0.7839 - val_recall: 0.6213 - lr: 1.0000e-04
# Epoch 9/150
# 431/431 [==============================] - ETA: 0s - loss: 0.6494 - accuracy: 0.6994 - f1_score: 0.6938 - precision: 0.7544 - recall: 0.6258
# Epoch 9: val_f1_score improved from 0.71450 to 0.72890, saving model to ResNet50_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 9 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 239s 554ms/step - loss: 0.6494 - accuracy: 0.6994 - f1_score: 0.6938 - precision: 0.7544 - recall: 0.6258 - val_loss: 0.6081 - val_accuracy: 0.7288 - val_f1_score: 0.7289 - val_precision: 0.7967 - val_recall: 0.6434 - lr: 1.0000e-04
# Epoch 10/150
# 431/431 [==============================] - ETA: 0s - loss: 0.6411 - accuracy: 0.7057 - f1_score: 0.7003 - precision: 0.7542 - recall: 0.6305
# Epoch 10: val_f1_score did not improve from 0.72890
#
# Epoch 10 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 232s 537ms/step - loss: 0.6411 - accuracy: 0.7057 - f1_score: 0.7003 - precision: 0.7542 - recall: 0.6305 - val_loss: 0.6131 - val_accuracy: 0.7213 - val_f1_score: 0.7143 - val_precision: 0.7890 - val_recall: 0.6329 - lr: 1.0000e-04
# Epoch 11/150
# 431/431 [==============================] - ETA: 0s - loss: 0.6350 - accuracy: 0.7081 - f1_score: 0.7032 - precision: 0.7602 - recall: 0.6347
# Epoch 11: val_f1_score did not improve from 0.72890
#
# Epoch 11 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 236s 547ms/step - loss: 0.6350 - accuracy: 0.7081 - f1_score: 0.7032 - precision: 0.7602 - recall: 0.6347 - val_loss: 0.5991 - val_accuracy: 0.7274 - val_f1_score: 0.7278 - val_precision: 0.7953 - val_recall: 0.6536 - lr: 1.0000e-04
# Epoch 12/150
# 431/431 [==============================] - ETA: 0s - loss: 0.6227 - accuracy: 0.7139 - f1_score: 0.7095 - precision: 0.7676 - recall: 0.6503
# Epoch 12: val_f1_score improved from 0.72890 to 0.73555, saving model to ResNet50_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 12 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 247s 573ms/step - loss: 0.6227 - accuracy: 0.7139 - f1_score: 0.7095 - precision: 0.7676 - recall: 0.6503 - val_loss: 0.5932 - val_accuracy: 0.7373 - val_f1_score: 0.7356 - val_precision: 0.7968 - val_recall: 0.6557 - lr: 1.0000e-04
# Epoch 13/150
# 431/431 [==============================] - ETA: 0s - loss: 0.6201 - accuracy: 0.7189 - f1_score: 0.7142 - precision: 0.7699 - recall: 0.6436
# Epoch 13: val_f1_score improved from 0.73555 to 0.73762, saving model to ResNet50_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 13 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 246s 571ms/step - loss: 0.6201 - accuracy: 0.7189 - f1_score: 0.7142 - precision: 0.7699 - recall: 0.6436 - val_loss: 0.5926 - val_accuracy: 0.7369 - val_f1_score: 0.7376 - val_precision: 0.7967 - val_recall: 0.6662 - lr: 1.0000e-04
# Epoch 14/150
# 431/431 [==============================] - ETA: 0s - loss: 0.6106 - accuracy: 0.7184 - f1_score: 0.7149 - precision: 0.7704 - recall: 0.6561
# Epoch 14: val_f1_score improved from 0.73762 to 0.73889, saving model to ResNet50_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 14 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 245s 568ms/step - loss: 0.6106 - accuracy: 0.7184 - f1_score: 0.7149 - precision: 0.7704 - recall: 0.6561 - val_loss: 0.5926 - val_accuracy: 0.7407 - val_f1_score: 0.7389 - val_precision: 0.8012 - val_recall: 0.6574 - lr: 1.0000e-04
# Epoch 15/150
# 431/431 [==============================] - ETA: 0s - loss: 0.6090 - accuracy: 0.7222 - f1_score: 0.7188 - precision: 0.7729 - recall: 0.6579
# Epoch 15: val_f1_score improved from 0.73889 to 0.74526, saving model to ResNet50_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 15 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 250s 579ms/step - loss: 0.6090 - accuracy: 0.7222 - f1_score: 0.7188 - precision: 0.7729 - recall: 0.6579 - val_loss: 0.5871 - val_accuracy: 0.7451 - val_f1_score: 0.7453 - val_precision: 0.8073 - val_recall: 0.6666 - lr: 1.0000e-04
# Epoch 16/150
# 431/431 [==============================] - ETA: 0s - loss: 0.6027 - accuracy: 0.7248 - f1_score: 0.7211 - precision: 0.7720 - recall: 0.6627
# Epoch 16: val_f1_score did not improve from 0.74526
#
# Epoch 16 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 235s 546ms/step - loss: 0.6027 - accuracy: 0.7248 - f1_score: 0.7211 - precision: 0.7720 - recall: 0.6627 - val_loss: 0.5831 - val_accuracy: 0.7410 - val_f1_score: 0.7435 - val_precision: 0.8038 - val_recall: 0.6696 - lr: 1.0000e-04
# Epoch 17/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5926 - accuracy: 0.7326 - f1_score: 0.7290 - precision: 0.7802 - recall: 0.6678
# Epoch 17: val_f1_score did not improve from 0.74526
#
# Epoch 17 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 235s 546ms/step - loss: 0.5926 - accuracy: 0.7326 - f1_score: 0.7290 - precision: 0.7802 - recall: 0.6678 - val_loss: 0.5796 - val_accuracy: 0.7383 - val_f1_score: 0.7395 - val_precision: 0.7976 - val_recall: 0.6683 - lr: 1.0000e-04
# Epoch 18/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5916 - accuracy: 0.7316 - f1_score: 0.7281 - precision: 0.7750 - recall: 0.6734
# Epoch 18: val_f1_score improved from 0.74526 to 0.74569, saving model to ResNet50_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 18 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 242s 560ms/step - loss: 0.5916 - accuracy: 0.7316 - f1_score: 0.7281 - precision: 0.7750 - recall: 0.6734 - val_loss: 0.5792 - val_accuracy: 0.7464 - val_f1_score: 0.7457 - val_precision: 0.8023 - val_recall: 0.6689 - lr: 1.0000e-04
# Epoch 19/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5846 - accuracy: 0.7313 - f1_score: 0.7277 - precision: 0.7765 - recall: 0.6721
# Epoch 19: val_f1_score improved from 0.74569 to 0.74782, saving model to ResNet50_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 19 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 240s 557ms/step - loss: 0.5846 - accuracy: 0.7313 - f1_score: 0.7277 - precision: 0.7765 - recall: 0.6721 - val_loss: 0.5786 - val_accuracy: 0.7427 - val_f1_score: 0.7478 - val_precision: 0.7879 - val_recall: 0.6706 - lr: 1.0000e-04
# Epoch 20/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5800 - accuracy: 0.7330 - f1_score: 0.7294 - precision: 0.7799 - recall: 0.6744
# Epoch 20: val_f1_score did not improve from 0.74782
#
# Epoch 20 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 241s 560ms/step - loss: 0.5800 - accuracy: 0.7330 - f1_score: 0.7294 - precision: 0.7799 - recall: 0.6744 - val_loss: 0.5679 - val_accuracy: 0.7461 - val_f1_score: 0.7468 - val_precision: 0.7955 - val_recall: 0.6771 - lr: 1.0000e-04
# Epoch 21/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5722 - accuracy: 0.7403 - f1_score: 0.7372 - precision: 0.7837 - recall: 0.6823
# Epoch 21: val_f1_score improved from 0.74782 to 0.75306, saving model to ResNet50_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 21 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 250s 580ms/step - loss: 0.5722 - accuracy: 0.7403 - f1_score: 0.7372 - precision: 0.7837 - recall: 0.6823 - val_loss: 0.5687 - val_accuracy: 0.7492 - val_f1_score: 0.7531 - val_precision: 0.8005 - val_recall: 0.6846 - lr: 1.0000e-04
# Epoch 22/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5752 - accuracy: 0.7418 - f1_score: 0.7391 - precision: 0.7856 - recall: 0.6825
# Epoch 22: val_f1_score did not improve from 0.75306
#
# Epoch 22 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 242s 560ms/step - loss: 0.5752 - accuracy: 0.7418 - f1_score: 0.7391 - precision: 0.7856 - recall: 0.6825 - val_loss: 0.5776 - val_accuracy: 0.7407 - val_f1_score: 0.7420 - val_precision: 0.7953 - val_recall: 0.6788 - lr: 1.0000e-04
# Epoch 23/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5630 - accuracy: 0.7457 - f1_score: 0.7434 - precision: 0.7855 - recall: 0.6905
# Epoch 23: val_f1_score did not improve from 0.75306
#
# Epoch 23 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 238s 552ms/step - loss: 0.5630 - accuracy: 0.7457 - f1_score: 0.7434 - precision: 0.7855 - recall: 0.6905 - val_loss: 0.5695 - val_accuracy: 0.7488 - val_f1_score: 0.7465 - val_precision: 0.7960 - val_recall: 0.6842 - lr: 1.0000e-04
# Epoch 24/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5614 - accuracy: 0.7443 - f1_score: 0.7413 - precision: 0.7852 - recall: 0.6926
# Epoch 24: val_f1_score did not improve from 0.75306
#
# Epoch 24 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 234s 543ms/step - loss: 0.5614 - accuracy: 0.7443 - f1_score: 0.7413 - precision: 0.7852 - recall: 0.6926 - val_loss: 0.5736 - val_accuracy: 0.7417 - val_f1_score: 0.7389 - val_precision: 0.7978 - val_recall: 0.6798 - lr: 1.0000e-04
# Epoch 25/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5615 - accuracy: 0.7465 - f1_score: 0.7436 - precision: 0.7864 - recall: 0.6923
# Epoch 25: val_f1_score improved from 0.75306 to 0.75375, saving model to ResNet50_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 25 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 241s 560ms/step - loss: 0.5615 - accuracy: 0.7465 - f1_score: 0.7436 - precision: 0.7864 - recall: 0.6923 - val_loss: 0.5604 - val_accuracy: 0.7508 - val_f1_score: 0.7537 - val_precision: 0.7983 - val_recall: 0.6835 - lr: 1.0000e-04
# Epoch 26/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5601 - accuracy: 0.7486 - f1_score: 0.7463 - precision: 0.7894 - recall: 0.6956
# Epoch 26: val_f1_score did not improve from 0.75375
#
# Epoch 26 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 237s 548ms/step - loss: 0.5601 - accuracy: 0.7486 - f1_score: 0.7463 - precision: 0.7894 - recall: 0.6956 - val_loss: 0.5629 - val_accuracy: 0.7444 - val_f1_score: 0.7453 - val_precision: 0.7998 - val_recall: 0.6856 - lr: 1.0000e-04
# Epoch 27/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5527 - accuracy: 0.7498 - f1_score: 0.7471 - precision: 0.7893 - recall: 0.6975
# Epoch 27: val_f1_score did not improve from 0.75375
#
# Epoch 27 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 239s 555ms/step - loss: 0.5527 - accuracy: 0.7498 - f1_score: 0.7471 - precision: 0.7893 - recall: 0.6975 - val_loss: 0.5628 - val_accuracy: 0.7508 - val_f1_score: 0.7500 - val_precision: 0.7975 - val_recall: 0.6866 - lr: 1.0000e-04
# Epoch 28/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5483 - accuracy: 0.7510 - f1_score: 0.7485 - precision: 0.7902 - recall: 0.7015
# Epoch 28: val_f1_score did not improve from 0.75375
#
# Epoch 28 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 242s 561ms/step - loss: 0.5483 - accuracy: 0.7510 - f1_score: 0.7485 - precision: 0.7902 - recall: 0.7015 - val_loss: 0.5615 - val_accuracy: 0.7492 - val_f1_score: 0.7489 - val_precision: 0.8030 - val_recall: 0.6873 - lr: 1.0000e-04
# Epoch 29/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5431 - accuracy: 0.7531 - f1_score: 0.7513 - precision: 0.7890 - recall: 0.7006
# Epoch 29: val_f1_score did not improve from 0.75375
#
# Epoch 29 Learning Rate : 9.999999747378752e-05
# 431/431 [==============================] - 244s 566ms/step - loss: 0.5431 - accuracy: 0.7531 - f1_score: 0.7513 - precision: 0.7890 - recall: 0.7006 - val_loss: 0.5590 - val_accuracy: 0.7485 - val_f1_score: 0.7482 - val_precision: 0.7998 - val_recall: 0.6873 - lr: 1.0000e-04
# Epoch 30/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5411 - accuracy: 0.7564 - f1_score: 0.7543 - precision: 0.7955 - recall: 0.7069
# Epoch 30: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 30: val_f1_score did not improve from 0.75375
#
# Epoch 30 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 243s 563ms/step - loss: 0.5411 - accuracy: 0.7564 - f1_score: 0.7543 - precision: 0.7955 - recall: 0.7069 - val_loss: 0.5629 - val_accuracy: 0.7441 - val_f1_score: 0.7469 - val_precision: 0.7932 - val_recall: 0.6910 - lr: 1.0000e-04
# Epoch 31/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5290 - accuracy: 0.7612 - f1_score: 0.7597 - precision: 0.7983 - recall: 0.7099
# Epoch 31: val_f1_score improved from 0.75375 to 0.75474, saving model to ResNet50_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 31 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 245s 570ms/step - loss: 0.5290 - accuracy: 0.7612 - f1_score: 0.7597 - precision: 0.7983 - recall: 0.7099 - val_loss: 0.5555 - val_accuracy: 0.7529 - val_f1_score: 0.7547 - val_precision: 0.7937 - val_recall: 0.6985 - lr: 3.0000e-05
# Epoch 32/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5295 - accuracy: 0.7614 - f1_score: 0.7598 - precision: 0.7960 - recall: 0.7111
# Epoch 32: val_f1_score did not improve from 0.75474
#
# Epoch 32 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 235s 544ms/step - loss: 0.5295 - accuracy: 0.7614 - f1_score: 0.7598 - precision: 0.7960 - recall: 0.7111 - val_loss: 0.5564 - val_accuracy: 0.7508 - val_f1_score: 0.7509 - val_precision: 0.7928 - val_recall: 0.6931 - lr: 3.0000e-05
# Epoch 33/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5259 - accuracy: 0.7646 - f1_score: 0.7632 - precision: 0.8018 - recall: 0.7178
# Epoch 33: val_f1_score did not improve from 0.75474
#
# Epoch 33 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 234s 544ms/step - loss: 0.5259 - accuracy: 0.7646 - f1_score: 0.7632 - precision: 0.8018 - recall: 0.7178 - val_loss: 0.5563 - val_accuracy: 0.7495 - val_f1_score: 0.7516 - val_precision: 0.7913 - val_recall: 0.6920 - lr: 3.0000e-05
# Epoch 34/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5262 - accuracy: 0.7649 - f1_score: 0.7628 - precision: 0.8010 - recall: 0.7184
# Epoch 34: val_f1_score improved from 0.75474 to 0.75720, saving model to ResNet50_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 34 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 240s 558ms/step - loss: 0.5262 - accuracy: 0.7649 - f1_score: 0.7628 - precision: 0.8010 - recall: 0.7184 - val_loss: 0.5550 - val_accuracy: 0.7566 - val_f1_score: 0.7572 - val_precision: 0.7985 - val_recall: 0.6910 - lr: 3.0000e-05
# Epoch 35/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5234 - accuracy: 0.7682 - f1_score: 0.7664 - precision: 0.8025 - recall: 0.7173
# Epoch 35: val_f1_score did not improve from 0.75720
#
# Epoch 35 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 234s 543ms/step - loss: 0.5234 - accuracy: 0.7682 - f1_score: 0.7664 - precision: 0.8025 - recall: 0.7173 - val_loss: 0.5558 - val_accuracy: 0.7532 - val_f1_score: 0.7540 - val_precision: 0.7968 - val_recall: 0.6999 - lr: 3.0000e-05
# Epoch 36/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5253 - accuracy: 0.7629 - f1_score: 0.7608 - precision: 0.7971 - recall: 0.7147
# Epoch 36: val_f1_score did not improve from 0.75720
#
# Epoch 36 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 242s 562ms/step - loss: 0.5253 - accuracy: 0.7629 - f1_score: 0.7608 - precision: 0.7971 - recall: 0.7147 - val_loss: 0.5580 - val_accuracy: 0.7556 - val_f1_score: 0.7558 - val_precision: 0.7985 - val_recall: 0.6978 - lr: 3.0000e-05
# Epoch 37/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5223 - accuracy: 0.7613 - f1_score: 0.7594 - precision: 0.7981 - recall: 0.7145
# Epoch 37: val_f1_score did not improve from 0.75720
#
# Epoch 37 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 242s 562ms/step - loss: 0.5223 - accuracy: 0.7613 - f1_score: 0.7594 - precision: 0.7981 - recall: 0.7145 - val_loss: 0.5545 - val_accuracy: 0.7505 - val_f1_score: 0.7521 - val_precision: 0.7941 - val_recall: 0.6961 - lr: 3.0000e-05
# Epoch 38/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5194 - accuracy: 0.7704 - f1_score: 0.7688 - precision: 0.8053 - recall: 0.7247
# Epoch 38: val_f1_score did not improve from 0.75720
#
# Epoch 38 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 239s 553ms/step - loss: 0.5194 - accuracy: 0.7704 - f1_score: 0.7688 - precision: 0.8053 - recall: 0.7247 - val_loss: 0.5558 - val_accuracy: 0.7464 - val_f1_score: 0.7480 - val_precision: 0.7890 - val_recall: 0.6978 - lr: 3.0000e-05
# Epoch 39/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5189 - accuracy: 0.7680 - f1_score: 0.7654 - precision: 0.7998 - recall: 0.7221
# Epoch 39: val_f1_score improved from 0.75720 to 0.75791, saving model to ResNet50_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 39 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 238s 553ms/step - loss: 0.5189 - accuracy: 0.7680 - f1_score: 0.7654 - precision: 0.7998 - recall: 0.7221 - val_loss: 0.5537 - val_accuracy: 0.7576 - val_f1_score: 0.7579 - val_precision: 0.7967 - val_recall: 0.6965 - lr: 3.0000e-05
# Epoch 40/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5161 - accuracy: 0.7695 - f1_score: 0.7681 - precision: 0.8051 - recall: 0.7229
# Epoch 40: val_f1_score did not improve from 0.75791
#
# Epoch 40 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 235s 545ms/step - loss: 0.5161 - accuracy: 0.7695 - f1_score: 0.7681 - precision: 0.8051 - recall: 0.7229 - val_loss: 0.5570 - val_accuracy: 0.7539 - val_f1_score: 0.7544 - val_precision: 0.7960 - val_recall: 0.6924 - lr: 3.0000e-05
# Epoch 41/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5127 - accuracy: 0.7690 - f1_score: 0.7675 - precision: 0.8042 - recall: 0.7258
# Epoch 41: val_f1_score did not improve from 0.75791
#
# Epoch 41 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 236s 548ms/step - loss: 0.5127 - accuracy: 0.7690 - f1_score: 0.7675 - precision: 0.8042 - recall: 0.7258 - val_loss: 0.5542 - val_accuracy: 0.7508 - val_f1_score: 0.7508 - val_precision: 0.7946 - val_recall: 0.7009 - lr: 3.0000e-05
# Epoch 42/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5214 - accuracy: 0.7657 - f1_score: 0.7639 - precision: 0.8020 - recall: 0.7215
# Epoch 42: val_f1_score did not improve from 0.75791
#
# Epoch 42 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 236s 548ms/step - loss: 0.5214 - accuracy: 0.7657 - f1_score: 0.7639 - precision: 0.8020 - recall: 0.7215 - val_loss: 0.5562 - val_accuracy: 0.7542 - val_f1_score: 0.7545 - val_precision: 0.7951 - val_recall: 0.6988 - lr: 3.0000e-05
# Epoch 43/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5185 - accuracy: 0.7686 - f1_score: 0.7670 - precision: 0.8045 - recall: 0.7209
# Epoch 43: val_f1_score did not improve from 0.75791
#
# Epoch 43 Learning Rate : 2.9999999242136255e-05
# 431/431 [==============================] - 242s 562ms/step - loss: 0.5185 - accuracy: 0.7686 - f1_score: 0.7670 - precision: 0.8045 - recall: 0.7209 - val_loss: 0.5556 - val_accuracy: 0.7553 - val_f1_score: 0.7559 - val_precision: 0.7978 - val_recall: 0.6988 - lr: 3.0000e-05
# Epoch 44/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5148 - accuracy: 0.7687 - f1_score: 0.7665 - precision: 0.8030 - recall: 0.7232
# Epoch 44: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 44: val_f1_score did not improve from 0.75791
#
# Epoch 44 Learning Rate : 8.999999408842996e-06
# 431/431 [==============================] - 242s 562ms/step - loss: 0.5148 - accuracy: 0.7687 - f1_score: 0.7665 - precision: 0.8030 - recall: 0.7232 - val_loss: 0.5563 - val_accuracy: 0.7508 - val_f1_score: 0.7519 - val_precision: 0.7938 - val_recall: 0.6988 - lr: 3.0000e-05
# Epoch 45/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5102 - accuracy: 0.7712 - f1_score: 0.7696 - precision: 0.8045 - recall: 0.7249
# Epoch 45: val_f1_score did not improve from 0.75791
#
# Epoch 45 Learning Rate : 8.999999408842996e-06
# 431/431 [==============================] - 243s 563ms/step - loss: 0.5102 - accuracy: 0.7712 - f1_score: 0.7696 - precision: 0.8045 - recall: 0.7249 - val_loss: 0.5549 - val_accuracy: 0.7508 - val_f1_score: 0.7523 - val_precision: 0.7939 - val_recall: 0.6965 - lr: 9.0000e-06
# Epoch 46/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5131 - accuracy: 0.7693 - f1_score: 0.7678 - precision: 0.8043 - recall: 0.7263
# Epoch 46: val_f1_score did not improve from 0.75791
#
# Epoch 46 Learning Rate : 8.999999408842996e-06
# 431/431 [==============================] - 242s 562ms/step - loss: 0.5131 - accuracy: 0.7693 - f1_score: 0.7678 - precision: 0.8043 - recall: 0.7263 - val_loss: 0.5548 - val_accuracy: 0.7508 - val_f1_score: 0.7524 - val_precision: 0.7941 - val_recall: 0.6988 - lr: 9.0000e-06
# Epoch 47/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5116 - accuracy: 0.7703 - f1_score: 0.7686 - precision: 0.8049 - recall: 0.7250
# Epoch 47: val_f1_score did not improve from 0.75791
#
# Epoch 47 Learning Rate : 8.999999408842996e-06
# 431/431 [==============================] - 237s 549ms/step - loss: 0.5116 - accuracy: 0.7703 - f1_score: 0.7686 - precision: 0.8049 - recall: 0.7250 - val_loss: 0.5537 - val_accuracy: 0.7542 - val_f1_score: 0.7555 - val_precision: 0.7953 - val_recall: 0.6999 - lr: 9.0000e-06
# Epoch 48/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5097 - accuracy: 0.7756 - f1_score: 0.7741 - precision: 0.8069 - recall: 0.7289
# Epoch 48: val_f1_score did not improve from 0.75791
#
# Epoch 48 Learning Rate : 8.999999408842996e-06
# 431/431 [==============================] - 237s 550ms/step - loss: 0.5097 - accuracy: 0.7756 - f1_score: 0.7741 - precision: 0.8069 - recall: 0.7289 - val_loss: 0.5533 - val_accuracy: 0.7529 - val_f1_score: 0.7545 - val_precision: 0.7936 - val_recall: 0.7005 - lr: 9.0000e-06
# Epoch 49/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5072 - accuracy: 0.7744 - f1_score: 0.7722 - precision: 0.8092 - recall: 0.7286
# Epoch 49: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
#
# Epoch 49: val_f1_score did not improve from 0.75791
#
# Epoch 49 Learning Rate : 2.699999868127634e-06
# 431/431 [==============================] - 236s 547ms/step - loss: 0.5072 - accuracy: 0.7744 - f1_score: 0.7722 - precision: 0.8092 - recall: 0.7286 - val_loss: 0.5534 - val_accuracy: 0.7515 - val_f1_score: 0.7530 - val_precision: 0.7918 - val_recall: 0.6995 - lr: 9.0000e-06
# Epoch 50/150
# 431/431 [==============================] - ETA: 0s - loss: 0.5061 - accuracy: 0.7733 - f1_score: 0.7718 - precision: 0.8048 - recall: 0.7292Restoring model weights from the end of the best epoch: 39.
#
# Epoch 50: val_f1_score did not improve from 0.75791
#
# Epoch 50 Learning Rate : 2.699999868127634e-06
# 431/431 [==============================] - 236s 548ms/step - loss: 0.5061 - accuracy: 0.7733 - f1_score: 0.7718 - precision: 0.8048 - recall: 0.7292 - val_loss: 0.5531 - val_accuracy: 0.7512 - val_f1_score: 0.7525 - val_precision: 0.7933 - val_recall: 0.6992 - lr: 2.7000e-06
# Epoch 50: early stopping
# done

# %%
# 1. Rebuild the model architecture blueprint first
model = get_ResNet50_Wavelet_Hybrid()

# 2. Load the weights directly into the blueprint
model.load_weights("ResNet50_Wavelet_Hybrid_Imbalanced_model.h5")

print("Model weights loaded successfully!")
# Out:
# Model weights loaded successfully!

# %%
# ==========================================================
# PLOT LEARNING CURVES (Loss, F1-Score, Precision)
# ==========================================================
print("start")

# 1. Loss Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Train Loss', color='red')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig("ResNet50_Wavelet_Imbalanced_Loss_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

# 2. F1 Score Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['f1_score'], label='Train F1-Score', color='blue')
plt.plot(history.history['val_f1_score'], label='Validation F1-Score', color='cyan')
plt.xlabel('Epochs')
plt.ylabel('F1-Score')
plt.legend()
plt.tight_layout()
plt.savefig("ResNet50_Wavelet_Imbalanced_F1_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

# 3. Precision Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['precision'], label='Train Precision', color='green')
plt.plot(history.history['val_precision'], label='Validation Precision', color='lightgreen')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.tight_layout()
plt.savefig("ResNet50_Wavelet_Imbalanced_Precision_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# EVALUATION (Training, Validation & Testing)
# ==========================================================
print("Evaluating on Training Set...")
train_results = model.evaluate(train_generator)

print("\nEvaluating on Validation Set...")
val_results = model.evaluate(val_generator)

print("\nEvaluating on Testing Set (Truly Unseen)...")
test_results = model.evaluate(test_generator)

# Order: [loss, accuracy, f1_score, precision, recall]
train_loss, train_acc, train_f1, train_precision, train_recall = train_results
val_loss, val_acc, val_f1, val_precision, val_recall = val_results
test_loss, test_acc, test_f1, test_precision, test_recall = test_results

print("\n" + "="*40)
print("TRAINING METRICS")
print("="*40)
print(f"Training Loss      : {train_loss:.4f}")
print(f"Training Accuracy  : {train_acc*100:.2f}%")
print(f"Training F1-Score  : {train_f1*100:.2f}%")
print(f"Training Precision : {train_precision*100:.2f}%")
print(f"Training Recall    : {train_recall*100:.2f}%")

print("\n" + "="*40)
print("VALIDATION METRICS")
print("="*40)
print(f"Validation Loss      : {val_loss:.4f}")
print(f"Validation Accuracy  : {val_acc*100:.2f}%")
print(f"Validation F1-Score  : {val_f1*100:.2f}%")
print(f"Validation Precision : {val_precision*100:.2f}%")
print(f"Validation Recall    : {val_recall*100:.2f}%")

print("\n" + "="*40)
print("TESTING METRICS (UNSEEN DATA)")
print("="*40)
print(f"Testing Loss      : {test_loss:.4f}")
print(f"Testing Accuracy  : {test_acc*100:.2f}%")
print(f"Testing F1-Score  : {test_f1*100:.2f}%")
print(f"Testing Precision : {test_precision*100:.2f}%")
print(f"Testing Recall    : {test_recall*100:.2f}%")
# Out:
# Evaluating on Training Set...
# 431/431 [==============================] - 201s 464ms/step - loss: 0.4521 - accuracy: 0.8114 - f1_score: 0.8014 - precision: 0.8378 - recall: 0.7427
#
# Evaluating on Validation Set...
# 92/92 [==============================] - 43s 459ms/step - loss: 0.5537 - accuracy: 0.7576 - f1_score: 0.7579 - precision: 0.7967 - recall: 0.6965
#
# Evaluating on Testing Set (Truly Unseen)...
# 94/94 [==============================] - 41s 434ms/step - loss: 0.6012 - accuracy: 0.7252 - f1_score: 0.7252 - precision: 0.7610 - recall: 0.6639
#
# ========================================
# TRAINING METRICS
# ========================================
# Training Loss      : 0.4521
# Training Accuracy  : 81.14%
# Training F1-Score  : 80.14%
# Training Precision : 83.78%
# Training Recall    : 74.27%
#
# ========================================
# VALIDATION METRICS
# ========================================
# Validation Loss      : 0.5537
# Validation Accuracy  : 75.76%
# Validation F1-Score  : 75.79%
# Validation Precision : 79.67%
# Validation Recall    : 69.65%
#
# ========================================
# TESTING METRICS (UNSEEN DATA)
# ========================================
# Testing Loss      : 0.6012
# Testing Accuracy  : 72.52%
# Testing F1-Score  : 72.52%
# Testing Precision : 76.10%
# Testing Recall    : 66.39%

# %%
# ==========================================================
# PRECISION, RECALL, F1-SCORE (Test Set - Unseen Data)
# ==========================================================
print("\nCalculating Precision, Recall, F1-score on Test Set...")

predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

true_classes = test_generator.classes
class_names = test_generator.class_names

print("\nClassification Report (Test Set):\n")
print(
    classification_report(
        true_classes,
        predicted_classes,
        target_names=class_names
    )
)

print("done1")
# Out:
# Calculating Precision, Recall, F1-score on Test Set...
# 94/94 [==============================] - 41s 431ms/step
#
# Classification Report (Test Set):
#
#               precision    recall  f1-score   support
#
#       Benign       0.62      0.55      0.58       924
#    Malignant       0.73      0.77      0.75      1309
#       Normal       0.83      0.85      0.84       769
#
#     accuracy                           0.73      3002
#    macro avg       0.73      0.73      0.73      3002
# weighted avg       0.72      0.73      0.72      3002
#
# done1

# %%
# ==========================================================
# CONFUSION MATRIX (Test Set)
# ==========================================================
print("Generating Confusion Matrix...")

import seaborn as sns

cm = confusion_matrix(true_classes, predicted_classes)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=class_names,
    yticklabels=class_names
)

plt.ylabel('True Label', fontsize=14)
plt.xlabel('Predicted Label', fontsize=14)
plt.xticks(rotation=45)
plt.yticks(rotation=0)

plt.tight_layout()
plt.savefig("ResNet50_Wavelet_Imbalanced_confusion_matrix_test.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# Generating Confusion Matrix...
# done1
