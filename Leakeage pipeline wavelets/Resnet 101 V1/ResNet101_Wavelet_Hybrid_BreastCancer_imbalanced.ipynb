# %% [markdown]
# # ResNet-101 + Wavelet Features (Hybrid) — Breast Cancer Classification
# Based on: Mohanty & Das (2025), *ResNet-101 backbone + wavelet features for complementary information*.
#
# Pipeline structure mirrors the EfficientNetB3 baseline notebook: frozen ImageNet backbone → pooled deep features,
# fused with handcrafted wavelet features → dense classifier head. Same callbacks, same metrics (F1/Precision/Recall),
# same evaluation + classification report + confusion matrix flow.

# %%
# ==========================================================
# INSTALL WAVELET LIBRARY (only needed once per environment)
# ==========================================================
# !pip install PyWavelets

print("start")

import os

Imbalanced_dataset = r"D:\Thesis_folder\Supervised_Imbalanced"

print("Imbalanced dataset ready")
# Out:
# start
# Imbalanced dataset ready

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("TensorFlow Version: ", tf.__version__)
# Out:
# Num GPUs Available:  1
# TensorFlow Version:  2.10.0

# %%
# ==========================================================
# IMPORTS
# ==========================================================
print("start")

import os
import numpy as np
import cv2
import pywt
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report, confusion_matrix

from tensorflow.keras.applications import ResNet101
from tensorflow.keras.applications.resnet import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Dense, GlobalAveragePooling2D, Dropout, Concatenate, BatchNormalization
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import Sequence, to_categorical
import tensorflow_addons as tfa
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint,
    Callback
)

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# CONFIGURATION
# ==========================================================
print("start")

DATASET_PATH = r"D:\Thesis_folder\Supervised_Imbalanced"

IMAGE_SIZE = (288, 288)          # native ResNet-101 input size
MODEL_INPUT_SIZE = (288, 288, 3)
NUM_CLASSES = 3
BATCH_SIZE = 32
EPOCHS = 150

WAVELET_NAME = "db1"             # Daubechies-1 (Haar), matches common breast-cancer wavelet studies
WAVELET_LEVEL = 2                # decomposition depth -> richer complementary features

train_dir = os.path.join(DATASET_PATH, "train")
val_dir = os.path.join(DATASET_PATH, "val")
test_dir = os.path.join(DATASET_PATH, "test")

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# WAVELET FEATURE EXTRACTION
# ==========================================================
# For each image we take a 2D Discrete Wavelet Transform (DWT) of the grayscale
# version, then summarise every sub-band (approximation + horizontal/vertical/
# diagonal detail) with mean, std and energy. This gives a compact, complementary
# texture descriptor that is concatenated with the ResNet-101 deep features,
# following the "ResNet-101 backbone + wavelet features for complementary
# information" design in Mohanty & Das (2025).

def extract_wavelet_features(image_rgb, wavelet=WAVELET_NAME, level=WAVELET_LEVEL):
    """
    image_rgb: HxWx3 uint8 or float array (0-255 range)
    Returns: 1D float32 feature vector
    """
    gray = cv2.cvtColor(image_rgb.astype(np.uint8), cv2.COLOR_RGB2GRAY)
    coeffs = pywt.wavedec2(gray, wavelet=wavelet, level=level)

    features = []
    for idx, c in enumerate(coeffs):
        if idx == 0:
            # approximation coefficients (single array)
            sub_bands = [c]
        else:
            # detail coefficients: tuple of (cH, cV, cD)
            sub_bands = list(c)

        for sub in sub_bands:
            features.append(sub.mean())
            features.append(sub.std())
            features.append(np.sum(sub.astype(np.float64) ** 2) / sub.size)  # normalised energy

    return np.array(features, dtype=np.float32)


def get_wavelet_feature_dim():
    """Run once on a dummy image to determine the wavelet feature vector length."""
    dummy = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 3), dtype=np.uint8)
    return extract_wavelet_features(dummy).shape[0]


WAVELET_FEATURE_DIM = get_wavelet_feature_dim()
print(f"Wavelet feature vector length: {WAVELET_FEATURE_DIM}")
# Out:
# Wavelet feature vector length: 21

# %%
# ==========================================================
# DUAL-INPUT DATA GENERATOR (ResNet-101 image branch + wavelet branch)
# ==========================================================
# ImageDataGenerator.flow_from_directory only yields (image, label) pairs, so a
# custom Sequence is used here to additionally compute the wavelet feature
# vector for every image in the batch. Directory layout is identical to the
# EfficientNetB3 notebook: DATASET_PATH/{train,val,test}/<class_name>/*.jpg

class ResNetWaveletGenerator(Sequence):
    def __init__(self, directory, image_size=IMAGE_SIZE, batch_size=BATCH_SIZE,
                 num_classes=NUM_CLASSES, shuffle=True):
        self.directory = directory
        self.image_size = image_size
        self.batch_size = batch_size
        self.num_classes = num_classes
        self.shuffle = shuffle

        self.class_names = sorted(
            d for d in os.listdir(directory)
            if os.path.isdir(os.path.join(directory, d))
        )
        self.class_indices = {name: i for i, name in enumerate(self.class_names)}

        self.filepaths = []
        self.labels = []
        for cls in self.class_names:
            cls_dir = os.path.join(directory, cls)
            for fname in os.listdir(cls_dir):
                if fname.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tif", ".tiff")):
                    self.filepaths.append(os.path.join(cls_dir, fname))
                    self.labels.append(self.class_indices[cls])

        self.labels = np.array(self.labels)
        self.indices = np.arange(len(self.filepaths))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.filepaths) / self.batch_size))

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

    def __getitem__(self, idx):
        batch_idx = self.indices[idx * self.batch_size:(idx + 1) * self.batch_size]

        batch_images = np.zeros((len(batch_idx), *self.image_size, 3), dtype=np.float32)
        batch_wavelets = np.zeros((len(batch_idx), WAVELET_FEATURE_DIM), dtype=np.float32)
        batch_labels = np.zeros((len(batch_idx), self.num_classes), dtype=np.float32)

        for i, fi in enumerate(batch_idx):
            img_bgr = cv2.imread(self.filepaths[fi])
            img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
            img_rgb = cv2.resize(img_rgb, self.image_size)

            # Wavelet branch computed on the raw (0-255) resized image
            batch_wavelets[i] = extract_wavelet_features(img_rgb)

            # ResNet-101 branch uses its own preprocessing (caffe-style mean subtraction)
            batch_images[i] = preprocess_input(img_rgb.astype(np.float32).copy())

            batch_labels[i] = to_categorical(self.labels[fi], num_classes=self.num_classes)

        return (batch_images, batch_wavelets), batch_labels

    # Convenience properties to mirror ImageDataGenerator API used later in the notebook
    @property
    def classes(self):
        return self.labels

    @property
    def class_indices_(self):
        return self.class_indices


train_generator = ResNetWaveletGenerator(train_dir, shuffle=True)
val_generator = ResNetWaveletGenerator(val_dir, shuffle=False)
test_generator = ResNetWaveletGenerator(test_dir, shuffle=False)

print("Classes found:", train_generator.class_names)
print("Train / Val / Test sizes:",
      len(train_generator.filepaths), len(val_generator.filepaths), len(test_generator.filepaths))
# Out:
# Classes found: ['Benign', 'Malignant', 'Normal']
# Train / Val / Test sizes: 13811 2960 2960

# %%
# ==========================================================
# MODEL DEFINITION: ResNet-101 (image branch) + Wavelet MLP (feature branch)
# ==========================================================
print("start")

f1_metric = tfa.metrics.F1Score(num_classes=NUM_CLASSES, average='macro', name='f1_score')
precision_metric = tf.keras.metrics.Precision(name='precision')
recall_metric = tf.keras.metrics.Recall(name='recall')

def get_ResNet101_Wavelet_Hybrid():
    # ---- Image branch: ResNet-101 (frozen, ImageNet weights) ----
    image_input = Input(shape=MODEL_INPUT_SIZE, name="image_input")
    base_model = ResNet101(
        input_tensor=image_input,
        weights='imagenet',
        include_top=False
    )
    base_model.trainable = False

    x_img = GlobalAveragePooling2D()(base_model.output)
    x_img = Dropout(0.3)(x_img)

    # ---- Wavelet branch: small MLP over handcrafted features ----
    wavelet_input = Input(shape=(WAVELET_FEATURE_DIM,), name="wavelet_input")
    x_wav = BatchNormalization()(wavelet_input)
    x_wav = Dense(64, activation='relu')(x_wav)
    x_wav = Dropout(0.3)(x_wav)

    # ---- Fusion + classifier head ----
    fused = Concatenate()([x_img, x_wav])
    fused = Dense(128, activation='relu')(fused)
    fused = Dropout(0.3)(fused)
    output = Dense(NUM_CLASSES, activation='softmax')(fused)

    model = Model(inputs=[image_input, wavelet_input], outputs=output)

    optimizer = Adam(learning_rate=0.0001)
    model.compile(
        loss="categorical_crossentropy",
        metrics=["accuracy", f1_metric, precision_metric, recall_metric],
        optimizer=optimizer
    )

    return model

model = get_ResNet101_Wavelet_Hybrid()
model.summary()

print("done1")
# Out:
# start
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 [==============================] - 11s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image_input (InputLayer)       [(None, 288, 288, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 294, 294, 3)  0           ['image_input[0][0]']
#
#  conv1_conv (Conv2D)            (None, 144, 144, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 144, 144, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 144, 144, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 146, 146, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 72, 72, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 72, 72, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 72, 72, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 72, 72, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 72, 72, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 72, 72, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 72, 72, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 72, 72, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 72, 72, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 72, 72, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 72, 72, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 72, 72, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 72, 72, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 72, 72, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 72, 72, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 72, 72, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 72, 72, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 72, 72, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 72, 72, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 72, 72, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 72, 72, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 36, 36, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 36, 36, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 36, 36, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 36, 36, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 36, 36, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 36, 36, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 36, 36, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 36, 36, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 36, 36, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 36, 36, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 36, 36, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 36, 36, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 36, 36, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 36, 36, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 36, 36, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 36, 36, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 36, 36, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 36, 36, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 36, 36, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 36, 36, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 36, 36, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 36, 36, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 36, 36, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 36, 36, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 36, 36, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 36, 36, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 18, 18, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 18, 18, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 18, 18, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 18, 18, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 18, 18, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 18, 18, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 18, 18, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 18, 18, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv4_block7_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block6_out[0][0]']
#
#  conv4_block7_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block7_1_conv[0][0]']
#  ization)
#
#  conv4_block7_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block7_1_bn[0][0]']
#  n)
#
#  conv4_block7_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block7_1_relu[0][0]']
#
#  conv4_block7_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block7_2_conv[0][0]']
#  ization)
#
#  conv4_block7_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block7_2_bn[0][0]']
#  n)
#
#  conv4_block7_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block7_2_relu[0][0]']
#                                 )
#
#  conv4_block7_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block7_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block7_add (Add)         (None, 18, 18, 1024  0           ['conv4_block6_out[0][0]',
#                                 )                                 'conv4_block7_3_bn[0][0]']
#
#  conv4_block7_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block7_add[0][0]']
#                                 )
#
#  conv4_block8_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block7_out[0][0]']
#
#  conv4_block8_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block8_1_conv[0][0]']
#  ization)
#
#  conv4_block8_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block8_1_bn[0][0]']
#  n)
#
#  conv4_block8_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block8_1_relu[0][0]']
#
#  conv4_block8_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block8_2_conv[0][0]']
#  ization)
#
#  conv4_block8_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block8_2_bn[0][0]']
#  n)
#
#  conv4_block8_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block8_2_relu[0][0]']
#                                 )
#
#  conv4_block8_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block8_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block8_add (Add)         (None, 18, 18, 1024  0           ['conv4_block7_out[0][0]',
#                                 )                                 'conv4_block8_3_bn[0][0]']
#
#  conv4_block8_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block8_add[0][0]']
#                                 )
#
#  conv4_block9_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block8_out[0][0]']
#
#  conv4_block9_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block9_1_conv[0][0]']
#  ization)
#
#  conv4_block9_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block9_1_bn[0][0]']
#  n)
#
#  conv4_block9_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block9_1_relu[0][0]']
#
#  conv4_block9_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block9_2_conv[0][0]']
#  ization)
#
#  conv4_block9_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block9_2_bn[0][0]']
#  n)
#
#  conv4_block9_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block9_2_relu[0][0]']
#                                 )
#
#  conv4_block9_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block9_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block9_add (Add)         (None, 18, 18, 1024  0           ['conv4_block8_out[0][0]',
#                                 )                                 'conv4_block9_3_bn[0][0]']
#
#  conv4_block9_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block9_add[0][0]']
#                                 )
#
#  conv4_block10_1_conv (Conv2D)  (None, 18, 18, 256)  262400      ['conv4_block9_out[0][0]']
#
#  conv4_block10_1_bn (BatchNorma  (None, 18, 18, 256)  1024       ['conv4_block10_1_conv[0][0]']
#  lization)
#
#  conv4_block10_1_relu (Activati  (None, 18, 18, 256)  0          ['conv4_block10_1_bn[0][0]']
#  on)
#
#  conv4_block10_2_conv (Conv2D)  (None, 18, 18, 256)  590080      ['conv4_block10_1_relu[0][0]']
#
# ...
#  conv4_block22_1_relu (Activati  (None, 18, 18, 256)  0          ['conv4_block22_1_bn[0][0]']
#  on)
#
#  conv4_block22_2_conv (Conv2D)  (None, 18, 18, 256)  590080      ['conv4_block22_1_relu[0][0]']
#
#  conv4_block22_2_bn (BatchNorma  (None, 18, 18, 256)  1024       ['conv4_block22_2_conv[0][0]']
#  lization)
#
#  conv4_block22_2_relu (Activati  (None, 18, 18, 256)  0          ['conv4_block22_2_bn[0][0]']
#  on)
#
#  conv4_block22_3_conv (Conv2D)  (None, 18, 18, 1024  263168      ['conv4_block22_2_relu[0][0]']
#                                 )
#
#  conv4_block22_3_bn (BatchNorma  (None, 18, 18, 1024  4096       ['conv4_block22_3_conv[0][0]']
#  lization)                      )
#
#  conv4_block22_add (Add)        (None, 18, 18, 1024  0           ['conv4_block21_out[0][0]',
#                                 )                                 'conv4_block22_3_bn[0][0]']
#
#  conv4_block22_out (Activation)  (None, 18, 18, 1024  0          ['conv4_block22_add[0][0]']
#                                 )
#
#  conv4_block23_1_conv (Conv2D)  (None, 18, 18, 256)  262400      ['conv4_block22_out[0][0]']
#
#  conv4_block23_1_bn (BatchNorma  (None, 18, 18, 256)  1024       ['conv4_block23_1_conv[0][0]']
#  lization)
#
#  conv4_block23_1_relu (Activati  (None, 18, 18, 256)  0          ['conv4_block23_1_bn[0][0]']
#  on)
#
#  conv4_block23_2_conv (Conv2D)  (None, 18, 18, 256)  590080      ['conv4_block23_1_relu[0][0]']
#
#  conv4_block23_2_bn (BatchNorma  (None, 18, 18, 256)  1024       ['conv4_block23_2_conv[0][0]']
#  lization)
#
#  conv4_block23_2_relu (Activati  (None, 18, 18, 256)  0          ['conv4_block23_2_bn[0][0]']
#  on)
#
#  conv4_block23_3_conv (Conv2D)  (None, 18, 18, 1024  263168      ['conv4_block23_2_relu[0][0]']
#                                 )
#
#  conv4_block23_3_bn (BatchNorma  (None, 18, 18, 1024  4096       ['conv4_block23_3_conv[0][0]']
#  lization)                      )
#
#  conv4_block23_add (Add)        (None, 18, 18, 1024  0           ['conv4_block22_out[0][0]',
#                                 )                                 'conv4_block23_3_bn[0][0]']
#
#  conv4_block23_out (Activation)  (None, 18, 18, 1024  0          ['conv4_block23_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 9, 9, 512)    524800      ['conv4_block23_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 9, 9, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 9, 9, 2048)   2099200     ['conv4_block23_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 9, 9, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 9, 9, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 9, 9, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 9, 9, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 9, 9, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 9, 9, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 9, 9, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 9, 9, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 9, 9, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 9, 9, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 9, 9, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 9, 9, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 9, 9, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 9, 9, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 9, 9, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 9, 9, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  wavelet_input (InputLayer)     [(None, 21)]         0           []
#
#  conv5_block3_out (Activation)  (None, 9, 9, 2048)   0           ['conv5_block3_add[0][0]']
#
#  batch_normalization (BatchNorm  (None, 21)          84          ['wavelet_input[0][0]']
#  alization)
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 64)           1408        ['batch_normalization[0][0]']
#
#  dropout (Dropout)              (None, 2048)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout_1 (Dropout)            (None, 64)           0           ['dense[0][0]']
#
#  concatenate (Concatenate)      (None, 2112)         0           ['dropout[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  dense_1 (Dense)                (None, 128)          270464      ['concatenate[0][0]']
#
#  dropout_2 (Dropout)            (None, 128)          0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 3)            387         ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 42,930,519
# Trainable params: 272,301
# Non-trainable params: 42,658,218
# __________________________________________________________________________________________________
# done1

# %%
# ==========================================================
# CALLBACKS (Monitor set to 'val_f1_score')
# ==========================================================
print("start")

early_stop = EarlyStopping(
    monitor='val_f1_score',
    mode='max',
    patience=16,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.3,
    patience=5,
    min_lr=5e-8,
    verbose=1
)

checkpoint = ModelCheckpoint(
    "ResNet101_Wavelet_Hybrid_Imbalanced_model.h5",
    monitor='val_f1_score',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

print("done")
# Out:
# start
# done

# %%
# ==========================================================
# SHOW LEARNING RATE
# ==========================================================
print("start")

class PrintLearningRate(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate.numpy()
        print(f"\nEpoch {epoch+1} Learning Rate : {lr}")

lr_callback = PrintLearningRate()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# TRAINING
# ==========================================================
print("start")

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[
        early_stop,
        reduce_lr,
        checkpoint,
        lr_callback
    ]
)
print("done")
# Out:
# start
# Epoch 1/150
# 432/432 [==============================] - ETA: 0s - loss: 0.9622 - accuracy: 0.5425 - f1_score: 0.5315 - precision: 0.5909 - recall: 0.4276
# Epoch 1: val_f1_score improved from -inf to 0.64722, saving model to ResNet101_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-05
# 432/432 [==============================] - 200s 453ms/step - loss: 0.9622 - accuracy: 0.5425 - f1_score: 0.5315 - precision: 0.5909 - recall: 0.4276 - val_loss: 0.7684 - val_accuracy: 0.6426 - val_f1_score: 0.6472 - val_precision: 0.7407 - val_recall: 0.5027 - lr: 1.0000e-04
# Epoch 2/150
# 432/432 [==============================] - ETA: 0s - loss: 0.8022 - accuracy: 0.6162 - f1_score: 0.6084 - precision: 0.6843 - recall: 0.5124
# Epoch 2: val_f1_score improved from 0.64722 to 0.66597, saving model to ResNet101_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 2 Learning Rate : 9.999999747378752e-05
# 432/432 [==============================] - 203s 471ms/step - loss: 0.8022 - accuracy: 0.6162 - f1_score: 0.6084 - precision: 0.6843 - recall: 0.5124 - val_loss: 0.7213 - val_accuracy: 0.6652 - val_f1_score: 0.6660 - val_precision: 0.7555 - val_recall: 0.5294 - lr: 1.0000e-04
# Epoch 3/150
# 432/432 [==============================] - ETA: 0s - loss: 0.7588 - accuracy: 0.6401 - f1_score: 0.6330 - precision: 0.7066 - recall: 0.5405
# Epoch 3: val_f1_score did not improve from 0.66597
#
# Epoch 3 Learning Rate : 9.999999747378752e-05
# 432/432 [==============================] - 193s 448ms/step - loss: 0.7588 - accuracy: 0.6401 - f1_score: 0.6330 - precision: 0.7066 - recall: 0.5405 - val_loss: 0.7040 - val_accuracy: 0.6693 - val_f1_score: 0.6640 - val_precision: 0.7636 - val_recall: 0.5456 - lr: 1.0000e-04
# Epoch 4/150
# 432/432 [==============================] - ETA: 0s - loss: 0.7256 - accuracy: 0.6536 - f1_score: 0.6478 - precision: 0.7225 - recall: 0.5639
# Epoch 4: val_f1_score improved from 0.66597 to 0.67967, saving model to ResNet101_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 4 Learning Rate : 9.999999747378752e-05
# 432/432 [==============================] - 210s 486ms/step - loss: 0.7256 - accuracy: 0.6536 - f1_score: 0.6478 - precision: 0.7225 - recall: 0.5639 - val_loss: 0.6830 - val_accuracy: 0.6804 - val_f1_score: 0.6797 - val_precision: 0.7629 - val_recall: 0.5642 - lr: 1.0000e-04
# Epoch 5/150
# 432/432 [==============================] - ETA: 0s - loss: 0.7073 - accuracy: 0.6659 - f1_score: 0.6610 - precision: 0.7310 - recall: 0.5786
# Epoch 5: val_f1_score did not improve from 0.67967
#
# Epoch 5 Learning Rate : 9.999999747378752e-05
# 432/432 [==============================] - 196s 455ms/step - loss: 0.7073 - accuracy: 0.6659 - f1_score: 0.6610 - precision: 0.7310 - recall: 0.5786 - val_loss: 0.6681 - val_accuracy: 0.6865 - val_f1_score: 0.6769 - val_precision: 0.7794 - val_recall: 0.5730 - lr: 1.0000e-04
# Epoch 6/150
# 432/432 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.6730 - f1_score: 0.6675 - precision: 0.7356 - recall: 0.5892
# Epoch 6: val_f1_score improved from 0.67967 to 0.69823, saving model to ResNet101_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 6 Learning Rate : 9.999999747378752e-05
# 432/432 [==============================] - 213s 493ms/step - loss: 0.6933 - accuracy: 0.6730 - f1_score: 0.6675 - precision: 0.7356 - recall: 0.5892 - val_loss: 0.6594 - val_accuracy: 0.6993 - val_f1_score: 0.6982 - val_precision: 0.7853 - val_recall: 0.5831 - lr: 1.0000e-04
# Epoch 7/150
# 432/432 [==============================] - ETA: 0s - loss: 0.6788 - accuracy: 0.6824 - f1_score: 0.6774 - precision: 0.7446 - recall: 0.5998
# Epoch 7: val_f1_score improved from 0.69823 to 0.70416, saving model to ResNet101_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 7 Learning Rate : 9.999999747378752e-05
# 432/432 [==============================] - 204s 473ms/step - loss: 0.6788 - accuracy: 0.6824 - f1_score: 0.6774 - precision: 0.7446 - recall: 0.5998 - val_loss: 0.6505 - val_accuracy: 0.7024 - val_f1_score: 0.7042 - val_precision: 0.7794 - val_recall: 0.6003 - lr: 1.0000e-04
# Epoch 8/150
# 432/432 [==============================] - ETA: 0s - loss: 0.6648 - accuracy: 0.6904 - f1_score: 0.6861 - precision: 0.7472 - recall: 0.6130
# Epoch 8: val_f1_score improved from 0.70416 to 0.71119, saving model to ResNet101_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 8 Learning Rate : 9.999999747378752e-05
# 432/432 [==============================] - 208s 481ms/step - loss: 0.6648 - accuracy: 0.6904 - f1_score: 0.6861 - precision: 0.7472 - recall: 0.6130 - val_loss: 0.6374 - val_accuracy: 0.7101 - val_f1_score: 0.7112 - val_precision: 0.7848 - val_recall: 0.6098 - lr: 1.0000e-04
# Epoch 9/150
# 432/432 [==============================] - ETA: 0s - loss: 0.6547 - accuracy: 0.6937 - f1_score: 0.6898 - precision: 0.7464 - recall: 0.6163
# Epoch 9: val_f1_score did not improve from 0.71119
#
# Epoch 9 Learning Rate : 9.999999747378752e-05
# 432/432 [==============================] - 190s 438ms/step - loss: 0.6547 - accuracy: 0.6937 - f1_score: 0.6898 - precision: 0.7464 - recall: 0.6163 - val_loss: 0.6332 - val_accuracy: 0.7108 - val_f1_score: 0.7085 - val_precision: 0.7857 - val_recall: 0.6142 - lr: 1.0000e-04
# Epoch 10/150
# 432/432 [==============================] - ETA: 0s - loss: 0.6466 - accuracy: 0.6966 - f1_score: 0.6932 - precision: 0.7517 - recall: 0.6218
# Epoch 10: val_f1_score improved from 0.71119 to 0.71703, saving model to ResNet101_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 10 Learning Rate : 9.999999747378752e-05
# 432/432 [==============================] - 203s 471ms/step - loss: 0.6466 - accuracy: 0.6966 - f1_score: 0.6932 - precision: 0.7517 - recall: 0.6218 - val_loss: 0.6291 - val_accuracy: 0.7149 - val_f1_score: 0.7170 - val_precision: 0.7827 - val_recall: 0.6206 - lr: 1.0000e-04
# Epoch 11/150
# 432/432 [==============================] - ETA: 0s - loss: 0.6417 - accuracy: 0.7053 - f1_score: 0.7017 - precision: 0.7565 - recall: 0.6356
# Epoch 11: val_f1_score improved from 0.71703 to 0.71989, saving model to ResNet101_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 11 Learning Rate : 9.999999747378752e-05
# 432/432 [==============================] - 205s 475ms/step - loss: 0.6417 - accuracy: 0.7053 - f1_score: 0.7017 - precision: 0.7565 - recall: 0.6356 - val_loss: 0.6238 - val_accuracy: 0.7213 - val_f1_score: 0.7199 - val_precision: 0.7888 - val_recall: 0.6169 - lr: 1.0000e-04
# Epoch 12/150
# 432/432 [==============================] - ETA: 0s - loss: 0.6290 - accuracy: 0.7110 - f1_score: 0.7086 - precision: 0.7606 - recall: 0.6373
# Epoch 12: val_f1_score improved from 0.71989 to 0.72300, saving model to ResNet101_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 12 Learning Rate : 9.999999747378752e-05
# 432/432 [==============================] - 204s 473ms/step - loss: 0.6290 - accuracy: 0.7110 - f1_score: 0.7086 - precision: 0.7606 - recall: 0.6373 - val_loss: 0.6206 - val_accuracy: 0.7243 - val_f1_score: 0.7230 - val_precision: 0.7877 - val_recall: 0.6355 - lr: 1.0000e-04
# Epoch 13/150
# 432/432 [==============================] - ETA: 0s - loss: 0.6228 - accuracy: 0.7112 - f1_score: 0.7076 - precision: 0.7622 - recall: 0.6427
# Epoch 13: val_f1_score improved from 0.72300 to 0.73134, saving model to ResNet101_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 13 Learning Rate : 9.999999747378752e-05
# 432/432 [==============================] - 213s 493ms/step - loss: 0.6228 - accuracy: 0.7112 - f1_score: 0.7076 - precision: 0.7622 - recall: 0.6427 - val_loss: 0.6092 - val_accuracy: 0.7318 - val_f1_score: 0.7313 - val_precision: 0.7906 - val_recall: 0.6389 - lr: 1.0000e-04
# Epoch 14/150
# 432/432 [==============================] - ETA: 0s - loss: 0.6182 - accuracy: 0.7178 - f1_score: 0.7150 - precision: 0.7638 - recall: 0.6484
# Epoch 14: val_f1_score did not improve from 0.73134
#
# Epoch 14 Learning Rate : 9.999999747378752e-05
# 432/432 [==============================] - 198s 458ms/step - loss: 0.6182 - accuracy: 0.7178 - f1_score: 0.7150 - precision: 0.7638 - recall: 0.6484 - val_loss: 0.6103 - val_accuracy: 0.7250 - val_f1_score: 0.7250 - val_precision: 0.7894 - val_recall: 0.6419 - lr: 1.0000e-04
# Epoch 15/150
# 432/432 [==============================] - ETA: 0s - loss: 0.6062 - accuracy: 0.7227 - f1_score: 0.7190 - precision: 0.7689 - recall: 0.6567
# Epoch 15: val_f1_score did not improve from 0.73134
#
# Epoch 15 Learning Rate : 9.999999747378752e-05
# 432/432 [==============================] - 193s 447ms/step - loss: 0.6062 - accuracy: 0.7227 - f1_score: 0.7190 - precision: 0.7689 - recall: 0.6567 - val_loss: 0.6116 - val_accuracy: 0.7280 - val_f1_score: 0.7277 - val_precision: 0.7839 - val_recall: 0.6497 - lr: 1.0000e-04
# Epoch 16/150
# 432/432 [==============================] - ETA: 0s - loss: 0.6053 - accuracy: 0.7228 - f1_score: 0.7205 - precision: 0.7661 - recall: 0.6580
# Epoch 16: val_f1_score did not improve from 0.73134
#
# Epoch 16 Learning Rate : 9.999999747378752e-05
# 432/432 [==============================] - 189s 437ms/step - loss: 0.6053 - accuracy: 0.7228 - f1_score: 0.7205 - precision: 0.7661 - recall: 0.6580 - val_loss: 0.6045 - val_accuracy: 0.7257 - val_f1_score: 0.7253 - val_precision: 0.7906 - val_recall: 0.6443 - lr: 1.0000e-04
# Epoch 17/150
# 432/432 [==============================] - ETA: 0s - loss: 0.6063 - accuracy: 0.7233 - f1_score: 0.7210 - precision: 0.7696 - recall: 0.6611
# Epoch 17: val_f1_score did not improve from 0.73134
#
# Epoch 17 Learning Rate : 9.999999747378752e-05
# 432/432 [==============================] - 190s 439ms/step - loss: 0.6063 - accuracy: 0.7233 - f1_score: 0.7210 - precision: 0.7696 - recall: 0.6611 - val_loss: 0.6052 - val_accuracy: 0.7274 - val_f1_score: 0.7209 - val_precision: 0.7854 - val_recall: 0.6405 - lr: 1.0000e-04
# Epoch 18/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5959 - accuracy: 0.7291 - f1_score: 0.7267 - precision: 0.7710 - recall: 0.6657
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 18: val_f1_score did not improve from 0.73134
#
# Epoch 18 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 189s 438ms/step - loss: 0.5959 - accuracy: 0.7291 - f1_score: 0.7267 - precision: 0.7710 - recall: 0.6657 - val_loss: 0.5984 - val_accuracy: 0.7318 - val_f1_score: 0.7288 - val_precision: 0.7902 - val_recall: 0.6554 - lr: 1.0000e-04
# Epoch 19/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5838 - accuracy: 0.7359 - f1_score: 0.7340 - precision: 0.7810 - recall: 0.6774
# Epoch 19: val_f1_score improved from 0.73134 to 0.73335, saving model to ResNet101_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 19 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 210s 485ms/step - loss: 0.5838 - accuracy: 0.7359 - f1_score: 0.7340 - precision: 0.7810 - recall: 0.6774 - val_loss: 0.5944 - val_accuracy: 0.7351 - val_f1_score: 0.7334 - val_precision: 0.7899 - val_recall: 0.6605 - lr: 3.0000e-05
# Epoch 20/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5807 - accuracy: 0.7334 - f1_score: 0.7315 - precision: 0.7774 - recall: 0.6790
# Epoch 20: val_f1_score improved from 0.73335 to 0.73685, saving model to ResNet101_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 20 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 212s 489ms/step - loss: 0.5807 - accuracy: 0.7334 - f1_score: 0.7315 - precision: 0.7774 - recall: 0.6790 - val_loss: 0.5936 - val_accuracy: 0.7368 - val_f1_score: 0.7368 - val_precision: 0.7856 - val_recall: 0.6584 - lr: 3.0000e-05
# Epoch 21/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5741 - accuracy: 0.7377 - f1_score: 0.7367 - precision: 0.7793 - recall: 0.6813
# Epoch 21: val_f1_score did not improve from 0.73685
#
# Epoch 21 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 197s 456ms/step - loss: 0.5741 - accuracy: 0.7377 - f1_score: 0.7367 - precision: 0.7793 - recall: 0.6813 - val_loss: 0.5917 - val_accuracy: 0.7348 - val_f1_score: 0.7353 - val_precision: 0.7854 - val_recall: 0.6666 - lr: 3.0000e-05
# Epoch 22/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5772 - accuracy: 0.7364 - f1_score: 0.7346 - precision: 0.7788 - recall: 0.6800
# Epoch 22: val_f1_score did not improve from 0.73685
#
# Epoch 22 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 198s 458ms/step - loss: 0.5772 - accuracy: 0.7364 - f1_score: 0.7346 - precision: 0.7788 - recall: 0.6800 - val_loss: 0.5934 - val_accuracy: 0.7368 - val_f1_score: 0.7357 - val_precision: 0.7888 - val_recall: 0.6611 - lr: 3.0000e-05
# Epoch 23/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5793 - accuracy: 0.7393 - f1_score: 0.7363 - precision: 0.7820 - recall: 0.6766
# Epoch 23: val_f1_score improved from 0.73685 to 0.73793, saving model to ResNet101_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 23 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 231s 534ms/step - loss: 0.5793 - accuracy: 0.7393 - f1_score: 0.7363 - precision: 0.7820 - recall: 0.6766 - val_loss: 0.5905 - val_accuracy: 0.7378 - val_f1_score: 0.7379 - val_precision: 0.7907 - val_recall: 0.6611 - lr: 3.0000e-05
# Epoch 24/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5705 - accuracy: 0.7397 - f1_score: 0.7379 - precision: 0.7813 - recall: 0.6824
# Epoch 24: val_f1_score did not improve from 0.73793
#
# Epoch 24 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 231s 535ms/step - loss: 0.5705 - accuracy: 0.7397 - f1_score: 0.7379 - precision: 0.7813 - recall: 0.6824 - val_loss: 0.5904 - val_accuracy: 0.7355 - val_f1_score: 0.7339 - val_precision: 0.7882 - val_recall: 0.6601 - lr: 3.0000e-05
# Epoch 25/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5682 - accuracy: 0.7412 - f1_score: 0.7387 - precision: 0.7813 - recall: 0.6829
# Epoch 25: val_f1_score improved from 0.73793 to 0.73826, saving model to ResNet101_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 25 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 205s 474ms/step - loss: 0.5682 - accuracy: 0.7412 - f1_score: 0.7387 - precision: 0.7813 - recall: 0.6829 - val_loss: 0.5886 - val_accuracy: 0.7382 - val_f1_score: 0.7383 - val_precision: 0.7915 - val_recall: 0.6706 - lr: 3.0000e-05
# Epoch 26/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5715 - accuracy: 0.7403 - f1_score: 0.7385 - precision: 0.7821 - recall: 0.6863
# Epoch 26: val_f1_score did not improve from 0.73826
#
# Epoch 26 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 193s 445ms/step - loss: 0.5715 - accuracy: 0.7403 - f1_score: 0.7385 - precision: 0.7821 - recall: 0.6863 - val_loss: 0.5896 - val_accuracy: 0.7375 - val_f1_score: 0.7347 - val_precision: 0.7852 - val_recall: 0.6608 - lr: 3.0000e-05
# Epoch 27/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5626 - accuracy: 0.7420 - f1_score: 0.7401 - precision: 0.7840 - recall: 0.6876
# Epoch 27: val_f1_score did not improve from 0.73826
#
# Epoch 27 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 197s 456ms/step - loss: 0.5626 - accuracy: 0.7420 - f1_score: 0.7401 - precision: 0.7840 - recall: 0.6876 - val_loss: 0.5868 - val_accuracy: 0.7382 - val_f1_score: 0.7359 - val_precision: 0.7895 - val_recall: 0.6689 - lr: 3.0000e-05
# Epoch 28/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5661 - accuracy: 0.7436 - f1_score: 0.7414 - precision: 0.7805 - recall: 0.6912
# Epoch 28: val_f1_score did not improve from 0.73826
#
# Epoch 28 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 200s 462ms/step - loss: 0.5661 - accuracy: 0.7436 - f1_score: 0.7414 - precision: 0.7805 - recall: 0.6912 - val_loss: 0.5835 - val_accuracy: 0.7389 - val_f1_score: 0.7376 - val_precision: 0.7861 - val_recall: 0.6669 - lr: 3.0000e-05
# Epoch 29/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5607 - accuracy: 0.7438 - f1_score: 0.7416 - precision: 0.7816 - recall: 0.6896
# Epoch 29: val_f1_score improved from 0.73826 to 0.73968, saving model to ResNet101_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 29 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 209s 484ms/step - loss: 0.5607 - accuracy: 0.7438 - f1_score: 0.7416 - precision: 0.7816 - recall: 0.6896 - val_loss: 0.5858 - val_accuracy: 0.7389 - val_f1_score: 0.7397 - val_precision: 0.7857 - val_recall: 0.6703 - lr: 3.0000e-05
# Epoch 30/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5606 - accuracy: 0.7436 - f1_score: 0.7421 - precision: 0.7830 - recall: 0.6882
# Epoch 30: val_f1_score did not improve from 0.73968
#
# Epoch 30 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 199s 460ms/step - loss: 0.5606 - accuracy: 0.7436 - f1_score: 0.7421 - precision: 0.7830 - recall: 0.6882 - val_loss: 0.5854 - val_accuracy: 0.7361 - val_f1_score: 0.7355 - val_precision: 0.7866 - val_recall: 0.6699 - lr: 3.0000e-05
# Epoch 31/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5628 - accuracy: 0.7461 - f1_score: 0.7440 - precision: 0.7837 - recall: 0.6971
# Epoch 31: val_f1_score did not improve from 0.73968
#
# Epoch 31 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 195s 451ms/step - loss: 0.5628 - accuracy: 0.7461 - f1_score: 0.7440 - precision: 0.7837 - recall: 0.6971 - val_loss: 0.5836 - val_accuracy: 0.7355 - val_f1_score: 0.7335 - val_precision: 0.7851 - val_recall: 0.6639 - lr: 3.0000e-05
# Epoch 32/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5567 - accuracy: 0.7466 - f1_score: 0.7445 - precision: 0.7859 - recall: 0.6978
# Epoch 32: val_f1_score did not improve from 0.73968
#
# Epoch 32 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 192s 445ms/step - loss: 0.5567 - accuracy: 0.7466 - f1_score: 0.7445 - precision: 0.7859 - recall: 0.6978 - val_loss: 0.5822 - val_accuracy: 0.7389 - val_f1_score: 0.7372 - val_precision: 0.7891 - val_recall: 0.6723 - lr: 3.0000e-05
# Epoch 33/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5540 - accuracy: 0.7503 - f1_score: 0.7488 - precision: 0.7879 - recall: 0.6984
# Epoch 33: val_f1_score did not improve from 0.73968
#
# Epoch 33 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 192s 445ms/step - loss: 0.5540 - accuracy: 0.7503 - f1_score: 0.7488 - precision: 0.7879 - recall: 0.6984 - val_loss: 0.5802 - val_accuracy: 0.7385 - val_f1_score: 0.7381 - val_precision: 0.7902 - val_recall: 0.6743 - lr: 3.0000e-05
# Epoch 34/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5545 - accuracy: 0.7474 - f1_score: 0.7458 - precision: 0.7864 - recall: 0.6972
# Epoch 34: val_f1_score improved from 0.73968 to 0.74097, saving model to ResNet101_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 34 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 206s 477ms/step - loss: 0.5545 - accuracy: 0.7474 - f1_score: 0.7458 - precision: 0.7864 - recall: 0.6972 - val_loss: 0.5804 - val_accuracy: 0.7416 - val_f1_score: 0.7410 - val_precision: 0.7919 - val_recall: 0.6723 - lr: 3.0000e-05
# Epoch 35/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5549 - accuracy: 0.7485 - f1_score: 0.7470 - precision: 0.7862 - recall: 0.6973
# Epoch 35: val_f1_score did not improve from 0.74097
#
# Epoch 35 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 196s 452ms/step - loss: 0.5549 - accuracy: 0.7485 - f1_score: 0.7470 - precision: 0.7862 - recall: 0.6973 - val_loss: 0.5787 - val_accuracy: 0.7365 - val_f1_score: 0.7351 - val_precision: 0.7917 - val_recall: 0.6753 - lr: 3.0000e-05
# Epoch 36/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5526 - accuracy: 0.7509 - f1_score: 0.7489 - precision: 0.7893 - recall: 0.6976
# Epoch 36: val_f1_score did not improve from 0.74097
#
# Epoch 36 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 199s 461ms/step - loss: 0.5526 - accuracy: 0.7509 - f1_score: 0.7489 - precision: 0.7893 - recall: 0.6976 - val_loss: 0.5794 - val_accuracy: 0.7412 - val_f1_score: 0.7401 - val_precision: 0.7896 - val_recall: 0.6797 - lr: 3.0000e-05
# Epoch 37/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5495 - accuracy: 0.7514 - f1_score: 0.7496 - precision: 0.7896 - recall: 0.7020
# Epoch 37: val_f1_score improved from 0.74097 to 0.74327, saving model to ResNet101_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 37 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 211s 489ms/step - loss: 0.5495 - accuracy: 0.7514 - f1_score: 0.7496 - precision: 0.7896 - recall: 0.7020 - val_loss: 0.5782 - val_accuracy: 0.7443 - val_f1_score: 0.7433 - val_precision: 0.7904 - val_recall: 0.6818 - lr: 3.0000e-05
# Epoch 38/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5504 - accuracy: 0.7498 - f1_score: 0.7481 - precision: 0.7874 - recall: 0.7030
# Epoch 38: val_f1_score did not improve from 0.74327
#
# Epoch 38 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 200s 462ms/step - loss: 0.5504 - accuracy: 0.7498 - f1_score: 0.7481 - precision: 0.7874 - recall: 0.7030 - val_loss: 0.5781 - val_accuracy: 0.7389 - val_f1_score: 0.7395 - val_precision: 0.7848 - val_recall: 0.6753 - lr: 3.0000e-05
# Epoch 39/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5502 - accuracy: 0.7530 - f1_score: 0.7520 - precision: 0.7882 - recall: 0.7015
# Epoch 39: val_f1_score did not improve from 0.74327
#
# Epoch 39 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 192s 445ms/step - loss: 0.5502 - accuracy: 0.7530 - f1_score: 0.7520 - precision: 0.7882 - recall: 0.7015 - val_loss: 0.5796 - val_accuracy: 0.7409 - val_f1_score: 0.7392 - val_precision: 0.7896 - val_recall: 0.6720 - lr: 3.0000e-05
# Epoch 40/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5483 - accuracy: 0.7539 - f1_score: 0.7520 - precision: 0.7912 - recall: 0.7034
# Epoch 40: val_f1_score did not improve from 0.74327
#
# Epoch 40 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 192s 445ms/step - loss: 0.5483 - accuracy: 0.7539 - f1_score: 0.7520 - precision: 0.7912 - recall: 0.7034 - val_loss: 0.5767 - val_accuracy: 0.7365 - val_f1_score: 0.7353 - val_precision: 0.7859 - val_recall: 0.6747 - lr: 3.0000e-05
# Epoch 41/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5459 - accuracy: 0.7552 - f1_score: 0.7537 - precision: 0.7911 - recall: 0.7049
# Epoch 41: val_f1_score did not improve from 0.74327
#
# Epoch 41 Learning Rate : 2.9999999242136255e-05
# 432/432 [==============================] - 193s 446ms/step - loss: 0.5459 - accuracy: 0.7552 - f1_score: 0.7537 - precision: 0.7911 - recall: 0.7049 - val_loss: 0.5746 - val_accuracy: 0.7405 - val_f1_score: 0.7407 - val_precision: 0.7892 - val_recall: 0.6794 - lr: 3.0000e-05
# Epoch 42/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5442 - accuracy: 0.7550 - f1_score: 0.7537 - precision: 0.7953 - recall: 0.7081
# Epoch 42: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 42: val_f1_score did not improve from 0.74327
#
# Epoch 42 Learning Rate : 8.999999408842996e-06
# 432/432 [==============================] - 193s 446ms/step - loss: 0.5442 - accuracy: 0.7550 - f1_score: 0.7537 - precision: 0.7953 - recall: 0.7081 - val_loss: 0.5757 - val_accuracy: 0.7453 - val_f1_score: 0.7432 - val_precision: 0.7909 - val_recall: 0.6834 - lr: 3.0000e-05
# Epoch 43/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5377 - accuracy: 0.7614 - f1_score: 0.7600 - precision: 0.7982 - recall: 0.7125
# Epoch 43: val_f1_score did not improve from 0.74327
#
# Epoch 43 Learning Rate : 8.999999408842996e-06
# 432/432 [==============================] - 200s 462ms/step - loss: 0.5377 - accuracy: 0.7614 - f1_score: 0.7600 - precision: 0.7982 - recall: 0.7125 - val_loss: 0.5748 - val_accuracy: 0.7429 - val_f1_score: 0.7427 - val_precision: 0.7873 - val_recall: 0.6841 - lr: 9.0000e-06
# Epoch 44/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5376 - accuracy: 0.7614 - f1_score: 0.7605 - precision: 0.7965 - recall: 0.7110
# Epoch 44: val_f1_score improved from 0.74327 to 0.74377, saving model to ResNet101_Wavelet_Hybrid_Imbalanced_model.h5
#
# Epoch 44 Learning Rate : 8.999999408842996e-06
# 432/432 [==============================] - 216s 501ms/step - loss: 0.5376 - accuracy: 0.7614 - f1_score: 0.7605 - precision: 0.7965 - recall: 0.7110 - val_loss: 0.5743 - val_accuracy: 0.7446 - val_f1_score: 0.7438 - val_precision: 0.7890 - val_recall: 0.6834 - lr: 9.0000e-06
# Epoch 45/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5370 - accuracy: 0.7582 - f1_score: 0.7578 - precision: 0.7940 - recall: 0.7102
# Epoch 45: val_f1_score did not improve from 0.74377
#
# Epoch 45 Learning Rate : 8.999999408842996e-06
# 432/432 [==============================] - 200s 463ms/step - loss: 0.5370 - accuracy: 0.7582 - f1_score: 0.7578 - precision: 0.7940 - recall: 0.7102 - val_loss: 0.5733 - val_accuracy: 0.7449 - val_f1_score: 0.7431 - val_precision: 0.7891 - val_recall: 0.6828 - lr: 9.0000e-06
# Epoch 46/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5405 - accuracy: 0.7537 - f1_score: 0.7516 - precision: 0.7915 - recall: 0.7083
# Epoch 46: val_f1_score did not improve from 0.74377
#
# Epoch 46 Learning Rate : 8.999999408842996e-06
# 432/432 [==============================] - 200s 462ms/step - loss: 0.5405 - accuracy: 0.7537 - f1_score: 0.7516 - precision: 0.7915 - recall: 0.7083 - val_loss: 0.5736 - val_accuracy: 0.7416 - val_f1_score: 0.7412 - val_precision: 0.7909 - val_recall: 0.6838 - lr: 9.0000e-06
# Epoch 47/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5350 - accuracy: 0.7577 - f1_score: 0.7565 - precision: 0.7931 - recall: 0.7104
# Epoch 47: val_f1_score did not improve from 0.74377
#
# Epoch 47 Learning Rate : 8.999999408842996e-06
# 432/432 [==============================] - 193s 447ms/step - loss: 0.5350 - accuracy: 0.7577 - f1_score: 0.7565 - precision: 0.7931 - recall: 0.7104 - val_loss: 0.5732 - val_accuracy: 0.7436 - val_f1_score: 0.7421 - val_precision: 0.7913 - val_recall: 0.6801 - lr: 9.0000e-06
# Epoch 48/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5396 - accuracy: 0.7578 - f1_score: 0.7562 - precision: 0.7926 - recall: 0.7104
# Epoch 48: val_f1_score did not improve from 0.74377
#
# Epoch 48 Learning Rate : 8.999999408842996e-06
# 432/432 [==============================] - 192s 444ms/step - loss: 0.5396 - accuracy: 0.7578 - f1_score: 0.7562 - precision: 0.7926 - recall: 0.7104 - val_loss: 0.5744 - val_accuracy: 0.7449 - val_f1_score: 0.7430 - val_precision: 0.7906 - val_recall: 0.6784 - lr: 9.0000e-06
# Epoch 49/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5377 - accuracy: 0.7590 - f1_score: 0.7578 - precision: 0.7940 - recall: 0.7107
# Epoch 49: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
#
# Epoch 49: val_f1_score did not improve from 0.74377
#
# Epoch 49 Learning Rate : 2.699999868127634e-06
# 432/432 [==============================] - 191s 443ms/step - loss: 0.5377 - accuracy: 0.7590 - f1_score: 0.7578 - precision: 0.7940 - recall: 0.7107 - val_loss: 0.5739 - val_accuracy: 0.7446 - val_f1_score: 0.7433 - val_precision: 0.7876 - val_recall: 0.6777 - lr: 9.0000e-06
# Epoch 50/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5370 - accuracy: 0.7558 - f1_score: 0.7544 - precision: 0.7941 - recall: 0.7091
# Epoch 50: val_f1_score did not improve from 0.74377
#
# Epoch 50 Learning Rate : 2.699999868127634e-06
# 432/432 [==============================] - 192s 446ms/step - loss: 0.5370 - accuracy: 0.7558 - f1_score: 0.7544 - precision: 0.7941 - recall: 0.7091 - val_loss: 0.5736 - val_accuracy: 0.7429 - val_f1_score: 0.7417 - val_precision: 0.7883 - val_recall: 0.6794 - lr: 2.7000e-06
# Epoch 51/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5341 - accuracy: 0.7595 - f1_score: 0.7580 - precision: 0.7959 - recall: 0.7141
# Epoch 51: val_f1_score did not improve from 0.74377
#
# Epoch 51 Learning Rate : 2.699999868127634e-06
# 432/432 [==============================] - 199s 461ms/step - loss: 0.5341 - accuracy: 0.7595 - f1_score: 0.7580 - precision: 0.7959 - recall: 0.7141 - val_loss: 0.5740 - val_accuracy: 0.7422 - val_f1_score: 0.7411 - val_precision: 0.7866 - val_recall: 0.6801 - lr: 2.7000e-06
# Epoch 52/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5380 - accuracy: 0.7582 - f1_score: 0.7570 - precision: 0.7946 - recall: 0.7109
# Epoch 52: val_f1_score did not improve from 0.74377
#
# Epoch 52 Learning Rate : 2.699999868127634e-06
# 432/432 [==============================] - 199s 460ms/step - loss: 0.5380 - accuracy: 0.7582 - f1_score: 0.7570 - precision: 0.7946 - recall: 0.7109 - val_loss: 0.5735 - val_accuracy: 0.7439 - val_f1_score: 0.7425 - val_precision: 0.7885 - val_recall: 0.6801 - lr: 2.7000e-06
# Epoch 53/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5352 - accuracy: 0.7619 - f1_score: 0.7611 - precision: 0.7963 - recall: 0.7133
# Epoch 53: val_f1_score did not improve from 0.74377
#
# Epoch 53 Learning Rate : 2.699999868127634e-06
# 432/432 [==============================] - 199s 461ms/step - loss: 0.5352 - accuracy: 0.7619 - f1_score: 0.7611 - precision: 0.7963 - recall: 0.7133 - val_loss: 0.5737 - val_accuracy: 0.7432 - val_f1_score: 0.7421 - val_precision: 0.7876 - val_recall: 0.6801 - lr: 2.7000e-06
# Epoch 54/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5381 - accuracy: 0.7576 - f1_score: 0.7558 - precision: 0.7913 - recall: 0.7104
# Epoch 54: ReduceLROnPlateau reducing learning rate to 8.099999604382901e-07.
#
# Epoch 54: val_f1_score did not improve from 0.74377
#
# Epoch 54 Learning Rate : 8.099999604382901e-07
# 432/432 [==============================] - 199s 461ms/step - loss: 0.5381 - accuracy: 0.7576 - f1_score: 0.7558 - precision: 0.7913 - recall: 0.7104 - val_loss: 0.5734 - val_accuracy: 0.7443 - val_f1_score: 0.7432 - val_precision: 0.7886 - val_recall: 0.6804 - lr: 2.7000e-06
# Epoch 55/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5362 - accuracy: 0.7575 - f1_score: 0.7561 - precision: 0.7931 - recall: 0.7091
# Epoch 55: val_f1_score did not improve from 0.74377
#
# Epoch 55 Learning Rate : 8.099999604382901e-07
# 432/432 [==============================] - 191s 442ms/step - loss: 0.5362 - accuracy: 0.7575 - f1_score: 0.7561 - precision: 0.7931 - recall: 0.7091 - val_loss: 0.5738 - val_accuracy: 0.7436 - val_f1_score: 0.7426 - val_precision: 0.7871 - val_recall: 0.6794 - lr: 8.1000e-07
# Epoch 56/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5362 - accuracy: 0.7587 - f1_score: 0.7574 - precision: 0.7932 - recall: 0.7092
# Epoch 56: val_f1_score did not improve from 0.74377
#
# Epoch 56 Learning Rate : 8.099999604382901e-07
# 432/432 [==============================] - 192s 443ms/step - loss: 0.5362 - accuracy: 0.7587 - f1_score: 0.7574 - precision: 0.7932 - recall: 0.7092 - val_loss: 0.5738 - val_accuracy: 0.7432 - val_f1_score: 0.7423 - val_precision: 0.7863 - val_recall: 0.6787 - lr: 8.1000e-07
# Epoch 57/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5340 - accuracy: 0.7582 - f1_score: 0.7565 - precision: 0.7975 - recall: 0.7139
# Epoch 57: val_f1_score did not improve from 0.74377
#
# Epoch 57 Learning Rate : 8.099999604382901e-07
# 432/432 [==============================] - 192s 445ms/step - loss: 0.5340 - accuracy: 0.7582 - f1_score: 0.7565 - precision: 0.7975 - recall: 0.7139 - val_loss: 0.5735 - val_accuracy: 0.7436 - val_f1_score: 0.7426 - val_precision: 0.7868 - val_recall: 0.6784 - lr: 8.1000e-07
# Epoch 58/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5301 - accuracy: 0.7603 - f1_score: 0.7587 - precision: 0.7954 - recall: 0.7140
# Epoch 58: val_f1_score did not improve from 0.74377
#
# Epoch 58 Learning Rate : 8.099999604382901e-07
# 432/432 [==============================] - 191s 442ms/step - loss: 0.5301 - accuracy: 0.7603 - f1_score: 0.7587 - precision: 0.7954 - recall: 0.7140 - val_loss: 0.5738 - val_accuracy: 0.7426 - val_f1_score: 0.7416 - val_precision: 0.7864 - val_recall: 0.6791 - lr: 8.1000e-07
# Epoch 59/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5363 - accuracy: 0.7579 - f1_score: 0.7564 - precision: 0.7947 - recall: 0.7106
# Epoch 59: ReduceLROnPlateau reducing learning rate to 2.4299998813148704e-07.
#
# Epoch 59: val_f1_score did not improve from 0.74377
#
# Epoch 59 Learning Rate : 2.4299998813148704e-07
# 432/432 [==============================] - 198s 458ms/step - loss: 0.5363 - accuracy: 0.7579 - f1_score: 0.7564 - precision: 0.7947 - recall: 0.7106 - val_loss: 0.5732 - val_accuracy: 0.7432 - val_f1_score: 0.7423 - val_precision: 0.7871 - val_recall: 0.6784 - lr: 8.1000e-07
# Epoch 60/150
# 432/432 [==============================] - ETA: 0s - loss: 0.5333 - accuracy: 0.7576 - f1_score: 0.7565 - precision: 0.7926 - recall: 0.7099Restoring model weights from the end of the best epoch: 44.
#
# Epoch 60: val_f1_score did not improve from 0.74377
#
# Epoch 60 Learning Rate : 2.4299998813148704e-07
# 432/432 [==============================] - 199s 460ms/step - loss: 0.5333 - accuracy: 0.7576 - f1_score: 0.7565 - precision: 0.7926 - recall: 0.7099 - val_loss: 0.5734 - val_accuracy: 0.7436 - val_f1_score: 0.7426 - val_precision: 0.7869 - val_recall: 0.6787 - lr: 2.4300e-07
# Epoch 60: early stopping
# done

# %%
# 1. Rebuild the model architecture blueprint first
model = get_ResNet101_Wavelet_Hybrid()

# 2. Load the weights directly into the blueprint
model.load_weights("ResNet101_Wavelet_Hybrid_Imbalanced_model.h5")

print("Model weights loaded successfully!")
# Out:
# Model weights loaded successfully!

# %%
# ==========================================================
# PLOT LEARNING CURVES (Loss, F1-Score, Precision)
# ==========================================================
print("start")

# 1. Loss Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Train Loss', color='red')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig("ResNet101_Wavelet_Imbalanced_Loss_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

# 2. F1 Score Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['f1_score'], label='Train F1-Score', color='blue')
plt.plot(history.history['val_f1_score'], label='Validation F1-Score', color='cyan')
plt.xlabel('Epochs')
plt.ylabel('F1-Score')
plt.legend()
plt.tight_layout()
plt.savefig("ResNet101_Wavelet_Imbalanced_F1_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

# 3. Precision Curve
plt.figure(figsize=(8, 6))
plt.plot(history.history['precision'], label='Train Precision', color='green')
plt.plot(history.history['val_precision'], label='Validation Precision', color='lightgreen')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.tight_layout()
plt.savefig("ResNet101_Wavelet_Imbalanced_Precision_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# EVALUATION (Training, Validation & Testing)
# ==========================================================
print("Evaluating on Training Set...")
train_results = model.evaluate(train_generator)

print("\nEvaluating on Validation Set...")
val_results = model.evaluate(val_generator)

print("\nEvaluating on Testing Set (Truly Unseen)...")
test_results = model.evaluate(test_generator)

# Order: [loss, accuracy, f1_score, precision, recall]
train_loss, train_acc, train_f1, train_precision, train_recall = train_results
val_loss, val_acc, val_f1, val_precision, val_recall = val_results
test_loss, test_acc, test_f1, test_precision, test_recall = test_results

print("\n" + "="*40)
print("TRAINING METRICS")
print("="*40)
print(f"Training Loss      : {train_loss:.4f}")
print(f"Training Accuracy  : {train_acc*100:.2f}%")
print(f"Training F1-Score  : {train_f1*100:.2f}%")
print(f"Training Precision : {train_precision*100:.2f}%")
print(f"Training Recall    : {train_recall*100:.2f}%")

print("\n" + "="*40)
print("VALIDATION METRICS")
print("="*40)
print(f"Validation Loss      : {val_loss:.4f}")
print(f"Validation Accuracy  : {val_acc*100:.2f}%")
print(f"Validation F1-Score  : {val_f1*100:.2f}%")
print(f"Validation Precision : {val_precision*100:.2f}%")
print(f"Validation Recall    : {val_recall*100:.2f}%")

print("\n" + "="*40)
print("TESTING METRICS (UNSEEN DATA)")
print("="*40)
print(f"Testing Loss      : {test_loss:.4f}")
print(f"Testing Accuracy  : {test_acc*100:.2f}%")
print(f"Testing F1-Score  : {test_f1*100:.2f}%")
print(f"Testing Precision : {test_precision*100:.2f}%")
print(f"Testing Recall    : {test_recall*100:.2f}%")
# Out:
# Evaluating on Training Set...
# 432/432 [==============================] - 165s 379ms/step - loss: 0.4761 - accuracy: 0.8002 - f1_score: 0.7906 - precision: 0.8285 - recall: 0.7304
#
# Evaluating on Validation Set...
# 93/93 [==============================] - 34s 363ms/step - loss: 0.5743 - accuracy: 0.7446 - f1_score: 0.7438 - precision: 0.7890 - recall: 0.6834
#
# Evaluating on Testing Set (Truly Unseen)...
# 93/93 [==============================] - 43s 463ms/step - loss: 0.5748 - accuracy: 0.7389 - f1_score: 0.7391 - precision: 0.7778 - recall: 0.6858
#
# ========================================
# TRAINING METRICS
# ========================================
# Training Loss      : 0.4761
# Training Accuracy  : 80.02%
# Training F1-Score  : 79.06%
# Training Precision : 82.85%
# Training Recall    : 73.04%
#
# ========================================
# VALIDATION METRICS
# ========================================
# Validation Loss      : 0.5743
# Validation Accuracy  : 74.46%
# Validation F1-Score  : 74.38%
# Validation Precision : 78.90%
# Validation Recall    : 68.34%
#
# ========================================
# TESTING METRICS (UNSEEN DATA)
# ========================================
# Testing Loss      : 0.5748
# Testing Accuracy  : 73.89%
# Testing F1-Score  : 73.91%
# Testing Precision : 77.78%
# Testing Recall    : 68.58%

# %%
# ==========================================================
# PRECISION, RECALL, F1-SCORE (Test Set - Unseen Data)
# ==========================================================
print("\nCalculating Precision, Recall, F1-score on Test Set...")

predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

true_classes = test_generator.classes
class_names = test_generator.class_names

print("\nClassification Report (Test Set):\n")
print(
    classification_report(
        true_classes,
        predicted_classes,
        target_names=class_names
    )
)

print("done1")
# Out:
# Calculating Precision, Recall, F1-score on Test Set...
# 93/93 [==============================] - 35s 365ms/step
#
# Classification Report (Test Set):
#
#               precision    recall  f1-score   support
#
#       Benign       0.64      0.60      0.62       911
#    Malignant       0.75      0.76      0.76      1263
#       Normal       0.82      0.87      0.84       786
#
#     accuracy                           0.74      2960
#    macro avg       0.74      0.74      0.74      2960
# weighted avg       0.74      0.74      0.74      2960
#
# done1

# %%
# ==========================================================
# CONFUSION MATRIX (Test Set)
# ==========================================================
print("Generating Confusion Matrix...")

import seaborn as sns

cm = confusion_matrix(true_classes, predicted_classes)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=class_names,
    yticklabels=class_names
)

plt.ylabel('True Label', fontsize=14)
plt.xlabel('Predicted Label', fontsize=14)
plt.xticks(rotation=45)
plt.yticks(rotation=0)

plt.tight_layout()
plt.savefig("ResNet101_Wavelet_Imbalanced_confusion_matrix_test.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# Generating Confusion Matrix...
# done1
