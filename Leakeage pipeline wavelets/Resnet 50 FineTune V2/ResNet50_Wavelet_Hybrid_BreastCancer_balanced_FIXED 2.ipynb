# %% [markdown]
# # ResNet-50 + Wavelet Features (Hybrid) — Breast Cancer Classification
# Based on: Mohanty & Das (2025), *ResNet-50 backbone + wavelet features for complementary information*.
#
# Pipeline structure mirrors the EfficientNetB3 baseline notebook: frozen ImageNet backbone → pooled deep features,
# fused with handcrafted wavelet features → dense classifier head. Same callbacks, same metrics (F1/Precision/Recall),
# same evaluation + classification report + confusion matrix flow.

# %%
# ==========================================================
# INSTALL WAVELET LIBRARY (only needed once per environment)
# ==========================================================
# !pip install PyWavelets

print("start")

import os

balanced_dataset = r"D:\Thesis_folder\Supervised_Balanced"

print("Balanced dataset ready")
# Out:
# start
# Balanced dataset ready

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("TensorFlow Version: ", tf.__version__)
# Out:
# Num GPUs Available:  1
# TensorFlow Version:  2.10.0

# %%
# ==========================================================
# IMPORTS
# ==========================================================
print("start")

import os
import numpy as np
import cv2
import pywt
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report, confusion_matrix

from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Dense, GlobalAveragePooling2D, Dropout, Concatenate, BatchNormalization
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import Sequence, to_categorical
import tensorflow_addons as tfa
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint,
    Callback
)

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# CONFIGURATION
# ==========================================================
print("start")

DATASET_PATH = r"D:\Thesis_folder\Supervised_Balanced"

IMAGE_SIZE = (320, 320)          # native ResNet-50 input size
MODEL_INPUT_SIZE = (320, 320, 3)
NUM_CLASSES = 3
BATCH_SIZE = 32
EPOCHS = 150

WAVELET_NAME = "db1"             # Daubechies-1 (Haar), matches common breast-cancer wavelet studies
WAVELET_LEVEL = 2                # decomposition depth -> richer complementary features

train_dir = os.path.join(DATASET_PATH, "train")
val_dir = os.path.join(DATASET_PATH, "val")
test_dir = os.path.join(DATASET_PATH, "test")

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# WAVELET FEATURE EXTRACTION
# ==========================================================
# For each image we take a 2D Discrete Wavelet Transform (DWT) of the grayscale
# version, then summarise every sub-band (approximation + horizontal/vertical/
# diagonal detail) with mean, std and energy. This gives a compact, complementary
# texture descriptor that is concatenated with the ResNet-50 deep features,
# following the "ResNet-50 backbone + wavelet features for complementary
# information" design in Mohanty & Das (2025).

def extract_wavelet_features(image_rgb, wavelet=WAVELET_NAME, level=WAVELET_LEVEL):
    """
    image_rgb: HxWx3 uint8 or float array (0-255 range)
    Returns: 1D float32 feature vector
    """
    gray = cv2.cvtColor(image_rgb.astype(np.uint8), cv2.COLOR_RGB2GRAY)
    coeffs = pywt.wavedec2(gray, wavelet=wavelet, level=level)

    features = []
    for idx, c in enumerate(coeffs):
        if idx == 0:
            # approximation coefficients (single array)
            sub_bands = [c]
        else:
            # detail coefficients: tuple of (cH, cV, cD)
            sub_bands = list(c)

        for sub in sub_bands:
            features.append(sub.mean())
            features.append(sub.std())
            features.append(np.sum(sub.astype(np.float64) ** 2) / sub.size)  # normalised energy

    return np.array(features, dtype=np.float32)


def get_wavelet_feature_dim():
    """Run once on a dummy image to determine the wavelet feature vector length."""
    dummy = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 3), dtype=np.uint8)
    return extract_wavelet_features(dummy).shape[0]


WAVELET_FEATURE_DIM = get_wavelet_feature_dim()
print(f"Wavelet feature vector length: {WAVELET_FEATURE_DIM}")
# Out:
# Wavelet feature vector length: 21

# %%
# ==========================================================
# DUAL-INPUT DATA GENERATOR (ResNet-50 image branch + wavelet branch)
# ==========================================================
# ImageDataGenerator.flow_from_directory only yields (image, label) pairs, so a
# custom Sequence is used here to additionally compute the wavelet feature
# vector for every image in the batch. Directory layout is identical to the
# EfficientNetB3 notebook: DATASET_PATH/{train,val,test}/<class_name>/*.jpg

class ResNetWaveletGenerator(Sequence):
    def __init__(self, directory, image_size=IMAGE_SIZE, batch_size=BATCH_SIZE,
                 num_classes=NUM_CLASSES, shuffle=True):
        self.directory = directory
        self.image_size = image_size
        self.batch_size = batch_size
        self.num_classes = num_classes
        self.shuffle = shuffle

        self.class_names = sorted(
            d for d in os.listdir(directory)
            if os.path.isdir(os.path.join(directory, d))
        )
        self.class_indices = {name: i for i, name in enumerate(self.class_names)}

        self.filepaths = []
        self.labels = []
        for cls in self.class_names:
            cls_dir = os.path.join(directory, cls)
            for fname in os.listdir(cls_dir):
                if fname.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tif", ".tiff")):
                    self.filepaths.append(os.path.join(cls_dir, fname))
                    self.labels.append(self.class_indices[cls])

        self.labels = np.array(self.labels)
        self.indices = np.arange(len(self.filepaths))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.filepaths) / self.batch_size))

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

    def __getitem__(self, idx):
        batch_idx = self.indices[idx * self.batch_size:(idx + 1) * self.batch_size]

        batch_images = np.zeros((len(batch_idx), *self.image_size, 3), dtype=np.float32)
        batch_wavelets = np.zeros((len(batch_idx), WAVELET_FEATURE_DIM), dtype=np.float32)
        batch_labels = np.zeros((len(batch_idx), self.num_classes), dtype=np.float32)

        for i, fi in enumerate(batch_idx):
            img_bgr = cv2.imread(self.filepaths[fi])
            img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
            img_rgb = cv2.resize(img_rgb, self.image_size)

            # Wavelet branch computed on the raw (0-255) resized image
            batch_wavelets[i] = extract_wavelet_features(img_rgb)

            # ResNet-50 branch uses its own preprocessing (caffe-style mean subtraction)
            batch_images[i] = preprocess_input(img_rgb.astype(np.float32).copy())

            batch_labels[i] = to_categorical(self.labels[fi], num_classes=self.num_classes)

        return (batch_images, batch_wavelets), batch_labels

    # Convenience properties to mirror ImageDataGenerator API used later in the notebook
    @property
    def classes(self):
        return self.labels

    @property
    def class_indices_(self):
        return self.class_indices


train_generator = ResNetWaveletGenerator(train_dir, shuffle=True)
val_generator = ResNetWaveletGenerator(val_dir, shuffle=False)
test_generator = ResNetWaveletGenerator(test_dir, shuffle=False)

print("Classes found:", train_generator.class_names)
print("Train / Val / Test sizes:",
      len(train_generator.filepaths), len(val_generator.filepaths), len(test_generator.filepaths))
# Out:
# Classes found: ['Benign', 'Malignant', 'Normal']
# Train / Val / Test sizes: 18000 2960 2960

# %%
# ==========================================================
# CLASS WEIGHTS -- targeted at the Benign<->Malignant confusion (NEW)
# ==========================================================
# The training set here is already near-balanced by augmentation, so a
# plain compute_class_weight('balanced') call would return ~1.0 for every
# class and change nothing. The confusion matrix on the imbalanced run
# showed the real problem isn't frequency -- it's that Benign and
# Malignant get mixed up with each other (305 Benign->Malignant and,
# more importantly, 204 Malignant->Benign, i.e. missed cancers), while
# Normal is barely confused with anything.
#
# So instead of frequency balancing, this applies a small manual boost to
# the Malignant class specifically, to push the loss to penalize missed
# Malignant cases (the costlier error direction) more heavily. Benign and
# Normal keep a weight of 1.0. Start with MALIGNANT_BOOST=1.3 and treat it
# as a tunable hyperparameter -- watch Malignant recall and Benign
# precision together as you adjust it, since pushing this too far will
# trade Malignant recall for more Benign/Normal cases being misclassified
# as Malignant.
print("start")

MALIGNANT_BOOST = 1.3

class_names = train_generator.class_names
class_weight = {i: 1.0 for i in range(len(class_names))}
malignant_idx = class_names.index("Malignant")
class_weight[malignant_idx] = MALIGNANT_BOOST

print("Class names:", class_names)
print("Class weights:", class_weight)

print("done1")
# Out:
# start
# Class names: ['Benign', 'Malignant', 'Normal']
# Class weights: {0: 1.0, 1: 1.3, 2: 1.0}
# done1

# %%
# ==========================================================
# MODEL DEFINITION: ResNet-50 (image branch) + Wavelet MLP (feature branch)
# ==========================================================
print("start")

f1_metric = tfa.metrics.F1Score(num_classes=NUM_CLASSES, average='macro', name='f1_score')
precision_metric = tf.keras.metrics.Precision(name='precision')
recall_metric = tf.keras.metrics.Recall(name='recall')

def get_ResNet50_Wavelet_Hybrid():
    # ---- Image branch: ResNet-50 (frozen, ImageNet weights) ----
    image_input = Input(shape=MODEL_INPUT_SIZE, name="image_input")
    base_model = ResNet50(
        input_tensor=image_input,
        weights='imagenet',
        include_top=False
    )
    base_model.trainable = False

    x_img = GlobalAveragePooling2D()(base_model.output)
    x_img = Dropout(0.3)(x_img)

    # ---- Wavelet branch: small MLP over handcrafted features ----
    wavelet_input = Input(shape=(WAVELET_FEATURE_DIM,), name="wavelet_input")
    x_wav = BatchNormalization()(wavelet_input)
    x_wav = Dense(64, activation='relu')(x_wav)
    x_wav = Dropout(0.3)(x_wav)

    # ---- Fusion + classifier head ----
    fused = Concatenate()([x_img, x_wav])
    fused = Dense(128, activation='relu')(fused)
    fused = Dropout(0.3)(fused)
    output = Dense(NUM_CLASSES, activation='softmax')(fused)

    model = Model(inputs=[image_input, wavelet_input], outputs=output)

    optimizer = Adam(learning_rate=0.0001)
    model.compile(
        loss="categorical_crossentropy",
        metrics=["accuracy", f1_metric, precision_metric, recall_metric],
        optimizer=optimizer
    )

    return model, base_model  # FIX: return base_model explicitly -- with input_tensor=image_input,
    # ResNet50's layers are flattened directly into model.layers, so there is no
    # single "resnet50" sub-layer to look up later, and guessing by param count
    # is not reliable (it can grab the wrong layer, e.g. a lone Conv2D).

model, base_model = get_ResNet50_Wavelet_Hybrid()
model.summary()

print("done1")
# Out:
# start
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image_input (InputLayer)       [(None, 320, 320, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 326, 326, 3)  0           ['image_input[0][0]']
#
#  conv1_conv (Conv2D)            (None, 160, 160, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 160, 160, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 160, 160, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 162, 162, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 80, 80, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 80, 80, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 80, 80, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 80, 80, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 80, 80, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 80, 80, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 80, 80, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 80, 80, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 80, 80, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 80, 80, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 80, 80, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 80, 80, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 80, 80, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 80, 80, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 80, 80, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 80, 80, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 80, 80, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 80, 80, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 80, 80, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 80, 80, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 80, 80, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 80, 80, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 80, 80, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 80, 80, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 80, 80, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 80, 80, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 80, 80, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 80, 80, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 80, 80, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 80, 80, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 80, 80, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 80, 80, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 80, 80, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 40, 40, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 40, 40, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 40, 40, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 40, 40, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 40, 40, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 40, 40, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 40, 40, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 40, 40, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 40, 40, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 40, 40, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 40, 40, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 40, 40, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 40, 40, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 40, 40, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 40, 40, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 40, 40, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 40, 40, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 40, 40, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 40, 40, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 40, 40, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 40, 40, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 40, 40, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 40, 40, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 40, 40, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 40, 40, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 40, 40, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 40, 40, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 40, 40, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 40, 40, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 40, 40, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 40, 40, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 40, 40, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 40, 40, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 40, 40, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 40, 40, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 40, 40, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 40, 40, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 40, 40, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 40, 40, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 40, 40, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 40, 40, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 40, 40, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 20, 20, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 20, 20, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 20, 20, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 20, 20, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 20, 20, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 20, 20, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 20, 20, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 20, 20, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 20, 20, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 20, 20, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 20, 20, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 20, 20, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 20, 20, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 20, 20, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 20, 20, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 20, 20, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 20, 20, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 20, 20, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 20, 20, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 20, 20, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 20, 20, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 20, 20, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 20, 20, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 20, 20, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 20, 20, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 20, 20, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 20, 20, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 20, 20, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 20, 20, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 20, 20, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 20, 20, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 20, 20, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 20, 20, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 20, 20, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 20, 20, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 20, 20, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 20, 20, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 20, 20, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 20, 20, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 20, 20, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 20, 20, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 20, 20, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 20, 20, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 20, 20, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 20, 20, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 20, 20, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 20, 20, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 20, 20, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 20, 20, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 20, 20, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 20, 20, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 20, 20, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 20, 20, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 20, 20, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 20, 20, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 20, 20, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 20, 20, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 20, 20, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 20, 20, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 20, 20, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 20, 20, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 20, 20, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 10, 10, 512)  524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 10, 10, 512)  2048       ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 10, 10, 512)  0          ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 10, 10, 512)  2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 10, 10, 512)  2048       ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 10, 10, 512)  0          ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 10, 10, 2048  2099200     ['conv4_block6_out[0][0]']
#                                 )
#
#  conv5_block1_3_conv (Conv2D)   (None, 10, 10, 2048  1050624     ['conv5_block1_2_relu[0][0]']
#                                 )
#
#  conv5_block1_0_bn (BatchNormal  (None, 10, 10, 2048  8192       ['conv5_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv5_block1_3_bn (BatchNormal  (None, 10, 10, 2048  8192       ['conv5_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv5_block1_add (Add)         (None, 10, 10, 2048  0           ['conv5_block1_0_bn[0][0]',
#                                 )                                 'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 10, 10, 2048  0           ['conv5_block1_add[0][0]']
#                                 )
#
#  conv5_block2_1_conv (Conv2D)   (None, 10, 10, 512)  1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 10, 10, 512)  2048       ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 10, 10, 512)  0          ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 10, 10, 512)  2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 10, 10, 512)  2048       ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 10, 10, 512)  0          ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 10, 10, 2048  1050624     ['conv5_block2_2_relu[0][0]']
#                                 )
#
#  conv5_block2_3_bn (BatchNormal  (None, 10, 10, 2048  8192       ['conv5_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv5_block2_add (Add)         (None, 10, 10, 2048  0           ['conv5_block1_out[0][0]',
#                                 )                                 'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 10, 10, 2048  0           ['conv5_block2_add[0][0]']
#                                 )
#
#  conv5_block3_1_conv (Conv2D)   (None, 10, 10, 512)  1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 10, 10, 512)  2048       ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 10, 10, 512)  0          ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 10, 10, 512)  2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 10, 10, 512)  2048       ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 10, 10, 512)  0          ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 10, 10, 2048  1050624     ['conv5_block3_2_relu[0][0]']
#                                 )
#
#  conv5_block3_3_bn (BatchNormal  (None, 10, 10, 2048  8192       ['conv5_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv5_block3_add (Add)         (None, 10, 10, 2048  0           ['conv5_block2_out[0][0]',
#                                 )                                 'conv5_block3_3_bn[0][0]']
#
#  wavelet_input (InputLayer)     [(None, 21)]         0           []
#
#  conv5_block3_out (Activation)  (None, 10, 10, 2048  0           ['conv5_block3_add[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 21)          84          ['wavelet_input[0][0]']
#  alization)
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 64)           1408        ['batch_normalization[0][0]']
#
#  dropout (Dropout)              (None, 2048)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout_1 (Dropout)            (None, 64)           0           ['dense[0][0]']
#
#  concatenate (Concatenate)      (None, 2112)         0           ['dropout[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  dense_1 (Dense)                (None, 128)          270464      ['concatenate[0][0]']
#
#  dropout_2 (Dropout)            (None, 128)          0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 3)            387         ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 23,860,055
# Trainable params: 272,301
# Non-trainable params: 23,587,754
# __________________________________________________________________________________________________
# done1

# %%
# ==========================================================
# CALLBACKS (Monitor set to 'val_f1_score')
# ==========================================================
print("start")

early_stop = EarlyStopping(
    monitor='val_f1_score',
    mode='max',
    patience=11,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.3,
    patience=5,
    min_lr=5e-8,
    verbose=1
)

checkpoint = ModelCheckpoint(
    "ResNet50_Wavelet_Hybrid_model.h5",
    monitor='val_f1_score',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

print("done")
# Out:
# start
# done

# %%
# ==========================================================
# SHOW LEARNING RATE
# ==========================================================
print("start")

class PrintLearningRate(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate.numpy()
        print(f"\nEpoch {epoch+1} Learning Rate : {lr}")

lr_callback = PrintLearningRate()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# TRAINING
# ==========================================================
print("start")

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    class_weight=class_weight,   # NEW -- see class-weight cell above
    callbacks=[
        early_stop,
        reduce_lr,
        checkpoint,
        lr_callback
    ]
)
print("done")
# Out:
# start
# Epoch 1/150
# 563/563 [==============================] - ETA: 0s - loss: 1.0179 - accuracy: 0.5534 - f1_score: 0.5469 - precision: 0.6015 - recall: 0.4404
# Epoch 1: val_f1_score improved from -inf to 0.61829, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 300s 526ms/step - loss: 1.0179 - accuracy: 0.5534 - f1_score: 0.5469 - precision: 0.6015 - recall: 0.4404 - val_loss: 0.7572 - val_accuracy: 0.6395 - val_f1_score: 0.6183 - val_precision: 0.7335 - val_recall: 0.5253 - lr: 1.0000e-04
# Epoch 2/150
# 563/563 [==============================] - ETA: 0s - loss: 0.8427 - accuracy: 0.6258 - f1_score: 0.6172 - precision: 0.6857 - recall: 0.5392
# Epoch 2: val_f1_score improved from 0.61829 to 0.64347, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 2 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 252s 447ms/step - loss: 0.8427 - accuracy: 0.6258 - f1_score: 0.6172 - precision: 0.6857 - recall: 0.5392 - val_loss: 0.7058 - val_accuracy: 0.6662 - val_f1_score: 0.6435 - val_precision: 0.7459 - val_recall: 0.5534 - lr: 1.0000e-04
# Epoch 3/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7914 - accuracy: 0.6492 - f1_score: 0.6420 - precision: 0.7087 - recall: 0.5706
# Epoch 3: val_f1_score improved from 0.64347 to 0.67100, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 3 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 255s 452ms/step - loss: 0.7914 - accuracy: 0.6492 - f1_score: 0.6420 - precision: 0.7087 - recall: 0.5706 - val_loss: 0.6824 - val_accuracy: 0.6834 - val_f1_score: 0.6710 - val_precision: 0.7661 - val_recall: 0.5642 - lr: 1.0000e-04
# Epoch 4/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7571 - accuracy: 0.6712 - f1_score: 0.6650 - precision: 0.7272 - recall: 0.5910
# Epoch 4: val_f1_score improved from 0.67100 to 0.68049, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 4 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 261s 462ms/step - loss: 0.7571 - accuracy: 0.6712 - f1_score: 0.6650 - precision: 0.7272 - recall: 0.5910 - val_loss: 0.6597 - val_accuracy: 0.6902 - val_f1_score: 0.6805 - val_precision: 0.7632 - val_recall: 0.5824 - lr: 1.0000e-04
# Epoch 5/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7350 - accuracy: 0.6782 - f1_score: 0.6728 - precision: 0.7303 - recall: 0.6053
# Epoch 5: val_f1_score improved from 0.68049 to 0.68187, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 5 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 259s 460ms/step - loss: 0.7350 - accuracy: 0.6782 - f1_score: 0.6728 - precision: 0.7303 - recall: 0.6053 - val_loss: 0.6531 - val_accuracy: 0.6990 - val_f1_score: 0.6819 - val_precision: 0.7620 - val_recall: 0.5939 - lr: 1.0000e-04
# Epoch 6/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7204 - accuracy: 0.6871 - f1_score: 0.6814 - precision: 0.7429 - recall: 0.6123
# Epoch 6: val_f1_score improved from 0.68187 to 0.69468, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 6 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 256s 454ms/step - loss: 0.7204 - accuracy: 0.6871 - f1_score: 0.6814 - precision: 0.7429 - recall: 0.6123 - val_loss: 0.6431 - val_accuracy: 0.7057 - val_f1_score: 0.6947 - val_precision: 0.7695 - val_recall: 0.6145 - lr: 1.0000e-04
# Epoch 7/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7055 - accuracy: 0.6966 - f1_score: 0.6913 - precision: 0.7518 - recall: 0.6293
# Epoch 7: val_f1_score did not improve from 0.69468
#
# Epoch 7 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 248s 440ms/step - loss: 0.7055 - accuracy: 0.6966 - f1_score: 0.6913 - precision: 0.7518 - recall: 0.6293 - val_loss: 0.6359 - val_accuracy: 0.7044 - val_f1_score: 0.6928 - val_precision: 0.7639 - val_recall: 0.6098 - lr: 1.0000e-04
# Epoch 8/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6951 - accuracy: 0.7013 - f1_score: 0.6965 - precision: 0.7511 - recall: 0.6301
# Epoch 8: val_f1_score improved from 0.69468 to 0.71540, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 8 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 254s 451ms/step - loss: 0.6951 - accuracy: 0.7013 - f1_score: 0.6965 - precision: 0.7511 - recall: 0.6301 - val_loss: 0.6223 - val_accuracy: 0.7213 - val_f1_score: 0.7154 - val_precision: 0.7823 - val_recall: 0.6240 - lr: 1.0000e-04
# Epoch 9/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6775 - accuracy: 0.7092 - f1_score: 0.7045 - precision: 0.7590 - recall: 0.6463
# Epoch 9: val_f1_score improved from 0.71540 to 0.72067, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 9 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 258s 458ms/step - loss: 0.6775 - accuracy: 0.7092 - f1_score: 0.7045 - precision: 0.7590 - recall: 0.6463 - val_loss: 0.6181 - val_accuracy: 0.7203 - val_f1_score: 0.7207 - val_precision: 0.7789 - val_recall: 0.6236 - lr: 1.0000e-04
# Epoch 10/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6728 - accuracy: 0.7080 - f1_score: 0.7035 - precision: 0.7571 - recall: 0.6451
# Epoch 10: val_f1_score did not improve from 0.72067
#
# Epoch 10 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 256s 453ms/step - loss: 0.6728 - accuracy: 0.7080 - f1_score: 0.7035 - precision: 0.7571 - recall: 0.6451 - val_loss: 0.6138 - val_accuracy: 0.7257 - val_f1_score: 0.7198 - val_precision: 0.7819 - val_recall: 0.6395 - lr: 1.0000e-04
# Epoch 11/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6624 - accuracy: 0.7169 - f1_score: 0.7124 - precision: 0.7622 - recall: 0.6528
# Epoch 11: val_f1_score did not improve from 0.72067
#
# Epoch 11 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 258s 458ms/step - loss: 0.6624 - accuracy: 0.7169 - f1_score: 0.7124 - precision: 0.7622 - recall: 0.6528 - val_loss: 0.6090 - val_accuracy: 0.7226 - val_f1_score: 0.7131 - val_precision: 0.7767 - val_recall: 0.6429 - lr: 1.0000e-04
# Epoch 12/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6501 - accuracy: 0.7206 - f1_score: 0.7163 - precision: 0.7652 - recall: 0.6570
# Epoch 12: val_f1_score did not improve from 0.72067
#
# Epoch 12 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 256s 456ms/step - loss: 0.6501 - accuracy: 0.7206 - f1_score: 0.7163 - precision: 0.7652 - recall: 0.6570 - val_loss: 0.6054 - val_accuracy: 0.7220 - val_f1_score: 0.7120 - val_precision: 0.7722 - val_recall: 0.6426 - lr: 1.0000e-04
# Epoch 13/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6492 - accuracy: 0.7238 - f1_score: 0.7193 - precision: 0.7683 - recall: 0.6624
# Epoch 13: val_f1_score improved from 0.72067 to 0.72295, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 13 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 256s 455ms/step - loss: 0.6492 - accuracy: 0.7238 - f1_score: 0.7193 - precision: 0.7683 - recall: 0.6624 - val_loss: 0.6043 - val_accuracy: 0.7287 - val_f1_score: 0.7230 - val_precision: 0.7811 - val_recall: 0.6426 - lr: 1.0000e-04
# Epoch 14/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6413 - accuracy: 0.7266 - f1_score: 0.7221 - precision: 0.7674 - recall: 0.6646
# Epoch 14: val_f1_score improved from 0.72295 to 0.72332, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 14 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 256s 454ms/step - loss: 0.6413 - accuracy: 0.7266 - f1_score: 0.7221 - precision: 0.7674 - recall: 0.6646 - val_loss: 0.5931 - val_accuracy: 0.7277 - val_f1_score: 0.7233 - val_precision: 0.7827 - val_recall: 0.6584 - lr: 1.0000e-04
# Epoch 15/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6369 - accuracy: 0.7276 - f1_score: 0.7230 - precision: 0.7705 - recall: 0.6688
# Epoch 15: val_f1_score improved from 0.72332 to 0.72752, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 15 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 254s 451ms/step - loss: 0.6369 - accuracy: 0.7276 - f1_score: 0.7230 - precision: 0.7705 - recall: 0.6688 - val_loss: 0.5940 - val_accuracy: 0.7257 - val_f1_score: 0.7275 - val_precision: 0.7817 - val_recall: 0.6497 - lr: 1.0000e-04
# Epoch 16/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6313 - accuracy: 0.7342 - f1_score: 0.7304 - precision: 0.7751 - recall: 0.6751
# Epoch 16: val_f1_score did not improve from 0.72752
#
# Epoch 16 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 257s 457ms/step - loss: 0.6313 - accuracy: 0.7342 - f1_score: 0.7304 - precision: 0.7751 - recall: 0.6751 - val_loss: 0.5913 - val_accuracy: 0.7294 - val_f1_score: 0.7225 - val_precision: 0.7836 - val_recall: 0.6568 - lr: 1.0000e-04
# Epoch 17/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6222 - accuracy: 0.7357 - f1_score: 0.7322 - precision: 0.7792 - recall: 0.6805
# Epoch 17: val_f1_score did not improve from 0.72752
#
# Epoch 17 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 258s 458ms/step - loss: 0.6222 - accuracy: 0.7357 - f1_score: 0.7322 - precision: 0.7792 - recall: 0.6805 - val_loss: 0.5888 - val_accuracy: 0.7240 - val_f1_score: 0.7139 - val_precision: 0.7781 - val_recall: 0.6517 - lr: 1.0000e-04
# Epoch 18/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6161 - accuracy: 0.7431 - f1_score: 0.7396 - precision: 0.7813 - recall: 0.6878
# Epoch 18: val_f1_score did not improve from 0.72752
#
# Epoch 18 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 258s 457ms/step - loss: 0.6161 - accuracy: 0.7431 - f1_score: 0.7396 - precision: 0.7813 - recall: 0.6878 - val_loss: 0.5832 - val_accuracy: 0.7307 - val_f1_score: 0.7204 - val_precision: 0.7747 - val_recall: 0.6598 - lr: 1.0000e-04
# Epoch 19/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6122 - accuracy: 0.7402 - f1_score: 0.7363 - precision: 0.7823 - recall: 0.6876
# Epoch 19: val_f1_score improved from 0.72752 to 0.73859, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 19 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 257s 457ms/step - loss: 0.6122 - accuracy: 0.7402 - f1_score: 0.7363 - precision: 0.7823 - recall: 0.6876 - val_loss: 0.5783 - val_accuracy: 0.7372 - val_f1_score: 0.7386 - val_precision: 0.7818 - val_recall: 0.6780 - lr: 1.0000e-04
# Epoch 20/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6073 - accuracy: 0.7422 - f1_score: 0.7387 - precision: 0.7808 - recall: 0.6896
# Epoch 20: val_f1_score did not improve from 0.73859
#
# Epoch 20 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 249s 441ms/step - loss: 0.6073 - accuracy: 0.7422 - f1_score: 0.7387 - precision: 0.7808 - recall: 0.6896 - val_loss: 0.5811 - val_accuracy: 0.7355 - val_f1_score: 0.7342 - val_precision: 0.7804 - val_recall: 0.6676 - lr: 1.0000e-04
# Epoch 21/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6031 - accuracy: 0.7462 - f1_score: 0.7427 - precision: 0.7867 - recall: 0.6915
# Epoch 21: val_f1_score did not improve from 0.73859
#
# Epoch 21 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 249s 443ms/step - loss: 0.6031 - accuracy: 0.7462 - f1_score: 0.7427 - precision: 0.7867 - recall: 0.6915 - val_loss: 0.5828 - val_accuracy: 0.7338 - val_f1_score: 0.7284 - val_precision: 0.7783 - val_recall: 0.6655 - lr: 1.0000e-04
# Epoch 22/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5961 - accuracy: 0.7512 - f1_score: 0.7480 - precision: 0.7913 - recall: 0.7014
# Epoch 22: val_f1_score improved from 0.73859 to 0.73961, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 22 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 263s 467ms/step - loss: 0.5961 - accuracy: 0.7512 - f1_score: 0.7480 - precision: 0.7913 - recall: 0.7014 - val_loss: 0.5759 - val_accuracy: 0.7378 - val_f1_score: 0.7396 - val_precision: 0.7809 - val_recall: 0.6851 - lr: 1.0000e-04
# Epoch 23/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5943 - accuracy: 0.7496 - f1_score: 0.7461 - precision: 0.7866 - recall: 0.6996
# Epoch 23: val_f1_score did not improve from 0.73961
#
# Epoch 23 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 260s 462ms/step - loss: 0.5943 - accuracy: 0.7496 - f1_score: 0.7461 - precision: 0.7866 - recall: 0.6996 - val_loss: 0.5776 - val_accuracy: 0.7355 - val_f1_score: 0.7334 - val_precision: 0.7824 - val_recall: 0.6730 - lr: 1.0000e-04
# Epoch 24/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5873 - accuracy: 0.7549 - f1_score: 0.7518 - precision: 0.7926 - recall: 0.7034
# Epoch 24: val_f1_score did not improve from 0.73961
#
# Epoch 24 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 259s 460ms/step - loss: 0.5873 - accuracy: 0.7549 - f1_score: 0.7518 - precision: 0.7926 - recall: 0.7034 - val_loss: 0.5710 - val_accuracy: 0.7358 - val_f1_score: 0.7358 - val_precision: 0.7770 - val_recall: 0.6814 - lr: 1.0000e-04
# Epoch 25/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5827 - accuracy: 0.7514 - f1_score: 0.7482 - precision: 0.7896 - recall: 0.7067
# Epoch 25: val_f1_score did not improve from 0.73961
#
# Epoch 25 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 255s 453ms/step - loss: 0.5827 - accuracy: 0.7514 - f1_score: 0.7482 - precision: 0.7896 - recall: 0.7067 - val_loss: 0.5719 - val_accuracy: 0.7382 - val_f1_score: 0.7309 - val_precision: 0.7815 - val_recall: 0.6861 - lr: 1.0000e-04
# Epoch 26/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5804 - accuracy: 0.7515 - f1_score: 0.7481 - precision: 0.7899 - recall: 0.7069
# Epoch 26: val_f1_score did not improve from 0.73961
#
# Epoch 26 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 249s 442ms/step - loss: 0.5804 - accuracy: 0.7515 - f1_score: 0.7481 - precision: 0.7899 - recall: 0.7069 - val_loss: 0.5728 - val_accuracy: 0.7365 - val_f1_score: 0.7306 - val_precision: 0.7834 - val_recall: 0.6855 - lr: 1.0000e-04
# Epoch 27/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5729 - accuracy: 0.7598 - f1_score: 0.7574 - precision: 0.7936 - recall: 0.7161
# Epoch 27: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 27: val_f1_score did not improve from 0.73961
#
# Epoch 27 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 250s 443ms/step - loss: 0.5729 - accuracy: 0.7598 - f1_score: 0.7574 - precision: 0.7936 - recall: 0.7161 - val_loss: 0.5725 - val_accuracy: 0.7348 - val_f1_score: 0.7311 - val_precision: 0.7782 - val_recall: 0.6818 - lr: 1.0000e-04
# Epoch 28/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5640 - accuracy: 0.7643 - f1_score: 0.7616 - precision: 0.7994 - recall: 0.7213
# Epoch 28: val_f1_score did not improve from 0.73961
#
# Epoch 28 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 250s 443ms/step - loss: 0.5640 - accuracy: 0.7643 - f1_score: 0.7616 - precision: 0.7994 - recall: 0.7213 - val_loss: 0.5631 - val_accuracy: 0.7331 - val_f1_score: 0.7291 - val_precision: 0.7852 - val_recall: 0.6868 - lr: 3.0000e-05
# Epoch 29/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5603 - accuracy: 0.7659 - f1_score: 0.7630 - precision: 0.7998 - recall: 0.7198
# Epoch 29: val_f1_score did not improve from 0.73961
#
# Epoch 29 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 256s 456ms/step - loss: 0.5603 - accuracy: 0.7659 - f1_score: 0.7630 - precision: 0.7998 - recall: 0.7198 - val_loss: 0.5683 - val_accuracy: 0.7389 - val_f1_score: 0.7365 - val_precision: 0.7835 - val_recall: 0.6895 - lr: 3.0000e-05
# Epoch 30/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5552 - accuracy: 0.7696 - f1_score: 0.7669 - precision: 0.8028 - recall: 0.7269
# Epoch 30: val_f1_score improved from 0.73961 to 0.74051, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 30 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 263s 467ms/step - loss: 0.5552 - accuracy: 0.7696 - f1_score: 0.7669 - precision: 0.8028 - recall: 0.7269 - val_loss: 0.5588 - val_accuracy: 0.7412 - val_f1_score: 0.7405 - val_precision: 0.7849 - val_recall: 0.6976 - lr: 3.0000e-05
# Epoch 31/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5548 - accuracy: 0.7679 - f1_score: 0.7657 - precision: 0.8017 - recall: 0.7255
# Epoch 31: val_f1_score improved from 0.74051 to 0.74286, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 31 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 265s 470ms/step - loss: 0.5548 - accuracy: 0.7679 - f1_score: 0.7657 - precision: 0.8017 - recall: 0.7255 - val_loss: 0.5631 - val_accuracy: 0.7439 - val_f1_score: 0.7429 - val_precision: 0.7842 - val_recall: 0.6922 - lr: 3.0000e-05
# Epoch 32/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5541 - accuracy: 0.7690 - f1_score: 0.7665 - precision: 0.8016 - recall: 0.7259
# Epoch 32: val_f1_score did not improve from 0.74286
#
# Epoch 32 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 251s 445ms/step - loss: 0.5541 - accuracy: 0.7690 - f1_score: 0.7665 - precision: 0.8016 - recall: 0.7259 - val_loss: 0.5639 - val_accuracy: 0.7409 - val_f1_score: 0.7366 - val_precision: 0.7844 - val_recall: 0.6895 - lr: 3.0000e-05
# Epoch 33/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5547 - accuracy: 0.7664 - f1_score: 0.7634 - precision: 0.8008 - recall: 0.7232
# Epoch 33: val_f1_score did not improve from 0.74286
#
# Epoch 33 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 249s 443ms/step - loss: 0.5547 - accuracy: 0.7664 - f1_score: 0.7634 - precision: 0.8008 - recall: 0.7232 - val_loss: 0.5613 - val_accuracy: 0.7412 - val_f1_score: 0.7385 - val_precision: 0.7853 - val_recall: 0.6932 - lr: 3.0000e-05
# Epoch 34/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5482 - accuracy: 0.7736 - f1_score: 0.7708 - precision: 0.8051 - recall: 0.7323
# Epoch 34: val_f1_score did not improve from 0.74286
#
# Epoch 34 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 249s 441ms/step - loss: 0.5482 - accuracy: 0.7736 - f1_score: 0.7708 - precision: 0.8051 - recall: 0.7323 - val_loss: 0.5623 - val_accuracy: 0.7395 - val_f1_score: 0.7339 - val_precision: 0.7867 - val_recall: 0.6889 - lr: 3.0000e-05
# Epoch 35/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5491 - accuracy: 0.7709 - f1_score: 0.7683 - precision: 0.8047 - recall: 0.7292
# Epoch 35: val_f1_score improved from 0.74286 to 0.74475, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 35 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 260s 462ms/step - loss: 0.5491 - accuracy: 0.7709 - f1_score: 0.7683 - precision: 0.8047 - recall: 0.7292 - val_loss: 0.5597 - val_accuracy: 0.7446 - val_f1_score: 0.7448 - val_precision: 0.7831 - val_recall: 0.6953 - lr: 3.0000e-05
# Epoch 36/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5477 - accuracy: 0.7756 - f1_score: 0.7730 - precision: 0.8058 - recall: 0.7371
# Epoch 36: val_f1_score did not improve from 0.74475
#
# Epoch 36 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 259s 460ms/step - loss: 0.5477 - accuracy: 0.7756 - f1_score: 0.7730 - precision: 0.8058 - recall: 0.7371 - val_loss: 0.5605 - val_accuracy: 0.7389 - val_f1_score: 0.7334 - val_precision: 0.7838 - val_recall: 0.6909 - lr: 3.0000e-05
# Epoch 37/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5485 - accuracy: 0.7734 - f1_score: 0.7708 - precision: 0.8057 - recall: 0.7300
# Epoch 37: val_f1_score did not improve from 0.74475
#
# Epoch 37 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 259s 459ms/step - loss: 0.5485 - accuracy: 0.7734 - f1_score: 0.7708 - precision: 0.8057 - recall: 0.7300 - val_loss: 0.5587 - val_accuracy: 0.7402 - val_f1_score: 0.7350 - val_precision: 0.7859 - val_recall: 0.6943 - lr: 3.0000e-05
# Epoch 38/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5478 - accuracy: 0.7743 - f1_score: 0.7714 - precision: 0.8052 - recall: 0.7314
# Epoch 38: val_f1_score did not improve from 0.74475
#
# Epoch 38 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 254s 451ms/step - loss: 0.5478 - accuracy: 0.7743 - f1_score: 0.7714 - precision: 0.8052 - recall: 0.7314 - val_loss: 0.5569 - val_accuracy: 0.7446 - val_f1_score: 0.7407 - val_precision: 0.7887 - val_recall: 0.6959 - lr: 3.0000e-05
# Epoch 39/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5431 - accuracy: 0.7733 - f1_score: 0.7708 - precision: 0.8060 - recall: 0.7329
# Epoch 39: val_f1_score did not improve from 0.74475
#
# Epoch 39 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 249s 443ms/step - loss: 0.5431 - accuracy: 0.7733 - f1_score: 0.7708 - precision: 0.8060 - recall: 0.7329 - val_loss: 0.5586 - val_accuracy: 0.7405 - val_f1_score: 0.7373 - val_precision: 0.7877 - val_recall: 0.6993 - lr: 3.0000e-05
# Epoch 40/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5480 - accuracy: 0.7702 - f1_score: 0.7676 - precision: 0.8006 - recall: 0.7276
# Epoch 40: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 40: val_f1_score did not improve from 0.74475
#
# Epoch 40 Learning Rate : 8.999999408842996e-06
# 563/563 [==============================] - 249s 441ms/step - loss: 0.5480 - accuracy: 0.7702 - f1_score: 0.7676 - precision: 0.8006 - recall: 0.7276 - val_loss: 0.5582 - val_accuracy: 0.7395 - val_f1_score: 0.7353 - val_precision: 0.7873 - val_recall: 0.6889 - lr: 3.0000e-05
# Epoch 41/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5381 - accuracy: 0.7768 - f1_score: 0.7743 - precision: 0.8083 - recall: 0.7348
# Epoch 41: val_f1_score did not improve from 0.74475
#
# Epoch 41 Learning Rate : 8.999999408842996e-06
# 563/563 [==============================] - 255s 453ms/step - loss: 0.5381 - accuracy: 0.7768 - f1_score: 0.7743 - precision: 0.8083 - recall: 0.7348 - val_loss: 0.5561 - val_accuracy: 0.7443 - val_f1_score: 0.7422 - val_precision: 0.7907 - val_recall: 0.6980 - lr: 9.0000e-06
# Epoch 42/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5373 - accuracy: 0.7771 - f1_score: 0.7745 - precision: 0.8089 - recall: 0.7353
# Epoch 42: val_f1_score did not improve from 0.74475
#
# Epoch 42 Learning Rate : 8.999999408842996e-06
# 563/563 [==============================] - 258s 458ms/step - loss: 0.5373 - accuracy: 0.7771 - f1_score: 0.7745 - precision: 0.8089 - recall: 0.7353 - val_loss: 0.5562 - val_accuracy: 0.7439 - val_f1_score: 0.7407 - val_precision: 0.7903 - val_recall: 0.7003 - lr: 9.0000e-06
# Epoch 43/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5389 - accuracy: 0.7776 - f1_score: 0.7750 - precision: 0.8080 - recall: 0.7357
# Epoch 43: val_f1_score did not improve from 0.74475
#
# Epoch 43 Learning Rate : 8.999999408842996e-06
# 563/563 [==============================] - 258s 458ms/step - loss: 0.5389 - accuracy: 0.7776 - f1_score: 0.7750 - precision: 0.8080 - recall: 0.7357 - val_loss: 0.5558 - val_accuracy: 0.7432 - val_f1_score: 0.7400 - val_precision: 0.7885 - val_recall: 0.6980 - lr: 9.0000e-06
# Epoch 44/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5338 - accuracy: 0.7808 - f1_score: 0.7783 - precision: 0.8094 - recall: 0.7393
# Epoch 44: val_f1_score did not improve from 0.74475
#
# Epoch 44 Learning Rate : 8.999999408842996e-06
# 563/563 [==============================] - 256s 454ms/step - loss: 0.5338 - accuracy: 0.7808 - f1_score: 0.7783 - precision: 0.8094 - recall: 0.7393 - val_loss: 0.5543 - val_accuracy: 0.7439 - val_f1_score: 0.7425 - val_precision: 0.7890 - val_recall: 0.7000 - lr: 9.0000e-06
# Epoch 45/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5340 - accuracy: 0.7796 - f1_score: 0.7773 - precision: 0.8106 - recall: 0.7396
# Epoch 45: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
#
# Epoch 45: val_f1_score did not improve from 0.74475
#
# Epoch 45 Learning Rate : 2.699999868127634e-06
# 563/563 [==============================] - 250s 444ms/step - loss: 0.5340 - accuracy: 0.7796 - f1_score: 0.7773 - precision: 0.8106 - recall: 0.7396 - val_loss: 0.5548 - val_accuracy: 0.7426 - val_f1_score: 0.7408 - val_precision: 0.7892 - val_recall: 0.6983 - lr: 9.0000e-06
# Epoch 46/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5386 - accuracy: 0.7768 - f1_score: 0.7742 - precision: 0.8087 - recall: 0.7372Restoring model weights from the end of the best epoch: 35.
#
# Epoch 46: val_f1_score did not improve from 0.74475
#
# Epoch 46 Learning Rate : 2.699999868127634e-06
# 563/563 [==============================] - 249s 442ms/step - loss: 0.5386 - accuracy: 0.7768 - f1_score: 0.7742 - precision: 0.8087 - recall: 0.7372 - val_loss: 0.5545 - val_accuracy: 0.7429 - val_f1_score: 0.7413 - val_precision: 0.7887 - val_recall: 0.6986 - lr: 2.7000e-06
# Epoch 46: early stopping
# done

# %%
# ==========================================================
# LOAD PHASE 1 (FROZEN BACKBONE) BEST WEIGHTS
# ==========================================================
# 1. Rebuild the model architecture blueprint first
model, base_model = get_ResNet50_Wavelet_Hybrid()

# 2. Load the weights directly into the blueprint
model.load_weights("ResNet50_Wavelet_Hybrid_model.h5")

print("Phase 1 model weights loaded successfully!")
# Out:
# Phase 1 model weights loaded successfully!

# %%
# ==========================================================
# PHASE 2: FINE-TUNING CALLBACKS (NEW)
# ==========================================================
print("start")

early_stop_ft = EarlyStopping(
    monitor='val_f1_score',
    mode='max',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

reduce_lr_ft = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.3,
    patience=4,
    min_lr=1e-8,
    verbose=1
)

checkpoint_ft = ModelCheckpoint(
    "ResNet50_Wavelet_Hybrid_Balanced_FineTuned_model.h5",
    monitor='val_f1_score',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# PHASE 2: FINE-TUNE THE RESNET-50 BACKBONE (NEW)
# ==========================================================
# Frozen ImageNet features are good at separating "lesion present" from
# "no lesion" (Normal was already well separated in the confusion matrix),
# but Benign vs Malignant needs finer texture/margin features that ImageNet
# weights were never trained to represent. Unfreezing the top of the
# backbone lets the model actually learn those.
print("start")

# base_model was returned directly by get_ResNet50_Wavelet_Hybrid() and
# loaded back into scope in the "LOAD PHASE 1" cell above -- no lookup needed.
base_model.trainable = True
for layer in base_model.layers[:-30]:
    layer.trainable = False
for layer in base_model.layers:
    if isinstance(layer, BatchNormalization):
        layer.trainable = False   # keep BN stats stable at a small batch size / low LR

optimizer_ft = Adam(learning_rate=1e-5)
model.compile(
    loss="categorical_crossentropy",
    metrics=["accuracy", f1_metric, precision_metric, recall_metric],
    optimizer=optimizer_ft
)

history_finetune = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=40,
    class_weight=class_weight,   # NEW -- same Malignant-boosted weighting as phase 1
    callbacks=[
        early_stop_ft,
        reduce_lr_ft,
        checkpoint_ft,
        lr_callback
    ]
)

print("done")
# Out:
# start
# Epoch 1/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0534 - accuracy: 0.9827 - f1_score: 0.9506 - precision: 0.9509 - recall: 0.9498
# Epoch 1: val_f1_score did not improve from 0.76470
#
# Epoch 1 Learning Rate : 9.999999747378752e-06
# 563/563 [==============================] - 252s 445ms/step - loss: 0.0534 - accuracy: 0.9827 - f1_score: 0.9506 - precision: 0.9509 - recall: 0.9498 - val_loss: 1.0413 - val_accuracy: 0.7490 - val_f1_score: 0.7558 - val_precision: 0.7509 - val_recall: 0.7456 - lr: 1.0000e-05
# Epoch 2/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0516 - accuracy: 0.9844 - f1_score: 0.9844 - precision: 0.9847 - recall: 0.9841
# Epoch 2: val_f1_score did not improve from 0.76470
#
# Epoch 2 Learning Rate : 9.999999747378752e-06
# 563/563 [==============================] - 253s 449ms/step - loss: 0.0516 - accuracy: 0.9844 - f1_score: 0.9844 - precision: 0.9847 - recall: 0.9841 - val_loss: 1.1828 - val_accuracy: 0.7375 - val_f1_score: 0.7461 - val_precision: 0.7390 - val_recall: 0.7365 - lr: 1.0000e-05
# Epoch 3/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0386 - accuracy: 0.9886 - f1_score: 0.9886 - precision: 0.9888 - recall: 0.9881
# Epoch 3: val_f1_score did not improve from 0.76470
#
# Epoch 3 Learning Rate : 9.999999747378752e-06
# 563/563 [==============================] - 254s 452ms/step - loss: 0.0386 - accuracy: 0.9886 - f1_score: 0.9886 - precision: 0.9888 - recall: 0.9881 - val_loss: 1.1711 - val_accuracy: 0.7392 - val_f1_score: 0.7383 - val_precision: 0.7424 - val_recall: 0.7372 - lr: 1.0000e-05
# Epoch 4/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0361 - accuracy: 0.9893 - f1_score: 0.9893 - precision: 0.9896 - recall: 0.9891
# Epoch 4: val_f1_score did not improve from 0.76470
#
# Epoch 4 Learning Rate : 9.999999747378752e-06
# 563/563 [==============================] - 252s 448ms/step - loss: 0.0361 - accuracy: 0.9893 - f1_score: 0.9893 - precision: 0.9896 - recall: 0.9891 - val_loss: 1.1859 - val_accuracy: 0.7375 - val_f1_score: 0.7481 - val_precision: 0.7401 - val_recall: 0.7368 - lr: 1.0000e-05
# Epoch 5/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0300 - accuracy: 0.9908 - f1_score: 0.9908 - precision: 0.9909 - recall: 0.9907
# Epoch 5: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
#
# Epoch 5: val_f1_score did not improve from 0.76470
#
# Epoch 5 Learning Rate : 2.9999998787388904e-06
# 563/563 [==============================] - 245s 436ms/step - loss: 0.0300 - accuracy: 0.9908 - f1_score: 0.9908 - precision: 0.9909 - recall: 0.9907 - val_loss: 1.1627 - val_accuracy: 0.7520 - val_f1_score: 0.7525 - val_precision: 0.7533 - val_recall: 0.7510 - lr: 1.0000e-05
# Epoch 6/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9973 - f1_score: 0.9973 - precision: 0.9973 - recall: 0.9972
# Epoch 6: val_f1_score did not improve from 0.76470
#
# Epoch 6 Learning Rate : 2.9999998787388904e-06
# 563/563 [==============================] - 245s 434ms/step - loss: 0.0103 - accuracy: 0.9973 - f1_score: 0.9973 - precision: 0.9973 - recall: 0.9972 - val_loss: 1.4217 - val_accuracy: 0.7611 - val_f1_score: 0.7633 - val_precision: 0.7617 - val_recall: 0.7601 - lr: 3.0000e-06
# Epoch 7/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.9982 - f1_score: 0.9982 - precision: 0.9982 - recall: 0.9982
# Epoch 7: val_f1_score did not improve from 0.76470
#
# Epoch 7 Learning Rate : 2.9999998787388904e-06
# 563/563 [==============================] - 251s 447ms/step - loss: 0.0069 - accuracy: 0.9982 - f1_score: 0.9982 - precision: 0.9982 - recall: 0.9982 - val_loss: 1.4325 - val_accuracy: 0.7584 - val_f1_score: 0.7622 - val_precision: 0.7597 - val_recall: 0.7571 - lr: 3.0000e-06
# Epoch 8/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9986 - f1_score: 0.9986 - precision: 0.9986 - recall: 0.9986
# Epoch 8: val_f1_score did not improve from 0.76470
#
# Epoch 8 Learning Rate : 2.9999998787388904e-06
# 563/563 [==============================] - 256s 455ms/step - loss: 0.0066 - accuracy: 0.9986 - f1_score: 0.9986 - precision: 0.9986 - recall: 0.9986 - val_loss: 1.4422 - val_accuracy: 0.7534 - val_f1_score: 0.7611 - val_precision: 0.7545 - val_recall: 0.7527 - lr: 3.0000e-06
# Epoch 9/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9992 - f1_score: 0.9992 - precision: 0.9992 - recall: 0.9992
# Epoch 9: val_f1_score improved from 0.76470 to 0.76766, saving model to ResNet50_Wavelet_Hybrid_Balanced_FineTuned_model.h5
#
# Epoch 9 Learning Rate : 2.9999998787388904e-06
# 563/563 [==============================] - 268s 475ms/step - loss: 0.0039 - accuracy: 0.9992 - f1_score: 0.9992 - precision: 0.9992 - recall: 0.9992 - val_loss: 1.5345 - val_accuracy: 0.7618 - val_f1_score: 0.7677 - val_precision: 0.7635 - val_recall: 0.7611 - lr: 3.0000e-06
# Epoch 10/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9986 - f1_score: 0.9986 - precision: 0.9987 - recall: 0.9985
# Epoch 10: val_f1_score did not improve from 0.76766
#
# Epoch 10 Learning Rate : 2.9999998787388904e-06
# 563/563 [==============================] - 254s 450ms/step - loss: 0.0056 - accuracy: 0.9986 - f1_score: 0.9986 - precision: 0.9987 - recall: 0.9985 - val_loss: 1.6585 - val_accuracy: 0.7595 - val_f1_score: 0.7670 - val_precision: 0.7599 - val_recall: 0.7581 - lr: 3.0000e-06
# Epoch 11/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9989 - f1_score: 0.9989 - precision: 0.9989 - recall: 0.9989
# Epoch 11: val_f1_score did not improve from 0.76766
#
# Epoch 11 Learning Rate : 2.9999998787388904e-06
# 563/563 [==============================] - 246s 438ms/step - loss: 0.0050 - accuracy: 0.9989 - f1_score: 0.9989 - precision: 0.9989 - recall: 0.9989 - val_loss: 1.5720 - val_accuracy: 0.7497 - val_f1_score: 0.7546 - val_precision: 0.7504 - val_recall: 0.7486 - lr: 3.0000e-06
# Epoch 12/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9992 - f1_score: 0.9992 - precision: 0.9992 - recall: 0.9992
# Epoch 12: val_f1_score did not improve from 0.76766
#
# Epoch 12 Learning Rate : 2.9999998787388904e-06
# 563/563 [==============================] - 246s 437ms/step - loss: 0.0034 - accuracy: 0.9992 - f1_score: 0.9992 - precision: 0.9992 - recall: 0.9992 - val_loss: 1.7918 - val_accuracy: 0.7551 - val_f1_score: 0.7591 - val_precision: 0.7558 - val_recall: 0.7547 - lr: 3.0000e-06
# Epoch 13/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9991 - f1_score: 0.9991 - precision: 0.9991 - recall: 0.9991
# Epoch 13: ReduceLROnPlateau reducing learning rate to 8.999999636216671e-07.
#
# Epoch 13: val_f1_score did not improve from 0.76766
#
# Epoch 13 Learning Rate : 8.999999749903509e-07
# 563/563 [==============================] - 248s 440ms/step - loss: 0.0036 - accuracy: 0.9991 - f1_score: 0.9991 - precision: 0.9991 - recall: 0.9991 - val_loss: 1.6977 - val_accuracy: 0.7642 - val_f1_score: 0.7671 - val_precision: 0.7644 - val_recall: 0.7642 - lr: 3.0000e-06
# Epoch 14/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9997 - f1_score: 0.9997 - precision: 0.9997 - recall: 0.9997
# Epoch 14: val_f1_score did not improve from 0.76766
#
# Epoch 14 Learning Rate : 8.999999749903509e-07
# 563/563 [==============================] - 253s 450ms/step - loss: 0.0016 - accuracy: 0.9997 - f1_score: 0.9997 - precision: 0.9997 - recall: 0.9997 - val_loss: 1.7400 - val_accuracy: 0.7588 - val_f1_score: 0.7634 - val_precision: 0.7584 - val_recall: 0.7571 - lr: 9.0000e-07
# Epoch 15/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9997 - f1_score: 0.9997 - precision: 0.9997 - recall: 0.9997
# Epoch 15: val_f1_score did not improve from 0.76766
#
# Epoch 15 Learning Rate : 8.999999749903509e-07
# 563/563 [==============================] - 256s 454ms/step - loss: 0.0017 - accuracy: 0.9997 - f1_score: 0.9997 - precision: 0.9997 - recall: 0.9997 - val_loss: 1.8069 - val_accuracy: 0.7564 - val_f1_score: 0.7606 - val_precision: 0.7567 - val_recall: 0.7564 - lr: 9.0000e-07
# Epoch 16/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9997 - f1_score: 0.9997 - precision: 0.9997 - recall: 0.9997
# Epoch 16: val_f1_score did not improve from 0.76766
#
# Epoch 16 Learning Rate : 8.999999749903509e-07
# 563/563 [==============================] - 255s 453ms/step - loss: 0.0013 - accuracy: 0.9997 - f1_score: 0.9997 - precision: 0.9997 - recall: 0.9997 - val_loss: 1.8871 - val_accuracy: 0.7547 - val_f1_score: 0.7565 - val_precision: 0.7555 - val_recall: 0.7547 - lr: 9.0000e-07
# Epoch 17/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9997 - f1_score: 0.9997 - precision: 0.9997 - recall: 0.9997
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.6999999249710525e-07.
#
# Epoch 17: val_f1_score did not improve from 0.76766
#
# Epoch 17 Learning Rate : 2.699999868127634e-07
# 563/563 [==============================] - 250s 443ms/step - loss: 0.0017 - accuracy: 0.9997 - f1_score: 0.9997 - precision: 0.9997 - recall: 0.9997 - val_loss: 1.8111 - val_accuracy: 0.7547 - val_f1_score: 0.7607 - val_precision: 0.7549 - val_recall: 0.7544 - lr: 9.0000e-07
# Epoch 18/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9997 - f1_score: 0.9997 - precision: 0.9997 - recall: 0.9997
# Epoch 18: val_f1_score did not improve from 0.76766
#
# Epoch 18 Learning Rate : 2.699999868127634e-07
# 563/563 [==============================] - 247s 438ms/step - loss: 0.0013 - accuracy: 0.9997 - f1_score: 0.9997 - precision: 0.9997 - recall: 0.9997 - val_loss: 1.8133 - val_accuracy: 0.7514 - val_f1_score: 0.7554 - val_precision: 0.7525 - val_recall: 0.7510 - lr: 2.7000e-07
# Epoch 19/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9998 - f1_score: 0.9998 - precision: 0.9998 - recall: 0.9998Restoring model weights from the end of the best epoch: 9.
#
# Epoch 19: val_f1_score did not improve from 0.76766
#
# Epoch 19 Learning Rate : 2.699999868127634e-07
# 563/563 [==============================] - 247s 439ms/step - loss: 0.0011 - accuracy: 0.9998 - f1_score: 0.9998 - precision: 0.9998 - recall: 0.9998 - val_loss: 1.8420 - val_accuracy: 0.7541 - val_f1_score: 0.7612 - val_precision: 0.7547 - val_recall: 0.7527 - lr: 2.7000e-07
# Epoch 19: early stopping
# done

# %%
# ==========================================================
# LOAD PHASE 2 (FINE-TUNED) BEST WEIGHTS -- use this for final evaluation
# ==========================================================
model, base_model = get_ResNet50_Wavelet_Hybrid()
base_model.trainable = True
for layer in base_model.layers[:-30]:
    layer.trainable = False
for layer in base_model.layers:
    if isinstance(layer, BatchNormalization):
        layer.trainable = False
model.compile(
    loss="categorical_crossentropy",
    metrics=["accuracy", f1_metric, precision_metric, recall_metric],
    optimizer=Adam(learning_rate=1e-5)
)
model.load_weights("ResNet50_Wavelet_Hybrid_Balanced_FineTuned_model.h5")

print("Fine-tuned model weights loaded successfully!")
# Out:
# Fine-tuned model weights loaded successfully!

# %%
# ==========================================================
# PLOT LEARNING CURVES (Loss, F1-Score, Precision)
# Phase 1 (frozen) and Phase 2 (fine-tuned) plotted as one continuous
# curve, with the join point marked (NEW).
# ==========================================================
print("start")

def concat_history(h1, h2, key):
    return h1.history[key] + h2.history[key]

phase1_end = len(history.history['loss'])

# 1. Loss Curve
plt.figure(figsize=(8, 6))
plt.plot(concat_history(history, history_finetune, 'loss'), label='Train Loss', color='red')
plt.plot(concat_history(history, history_finetune, 'val_loss'), label='Validation Loss', color='orange')
plt.axvline(phase1_end, linestyle='--', color='gray', label='Fine-tuning starts')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig("ResNet50_Wavelet_Balanced_Loss_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

# 2. F1 Score Curve
plt.figure(figsize=(8, 6))
plt.plot(concat_history(history, history_finetune, 'f1_score'), label='Train F1-Score', color='blue')
plt.plot(concat_history(history, history_finetune, 'val_f1_score'), label='Validation F1-Score', color='cyan')
plt.axvline(phase1_end, linestyle='--', color='gray', label='Fine-tuning starts')
plt.xlabel('Epochs')
plt.ylabel('F1-Score')
plt.legend()
plt.tight_layout()
plt.savefig("ResNet50_Wavelet_Balanced_F1_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

# 3. Precision Curve
plt.figure(figsize=(8, 6))
plt.plot(concat_history(history, history_finetune, 'precision'), label='Train Precision', color='green')
plt.plot(concat_history(history, history_finetune, 'val_precision'), label='Validation Precision', color='lightgreen')
plt.axvline(phase1_end, linestyle='--', color='gray', label='Fine-tuning starts')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.tight_layout()
plt.savefig("ResNet50_Wavelet_Balanced_Precision_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# EVALUATION (Training, Validation & Testing)
# ==========================================================
print("Evaluating on Training Set...")
train_results = model.evaluate(train_generator)

print("\nEvaluating on Validation Set...")
val_results = model.evaluate(val_generator)

print("\nEvaluating on Testing Set (Truly Unseen)...")
test_results = model.evaluate(test_generator)

# Order: [loss, accuracy, f1_score, precision, recall]
train_loss, train_acc, train_f1, train_precision, train_recall = train_results
val_loss, val_acc, val_f1, val_precision, val_recall = val_results
test_loss, test_acc, test_f1, test_precision, test_recall = test_results

print("\n" + "="*40)
print("TRAINING METRICS")
print("="*40)
print(f"Training Loss      : {train_loss:.4f}")
print(f"Training Accuracy  : {train_acc*100:.2f}%")
print(f"Training F1-Score  : {train_f1*100:.2f}%")
print(f"Training Precision : {train_precision*100:.2f}%")
print(f"Training Recall    : {train_recall*100:.2f}%")

print("\n" + "="*40)
print("VALIDATION METRICS")
print("="*40)
print(f"Validation Loss      : {val_loss:.4f}")
print(f"Validation Accuracy  : {val_acc*100:.2f}%")
print(f"Validation F1-Score  : {val_f1*100:.2f}%")
print(f"Validation Precision : {val_precision*100:.2f}%")
print(f"Validation Recall    : {val_recall*100:.2f}%")

print("\n" + "="*40)
print("TESTING METRICS (UNSEEN DATA)")
print("="*40)
print(f"Testing Loss      : {test_loss:.4f}")
print(f"Testing Accuracy  : {test_acc*100:.2f}%")
print(f"Testing F1-Score  : {test_f1*100:.2f}%")
print(f"Testing Precision : {test_precision*100:.2f}%")
print(f"Testing Recall    : {test_recall*100:.2f}%")
# Out:
# Evaluating on Training Set...
# 563/563 [==============================] - 219s 387ms/step - loss: 4.8235e-04 - accuracy: 0.9999 - f1_score: 0.9655 - precision: 0.9654 - recall: 0.9650
#
# Evaluating on Validation Set...
# 93/93 [==============================] - 37s 390ms/step - loss: 1.5345 - accuracy: 0.7618 - f1_score: 0.7677 - precision: 0.7635 - recall: 0.7611
#
# Evaluating on Testing Set (Truly Unseen)...
# 93/93 [==============================] - 43s 459ms/step - loss: 1.6612 - accuracy: 0.7466 - f1_score: 0.7537 - precision: 0.7482 - recall: 0.7459
#
# ========================================
# TRAINING METRICS
# ========================================
# Training Loss      : 0.0005
# Training Accuracy  : 99.99%
# Training F1-Score  : 96.55%
# Training Precision : 96.54%
# Training Recall    : 96.50%
#
# ========================================
# VALIDATION METRICS
# ========================================
# Validation Loss      : 1.5345
# Validation Accuracy  : 76.18%
# Validation F1-Score  : 76.77%
# Validation Precision : 76.35%
# Validation Recall    : 76.11%
#
# ========================================
# TESTING METRICS (UNSEEN DATA)
# ========================================
# Testing Loss      : 1.6612
# Testing Accuracy  : 74.66%
# Testing F1-Score  : 75.37%
# Testing Precision : 74.82%
# Testing Recall    : 74.59%

# %%
# ==========================================================
# PRECISION, RECALL, F1-SCORE (Test Set - Unseen Data)
# ==========================================================
print("\nCalculating Precision, Recall, F1-score on Test Set...")

predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

true_classes = test_generator.classes
class_names = test_generator.class_names

print("\nClassification Report (Test Set):\n")
print(
    classification_report(
        true_classes,
        predicted_classes,
        target_names=class_names
    )
)

print("done1")
# Out:
# Calculating Precision, Recall, F1-score on Test Set...
# 93/93 [==============================] - 36s 378ms/step
#
# Classification Report (Test Set):
#
#               precision    recall  f1-score   support
#
#       Benign       0.62      0.69      0.65       910
#    Malignant       0.77      0.72      0.74      1263
#       Normal       0.86      0.86      0.86       787
#
#     accuracy                           0.75      2960
#    macro avg       0.75      0.76      0.75      2960
# weighted avg       0.75      0.75      0.75      2960
#
# done1

# %%
# ==========================================================
# CONFUSION MATRIX (Test Set)
# ==========================================================
print("Generating Confusion Matrix...")

import seaborn as sns

cm = confusion_matrix(true_classes, predicted_classes)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=class_names,
    yticklabels=class_names
)

plt.ylabel('True Label', fontsize=14)
plt.xlabel('Predicted Label', fontsize=14)
plt.xticks(rotation=45)
plt.yticks(rotation=0)

plt.tight_layout()
plt.savefig("ResNet50_Wavelet_confusion_matrix_test.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# Generating Confusion Matrix...
# done1
