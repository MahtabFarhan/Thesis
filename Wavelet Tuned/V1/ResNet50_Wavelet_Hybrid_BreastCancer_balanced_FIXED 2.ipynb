# %% [markdown]
# # ResNet-50 + Wavelet Features (Hybrid) — Breast Cancer Classification
# Based on: Mohanty & Das (2025), *ResNet-50 backbone + wavelet features for complementary information*.
#
# Pipeline structure mirrors the EfficientNetB3 baseline notebook: frozen ImageNet backbone → pooled deep features,
# fused with handcrafted wavelet features → dense classifier head. Same callbacks, same metrics (F1/Precision/Recall),
# same evaluation + classification report + confusion matrix flow.

# %%
# ==========================================================
# INSTALL WAVELET LIBRARY (only needed once per environment)
# ==========================================================
# !pip install PyWavelets

print("start")

import os

balanced_dataset = r"D:\Thesis_folder\Preprocessed_PipelineSupervised_Balanced"

print("Balanced dataset ready")
# Out:
# start
# Balanced dataset ready

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("TensorFlow Version: ", tf.__version__)
# Out:
# Num GPUs Available:  1
# TensorFlow Version:  2.10.0

# %%
# ==========================================================
# IMPORTS
# ==========================================================
print("start")

import os
import numpy as np
import cv2
import pywt
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report, confusion_matrix

from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Dense, GlobalAveragePooling2D, Dropout, Concatenate, BatchNormalization
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import Sequence, to_categorical
import tensorflow_addons as tfa
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint,
    Callback
)

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# CONFIGURATION
# ==========================================================
print("start")

DATASET_PATH = r"D:\Thesis_folder\Preprocessed_Pipeline\Supervised_Balanced"

IMAGE_SIZE = (288, 288)          # native ResNet-50 input size
MODEL_INPUT_SIZE = (288, 288, 3)
NUM_CLASSES = 3
BATCH_SIZE = 32
EPOCHS = 150

WAVELET_NAME = "db1"             # Daubechies-1 (Haar), matches common breast-cancer wavelet studies
WAVELET_LEVEL = 2                # decomposition depth -> richer complementary features

train_dir = os.path.join(DATASET_PATH, "train")
val_dir = os.path.join(DATASET_PATH, "val")
test_dir = os.path.join(DATASET_PATH, "test")

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# WAVELET FEATURE EXTRACTION
# ==========================================================
# For each image we take a 2D Discrete Wavelet Transform (DWT) of the grayscale
# version, then summarise every sub-band (approximation + horizontal/vertical/
# diagonal detail) with mean, std and energy. This gives a compact, complementary
# texture descriptor that is concatenated with the ResNet-50 deep features,
# following the "ResNet-50 backbone + wavelet features for complementary
# information" design in Mohanty & Das (2025).

def extract_wavelet_features(image_rgb, wavelet=WAVELET_NAME, level=WAVELET_LEVEL):
    """
    image_rgb: HxWx3 uint8 or float array (0-255 range)
    Returns: 1D float32 feature vector
    """
    gray = cv2.cvtColor(image_rgb.astype(np.uint8), cv2.COLOR_RGB2GRAY)
    coeffs = pywt.wavedec2(gray, wavelet=wavelet, level=level)

    features = []
    for idx, c in enumerate(coeffs):
        if idx == 0:
            # approximation coefficients (single array)
            sub_bands = [c]
        else:
            # detail coefficients: tuple of (cH, cV, cD)
            sub_bands = list(c)

        for sub in sub_bands:
            features.append(sub.mean())
            features.append(sub.std())
            features.append(np.sum(sub.astype(np.float64) ** 2) / sub.size)  # normalised energy

    return np.array(features, dtype=np.float32)


def get_wavelet_feature_dim():
    """Run once on a dummy image to determine the wavelet feature vector length."""
    dummy = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 3), dtype=np.uint8)
    return extract_wavelet_features(dummy).shape[0]


WAVELET_FEATURE_DIM = get_wavelet_feature_dim()
print(f"Wavelet feature vector length: {WAVELET_FEATURE_DIM}")
# Out:
# Wavelet feature vector length: 21

# %%
# ==========================================================
# DUAL-INPUT DATA GENERATOR (ResNet-50 image branch + wavelet branch)
# ==========================================================
# ImageDataGenerator.flow_from_directory only yields (image, label) pairs, so a
# custom Sequence is used here to additionally compute the wavelet feature
# vector for every image in the batch. Directory layout is identical to the
# EfficientNetB3 notebook: DATASET_PATH/{train,val,test}/<class_name>/*.jpg

class ResNetWaveletGenerator(Sequence):
    def __init__(self, directory, image_size=IMAGE_SIZE, batch_size=BATCH_SIZE,
                 num_classes=NUM_CLASSES, shuffle=True):
        self.directory = directory
        self.image_size = image_size
        self.batch_size = batch_size
        self.num_classes = num_classes
        self.shuffle = shuffle

        self.class_names = sorted(
            d for d in os.listdir(directory)
            if os.path.isdir(os.path.join(directory, d))
        )
        self.class_indices = {name: i for i, name in enumerate(self.class_names)}

        self.filepaths = []
        self.labels = []
        for cls in self.class_names:
            cls_dir = os.path.join(directory, cls)
            for fname in os.listdir(cls_dir):
                if fname.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tif", ".tiff")):
                    self.filepaths.append(os.path.join(cls_dir, fname))
                    self.labels.append(self.class_indices[cls])

        self.labels = np.array(self.labels)
        self.indices = np.arange(len(self.filepaths))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.filepaths) / self.batch_size))

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

    def __getitem__(self, idx):
        batch_idx = self.indices[idx * self.batch_size:(idx + 1) * self.batch_size]

        batch_images = np.zeros((len(batch_idx), *self.image_size, 3), dtype=np.float32)
        batch_wavelets = np.zeros((len(batch_idx), WAVELET_FEATURE_DIM), dtype=np.float32)
        batch_labels = np.zeros((len(batch_idx), self.num_classes), dtype=np.float32)

        for i, fi in enumerate(batch_idx):
            img_bgr = cv2.imread(self.filepaths[fi])
            img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
            img_rgb = cv2.resize(img_rgb, self.image_size)

            # Wavelet branch computed on the raw (0-255) resized image
            batch_wavelets[i] = extract_wavelet_features(img_rgb)

            # ResNet-50 branch uses its own preprocessing (caffe-style mean subtraction)
            batch_images[i] = preprocess_input(img_rgb.astype(np.float32).copy())

            batch_labels[i] = to_categorical(self.labels[fi], num_classes=self.num_classes)

        return (batch_images, batch_wavelets), batch_labels

    # Convenience properties to mirror ImageDataGenerator API used later in the notebook
    @property
    def classes(self):
        return self.labels

    @property
    def class_indices_(self):
        return self.class_indices


train_generator = ResNetWaveletGenerator(train_dir, shuffle=True)
val_generator = ResNetWaveletGenerator(val_dir, shuffle=False)
test_generator = ResNetWaveletGenerator(test_dir, shuffle=False)

print("Classes found:", train_generator.class_names)
print("Train / Val / Test sizes:",
      len(train_generator.filepaths), len(val_generator.filepaths), len(test_generator.filepaths))
# Out:
# Classes found: ['Benign', 'Malignant', 'Normal']
# Train / Val / Test sizes: 18000 2965 2943

# %%
# ==========================================================
# CLASS WEIGHTS -- targeted at the Benign<->Malignant confusion (NEW)
# ==========================================================
# The training set here is already near-balanced by augmentation, so a
# plain compute_class_weight('balanced') call would return ~1.0 for every
# class and change nothing. The confusion matrix on the imbalanced run
# showed the real problem isn't frequency -- it's that Benign and
# Malignant get mixed up with each other (305 Benign->Malignant and,
# more importantly, 204 Malignant->Benign, i.e. missed cancers), while
# Normal is barely confused with anything.
#
# So instead of frequency balancing, this applies a small manual boost to
# the Malignant class specifically, to push the loss to penalize missed
# Malignant cases (the costlier error direction) more heavily. Benign and
# Normal keep a weight of 1.0. Start with MALIGNANT_BOOST=1.3 and treat it
# as a tunable hyperparameter -- watch Malignant recall and Benign
# precision together as you adjust it, since pushing this too far will
# trade Malignant recall for more Benign/Normal cases being misclassified
# as Malignant.
print("start")

MALIGNANT_BOOST = 1.3

class_names = train_generator.class_names
class_weight = {i: 1.0 for i in range(len(class_names))}
malignant_idx = class_names.index("Malignant")
class_weight[malignant_idx] = MALIGNANT_BOOST

print("Class names:", class_names)
print("Class weights:", class_weight)

print("done1")
# Out:
# start
# Class names: ['Benign', 'Malignant', 'Normal']
# Class weights: {0: 1.0, 1: 1.3, 2: 1.0}
# done1

# %%
# ==========================================================
# MODEL DEFINITION: ResNet-50 (image branch) + Wavelet MLP (feature branch)
# ==========================================================
print("start")

f1_metric = tfa.metrics.F1Score(num_classes=NUM_CLASSES, average='macro', name='f1_score')
precision_metric = tf.keras.metrics.Precision(name='precision')
recall_metric = tf.keras.metrics.Recall(name='recall')

def get_ResNet50_Wavelet_Hybrid():
    # ---- Image branch: ResNet-50 (frozen, ImageNet weights) ----
    image_input = Input(shape=MODEL_INPUT_SIZE, name="image_input")
    base_model = ResNet50(
        input_tensor=image_input,
        weights='imagenet',
        include_top=False
    )
    base_model.trainable = False

    x_img = GlobalAveragePooling2D()(base_model.output)
    x_img = Dropout(0.3)(x_img)

    # ---- Wavelet branch: small MLP over handcrafted features ----
    wavelet_input = Input(shape=(WAVELET_FEATURE_DIM,), name="wavelet_input")
    x_wav = BatchNormalization()(wavelet_input)
    x_wav = Dense(64, activation='relu')(x_wav)
    x_wav = Dropout(0.3)(x_wav)

    # ---- Fusion + classifier head ----
    fused = Concatenate()([x_img, x_wav])
    fused = Dense(128, activation='relu')(fused)
    fused = Dropout(0.3)(fused)
    output = Dense(NUM_CLASSES, activation='softmax')(fused)

    model = Model(inputs=[image_input, wavelet_input], outputs=output)

    optimizer = Adam(learning_rate=0.0001)
    model.compile(
        loss="categorical_crossentropy",
        metrics=["accuracy", f1_metric, precision_metric, recall_metric],
        optimizer=optimizer
    )

    return model, base_model  # FIX: return base_model explicitly -- with input_tensor=image_input,
    # ResNet50's layers are flattened directly into model.layers, so there is no
    # single "resnet50" sub-layer to look up later, and guessing by param count
    # is not reliable (it can grab the wrong layer, e.g. a lone Conv2D).

model, base_model = get_ResNet50_Wavelet_Hybrid()
model.summary()

print("done1")
# Out:
# start
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image_input (InputLayer)       [(None, 288, 288, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 294, 294, 3)  0           ['image_input[0][0]']
#
#  conv1_conv (Conv2D)            (None, 144, 144, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 144, 144, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 144, 144, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 146, 146, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 72, 72, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 72, 72, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 72, 72, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 72, 72, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 72, 72, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 72, 72, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 72, 72, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 72, 72, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 72, 72, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 72, 72, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 72, 72, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 72, 72, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 72, 72, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 72, 72, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 72, 72, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 72, 72, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 72, 72, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 72, 72, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 72, 72, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 72, 72, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 72, 72, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 72, 72, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 72, 72, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 36, 36, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 36, 36, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 36, 36, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 36, 36, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 36, 36, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 36, 36, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 36, 36, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 36, 36, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 36, 36, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 36, 36, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 36, 36, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 36, 36, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 36, 36, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 36, 36, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 36, 36, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 36, 36, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 36, 36, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 36, 36, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 36, 36, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 36, 36, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 36, 36, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 36, 36, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 36, 36, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 36, 36, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 36, 36, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 36, 36, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 36, 36, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 36, 36, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 18, 18, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 18, 18, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 18, 18, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 18, 18, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 18, 18, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 18, 18, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 18, 18, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 18, 18, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 18, 18, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 18, 18, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 18, 18, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 18, 18, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 18, 18, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 18, 18, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 9, 9, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 9, 9, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 9, 9, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 9, 9, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 9, 9, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 9, 9, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 9, 9, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 9, 9, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 9, 9, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 9, 9, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 9, 9, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 9, 9, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 9, 9, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 9, 9, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 9, 9, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 9, 9, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 9, 9, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 9, 9, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 9, 9, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 9, 9, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 9, 9, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  wavelet_input (InputLayer)     [(None, 21)]         0           []
#
#  conv5_block3_out (Activation)  (None, 9, 9, 2048)   0           ['conv5_block3_add[0][0]']
#
#  batch_normalization (BatchNorm  (None, 21)          84          ['wavelet_input[0][0]']
#  alization)
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 64)           1408        ['batch_normalization[0][0]']
#
#  dropout (Dropout)              (None, 2048)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout_1 (Dropout)            (None, 64)           0           ['dense[0][0]']
#
#  concatenate (Concatenate)      (None, 2112)         0           ['dropout[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  dense_1 (Dense)                (None, 128)          270464      ['concatenate[0][0]']
#
#  dropout_2 (Dropout)            (None, 128)          0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 3)            387         ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 23,860,055
# Trainable params: 272,301
# Non-trainable params: 23,587,754
# __________________________________________________________________________________________________
# done1

# %%
# ==========================================================
# CALLBACKS (Monitor set to 'val_f1_score')
# ==========================================================
print("start")

early_stop = EarlyStopping(
    monitor='val_f1_score',
    mode='max',
    patience=11,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.3,
    patience=5,
    min_lr=5e-8,
    verbose=1
)

checkpoint = ModelCheckpoint(
    "ResNet50_Wavelet_Hybrid_model.h5",
    monitor='val_f1_score',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

print("done")
# Out:
# start
# done

# %%
# ==========================================================
# SHOW LEARNING RATE
# ==========================================================
print("start")

class PrintLearningRate(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate.numpy()
        print(f"\nEpoch {epoch+1} Learning Rate : {lr}")

lr_callback = PrintLearningRate()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# TRAINING
# ==========================================================
print("start")

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    class_weight=class_weight,   # NEW -- see class-weight cell above
    callbacks=[
        early_stop,
        reduce_lr,
        checkpoint,
        lr_callback
    ]
)
print("done")
# Out:
# start
# Epoch 1/150
# 563/563 [==============================] - ETA: 0s - loss: 1.0023 - accuracy: 0.5592 - f1_score: 0.5516 - precision: 0.6105 - recall: 0.4469
# Epoch 1: val_f1_score improved from -inf to 0.62000, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 542s 956ms/step - loss: 1.0023 - accuracy: 0.5592 - f1_score: 0.5516 - precision: 0.6105 - recall: 0.4469 - val_loss: 0.7577 - val_accuracy: 0.6435 - val_f1_score: 0.6200 - val_precision: 0.7371 - val_recall: 0.5258 - lr: 1.0000e-04
# Epoch 2/150
# 563/563 [==============================] - ETA: 0s - loss: 0.8495 - accuracy: 0.6251 - f1_score: 0.6166 - precision: 0.6877 - recall: 0.5355
# Epoch 2: val_f1_score improved from 0.62000 to 0.65343, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 2 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 267s 475ms/step - loss: 0.8495 - accuracy: 0.6251 - f1_score: 0.6166 - precision: 0.6877 - recall: 0.5355 - val_loss: 0.7173 - val_accuracy: 0.6594 - val_f1_score: 0.6534 - val_precision: 0.7573 - val_recall: 0.5390 - lr: 1.0000e-04
# Epoch 3/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7934 - accuracy: 0.6541 - f1_score: 0.6464 - precision: 0.7123 - recall: 0.5686
# Epoch 3: val_f1_score improved from 0.65343 to 0.65972, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 3 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 276s 490ms/step - loss: 0.7934 - accuracy: 0.6541 - f1_score: 0.6464 - precision: 0.7123 - recall: 0.5686 - val_loss: 0.6852 - val_accuracy: 0.6742 - val_f1_score: 0.6597 - val_precision: 0.7497 - val_recall: 0.5636 - lr: 1.0000e-04
# Epoch 4/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7658 - accuracy: 0.6644 - f1_score: 0.6568 - precision: 0.7214 - recall: 0.5847
# Epoch 4: val_f1_score improved from 0.65972 to 0.66560, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 4 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 282s 500ms/step - loss: 0.7658 - accuracy: 0.6644 - f1_score: 0.6568 - precision: 0.7214 - recall: 0.5847 - val_loss: 0.6732 - val_accuracy: 0.6745 - val_f1_score: 0.6656 - val_precision: 0.7586 - val_recall: 0.5754 - lr: 1.0000e-04
# Epoch 5/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7440 - accuracy: 0.6763 - f1_score: 0.6695 - precision: 0.7348 - recall: 0.5972
# Epoch 5: val_f1_score improved from 0.66560 to 0.67044, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 5 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 281s 499ms/step - loss: 0.7440 - accuracy: 0.6763 - f1_score: 0.6695 - precision: 0.7348 - recall: 0.5972 - val_loss: 0.6654 - val_accuracy: 0.6847 - val_f1_score: 0.6704 - val_precision: 0.7549 - val_recall: 0.5868 - lr: 1.0000e-04
# Epoch 6/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7259 - accuracy: 0.6829 - f1_score: 0.6765 - precision: 0.7408 - recall: 0.6065
# Epoch 6: val_f1_score improved from 0.67044 to 0.69097, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 6 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 273s 484ms/step - loss: 0.7259 - accuracy: 0.6829 - f1_score: 0.6765 - precision: 0.7408 - recall: 0.6065 - val_loss: 0.6521 - val_accuracy: 0.6958 - val_f1_score: 0.6910 - val_precision: 0.7676 - val_recall: 0.5936 - lr: 1.0000e-04
# Epoch 7/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7126 - accuracy: 0.6917 - f1_score: 0.6862 - precision: 0.7477 - recall: 0.6177
# Epoch 7: val_f1_score did not improve from 0.69097
#
# Epoch 7 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 254s 451ms/step - loss: 0.7126 - accuracy: 0.6917 - f1_score: 0.6862 - precision: 0.7477 - recall: 0.6177 - val_loss: 0.6513 - val_accuracy: 0.6857 - val_f1_score: 0.6653 - val_precision: 0.7544 - val_recall: 0.5916 - lr: 1.0000e-04
# Epoch 8/150
# 563/563 [==============================] - ETA: 0s - loss: 0.7027 - accuracy: 0.6946 - f1_score: 0.6886 - precision: 0.7526 - recall: 0.6206
# Epoch 8: val_f1_score did not improve from 0.69097
#
# Epoch 8 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 253s 450ms/step - loss: 0.7027 - accuracy: 0.6946 - f1_score: 0.6886 - precision: 0.7526 - recall: 0.6206 - val_loss: 0.6381 - val_accuracy: 0.6981 - val_f1_score: 0.6882 - val_precision: 0.7698 - val_recall: 0.6000 - lr: 1.0000e-04
# Epoch 9/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6907 - accuracy: 0.7014 - f1_score: 0.6957 - precision: 0.7533 - recall: 0.6299
# Epoch 9: val_f1_score improved from 0.69097 to 0.69594, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 9 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 263s 467ms/step - loss: 0.6907 - accuracy: 0.7014 - f1_score: 0.6957 - precision: 0.7533 - recall: 0.6299 - val_loss: 0.6365 - val_accuracy: 0.6998 - val_f1_score: 0.6959 - val_precision: 0.7694 - val_recall: 0.6020 - lr: 1.0000e-04
# Epoch 10/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6815 - accuracy: 0.7061 - f1_score: 0.7012 - precision: 0.7593 - recall: 0.6336
# Epoch 10: val_f1_score improved from 0.69594 to 0.70259, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 10 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 280s 497ms/step - loss: 0.6815 - accuracy: 0.7061 - f1_score: 0.7012 - precision: 0.7593 - recall: 0.6336 - val_loss: 0.6326 - val_accuracy: 0.7083 - val_f1_score: 0.7026 - val_precision: 0.7657 - val_recall: 0.6172 - lr: 1.0000e-04
# Epoch 11/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6692 - accuracy: 0.7136 - f1_score: 0.7087 - precision: 0.7636 - recall: 0.6444
# Epoch 11: val_f1_score did not improve from 0.70259
#
# Epoch 11 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 270s 478ms/step - loss: 0.6692 - accuracy: 0.7136 - f1_score: 0.7087 - precision: 0.7636 - recall: 0.6444 - val_loss: 0.6301 - val_accuracy: 0.7039 - val_f1_score: 0.6995 - val_precision: 0.7698 - val_recall: 0.6111 - lr: 1.0000e-04
# Epoch 12/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6619 - accuracy: 0.7162 - f1_score: 0.7115 - precision: 0.7646 - recall: 0.6496
# Epoch 12: val_f1_score did not improve from 0.70259
#
# Epoch 12 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 264s 469ms/step - loss: 0.6619 - accuracy: 0.7162 - f1_score: 0.7115 - precision: 0.7646 - recall: 0.6496 - val_loss: 0.6262 - val_accuracy: 0.7049 - val_f1_score: 0.6920 - val_precision: 0.7618 - val_recall: 0.6192 - lr: 1.0000e-04
# Epoch 13/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6596 - accuracy: 0.7168 - f1_score: 0.7118 - precision: 0.7645 - recall: 0.6489
# Epoch 13: val_f1_score did not improve from 0.70259
#
# Epoch 13 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 254s 452ms/step - loss: 0.6596 - accuracy: 0.7168 - f1_score: 0.7118 - precision: 0.7645 - recall: 0.6489 - val_loss: 0.6249 - val_accuracy: 0.7066 - val_f1_score: 0.6994 - val_precision: 0.7649 - val_recall: 0.6165 - lr: 1.0000e-04
# Epoch 14/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6487 - accuracy: 0.7207 - f1_score: 0.7164 - precision: 0.7725 - recall: 0.6553
# Epoch 14: val_f1_score improved from 0.70259 to 0.70981, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 14 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 258s 459ms/step - loss: 0.6487 - accuracy: 0.7207 - f1_score: 0.7164 - precision: 0.7725 - recall: 0.6553 - val_loss: 0.6175 - val_accuracy: 0.7137 - val_f1_score: 0.7098 - val_precision: 0.7767 - val_recall: 0.6148 - lr: 1.0000e-04
# Epoch 15/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6475 - accuracy: 0.7233 - f1_score: 0.7187 - precision: 0.7737 - recall: 0.6578
# Epoch 15: val_f1_score did not improve from 0.70981
#
# Epoch 15 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 260s 462ms/step - loss: 0.6475 - accuracy: 0.7233 - f1_score: 0.7187 - precision: 0.7737 - recall: 0.6578 - val_loss: 0.6153 - val_accuracy: 0.7143 - val_f1_score: 0.7060 - val_precision: 0.7643 - val_recall: 0.6378 - lr: 1.0000e-04
# Epoch 16/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6359 - accuracy: 0.7288 - f1_score: 0.7246 - precision: 0.7732 - recall: 0.6632
# Epoch 16: val_f1_score improved from 0.70981 to 0.71812, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 16 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 276s 489ms/step - loss: 0.6359 - accuracy: 0.7288 - f1_score: 0.7246 - precision: 0.7732 - recall: 0.6632 - val_loss: 0.6077 - val_accuracy: 0.7201 - val_f1_score: 0.7181 - val_precision: 0.7787 - val_recall: 0.6290 - lr: 1.0000e-04
# Epoch 17/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6332 - accuracy: 0.7312 - f1_score: 0.7273 - precision: 0.7780 - recall: 0.6677
# Epoch 17: val_f1_score did not improve from 0.71812
#
# Epoch 17 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 271s 481ms/step - loss: 0.6332 - accuracy: 0.7312 - f1_score: 0.7273 - precision: 0.7780 - recall: 0.6677 - val_loss: 0.6082 - val_accuracy: 0.7211 - val_f1_score: 0.7181 - val_precision: 0.7762 - val_recall: 0.6455 - lr: 1.0000e-04
# Epoch 18/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6212 - accuracy: 0.7368 - f1_score: 0.7330 - precision: 0.7780 - recall: 0.6759
# Epoch 18: val_f1_score did not improve from 0.71812
#
# Epoch 18 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 266s 473ms/step - loss: 0.6212 - accuracy: 0.7368 - f1_score: 0.7330 - precision: 0.7780 - recall: 0.6759 - val_loss: 0.6085 - val_accuracy: 0.7204 - val_f1_score: 0.7180 - val_precision: 0.7699 - val_recall: 0.6479 - lr: 1.0000e-04
# Epoch 19/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6213 - accuracy: 0.7346 - f1_score: 0.7308 - precision: 0.7786 - recall: 0.6763
# Epoch 19: val_f1_score did not improve from 0.71812
#
# Epoch 19 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 254s 451ms/step - loss: 0.6213 - accuracy: 0.7346 - f1_score: 0.7308 - precision: 0.7786 - recall: 0.6763 - val_loss: 0.6095 - val_accuracy: 0.7123 - val_f1_score: 0.7014 - val_precision: 0.7663 - val_recall: 0.6381 - lr: 1.0000e-04
# Epoch 20/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6089 - accuracy: 0.7431 - f1_score: 0.7394 - precision: 0.7858 - recall: 0.6884
# Epoch 20: val_f1_score improved from 0.71812 to 0.71826, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 20 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 257s 457ms/step - loss: 0.6089 - accuracy: 0.7431 - f1_score: 0.7394 - precision: 0.7858 - recall: 0.6884 - val_loss: 0.6009 - val_accuracy: 0.7201 - val_f1_score: 0.7183 - val_precision: 0.7701 - val_recall: 0.6553 - lr: 1.0000e-04
# Epoch 21/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6069 - accuracy: 0.7401 - f1_score: 0.7365 - precision: 0.7854 - recall: 0.6831
# Epoch 21: val_f1_score did not improve from 0.71826
#
# Epoch 21 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 260s 461ms/step - loss: 0.6069 - accuracy: 0.7401 - f1_score: 0.7365 - precision: 0.7854 - recall: 0.6831 - val_loss: 0.6028 - val_accuracy: 0.7123 - val_f1_score: 0.7078 - val_precision: 0.7706 - val_recall: 0.6459 - lr: 1.0000e-04
# Epoch 22/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6006 - accuracy: 0.7454 - f1_score: 0.7422 - precision: 0.7845 - recall: 0.6907
# Epoch 22: val_f1_score did not improve from 0.71826
#
# Epoch 22 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 267s 474ms/step - loss: 0.6006 - accuracy: 0.7454 - f1_score: 0.7422 - precision: 0.7845 - recall: 0.6907 - val_loss: 0.6122 - val_accuracy: 0.7116 - val_f1_score: 0.6935 - val_precision: 0.7581 - val_recall: 0.6405 - lr: 1.0000e-04
# Epoch 23/150
# 563/563 [==============================] - ETA: 0s - loss: 0.6002 - accuracy: 0.7452 - f1_score: 0.7415 - precision: 0.7859 - recall: 0.6904
# Epoch 23: val_f1_score improved from 0.71826 to 0.72189, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 23 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 280s 496ms/step - loss: 0.6002 - accuracy: 0.7452 - f1_score: 0.7415 - precision: 0.7859 - recall: 0.6904 - val_loss: 0.5928 - val_accuracy: 0.7238 - val_f1_score: 0.7219 - val_precision: 0.7818 - val_recall: 0.6503 - lr: 1.0000e-04
# Epoch 24/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5908 - accuracy: 0.7544 - f1_score: 0.7509 - precision: 0.7950 - recall: 0.7013
# Epoch 24: val_f1_score improved from 0.72189 to 0.72892, saving model to ResNet50_Wavelet_Hybrid_model.h5
#
# Epoch 24 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 275s 488ms/step - loss: 0.5908 - accuracy: 0.7544 - f1_score: 0.7509 - precision: 0.7950 - recall: 0.7013 - val_loss: 0.5907 - val_accuracy: 0.7302 - val_f1_score: 0.7289 - val_precision: 0.7814 - val_recall: 0.6560 - lr: 1.0000e-04
# Epoch 25/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5923 - accuracy: 0.7508 - f1_score: 0.7473 - precision: 0.7881 - recall: 0.6969
# Epoch 25: val_f1_score did not improve from 0.72892
#
# Epoch 25 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 269s 478ms/step - loss: 0.5923 - accuracy: 0.7508 - f1_score: 0.7473 - precision: 0.7881 - recall: 0.6969 - val_loss: 0.5963 - val_accuracy: 0.7167 - val_f1_score: 0.7075 - val_precision: 0.7661 - val_recall: 0.6530 - lr: 1.0000e-04
# Epoch 26/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5912 - accuracy: 0.7492 - f1_score: 0.7459 - precision: 0.7894 - recall: 0.6963
# Epoch 26: val_f1_score did not improve from 0.72892
#
# Epoch 26 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 261s 464ms/step - loss: 0.5912 - accuracy: 0.7492 - f1_score: 0.7459 - precision: 0.7894 - recall: 0.6963 - val_loss: 0.5925 - val_accuracy: 0.7228 - val_f1_score: 0.7157 - val_precision: 0.7729 - val_recall: 0.6567 - lr: 1.0000e-04
# Epoch 27/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5844 - accuracy: 0.7564 - f1_score: 0.7533 - precision: 0.7925 - recall: 0.7037
# Epoch 27: val_f1_score did not improve from 0.72892
#
# Epoch 27 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 258s 458ms/step - loss: 0.5844 - accuracy: 0.7564 - f1_score: 0.7533 - precision: 0.7925 - recall: 0.7037 - val_loss: 0.5903 - val_accuracy: 0.7288 - val_f1_score: 0.7233 - val_precision: 0.7679 - val_recall: 0.6685 - lr: 1.0000e-04
# Epoch 28/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5697 - accuracy: 0.7608 - f1_score: 0.7576 - precision: 0.7973 - recall: 0.7129
# Epoch 28: val_f1_score did not improve from 0.72892
#
# Epoch 28 Learning Rate : 9.999999747378752e-05
# 563/563 [==============================] - 281s 499ms/step - loss: 0.5697 - accuracy: 0.7608 - f1_score: 0.7576 - precision: 0.7973 - recall: 0.7129 - val_loss: 0.5887 - val_accuracy: 0.7224 - val_f1_score: 0.7214 - val_precision: 0.7672 - val_recall: 0.6658 - lr: 1.0000e-04
# Epoch 29/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5742 - accuracy: 0.7609 - f1_score: 0.7576 - precision: 0.7983 - recall: 0.7101
# Epoch 29: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 29: val_f1_score did not improve from 0.72892
#
# Epoch 29 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 294s 522ms/step - loss: 0.5742 - accuracy: 0.7609 - f1_score: 0.7576 - precision: 0.7983 - recall: 0.7101 - val_loss: 0.6011 - val_accuracy: 0.7157 - val_f1_score: 0.7021 - val_precision: 0.7612 - val_recall: 0.6610 - lr: 1.0000e-04
# Epoch 30/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5660 - accuracy: 0.7655 - f1_score: 0.7622 - precision: 0.7982 - recall: 0.7154
# Epoch 30: val_f1_score did not improve from 0.72892
#
# Epoch 30 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 273s 485ms/step - loss: 0.5660 - accuracy: 0.7655 - f1_score: 0.7622 - precision: 0.7982 - recall: 0.7154 - val_loss: 0.5870 - val_accuracy: 0.7238 - val_f1_score: 0.7180 - val_precision: 0.7738 - val_recall: 0.6624 - lr: 3.0000e-05
# Epoch 31/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5580 - accuracy: 0.7676 - f1_score: 0.7650 - precision: 0.8030 - recall: 0.7216
# Epoch 31: val_f1_score did not improve from 0.72892
#
# Epoch 31 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 268s 476ms/step - loss: 0.5580 - accuracy: 0.7676 - f1_score: 0.7650 - precision: 0.8030 - recall: 0.7216 - val_loss: 0.5854 - val_accuracy: 0.7272 - val_f1_score: 0.7234 - val_precision: 0.7700 - val_recall: 0.6728 - lr: 3.0000e-05
# Epoch 32/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5551 - accuracy: 0.7706 - f1_score: 0.7682 - precision: 0.8030 - recall: 0.7237
# Epoch 32: val_f1_score did not improve from 0.72892
#
# Epoch 32 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 259s 460ms/step - loss: 0.5551 - accuracy: 0.7706 - f1_score: 0.7682 - precision: 0.8030 - recall: 0.7237 - val_loss: 0.5863 - val_accuracy: 0.7251 - val_f1_score: 0.7211 - val_precision: 0.7651 - val_recall: 0.6735 - lr: 3.0000e-05
# Epoch 33/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5537 - accuracy: 0.7678 - f1_score: 0.7654 - precision: 0.8030 - recall: 0.7248
# Epoch 33: val_f1_score did not improve from 0.72892
#
# Epoch 33 Learning Rate : 2.9999999242136255e-05
# 563/563 [==============================] - 259s 459ms/step - loss: 0.5537 - accuracy: 0.7678 - f1_score: 0.7654 - precision: 0.8030 - recall: 0.7248 - val_loss: 0.5859 - val_accuracy: 0.7268 - val_f1_score: 0.7206 - val_precision: 0.7705 - val_recall: 0.6725 - lr: 3.0000e-05
# Epoch 34/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5509 - accuracy: 0.7705 - f1_score: 0.7675 - precision: 0.8064 - recall: 0.7266
# Epoch 34: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 34: val_f1_score did not improve from 0.72892
#
# Epoch 34 Learning Rate : 8.999999408842996e-06
# 563/563 [==============================] - 261s 463ms/step - loss: 0.5509 - accuracy: 0.7705 - f1_score: 0.7675 - precision: 0.8064 - recall: 0.7266 - val_loss: 0.5888 - val_accuracy: 0.7245 - val_f1_score: 0.7178 - val_precision: 0.7671 - val_recall: 0.6698 - lr: 3.0000e-05
# Epoch 35/150
# 563/563 [==============================] - ETA: 0s - loss: 0.5483 - accuracy: 0.7717 - f1_score: 0.7692 - precision: 0.8059 - recall: 0.7273Restoring model weights from the end of the best epoch: 24.
#
# Epoch 35: val_f1_score did not improve from 0.72892
#
# Epoch 35 Learning Rate : 8.999999408842996e-06
# 563/563 [==============================] - 269s 477ms/step - loss: 0.5483 - accuracy: 0.7717 - f1_score: 0.7692 - precision: 0.8059 - recall: 0.7273 - val_loss: 0.5846 - val_accuracy: 0.7285 - val_f1_score: 0.7244 - val_precision: 0.7697 - val_recall: 0.6752 - lr: 9.0000e-06
# Epoch 35: early stopping
# done

# %%
# ==========================================================
# LOAD PHASE 1 (FROZEN BACKBONE) BEST WEIGHTS
# ==========================================================
# 1. Rebuild the model architecture blueprint first
model, base_model = get_ResNet50_Wavelet_Hybrid()

# 2. Load the weights directly into the blueprint
model.load_weights("ResNet50_Wavelet_Hybrid_model.h5")

print("Phase 1 model weights loaded successfully!")
# Out:
# Phase 1 model weights loaded successfully!

# %%
# ==========================================================
# PHASE 2: FINE-TUNING CALLBACKS (NEW)
# ==========================================================
print("start")

early_stop_ft = EarlyStopping(
    monitor='val_f1_score',
    mode='max',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

reduce_lr_ft = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.3,
    patience=4,
    min_lr=1e-8,
    verbose=1
)

checkpoint_ft = ModelCheckpoint(
    "ResNet50_Wavelet_Hybrid_Balanced_FineTuned_model.h5",
    monitor='val_f1_score',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# PHASE 2: FINE-TUNE THE RESNET-50 BACKBONE (NEW)
# ==========================================================
# Frozen ImageNet features are good at separating "lesion present" from
# "no lesion" (Normal was already well separated in the confusion matrix),
# but Benign vs Malignant needs finer texture/margin features that ImageNet
# weights were never trained to represent. Unfreezing the top of the
# backbone lets the model actually learn those.
print("start")

# base_model was returned directly by get_ResNet50_Wavelet_Hybrid() and
# loaded back into scope in the "LOAD PHASE 1" cell above -- no lookup needed.
base_model.trainable = True
for layer in base_model.layers[:-30]:
    layer.trainable = False
for layer in base_model.layers:
    if isinstance(layer, BatchNormalization):
        layer.trainable = False   # keep BN stats stable at a small batch size / low LR

optimizer_ft = Adam(learning_rate=1e-5)
model.compile(
    loss="categorical_crossentropy",
    metrics=["accuracy", f1_metric, precision_metric, recall_metric],
    optimizer=optimizer_ft
)

history_finetune = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=40,
    class_weight=class_weight,   # NEW -- same Malignant-boosted weighting as phase 1
    callbacks=[
        early_stop_ft,
        reduce_lr_ft,
        checkpoint_ft,
        lr_callback
    ]
)

print("done")
# Out:
# start
# Epoch 1/40
# 563/563 [==============================] - ETA: 0s - loss: 0.5853 - accuracy: 0.7547 - f1_score: 0.7479 - precision: 0.7898 - recall: 0.6970
# Epoch 1: val_f1_score improved from -inf to 0.72757, saving model to ResNet50_Wavelet_Hybrid_Balanced_FineTuned_model.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-06
# 563/563 [==============================] - 273s 482ms/step - loss: 0.5853 - accuracy: 0.7547 - f1_score: 0.7479 - precision: 0.7898 - recall: 0.6970 - val_loss: 0.5834 - val_accuracy: 0.7312 - val_f1_score: 0.7276 - val_precision: 0.7801 - val_recall: 0.6725 - lr: 1.0000e-05
# Epoch 2/40
# 563/563 [==============================] - ETA: 0s - loss: 0.5229 - accuracy: 0.7834 - f1_score: 0.7808 - precision: 0.8132 - recall: 0.7393
# Epoch 2: val_f1_score did not improve from 0.72757
#
# Epoch 2 Learning Rate : 9.999999747378752e-06
# 563/563 [==============================] - 265s 470ms/step - loss: 0.5229 - accuracy: 0.7834 - f1_score: 0.7808 - precision: 0.8132 - recall: 0.7393 - val_loss: 0.6344 - val_accuracy: 0.7130 - val_f1_score: 0.6934 - val_precision: 0.7467 - val_recall: 0.6702 - lr: 1.0000e-05
# Epoch 3/40
# 563/563 [==============================] - ETA: 0s - loss: 0.4647 - accuracy: 0.8108 - f1_score: 0.8087 - precision: 0.8348 - recall: 0.7814
# Epoch 3: val_f1_score improved from 0.72757 to 0.73433, saving model to ResNet50_Wavelet_Hybrid_Balanced_FineTuned_model.h5
#
# Epoch 3 Learning Rate : 9.999999747378752e-06
# 563/563 [==============================] - 262s 465ms/step - loss: 0.4647 - accuracy: 0.8108 - f1_score: 0.8087 - precision: 0.8348 - recall: 0.7814 - val_loss: 0.5768 - val_accuracy: 0.7268 - val_f1_score: 0.7343 - val_precision: 0.7550 - val_recall: 0.6911 - lr: 1.0000e-05
# Epoch 4/40
# 563/563 [==============================] - ETA: 0s - loss: 0.4094 - accuracy: 0.8363 - f1_score: 0.8349 - precision: 0.8526 - recall: 0.8163
# Epoch 4: val_f1_score improved from 0.73433 to 0.73767, saving model to ResNet50_Wavelet_Hybrid_Balanced_FineTuned_model.h5
#
# Epoch 4 Learning Rate : 9.999999747378752e-06
# 563/563 [==============================] - 269s 478ms/step - loss: 0.4094 - accuracy: 0.8363 - f1_score: 0.8349 - precision: 0.8526 - recall: 0.8163 - val_loss: 0.5995 - val_accuracy: 0.7393 - val_f1_score: 0.7377 - val_precision: 0.7592 - val_recall: 0.7059 - lr: 1.0000e-05
# Epoch 5/40
# 563/563 [==============================] - ETA: 0s - loss: 0.3454 - accuracy: 0.8671 - f1_score: 0.8662 - precision: 0.8786 - recall: 0.8519
# Epoch 5: val_f1_score improved from 0.73767 to 0.74003, saving model to ResNet50_Wavelet_Hybrid_Balanced_FineTuned_model.h5
#
# Epoch 5 Learning Rate : 9.999999747378752e-06
# 563/563 [==============================] - 280s 498ms/step - loss: 0.3454 - accuracy: 0.8671 - f1_score: 0.8662 - precision: 0.8786 - recall: 0.8519 - val_loss: 0.6557 - val_accuracy: 0.7379 - val_f1_score: 0.7400 - val_precision: 0.7556 - val_recall: 0.7228 - lr: 1.0000e-05
# Epoch 6/40
# 563/563 [==============================] - ETA: 0s - loss: 0.2944 - accuracy: 0.8843 - f1_score: 0.8836 - precision: 0.8942 - recall: 0.8750
# Epoch 6: val_f1_score did not improve from 0.74003
#
# Epoch 6 Learning Rate : 9.999999747378752e-06
# 563/563 [==============================] - 272s 482ms/step - loss: 0.2944 - accuracy: 0.8843 - f1_score: 0.8836 - precision: 0.8942 - recall: 0.8750 - val_loss: 0.6922 - val_accuracy: 0.7369 - val_f1_score: 0.7328 - val_precision: 0.7527 - val_recall: 0.7248 - lr: 1.0000e-05
# Epoch 7/40
# 563/563 [==============================] - ETA: 0s - loss: 0.2364 - accuracy: 0.9126 - f1_score: 0.9122 - precision: 0.9184 - recall: 0.9061
# Epoch 7: val_f1_score did not improve from 0.74003
#
# Epoch 7 Learning Rate : 9.999999747378752e-06
# 563/563 [==============================] - 268s 475ms/step - loss: 0.2364 - accuracy: 0.9126 - f1_score: 0.9122 - precision: 0.9184 - recall: 0.9061 - val_loss: 0.7665 - val_accuracy: 0.7298 - val_f1_score: 0.7333 - val_precision: 0.7375 - val_recall: 0.7211 - lr: 1.0000e-05
# Epoch 8/40
# 563/563 [==============================] - ETA: 0s - loss: 0.1843 - accuracy: 0.9343 - f1_score: 0.9341 - precision: 0.9383 - recall: 0.9302
# Epoch 8: val_f1_score did not improve from 0.74003
#
# Epoch 8 Learning Rate : 9.999999747378752e-06
# 563/563 [==============================] - 260s 462ms/step - loss: 0.1843 - accuracy: 0.9343 - f1_score: 0.9341 - precision: 0.9383 - recall: 0.9302 - val_loss: 0.8674 - val_accuracy: 0.7248 - val_f1_score: 0.7219 - val_precision: 0.7309 - val_recall: 0.7147 - lr: 1.0000e-05
# Epoch 9/40
# 563/563 [==============================] - ETA: 0s - loss: 0.1410 - accuracy: 0.9501 - f1_score: 0.9500 - precision: 0.9525 - recall: 0.9479
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
#
# Epoch 9: val_f1_score did not improve from 0.74003
#
# Epoch 9 Learning Rate : 2.9999998787388904e-06
# 563/563 [==============================] - 257s 457ms/step - loss: 0.1410 - accuracy: 0.9501 - f1_score: 0.9500 - precision: 0.9525 - recall: 0.9479 - val_loss: 0.9027 - val_accuracy: 0.7322 - val_f1_score: 0.7342 - val_precision: 0.7357 - val_recall: 0.7258 - lr: 1.0000e-05
# Epoch 10/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0702 - accuracy: 0.9780 - f1_score: 0.9780 - precision: 0.9788 - recall: 0.9769
# Epoch 10: val_f1_score did not improve from 0.74003
#
# Epoch 10 Learning Rate : 2.9999998787388904e-06
# 563/563 [==============================] - 261s 463ms/step - loss: 0.0702 - accuracy: 0.9780 - f1_score: 0.9780 - precision: 0.9788 - recall: 0.9769 - val_loss: 1.1995 - val_accuracy: 0.7180 - val_f1_score: 0.7225 - val_precision: 0.7225 - val_recall: 0.7167 - lr: 3.0000e-06
# Epoch 11/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0539 - accuracy: 0.9839 - f1_score: 0.9839 - precision: 0.9840 - recall: 0.9835
# Epoch 11: val_f1_score did not improve from 0.74003
#
# Epoch 11 Learning Rate : 2.9999998787388904e-06
# 563/563 [==============================] - 273s 484ms/step - loss: 0.0539 - accuracy: 0.9839 - f1_score: 0.9839 - precision: 0.9840 - recall: 0.9835 - val_loss: 1.1760 - val_accuracy: 0.7211 - val_f1_score: 0.7235 - val_precision: 0.7244 - val_recall: 0.7180 - lr: 3.0000e-06
# Epoch 12/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0426 - accuracy: 0.9881 - f1_score: 0.9881 - precision: 0.9887 - recall: 0.9878
# Epoch 12: val_f1_score did not improve from 0.74003
#
# Epoch 12 Learning Rate : 2.9999998787388904e-06
# 563/563 [==============================] - 274s 487ms/step - loss: 0.0426 - accuracy: 0.9881 - f1_score: 0.9881 - precision: 0.9887 - recall: 0.9878 - val_loss: 1.3119 - val_accuracy: 0.7231 - val_f1_score: 0.7266 - val_precision: 0.7256 - val_recall: 0.7224 - lr: 3.0000e-06
# Epoch 13/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0355 - accuracy: 0.9893 - f1_score: 0.9893 - precision: 0.9895 - recall: 0.9892
# Epoch 13: ReduceLROnPlateau reducing learning rate to 8.999999636216671e-07.
#
# Epoch 13: val_f1_score did not improve from 0.74003
#
# Epoch 13 Learning Rate : 8.999999749903509e-07
# 563/563 [==============================] - 272s 483ms/step - loss: 0.0355 - accuracy: 0.9893 - f1_score: 0.9893 - precision: 0.9895 - recall: 0.9892 - val_loss: 1.4231 - val_accuracy: 0.7180 - val_f1_score: 0.7202 - val_precision: 0.7194 - val_recall: 0.7150 - lr: 3.0000e-06
# Epoch 14/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9943 - f1_score: 0.9943 - precision: 0.9945 - recall: 0.9942
# Epoch 14: val_f1_score did not improve from 0.74003
#
# Epoch 14 Learning Rate : 8.999999749903509e-07
# 563/563 [==============================] - 261s 463ms/step - loss: 0.0237 - accuracy: 0.9943 - f1_score: 0.9943 - precision: 0.9945 - recall: 0.9942 - val_loss: 1.4865 - val_accuracy: 0.7126 - val_f1_score: 0.7187 - val_precision: 0.7126 - val_recall: 0.7110 - lr: 9.0000e-07
# Epoch 15/40
# 563/563 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9943 - f1_score: 0.9943 - precision: 0.9945 - recall: 0.9942Restoring model weights from the end of the best epoch: 5.
#
# Epoch 15: val_f1_score did not improve from 0.74003
#
# Epoch 15 Learning Rate : 8.999999749903509e-07
# 563/563 [==============================] - 257s 456ms/step - loss: 0.0207 - accuracy: 0.9943 - f1_score: 0.9943 - precision: 0.9945 - recall: 0.9942 - val_loss: 1.5072 - val_accuracy: 0.7234 - val_f1_score: 0.7295 - val_precision: 0.7244 - val_recall: 0.7218 - lr: 9.0000e-07
# Epoch 15: early stopping
# done

# %%
# ==========================================================
# LOAD PHASE 2 (FINE-TUNED) BEST WEIGHTS -- use this for final evaluation
# ==========================================================
model, base_model = get_ResNet50_Wavelet_Hybrid()
base_model.trainable = True
for layer in base_model.layers[:-30]:
    layer.trainable = False
for layer in base_model.layers:
    if isinstance(layer, BatchNormalization):
        layer.trainable = False
model.compile(
    loss="categorical_crossentropy",
    metrics=["accuracy", f1_metric, precision_metric, recall_metric],
    optimizer=Adam(learning_rate=1e-5)
)
model.load_weights("ResNet50_Wavelet_Hybrid_Balanced_FineTuned_model.h5")

print("Fine-tuned model weights loaded successfully!")
# Out:
# Fine-tuned model weights loaded successfully!

# %%
# ==========================================================
# PLOT LEARNING CURVES (Loss, F1-Score, Precision)
# Phase 1 (frozen) and Phase 2 (fine-tuned) plotted as one continuous
# curve, with the join point marked (NEW).
# ==========================================================
print("start")

def concat_history(h1, h2, key):
    return h1.history[key] + h2.history[key]

phase1_end = len(history.history['loss'])

# 1. Loss Curve
plt.figure(figsize=(8, 6))
plt.plot(concat_history(history, history_finetune, 'loss'), label='Train Loss', color='red')
plt.plot(concat_history(history, history_finetune, 'val_loss'), label='Validation Loss', color='orange')
plt.axvline(phase1_end, linestyle='--', color='gray', label='Fine-tuning starts')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig("ResNet50_Wavelet_Balanced_Loss_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

# 2. F1 Score Curve
plt.figure(figsize=(8, 6))
plt.plot(concat_history(history, history_finetune, 'f1_score'), label='Train F1-Score', color='blue')
plt.plot(concat_history(history, history_finetune, 'val_f1_score'), label='Validation F1-Score', color='cyan')
plt.axvline(phase1_end, linestyle='--', color='gray', label='Fine-tuning starts')
plt.xlabel('Epochs')
plt.ylabel('F1-Score')
plt.legend()
plt.tight_layout()
plt.savefig("ResNet50_Wavelet_Balanced_F1_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

# 3. Precision Curve
plt.figure(figsize=(8, 6))
plt.plot(concat_history(history, history_finetune, 'precision'), label='Train Precision', color='green')
plt.plot(concat_history(history, history_finetune, 'val_precision'), label='Validation Precision', color='lightgreen')
plt.axvline(phase1_end, linestyle='--', color='gray', label='Fine-tuning starts')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.tight_layout()
plt.savefig("ResNet50_Wavelet_Balanced_Precision_Curve.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# EVALUATION (Training, Validation & Testing)
# ==========================================================
print("Evaluating on Training Set...")
train_results = model.evaluate(train_generator)

print("\nEvaluating on Validation Set...")
val_results = model.evaluate(val_generator)

print("\nEvaluating on Testing Set (Truly Unseen)...")
test_results = model.evaluate(test_generator)

# Order: [loss, accuracy, f1_score, precision, recall]
train_loss, train_acc, train_f1, train_precision, train_recall = train_results
val_loss, val_acc, val_f1, val_precision, val_recall = val_results
test_loss, test_acc, test_f1, test_precision, test_recall = test_results

print("\n" + "="*40)
print("TRAINING METRICS")
print("="*40)
print(f"Training Loss      : {train_loss:.4f}")
print(f"Training Accuracy  : {train_acc*100:.2f}%")
print(f"Training F1-Score  : {train_f1*100:.2f}%")
print(f"Training Precision : {train_precision*100:.2f}%")
print(f"Training Recall    : {train_recall*100:.2f}%")

print("\n" + "="*40)
print("VALIDATION METRICS")
print("="*40)
print(f"Validation Loss      : {val_loss:.4f}")
print(f"Validation Accuracy  : {val_acc*100:.2f}%")
print(f"Validation F1-Score  : {val_f1*100:.2f}%")
print(f"Validation Precision : {val_precision*100:.2f}%")
print(f"Validation Recall    : {val_recall*100:.2f}%")

print("\n" + "="*40)
print("TESTING METRICS (UNSEEN DATA)")
print("="*40)
print(f"Testing Loss      : {test_loss:.4f}")
print(f"Testing Accuracy  : {test_acc*100:.2f}%")
print(f"Testing F1-Score  : {test_f1*100:.2f}%")
print(f"Testing Precision : {test_precision*100:.2f}%")
print(f"Testing Recall    : {test_recall*100:.2f}%")
# Out:
# Evaluating on Training Set...
# 563/563 [==============================] - 234s 414ms/step - loss: 0.2115 - accuracy: 0.9228 - f1_score: 0.8949 - precision: 0.9001 - recall: 0.8852
#
# Evaluating on Validation Set...
# 93/93 [==============================] - 40s 424ms/step - loss: 0.6557 - accuracy: 0.7379 - f1_score: 0.7400 - precision: 0.7556 - recall: 0.7228
#
# Evaluating on Testing Set (Truly Unseen)...
# 92/92 [==============================] - 51s 548ms/step - loss: 0.6747 - accuracy: 0.7469 - f1_score: 0.7442 - precision: 0.7595 - recall: 0.7299
#
# ========================================
# TRAINING METRICS
# ========================================
# Training Loss      : 0.2115
# Training Accuracy  : 92.28%
# Training F1-Score  : 89.49%
# Training Precision : 90.01%
# Training Recall    : 88.52%
#
# ========================================
# VALIDATION METRICS
# ========================================
# Validation Loss      : 0.6557
# Validation Accuracy  : 73.79%
# Validation F1-Score  : 74.00%
# Validation Precision : 75.56%
# Validation Recall    : 72.28%
#
# ========================================
# TESTING METRICS (UNSEEN DATA)
# ========================================
# Testing Loss      : 0.6747
# Testing Accuracy  : 74.69%
# Testing F1-Score  : 74.42%
# Testing Precision : 75.95%
# Testing Recall    : 72.99%

# %%
# ==========================================================
# PRECISION, RECALL, F1-SCORE (Test Set - Unseen Data)
# ==========================================================
print("\nCalculating Precision, Recall, F1-score on Test Set...")

predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

true_classes = test_generator.classes
class_names = test_generator.class_names

print("\nClassification Report (Test Set):\n")
print(
    classification_report(
        true_classes,
        predicted_classes,
        target_names=class_names
    )
)

print("done1")
# Out:
# Calculating Precision, Recall, F1-score on Test Set...
# 92/92 [==============================] - 37s 400ms/step
#
# Classification Report (Test Set):
#
#               precision    recall  f1-score   support
#
#       Benign       0.66      0.57      0.61       888
#    Malignant       0.73      0.82      0.77      1266
#       Normal       0.87      0.83      0.85       789
#
#     accuracy                           0.75      2943
#    macro avg       0.75      0.74      0.74      2943
# weighted avg       0.75      0.75      0.74      2943
#
# done1

# %%
# ==========================================================
# CONFUSION MATRIX (Test Set)
# ==========================================================
print("Generating Confusion Matrix...")

import seaborn as sns

cm = confusion_matrix(true_classes, predicted_classes)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=class_names,
    yticklabels=class_names
)

plt.ylabel('True Label', fontsize=14)
plt.xlabel('Predicted Label', fontsize=14)
plt.xticks(rotation=45)
plt.yticks(rotation=0)

plt.tight_layout()
plt.savefig("ResNet50_Wavelet_confusion_matrix_test.pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# Generating Confusion Matrix...
# done1
