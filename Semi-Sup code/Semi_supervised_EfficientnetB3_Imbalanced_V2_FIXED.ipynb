# %%
# ==========================================================

print("start")

import os

semi_supervised_dir = r"D:\Thesis_folder\Preprocessed_Pipeline\Semi_Supervised_ImBalanced"

print("Paths defined and ready")
print("done1")
# Out:
# start
# Paths defined and ready
# done1

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("TensorFlow Version: ", tf.__version__)
# Out:
# Num GPUs Available:  1
# TensorFlow Version:  2.10.0

# %%
# ==========================================================
# IMPORTS
# ==========================================================
print("start")

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import shutil
import random
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall
import tensorflow_addons as tfa
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint,
    Callback
)

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# CONFIGURATION & PARAMETERS
# ==========================================================
print("start")

IMAGE_SIZE = (288, 288)
MODEL_INPUT_SIZE = (288, 288, 3)
NUM_CLASSES = 3
BATCH_SIZE = 32
EPOCHS = 150

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# DATA FLOW GENERATORS SETUP (UNBALANCED PATHS)
# ==========================================================
print("start")

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import preprocess_input
import os

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

test_val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

base_path = r"D:\Thesis_folder\Preprocessed_Pipeline\Semi_Supervised_ImBalanced"

train_labeled_generator = train_datagen.flow_from_directory(
    os.path.join(base_path, 'labeled_train'),
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

train_unlabeled_generator = test_val_datagen.flow_from_directory(
    os.path.join(base_path, 'unlabeled_train'),
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode=None,
    shuffle=False
)

# FIX: val must come from the 'val' folder, which is disjoint from 'test'.
# The previous version pointed both val_generator and test_generator at
# 'test', which meant every checkpoint/early-stopping decision was made
# using the test set itself.
val_generator = test_val_datagen.flow_from_directory(
    os.path.join(base_path, 'val'),
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

test_generator = test_val_datagen.flow_from_directory(
    os.path.join(base_path, 'test'),
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Sanity check: fail loudly instead of silently training on the wrong data
assert train_labeled_generator.num_classes == 3, (
    f"Expected 3 classes, found {train_labeled_generator.num_classes}. "
    "Rerun the preprocessing pipeline from a clean state -- "
    "Suspicious_Malignant should already be merged into Malignant."
)
assert val_generator.samples != test_generator.samples or \
       set(val_generator.filenames) != set(test_generator.filenames), (
    "val_generator and test_generator appear to point at the same files."
)

print("done1")
# Out:
# start
# Found 3950 images belonging to 3 classes.
# Found 9873 images belonging to 3 classes.
# Found 2965 images belonging to 3 classes.
# Found 2943 images belonging to 3 classes.
# done1

# %%
# ==========================================================
# MODEL INITIALIZATION (EfficientNetB3 Backbone)
# ==========================================================
print("start")

# Initialize all metrics
f1_metric = tfa.metrics.F1Score(num_classes=NUM_CLASSES, average='macro', name='f1_score')
precision_metric = Precision(name='precision')
recall_metric = Recall(name='recall') # <-- 1. Initialized Recall

def get_EfficientNetB3():
    # 1. Load the EfficientNetB3 Base Model with ImageNet weights
    base_model = EfficientNetB3(
        input_shape=MODEL_INPUT_SIZE,
        weights='imagenet',
        include_top=False
    )

    # Freeze the base model layers for Phase 1
    base_model.trainable = False

    # 2. Build the Custom Top
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.3)(x)
    outputs = Dense(NUM_CLASSES, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=outputs)

    # 3. Compile the model
    optimizer = Adam(learning_rate=0.0001)

    # 2. Added recall_metric to the compile step
    model.compile(
        loss="categorical_crossentropy",
        metrics=["accuracy", f1_metric, precision_metric, recall_metric], 
        optimizer=optimizer
    )

    return model

model = get_EfficientNetB3()

# Display the model architecture
model.summary()

print("done1")
# Out:
# start
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 288, 288, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 288, 288, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 288, 288, 3)  7           ['rescaling[0][0]']
#
#  rescaling_1 (Rescaling)        (None, 288, 288, 3)  0           ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 289, 289, 3)  0           ['rescaling_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 144, 144, 40  1080        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 144, 144, 40  160         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 144, 144, 40  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 144, 144, 40  360        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 144, 144, 40  160        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 144, 144, 40  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 40)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 40)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 10)     410         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 40)     440         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 144, 144, 40  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 144, 144, 24  960         ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 144, 144, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 144, 144, 24  216        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 144, 144, 24  96         ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 144, 144, 24  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 144, 144, 24  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 144, 144, 24  576         ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 144, 144, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 144, 144, 24  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 144, 144, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 144, 144, 14  3456        ['block1b_add[0][0]']
#                                 4)
#
#  block2a_expand_bn (BatchNormal  (None, 144, 144, 14  576        ['block2a_expand_conv[0][0]']
#  ization)                       4)
#
#  block2a_expand_activation (Act  (None, 144, 144, 14  0          ['block2a_expand_bn[0][0]']
#  ivation)                       4)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 145, 145, 14  0          ['block2a_expand_activation[0][0]
#  g2D)                           4)                               ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 72, 72, 144)  1296       ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 72, 72, 144)  576        ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 72, 72, 144)  0          ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 72, 72, 144)  0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 72, 72, 32)   4608        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 72, 72, 32)  128         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 72, 72, 192)  6144        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 72, 72, 192)  768        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 72, 72, 192)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 72, 72, 192)  1728       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 72, 72, 192)  768        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 72, 72, 192)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 192)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 72, 72, 192)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 72, 72, 32)   6144        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 72, 72, 32)  128         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 72, 72, 32)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 72, 72, 32)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 72, 72, 192)  6144        ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 72, 72, 192)  768        ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 72, 72, 192)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 72, 72, 192)  1728       ['block2c_expand_activation[0][0]
#  D)                                                              ']
#
#  block2c_bn (BatchNormalization  (None, 72, 72, 192)  768        ['block2c_dwconv[0][0]']
#  )
#
#  block2c_activation (Activation  (None, 72, 72, 192)  0          ['block2c_bn[0][0]']
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 192)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 72, 72, 192)  0           ['block2c_activation[0][0]',
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 72, 72, 32)   6144        ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 72, 72, 32)  128         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 72, 72, 32)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 72, 72, 32)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 72, 72, 192)  6144        ['block2c_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 72, 72, 192)  768        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 72, 72, 192)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 75, 75, 192)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 36, 36, 192)  4800       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 36, 36, 192)  768        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 36, 36, 192)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 192)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 36, 36, 192)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 36, 36, 48)   9216        ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 36, 36, 48)  192         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 36, 36, 288)  13824       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 36, 36, 288)  1152       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 36, 36, 288)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 36, 36, 288)  7200       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 36, 36, 288)  1152       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 36, 36, 288)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 288)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 36, 36, 288)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 36, 36, 48)   13824       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 36, 36, 48)  192         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 36, 36, 48)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 36, 36, 48)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 36, 36, 288)  13824       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 36, 36, 288)  1152       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 36, 36, 288)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 36, 36, 288)  7200       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 36, 36, 288)  1152       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 36, 36, 288)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 288)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 36, 36, 288)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 36, 36, 48)   13824       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 36, 36, 48)  192         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 36, 36, 48)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 36, 36, 48)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 36, 36, 288)  13824       ['block3c_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 36, 36, 288)  1152       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 36, 36, 288)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 37, 37, 288)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 18, 18, 288)  2592       ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 18, 18, 288)  1152       ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 18, 18, 288)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 288)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 18, 18, 288)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 18, 18, 96)   27648       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 18, 18, 96)  384         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 18, 18, 576)  55296       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 18, 18, 576)  2304       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 18, 18, 576)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 18, 18, 576)  5184       ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 18, 18, 576)  2304       ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 18, 18, 576)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 576)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 18, 18, 576)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 18, 18, 96)   55296       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 18, 18, 96)  384         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 18, 18, 96)   0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 18, 18, 96)   0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 18, 18, 576)  55296       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 18, 18, 576)  2304       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 18, 18, 576)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 18, 18, 576)  5184       ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 18, 18, 576)  2304       ['block4c_dwconv[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 18, 18, 576)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 576)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 18, 18, 576)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 18, 18, 96)   55296       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 18, 18, 96)  384         ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 18, 18, 96)   0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 18, 18, 96)   0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 18, 18, 576)  55296       ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 18, 18, 576)  2304       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 18, 18, 576)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv (DepthwiseConv2  (None, 18, 18, 576)  5184       ['block4d_expand_activation[0][0]
#  D)                                                              ']
#
#  block4d_bn (BatchNormalization  (None, 18, 18, 576)  2304       ['block4d_dwconv[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 18, 18, 576)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 576)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 18, 18, 576)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 18, 18, 96)   55296       ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 18, 18, 96)  384         ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (Dropout)         (None, 18, 18, 96)   0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 18, 18, 96)   0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, 18, 18, 576)  55296       ['block4d_add[0][0]']
#
#  block4e_expand_bn (BatchNormal  (None, 18, 18, 576)  2304       ['block4e_expand_conv[0][0]']
#  ization)
#
#  block4e_expand_activation (Act  (None, 18, 18, 576)  0          ['block4e_expand_bn[0][0]']
#  ivation)
#
#  block4e_dwconv (DepthwiseConv2  (None, 18, 18, 576)  5184       ['block4e_expand_activation[0][0]
#  D)                                                              ']
#
#  block4e_bn (BatchNormalization  (None, 18, 18, 576)  2304       ['block4e_dwconv[0][0]']
#  )
#
#  block4e_activation (Activation  (None, 18, 18, 576)  0          ['block4e_bn[0][0]']
#  )
# ...
#
#  block6e_dwconv (DepthwiseConv2  (None, 9, 9, 1392)  34800       ['block6e_expand_activation[0][0]
#  D)                                                              ']
#
#  block6e_bn (BatchNormalization  (None, 9, 9, 1392)  5568        ['block6e_dwconv[0][0]']
#  )
#
#  block6e_activation (Activation  (None, 9, 9, 1392)  0           ['block6e_bn[0][0]']
#  )
#
#  block6e_se_squeeze (GlobalAver  (None, 1392)        0           ['block6e_activation[0][0]']
#  agePooling2D)
#
#  block6e_se_reshape (Reshape)   (None, 1, 1, 1392)   0           ['block6e_se_squeeze[0][0]']
#
#  block6e_se_reduce (Conv2D)     (None, 1, 1, 58)     80794       ['block6e_se_reshape[0][0]']
#
#  block6e_se_expand (Conv2D)     (None, 1, 1, 1392)   82128       ['block6e_se_reduce[0][0]']
#
#  block6e_se_excite (Multiply)   (None, 9, 9, 1392)   0           ['block6e_activation[0][0]',
#                                                                   'block6e_se_expand[0][0]']
#
#  block6e_project_conv (Conv2D)  (None, 9, 9, 232)    322944      ['block6e_se_excite[0][0]']
#
#  block6e_project_bn (BatchNorma  (None, 9, 9, 232)   928         ['block6e_project_conv[0][0]']
#  lization)
#
#  block6e_drop (Dropout)         (None, 9, 9, 232)    0           ['block6e_project_bn[0][0]']
#
#  block6e_add (Add)              (None, 9, 9, 232)    0           ['block6e_drop[0][0]',
#                                                                   'block6d_add[0][0]']
#
#  block6f_expand_conv (Conv2D)   (None, 9, 9, 1392)   322944      ['block6e_add[0][0]']
#
#  block6f_expand_bn (BatchNormal  (None, 9, 9, 1392)  5568        ['block6f_expand_conv[0][0]']
#  ization)
#
#  block6f_expand_activation (Act  (None, 9, 9, 1392)  0           ['block6f_expand_bn[0][0]']
#  ivation)
#
#  block6f_dwconv (DepthwiseConv2  (None, 9, 9, 1392)  34800       ['block6f_expand_activation[0][0]
#  D)                                                              ']
#
#  block6f_bn (BatchNormalization  (None, 9, 9, 1392)  5568        ['block6f_dwconv[0][0]']
#  )
#
#  block6f_activation (Activation  (None, 9, 9, 1392)  0           ['block6f_bn[0][0]']
#  )
#
#  block6f_se_squeeze (GlobalAver  (None, 1392)        0           ['block6f_activation[0][0]']
#  agePooling2D)
#
#  block6f_se_reshape (Reshape)   (None, 1, 1, 1392)   0           ['block6f_se_squeeze[0][0]']
#
#  block6f_se_reduce (Conv2D)     (None, 1, 1, 58)     80794       ['block6f_se_reshape[0][0]']
#
#  block6f_se_expand (Conv2D)     (None, 1, 1, 1392)   82128       ['block6f_se_reduce[0][0]']
#
#  block6f_se_excite (Multiply)   (None, 9, 9, 1392)   0           ['block6f_activation[0][0]',
#                                                                   'block6f_se_expand[0][0]']
#
#  block6f_project_conv (Conv2D)  (None, 9, 9, 232)    322944      ['block6f_se_excite[0][0]']
#
#  block6f_project_bn (BatchNorma  (None, 9, 9, 232)   928         ['block6f_project_conv[0][0]']
#  lization)
#
#  block6f_drop (Dropout)         (None, 9, 9, 232)    0           ['block6f_project_bn[0][0]']
#
#  block6f_add (Add)              (None, 9, 9, 232)    0           ['block6f_drop[0][0]',
#                                                                   'block6e_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 9, 9, 1392)   322944      ['block6f_add[0][0]']
#
#  block7a_expand_bn (BatchNormal  (None, 9, 9, 1392)  5568        ['block7a_expand_conv[0][0]']
#  ization)
#
#  block7a_expand_activation (Act  (None, 9, 9, 1392)  0           ['block7a_expand_bn[0][0]']
#  ivation)
#
#  block7a_dwconv (DepthwiseConv2  (None, 9, 9, 1392)  12528       ['block7a_expand_activation[0][0]
#  D)                                                              ']
#
#  block7a_bn (BatchNormalization  (None, 9, 9, 1392)  5568        ['block7a_dwconv[0][0]']
#  )
#
#  block7a_activation (Activation  (None, 9, 9, 1392)  0           ['block7a_bn[0][0]']
#  )
#
#  block7a_se_squeeze (GlobalAver  (None, 1392)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1392)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 58)     80794       ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1392)   82128       ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 9, 9, 1392)   0           ['block7a_activation[0][0]',
#                                                                   'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 9, 9, 384)    534528      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 9, 9, 384)   1536        ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 9, 9, 2304)   884736      ['block7a_project_bn[0][0]']
#
#  block7b_expand_bn (BatchNormal  (None, 9, 9, 2304)  9216        ['block7b_expand_conv[0][0]']
#  ization)
#
#  block7b_expand_activation (Act  (None, 9, 9, 2304)  0           ['block7b_expand_bn[0][0]']
#  ivation)
#
#  block7b_dwconv (DepthwiseConv2  (None, 9, 9, 2304)  20736       ['block7b_expand_activation[0][0]
#  D)                                                              ']
#
#  block7b_bn (BatchNormalization  (None, 9, 9, 2304)  9216        ['block7b_dwconv[0][0]']
#  )
#
#  block7b_activation (Activation  (None, 9, 9, 2304)  0           ['block7b_bn[0][0]']
#  )
#
#  block7b_se_squeeze (GlobalAver  (None, 2304)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 2304)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 96)     221280      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 2304)   223488      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 9, 9, 2304)   0           ['block7b_activation[0][0]',
#                                                                   'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 9, 9, 384)    884736      ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 9, 9, 384)   1536        ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 9, 9, 384)    0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 9, 9, 384)    0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)              (None, 9, 9, 1536)   589824      ['block7b_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 9, 9, 1536)   6144        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 9, 9, 1536)   0           ['top_bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1536)        0           ['top_activation[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 1536)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 3)            4611        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 10,788,146
# Trainable params: 4,611
# Non-trainable params: 10,783,535
# __________________________________________________________________________________________________
# done1

# %%
# ==========================================================
# TRAINING MONITORING CALLBACKS
# ==========================================================
print("start")

early_stop = EarlyStopping(
    monitor='val_f1_score',
    mode='max',
    patience=11,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_f1_score',
    mode='max',
    factor=0.3,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

checkpoint_initial = ModelCheckpoint(
    "EfficientNetB3_SemiSupervised_Initial_imbalanced.h5",
    monitor='val_f1_score',
    save_best_only=True,
    save_weights_only=True,  # <--- FIX APPLIED HERE
    mode='max',
    verbose=1
)

print("done")
# Out:
# start
# done

# %%
print("start")

class PrintLearningRate(Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate.numpy()
        print(f"\nEpoch {epoch+1} Learning Rate : {lr}")

lr_callback = PrintLearningRate()

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# PHASE 1: INITIAL MODEL TRAINING (15% Labeled Subset)
# ==========================================================
print("start")

history_initial = model.fit(
    train_labeled_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stop, reduce_lr, checkpoint_initial, lr_callback]
)

print("Initial baseline model training complete")
# Out:
# start
# Epoch 1/150
# 124/124 [==============================] - ETA: 0s - loss: 1.1260 - accuracy: 0.3952 - f1_score: 0.3736 - precision: 0.4433 - recall: 0.1691
# Epoch 1: val_f1_score improved from -inf to 0.39135, saving model to EfficientNetB3_SemiSupervised_Initial_imbalanced.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-05
# 124/124 [==============================] - 138s 1s/step - loss: 1.1260 - accuracy: 0.3952 - f1_score: 0.3736 - precision: 0.4433 - recall: 0.1691 - val_loss: 1.0223 - val_accuracy: 0.4610 - val_f1_score: 0.3913 - val_precision: 0.5805 - val_recall: 0.2310 - lr: 1.0000e-04
# Epoch 2/150
# 124/124 [==============================] - ETA: 0s - loss: 1.0221 - accuracy: 0.4792 - f1_score: 0.4450 - precision: 0.5694 - recall: 0.2638
# Epoch 2: val_f1_score improved from 0.39135 to 0.52459, saving model to EfficientNetB3_SemiSupervised_Initial_imbalanced.h5
#
# Epoch 2 Learning Rate : 9.999999747378752e-05
# 124/124 [==============================] - 61s 496ms/step - loss: 1.0221 - accuracy: 0.4792 - f1_score: 0.4450 - precision: 0.5694 - recall: 0.2638 - val_loss: 0.9584 - val_accuracy: 0.5433 - val_f1_score: 0.5246 - val_precision: 0.6617 - val_recall: 0.2705 - lr: 1.0000e-04
# Epoch 3/150
# 124/124 [==============================] - ETA: 0s - loss: 0.9608 - accuracy: 0.5387 - f1_score: 0.5255 - precision: 0.6228 - recall: 0.3172
# Epoch 3: val_f1_score improved from 0.52459 to 0.55182, saving model to EfficientNetB3_SemiSupervised_Initial_imbalanced.h5
#
# Epoch 3 Learning Rate : 9.999999747378752e-05
# 124/124 [==============================] - 62s 498ms/step - loss: 0.9608 - accuracy: 0.5387 - f1_score: 0.5255 - precision: 0.6228 - recall: 0.3172 - val_loss: 0.9197 - val_accuracy: 0.5683 - val_f1_score: 0.5518 - val_precision: 0.6962 - val_recall: 0.3339 - lr: 1.0000e-04
# Epoch 4/150
# 124/124 [==============================] - ETA: 0s - loss: 0.9267 - accuracy: 0.5597 - f1_score: 0.5489 - precision: 0.6556 - recall: 0.3658
# Epoch 4: val_f1_score improved from 0.55182 to 0.57882, saving model to EfficientNetB3_SemiSupervised_Initial_imbalanced.h5
#
# Epoch 4 Learning Rate : 9.999999747378752e-05
# 124/124 [==============================] - 62s 503ms/step - loss: 0.9267 - accuracy: 0.5597 - f1_score: 0.5489 - precision: 0.6556 - recall: 0.3658 - val_loss: 0.8905 - val_accuracy: 0.5933 - val_f1_score: 0.5788 - val_precision: 0.7158 - val_recall: 0.3865 - lr: 1.0000e-04
# Epoch 5/150
# 124/124 [==============================] - ETA: 0s - loss: 0.8950 - accuracy: 0.5797 - f1_score: 0.5697 - precision: 0.6855 - recall: 0.3995
# Epoch 5: val_f1_score improved from 0.57882 to 0.59291, saving model to EfficientNetB3_SemiSupervised_Initial_imbalanced.h5
#
# Epoch 5 Learning Rate : 9.999999747378752e-05
# 124/124 [==============================] - 66s 532ms/step - loss: 0.8950 - accuracy: 0.5797 - f1_score: 0.5697 - precision: 0.6855 - recall: 0.3995 - val_loss: 0.8706 - val_accuracy: 0.6074 - val_f1_score: 0.5929 - val_precision: 0.7184 - val_recall: 0.4260 - lr: 1.0000e-04
# Epoch 6/150
# 124/124 [==============================] - ETA: 0s - loss: 0.8797 - accuracy: 0.5922 - f1_score: 0.5838 - precision: 0.6719 - recall: 0.4251
# Epoch 6: val_f1_score improved from 0.59291 to 0.59416, saving model to EfficientNetB3_SemiSupervised_Initial_imbalanced.h5
#
# Epoch 6 Learning Rate : 9.999999747378752e-05
# 124/124 [==============================] - 62s 496ms/step - loss: 0.8797 - accuracy: 0.5922 - f1_score: 0.5838 - precision: 0.6719 - recall: 0.4251 - val_loss: 0.8558 - val_accuracy: 0.6121 - val_f1_score: 0.5942 - val_precision: 0.7187 - val_recall: 0.4438 - lr: 1.0000e-04
# Epoch 7/150
# 124/124 [==============================] - ETA: 0s - loss: 0.8635 - accuracy: 0.6035 - f1_score: 0.5948 - precision: 0.6836 - recall: 0.4435
# Epoch 7: val_f1_score improved from 0.59416 to 0.60885, saving model to EfficientNetB3_SemiSupervised_Initial_imbalanced.h5
#
# Epoch 7 Learning Rate : 9.999999747378752e-05
# 124/124 [==============================] - 62s 495ms/step - loss: 0.8635 - accuracy: 0.6035 - f1_score: 0.5948 - precision: 0.6836 - recall: 0.4435 - val_loss: 0.8416 - val_accuracy: 0.6239 - val_f1_score: 0.6088 - val_precision: 0.7211 - val_recall: 0.4648 - lr: 1.0000e-04
# Epoch 8/150
# 124/124 [==============================] - ETA: 0s - loss: 0.8548 - accuracy: 0.6101 - f1_score: 0.6013 - precision: 0.6918 - recall: 0.4620
# Epoch 8: val_f1_score did not improve from 0.60885
#
# Epoch 8 Learning Rate : 9.999999747378752e-05
# 124/124 [==============================] - 50s 399ms/step - loss: 0.8548 - accuracy: 0.6101 - f1_score: 0.6013 - precision: 0.6918 - recall: 0.4620 - val_loss: 0.8327 - val_accuracy: 0.6219 - val_f1_score: 0.6049 - val_precision: 0.7233 - val_recall: 0.4691 - lr: 1.0000e-04
# Epoch 9/150
# 124/124 [==============================] - ETA: 0s - loss: 0.8375 - accuracy: 0.6142 - f1_score: 0.6037 - precision: 0.6981 - recall: 0.4754
# Epoch 9: val_f1_score improved from 0.60885 to 0.61772, saving model to EfficientNetB3_SemiSupervised_Initial_imbalanced.h5
#
# Epoch 9 Learning Rate : 9.999999747378752e-05
# 124/124 [==============================] - 61s 494ms/step - loss: 0.8375 - accuracy: 0.6142 - f1_score: 0.6037 - precision: 0.6981 - recall: 0.4754 - val_loss: 0.8213 - val_accuracy: 0.6317 - val_f1_score: 0.6177 - val_precision: 0.7248 - val_recall: 0.4867 - lr: 1.0000e-04
# Epoch 10/150
# 124/124 [==============================] - ETA: 0s - loss: 0.8301 - accuracy: 0.6271 - f1_score: 0.6190 - precision: 0.6992 - recall: 0.4790
# Epoch 10: val_f1_score did not improve from 0.61772
#
# Epoch 10 Learning Rate : 9.999999747378752e-05
# 124/124 [==============================] - 49s 394ms/step - loss: 0.8301 - accuracy: 0.6271 - f1_score: 0.6190 - precision: 0.6992 - recall: 0.4790 - val_loss: 0.8175 - val_accuracy: 0.6270 - val_f1_score: 0.6082 - val_precision: 0.7152 - val_recall: 0.4954 - lr: 1.0000e-04
# Epoch 11/150
# 124/124 [==============================] - ETA: 0s - loss: 0.8210 - accuracy: 0.6243 - f1_score: 0.6126 - precision: 0.6969 - recall: 0.4924
# Epoch 11: val_f1_score improved from 0.61772 to 0.62696, saving model to EfficientNetB3_SemiSupervised_Initial_imbalanced.h5
#
# Epoch 11 Learning Rate : 9.999999747378752e-05
# 124/124 [==============================] - 61s 491ms/step - loss: 0.8210 - accuracy: 0.6243 - f1_score: 0.6126 - precision: 0.6969 - recall: 0.4924 - val_loss: 0.8070 - val_accuracy: 0.6395 - val_f1_score: 0.6270 - val_precision: 0.7214 - val_recall: 0.5005 - lr: 1.0000e-04
# Epoch 12/150
# 124/124 [==============================] - ETA: 0s - loss: 0.8153 - accuracy: 0.6210 - f1_score: 0.6136 - precision: 0.7071 - recall: 0.4992
# Epoch 12: val_f1_score did not improve from 0.62696
#
# Epoch 12 Learning Rate : 9.999999747378752e-05
# 124/124 [==============================] - 50s 401ms/step - loss: 0.8153 - accuracy: 0.6210 - f1_score: 0.6136 - precision: 0.7071 - recall: 0.4992 - val_loss: 0.8072 - val_accuracy: 0.6280 - val_f1_score: 0.6075 - val_precision: 0.7172 - val_recall: 0.5056 - lr: 1.0000e-04
# Epoch 13/150
# 124/124 [==============================] - ETA: 0s - loss: 0.8103 - accuracy: 0.6311 - f1_score: 0.6216 - precision: 0.7029 - recall: 0.5030
# Epoch 13: val_f1_score improved from 0.62696 to 0.62993, saving model to EfficientNetB3_SemiSupervised_Initial_imbalanced.h5
#
# Epoch 13 Learning Rate : 9.999999747378752e-05
# 124/124 [==============================] - 62s 500ms/step - loss: 0.8103 - accuracy: 0.6311 - f1_score: 0.6216 - precision: 0.7029 - recall: 0.5030 - val_loss: 0.7964 - val_accuracy: 0.6418 - val_f1_score: 0.6299 - val_precision: 0.7228 - val_recall: 0.5153 - lr: 1.0000e-04
# Epoch 14/150
# 124/124 [==============================] - ETA: 0s - loss: 0.7987 - accuracy: 0.6420 - f1_score: 0.6311 - precision: 0.7101 - recall: 0.5134
# Epoch 14: val_f1_score improved from 0.62993 to 0.63652, saving model to EfficientNetB3_SemiSupervised_Initial_imbalanced.h5
#
# Epoch 14 Learning Rate : 9.999999747378752e-05
# 124/124 [==============================] - 63s 506ms/step - loss: 0.7987 - accuracy: 0.6420 - f1_score: 0.6311 - precision: 0.7101 - recall: 0.5134 - val_loss: 0.7903 - val_accuracy: 0.6459 - val_f1_score: 0.6365 - val_precision: 0.7280 - val_recall: 0.5207 - lr: 1.0000e-04
# Epoch 15/150
# 124/124 [==============================] - ETA: 0s - loss: 0.7936 - accuracy: 0.6425 - f1_score: 0.6343 - precision: 0.7180 - recall: 0.5319
# Epoch 15: val_f1_score did not improve from 0.63652
#
# Epoch 15 Learning Rate : 9.999999747378752e-05
# 124/124 [==============================] - 51s 408ms/step - loss: 0.7936 - accuracy: 0.6425 - f1_score: 0.6343 - precision: 0.7180 - recall: 0.5319 - val_loss: 0.7877 - val_accuracy: 0.6422 - val_f1_score: 0.6292 - val_precision: 0.7303 - val_recall: 0.5224 - lr: 1.0000e-04
# Epoch 16/150
# 124/124 [==============================] - ETA: 0s - loss: 0.7927 - accuracy: 0.6395 - f1_score: 0.6316 - precision: 0.7088 - recall: 0.5281
# Epoch 16: val_f1_score did not improve from 0.63652
#
# Epoch 16 Learning Rate : 9.999999747378752e-05
# 124/124 [==============================] - 50s 405ms/step - loss: 0.7927 - accuracy: 0.6395 - f1_score: 0.6316 - precision: 0.7088 - recall: 0.5281 - val_loss: 0.7840 - val_accuracy: 0.6428 - val_f1_score: 0.6296 - val_precision: 0.7289 - val_recall: 0.5251 - lr: 1.0000e-04
# Epoch 17/150
# 124/124 [==============================] - ETA: 0s - loss: 0.7876 - accuracy: 0.6423 - f1_score: 0.6337 - precision: 0.7097 - recall: 0.5286
# Epoch 17: val_f1_score did not improve from 0.63652
#
# Epoch 17 Learning Rate : 9.999999747378752e-05
# 124/124 [==============================] - 49s 394ms/step - loss: 0.7876 - accuracy: 0.6423 - f1_score: 0.6337 - precision: 0.7097 - recall: 0.5286 - val_loss: 0.7805 - val_accuracy: 0.6462 - val_f1_score: 0.6349 - val_precision: 0.7309 - val_recall: 0.5322 - lr: 1.0000e-04
# Epoch 18/150
# 124/124 [==============================] - ETA: 0s - loss: 0.7872 - accuracy: 0.6438 - f1_score: 0.6355 - precision: 0.7111 - recall: 0.5291
# Epoch 18: val_f1_score did not improve from 0.63652
#
# Epoch 18 Learning Rate : 9.999999747378752e-05
# 124/124 [==============================] - 48s 392ms/step - loss: 0.7872 - accuracy: 0.6438 - f1_score: 0.6355 - precision: 0.7111 - recall: 0.5291 - val_loss: 0.7819 - val_accuracy: 0.6401 - val_f1_score: 0.6228 - val_precision: 0.7248 - val_recall: 0.5295 - lr: 1.0000e-04
# Epoch 19/150
# 124/124 [==============================] - ETA: 0s - loss: 0.7788 - accuracy: 0.6532 - f1_score: 0.6434 - precision: 0.7246 - recall: 0.5415
# Epoch 19: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 19: val_f1_score did not improve from 0.63652
#
# Epoch 19 Learning Rate : 2.9999999242136255e-05
# 124/124 [==============================] - 49s 400ms/step - loss: 0.7788 - accuracy: 0.6532 - f1_score: 0.6434 - precision: 0.7246 - recall: 0.5415 - val_loss: 0.7752 - val_accuracy: 0.6462 - val_f1_score: 0.6341 - val_precision: 0.7278 - val_recall: 0.5393 - lr: 1.0000e-04
# Epoch 20/150
# 124/124 [==============================] - ETA: 0s - loss: 0.7775 - accuracy: 0.6547 - f1_score: 0.6493 - precision: 0.7120 - recall: 0.5451
# Epoch 20: val_f1_score did not improve from 0.63652
#
# Epoch 20 Learning Rate : 2.9999999242136255e-05
# 124/124 [==============================] - 50s 401ms/step - loss: 0.7775 - accuracy: 0.6547 - f1_score: 0.6493 - precision: 0.7120 - recall: 0.5451 - val_loss: 0.7751 - val_accuracy: 0.6462 - val_f1_score: 0.6326 - val_precision: 0.7273 - val_recall: 0.5406 - lr: 3.0000e-05
# Epoch 21/150
# 124/124 [==============================] - ETA: 0s - loss: 0.7772 - accuracy: 0.6446 - f1_score: 0.6366 - precision: 0.7223 - recall: 0.5339
# Epoch 21: val_f1_score did not improve from 0.63652
#
# Epoch 21 Learning Rate : 2.9999999242136255e-05
# 124/124 [==============================] - 49s 396ms/step - loss: 0.7772 - accuracy: 0.6446 - f1_score: 0.6366 - precision: 0.7223 - recall: 0.5339 - val_loss: 0.7744 - val_accuracy: 0.6438 - val_f1_score: 0.6299 - val_precision: 0.7285 - val_recall: 0.5403 - lr: 3.0000e-05
# Epoch 22/150
# 124/124 [==============================] - ETA: 0s - loss: 0.7773 - accuracy: 0.6433 - f1_score: 0.6363 - precision: 0.7185 - recall: 0.5365
# Epoch 22: val_f1_score did not improve from 0.63652
#
# Epoch 22 Learning Rate : 2.9999999242136255e-05
# 124/124 [==============================] - 50s 399ms/step - loss: 0.7773 - accuracy: 0.6433 - f1_score: 0.6363 - precision: 0.7185 - recall: 0.5365 - val_loss: 0.7735 - val_accuracy: 0.6442 - val_f1_score: 0.6306 - val_precision: 0.7302 - val_recall: 0.5403 - lr: 3.0000e-05
# Epoch 23/150
# 124/124 [==============================] - ETA: 0s - loss: 0.7714 - accuracy: 0.6491 - f1_score: 0.6423 - precision: 0.7230 - recall: 0.5418
# Epoch 23: val_f1_score did not improve from 0.63652
#
# Epoch 23 Learning Rate : 2.9999999242136255e-05
# 124/124 [==============================] - 52s 416ms/step - loss: 0.7714 - accuracy: 0.6491 - f1_score: 0.6423 - precision: 0.7230 - recall: 0.5418 - val_loss: 0.7740 - val_accuracy: 0.6445 - val_f1_score: 0.6299 - val_precision: 0.7278 - val_recall: 0.5420 - lr: 3.0000e-05
# Epoch 24/150
# 124/124 [==============================] - ETA: 0s - loss: 0.7710 - accuracy: 0.6554 - f1_score: 0.6474 - precision: 0.7170 - recall: 0.5438
# Epoch 24: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 24: val_f1_score did not improve from 0.63652
#
# Epoch 24 Learning Rate : 8.999999408842996e-06
# 124/124 [==============================] - 51s 414ms/step - loss: 0.7710 - accuracy: 0.6554 - f1_score: 0.6474 - precision: 0.7170 - recall: 0.5438 - val_loss: 0.7720 - val_accuracy: 0.6469 - val_f1_score: 0.6332 - val_precision: 0.7301 - val_recall: 0.5420 - lr: 3.0000e-05
# Epoch 25/150
# 124/124 [==============================] - ETA: 0s - loss: 0.7671 - accuracy: 0.6570 - f1_score: 0.6501 - precision: 0.7162 - recall: 0.5418Restoring model weights from the end of the best epoch: 14.
#
# Epoch 25: val_f1_score did not improve from 0.63652
#
# Epoch 25 Learning Rate : 8.999999408842996e-06
# 124/124 [==============================] - 52s 421ms/step - loss: 0.7671 - accuracy: 0.6570 - f1_score: 0.6501 - precision: 0.7162 - recall: 0.5418 - val_loss: 0.7717 - val_accuracy: 0.6472 - val_f1_score: 0.6338 - val_precision: 0.7293 - val_recall: 0.5423 - lr: 9.0000e-06
# Epoch 25: early stopping
# Initial baseline model training complete

# %%
# ==========================================================
# PHASE 2 & 3: ITERATIVE SEMI-SUPERVISED SELF-TRAINING LOOP
# ==========================================================
# --- DEFINE PATHS AT TOP OF LOOP CELL ---
print("start")
base_path = r"D:\Thesis_folder\Preprocessed_Pipeline\Semi_Supervised_Imbalanced"
train_dir = os.path.join(base_path, 'labeled_train')
unlabeled_dir = os.path.join(base_path, 'unlabeled_train')
train_combined_dir = os.path.join(base_path, 'train_combined')


NUM_ITERATIONS = 5
EPOCHS_PER_ITERATION = 7
CONFIDENCE_THRESHOLD = 0.90

class CombinedHistory:
    def __init__(self):
        self.history = {
            'loss': [], 'val_loss': [],
            'f1_score': [], 'val_f1_score': [],
            'precision': [], 'val_precision': [],
            'accuracy': [], 'val_accuracy': []
        }
history_final = CombinedHistory()

print("Initializing combined training directory with baseline labeled data...")
if os.path.exists(train_combined_dir):
    shutil.rmtree(train_combined_dir)
os.makedirs(train_combined_dir, exist_ok=True)

for class_name in os.listdir(train_dir):
    src_class_dir = os.path.join(train_dir, class_name)
    dst_class_dir = os.path.join(train_combined_dir, class_name)
    if os.path.isdir(src_class_dir):
        shutil.copytree(src_class_dir, dst_class_dir)

# --- START THE ITERATIVE LOOP ---
for iteration in range(NUM_ITERATIONS):
    print(f"\n==================================================")
    print(f" STARTING ITERATION {iteration + 1} / {NUM_ITERATIONS}")
    print(f"==================================================")

    predict_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
        preprocessing_function=preprocess_input
    )

    unlabeled_generator = predict_datagen.flow_from_directory(
        unlabeled_dir,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False
    )

    if unlabeled_generator.samples == 0:
        print("No remaining images left in the unlabeled directory! Ending loop early.")
        break

    print(f"Predicting on {unlabeled_generator.samples} remaining unlabeled images...")
    predictions = model.predict(unlabeled_generator, verbose=1)

    # FIX: derive this from the generator instead of hardcoding -- the old
    # hardcoded dict included a leftover 4th class (Suspicious_Malignant)
    # from an earlier, unmerged version of the dataset.
    inv_class_indices = {v: k for k, v in train_labeled_generator.class_indices.items()}
    filenames = unlabeled_generator.filenames

    moved_count = 0
    for i, pred in enumerate(predictions):
        max_confidence = np.max(pred)

        if max_confidence >= CONFIDENCE_THRESHOLD:
            predicted_class_idx = np.argmax(pred)
            predicted_class_name = inv_class_indices[predicted_class_idx]

            src_file_path = os.path.join(unlabeled_dir, filenames[i])
            file_basename = os.path.basename(filenames[i])
            dst_file_path = os.path.join(train_combined_dir, predicted_class_name, file_basename)

            if os.path.exists(src_file_path):
                shutil.move(src_file_path, dst_file_path)
                moved_count += 1

    print(f"Iteration {iteration + 1}: Successfully incorporated {moved_count} new pseudo-labels.")

    train_combined_generator = train_datagen.flow_from_directory(
        train_combined_dir,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=True
    )

    for layer in model.layers:
        if isinstance(layer, tf.keras.layers.BatchNormalization):
            layer.trainable = False
        else:
            layer.trainable = True

    model.compile(
        loss="categorical_crossentropy",
        metrics=["accuracy", f1_metric, precision_metric],
        optimizer=Adam(learning_rate=1e-5)
    )

    checkpoint_final = ModelCheckpoint(
        "EfficientNetB3_SemiSupervised_Final_imbalanced.h5",
        monitor='val_f1_score',
        save_best_only=True,
        save_weights_only=True,
        mode='max',
        verbose=1
    )

    print(f"Training model for {EPOCHS_PER_ITERATION} epochs on updated dataset...")
    history = model.fit(
        train_combined_generator,
        validation_data=val_generator,
        epochs=EPOCHS_PER_ITERATION,
        callbacks=[early_stop, reduce_lr, checkpoint_final, lr_callback]
    )

    for key in history_final.history.keys():
        if key in history.history:
            history_final.history[key].extend(history.history[key])

print("\nIterative Semi-Supervised training loop successfully completed!")
print("done1")
# Out:
# start
# Initializing combined training directory with baseline labeled data...
#
# ==================================================
#  STARTING ITERATION 1 / 5
# ==================================================
# Found 9873 images belonging to 3 classes.
# Predicting on 9873 remaining unlabeled images...
# 309/309 [==============================] - 150s 484ms/step
# Iteration 1: Successfully incorporated 54 new pseudo-labels.
# Found 4004 images belonging to 3 classes.
# Training model for 7 epochs on updated dataset...
# Epoch 1/7
# 126/126 [==============================] - ETA: 0s - loss: 0.7566 - accuracy: 0.6506 - f1_score: 0.6394 - precision: 0.7215
# Epoch 1: val_f1_score improved from -inf to 0.62287, saving model to EfficientNetB3_SemiSupervised_Final_imbalanced.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-06
# 126/126 [==============================] - 69s 510ms/step - loss: 0.7566 - accuracy: 0.6506 - f1_score: 0.6394 - precision: 0.7215 - val_loss: 0.7402 - val_accuracy: 0.6472 - val_f1_score: 0.6229 - val_precision: 0.7130 - lr: 1.0000e-05
# Epoch 2/7
# 126/126 [==============================] - ETA: 0s - loss: 0.6843 - accuracy: 0.6923 - f1_score: 0.6858 - precision: 0.7442
# Epoch 2: val_f1_score improved from 0.62287 to 0.66617, saving model to EfficientNetB3_SemiSupervised_Final_imbalanced.h5
#
# Epoch 2 Learning Rate : 9.999999747378752e-06
# 126/126 [==============================] - 66s 526ms/step - loss: 0.6843 - accuracy: 0.6923 - f1_score: 0.6858 - precision: 0.7442 - val_loss: 0.7062 - val_accuracy: 0.6675 - val_f1_score: 0.6662 - val_precision: 0.7265 - lr: 1.0000e-05
# Epoch 3/7
# 126/126 [==============================] - ETA: 0s - loss: 0.6505 - accuracy: 0.7068 - f1_score: 0.7045 - precision: 0.7548
# Epoch 3: val_f1_score improved from 0.66617 to 0.67169, saving model to EfficientNetB3_SemiSupervised_Final_imbalanced.h5
#
# Epoch 3 Learning Rate : 9.999999747378752e-06
# 126/126 [==============================] - 64s 509ms/step - loss: 0.6505 - accuracy: 0.7068 - f1_score: 0.7045 - precision: 0.7548 - val_loss: 0.6928 - val_accuracy: 0.6830 - val_f1_score: 0.6717 - val_precision: 0.7394 - lr: 1.0000e-05
# Epoch 4/7
# 126/126 [==============================] - ETA: 0s - loss: 0.6166 - accuracy: 0.7230 - f1_score: 0.7191 - precision: 0.7676
# Epoch 4: val_f1_score improved from 0.67169 to 0.67204, saving model to EfficientNetB3_SemiSupervised_Final_imbalanced.h5
#
# Epoch 4 Learning Rate : 9.999999747378752e-06
# 126/126 [==============================] - 66s 522ms/step - loss: 0.6166 - accuracy: 0.7230 - f1_score: 0.7191 - precision: 0.7676 - val_loss: 0.6833 - val_accuracy: 0.6863 - val_f1_score: 0.6720 - val_precision: 0.7314 - lr: 1.0000e-05
# Epoch 5/7
# 126/126 [==============================] - ETA: 0s - loss: 0.5725 - accuracy: 0.7527 - f1_score: 0.7491 - precision: 0.7930
# Epoch 5: val_f1_score improved from 0.67204 to 0.69098, saving model to EfficientNetB3_SemiSupervised_Final_imbalanced.h5
#
# Epoch 5 Learning Rate : 9.999999747378752e-06
# 126/126 [==============================] - 64s 510ms/step - loss: 0.5725 - accuracy: 0.7527 - f1_score: 0.7491 - precision: 0.7930 - val_loss: 0.6761 - val_accuracy: 0.6958 - val_f1_score: 0.6910 - val_precision: 0.7426 - lr: 1.0000e-05
# Epoch 6/7
# 126/126 [==============================] - ETA: 0s - loss: 0.5341 - accuracy: 0.7737 - f1_score: 0.7731 - precision: 0.8068
# Epoch 6: val_f1_score did not improve from 0.69098
#
# Epoch 6 Learning Rate : 9.999999747378752e-06
# 126/126 [==============================] - 53s 418ms/step - loss: 0.5341 - accuracy: 0.7737 - f1_score: 0.7731 - precision: 0.8068 - val_loss: 0.6918 - val_accuracy: 0.6887 - val_f1_score: 0.6794 - val_precision: 0.7273 - lr: 1.0000e-05
# Epoch 7/7
# 126/126 [==============================] - ETA: 0s - loss: 0.5039 - accuracy: 0.7805 - f1_score: 0.7793 - precision: 0.8163
# Epoch 7: val_f1_score improved from 0.69098 to 0.69651, saving model to EfficientNetB3_SemiSupervised_Final_imbalanced.h5
#
# Epoch 7 Learning Rate : 9.999999747378752e-06
# 126/126 [==============================] - 64s 510ms/step - loss: 0.5039 - accuracy: 0.7805 - f1_score: 0.7793 - precision: 0.8163 - val_loss: 0.6657 - val_accuracy: 0.7005 - val_f1_score: 0.6965 - val_precision: 0.7397 - lr: 1.0000e-05
#
# ==================================================
#  STARTING ITERATION 2 / 5
# ==================================================
# Found 9819 images belonging to 3 classes.
# Predicting on 9819 remaining unlabeled images...
# 307/307 [==============================] - 73s 236ms/step
# Iteration 2: Successfully incorporated 2676 new pseudo-labels.
# Found 6680 images belonging to 3 classes.
# Training model for 7 epochs on updated dataset...
# Epoch 1/7
# 209/209 [==============================] - ETA: 0s - loss: 0.3068 - accuracy: 0.8772 - f1_score: 0.8133 - precision: 0.8503
# Epoch 1: val_f1_score improved from -inf to 0.68694, saving model to EfficientNetB3_SemiSupervised_Final_imbalanced.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-06
# 209/209 [==============================] - 95s 435ms/step - loss: 0.3068 - accuracy: 0.8772 - f1_score: 0.8133 - precision: 0.8503 - val_loss: 0.7111 - val_accuracy: 0.6941 - val_f1_score: 0.6869 - val_precision: 0.7244 - lr: 1.0000e-05
# Epoch 2/7
# 209/209 [==============================] - ETA: 0s - loss: 0.2798 - accuracy: 0.8891 - f1_score: 0.8788 - precision: 0.9042
# Epoch 2: val_f1_score improved from 0.68694 to 0.69816, saving model to EfficientNetB3_SemiSupervised_Final_imbalanced.h5
#
# Epoch 2 Learning Rate : 9.999999747378752e-06
# 209/209 [==============================] - 89s 427ms/step - loss: 0.2798 - accuracy: 0.8891 - f1_score: 0.8788 - precision: 0.9042 - val_loss: 0.7094 - val_accuracy: 0.7066 - val_f1_score: 0.6982 - val_precision: 0.7308 - lr: 1.0000e-05
# Epoch 3/7
# 209/209 [==============================] - ETA: 0s - loss: 0.2534 - accuracy: 0.8948 - f1_score: 0.8856 - precision: 0.9093
# Epoch 3: val_f1_score did not improve from 0.69816
#
# Epoch 3 Learning Rate : 9.999999747378752e-06
# 209/209 [==============================] - 78s 370ms/step - loss: 0.2534 - accuracy: 0.8948 - f1_score: 0.8856 - precision: 0.9093 - val_loss: 0.7168 - val_accuracy: 0.6958 - val_f1_score: 0.6944 - val_precision: 0.7146 - lr: 1.0000e-05
# Epoch 4/7
# 209/209 [==============================] - ETA: 0s - loss: 0.2305 - accuracy: 0.9091 - f1_score: 0.9014 - precision: 0.9190
# Epoch 4: val_f1_score did not improve from 0.69816
#
# Epoch 4 Learning Rate : 9.999999747378752e-06
# 209/209 [==============================] - 74s 354ms/step - loss: 0.2305 - accuracy: 0.9091 - f1_score: 0.9014 - precision: 0.9190 - val_loss: 0.7693 - val_accuracy: 0.7046 - val_f1_score: 0.6962 - val_precision: 0.7210 - lr: 1.0000e-05
# Epoch 5/7
# 209/209 [==============================] - ETA: 0s - loss: 0.2118 - accuracy: 0.9150 - f1_score: 0.9075 - precision: 0.9251
# Epoch 5: val_f1_score improved from 0.69816 to 0.70056, saving model to EfficientNetB3_SemiSupervised_Final_imbalanced.h5
#
# Epoch 5 Learning Rate : 9.999999747378752e-06
# 209/209 [==============================] - 88s 421ms/step - loss: 0.2118 - accuracy: 0.9150 - f1_score: 0.9075 - precision: 0.9251 - val_loss: 0.7925 - val_accuracy: 0.7042 - val_f1_score: 0.7006 - val_precision: 0.7170 - lr: 1.0000e-05
# Epoch 6/7
# 209/209 [==============================] - ETA: 0s - loss: 0.1878 - accuracy: 0.9251 - f1_score: 0.9185 - precision: 0.9333
# Epoch 6: val_f1_score did not improve from 0.70056
#
# Epoch 6 Learning Rate : 9.999999747378752e-06
# 209/209 [==============================] - 78s 369ms/step - loss: 0.1878 - accuracy: 0.9251 - f1_score: 0.9185 - precision: 0.9333 - val_loss: 0.8145 - val_accuracy: 0.6995 - val_f1_score: 0.6947 - val_precision: 0.7152 - lr: 1.0000e-05
# Epoch 7/7
# 209/209 [==============================] - ETA: 0s - loss: 0.1657 - accuracy: 0.9362 - f1_score: 0.9304 - precision: 0.9422
# Epoch 7: val_f1_score did not improve from 0.70056
#
# Epoch 7 Learning Rate : 9.999999747378752e-06
# 209/209 [==============================] - 77s 366ms/step - loss: 0.1657 - accuracy: 0.9362 - f1_score: 0.9304 - precision: 0.9422 - val_loss: 0.8310 - val_accuracy: 0.6948 - val_f1_score: 0.6910 - val_precision: 0.7054 - lr: 1.0000e-05
#
# ==================================================
#  STARTING ITERATION 3 / 5
# ==================================================
# Found 7143 images belonging to 3 classes.
# Predicting on 7143 remaining unlabeled images...
# 224/224 [==============================] - 49s 216ms/step
# Iteration 3: Successfully incorporated 2473 new pseudo-labels.
# Found 9153 images belonging to 3 classes.
# Training model for 7 epochs on updated dataset...
# Epoch 1/7
# 287/287 [==============================] - ETA: 0s - loss: 0.1438 - accuracy: 0.9459 - f1_score: 0.8781 - precision: 0.8922
# Epoch 1: val_f1_score improved from -inf to 0.69676, saving model to EfficientNetB3_SemiSupervised_Final_imbalanced.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-06
# 287/287 [==============================] - 114s 381ms/step - loss: 0.1438 - accuracy: 0.9459 - f1_score: 0.8781 - precision: 0.8922 - val_loss: 0.9640 - val_accuracy: 0.7025 - val_f1_score: 0.6968 - val_precision: 0.7093 - lr: 1.0000e-05
# Epoch 2/7
# 287/287 [==============================] - ETA: 0s - loss: 0.1189 - accuracy: 0.9549 - f1_score: 0.9515 - precision: 0.9594
# Epoch 2: val_f1_score did not improve from 0.69676
#
# Epoch 2 Learning Rate : 9.999999747378752e-06
# 287/287 [==============================] - 91s 317ms/step - loss: 0.1189 - accuracy: 0.9549 - f1_score: 0.9515 - precision: 0.9594 - val_loss: 1.0056 - val_accuracy: 0.6850 - val_f1_score: 0.6852 - val_precision: 0.6945 - lr: 1.0000e-05
# Epoch 3/7
# 287/287 [==============================] - ETA: 0s - loss: 0.1093 - accuracy: 0.9600 - f1_score: 0.9572 - precision: 0.9634
# Epoch 3: val_f1_score improved from 0.69676 to 0.69863, saving model to EfficientNetB3_SemiSupervised_Final_imbalanced.h5
#
# Epoch 3 Learning Rate : 9.999999747378752e-06
# 287/287 [==============================] - 106s 367ms/step - loss: 0.1093 - accuracy: 0.9600 - f1_score: 0.9572 - precision: 0.9634 - val_loss: 1.0572 - val_accuracy: 0.6985 - val_f1_score: 0.6986 - val_precision: 0.7057 - lr: 1.0000e-05
# Epoch 4/7
# 287/287 [==============================] - ETA: 0s - loss: 0.0928 - accuracy: 0.9685 - f1_score: 0.9661 - precision: 0.9712
# Epoch 4: val_f1_score did not improve from 0.69863
#
# Epoch 4 Learning Rate : 9.999999747378752e-06
# 287/287 [==============================] - 89s 308ms/step - loss: 0.0928 - accuracy: 0.9685 - f1_score: 0.9661 - precision: 0.9712 - val_loss: 1.1325 - val_accuracy: 0.6971 - val_f1_score: 0.6882 - val_precision: 0.7029 - lr: 1.0000e-05
# Epoch 5/7
# 287/287 [==============================] - ETA: 0s - loss: 0.0919 - accuracy: 0.9653 - f1_score: 0.9625 - precision: 0.9675
# Epoch 5: val_f1_score did not improve from 0.69863
#
# Epoch 5 Learning Rate : 9.999999747378752e-06
# 287/287 [==============================] - 90s 314ms/step - loss: 0.0919 - accuracy: 0.9653 - f1_score: 0.9625 - precision: 0.9675 - val_loss: 1.2377 - val_accuracy: 0.6948 - val_f1_score: 0.6869 - val_precision: 0.7046 - lr: 1.0000e-05
# Epoch 6/7
# 287/287 [==============================] - ETA: 0s - loss: 0.0741 - accuracy: 0.9747 - f1_score: 0.9726 - precision: 0.9767
# Epoch 6: val_f1_score did not improve from 0.69863
#
# Epoch 6 Learning Rate : 9.999999747378752e-06
# 287/287 [==============================] - 91s 315ms/step - loss: 0.0741 - accuracy: 0.9747 - f1_score: 0.9726 - precision: 0.9767 - val_loss: 1.3109 - val_accuracy: 0.6985 - val_f1_score: 0.6915 - val_precision: 0.7053 - lr: 1.0000e-05
# Epoch 7/7
# 287/287 [==============================] - ETA: 0s - loss: 0.0703 - accuracy: 0.9742 - f1_score: 0.9725 - precision: 0.9756
# Epoch 7: val_f1_score did not improve from 0.69863
#
# Epoch 7 Learning Rate : 9.999999747378752e-06
# 287/287 [==============================] - 91s 316ms/step - loss: 0.0703 - accuracy: 0.9742 - f1_score: 0.9725 - precision: 0.9756 - val_loss: 1.2906 - val_accuracy: 0.6985 - val_f1_score: 0.6970 - val_precision: 0.7026 - lr: 1.0000e-05
#
# ==================================================
#  STARTING ITERATION 4 / 5
# ==================================================
# Found 4670 images belonging to 3 classes.
# Predicting on 4670 remaining unlabeled images...
# 146/146 [==============================] - 35s 237ms/step
# Iteration 4: Successfully incorporated 2020 new pseudo-labels.
# Found 11173 images belonging to 3 classes.
# Training model for 7 epochs on updated dataset...
# Epoch 1/7
# 350/350 [==============================] - ETA: 0s - loss: 0.0895 - accuracy: 0.9674 - f1_score: 0.9091 - precision: 0.9137
# Epoch 1: val_f1_score improved from -inf to 0.68182, saving model to EfficientNetB3_SemiSupervised_Final_imbalanced.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-06
# 350/350 [==============================] - 126s 347ms/step - loss: 0.0895 - accuracy: 0.9674 - f1_score: 0.9091 - precision: 0.9137 - val_loss: 1.4409 - val_accuracy: 0.6870 - val_f1_score: 0.6818 - val_precision: 0.6909 - lr: 1.0000e-05
# Epoch 2/7
# 350/350 [==============================] - ETA: 0s - loss: 0.0859 - accuracy: 0.9693 - f1_score: 0.9686 - precision: 0.9712
# Epoch 2: val_f1_score improved from 0.68182 to 0.69312, saving model to EfficientNetB3_SemiSupervised_Final_imbalanced.h5
#
# Epoch 2 Learning Rate : 9.999999747378752e-06
# 350/350 [==============================] - 119s 339ms/step - loss: 0.0859 - accuracy: 0.9693 - f1_score: 0.9686 - precision: 0.9712 - val_loss: 1.4672 - val_accuracy: 0.6995 - val_f1_score: 0.6931 - val_precision: 0.7028 - lr: 1.0000e-05
# Epoch 3/7
# 350/350 [==============================] - ETA: 0s - loss: 0.0721 - accuracy: 0.9745 - f1_score: 0.9738 - precision: 0.9758
# Epoch 3: val_f1_score improved from 0.69312 to 0.69556, saving model to EfficientNetB3_SemiSupervised_Final_imbalanced.h5
#
# Epoch 3 Learning Rate : 9.999999747378752e-06
# 350/350 [==============================] - 120s 342ms/step - loss: 0.0721 - accuracy: 0.9745 - f1_score: 0.9738 - precision: 0.9758 - val_loss: 1.5449 - val_accuracy: 0.6992 - val_f1_score: 0.6956 - val_precision: 0.6999 - lr: 1.0000e-05
# Epoch 4/7
# 350/350 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9790 - f1_score: 0.9785 - precision: 0.9798
# Epoch 4: val_f1_score improved from 0.69556 to 0.70090, saving model to EfficientNetB3_SemiSupervised_Final_imbalanced.h5
#
# Epoch 4 Learning Rate : 9.999999747378752e-06
# 350/350 [==============================] - 119s 339ms/step - loss: 0.0641 - accuracy: 0.9790 - f1_score: 0.9785 - precision: 0.9798 - val_loss: 1.6183 - val_accuracy: 0.7062 - val_f1_score: 0.7009 - val_precision: 0.7082 - lr: 1.0000e-05
# Epoch 5/7
# 350/350 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9775 - f1_score: 0.9770 - precision: 0.9785
# Epoch 5: val_f1_score did not improve from 0.70090
#
# Epoch 5 Learning Rate : 9.999999747378752e-06
# 350/350 [==============================] - 106s 301ms/step - loss: 0.0641 - accuracy: 0.9775 - f1_score: 0.9770 - precision: 0.9785 - val_loss: 1.7473 - val_accuracy: 0.6992 - val_f1_score: 0.6911 - val_precision: 0.7033 - lr: 1.0000e-05
# Epoch 6/7
# 350/350 [==============================] - ETA: 0s - loss: 0.0603 - accuracy: 0.9788 - f1_score: 0.9782 - precision: 0.9795
# Epoch 6: val_f1_score improved from 0.70090 to 0.70295, saving model to EfficientNetB3_SemiSupervised_Final_imbalanced.h5
#
# Epoch 6 Learning Rate : 9.999999747378752e-06
# 350/350 [==============================] - 117s 334ms/step - loss: 0.0603 - accuracy: 0.9788 - f1_score: 0.9782 - precision: 0.9795 - val_loss: 1.6388 - val_accuracy: 0.7039 - val_f1_score: 0.7030 - val_precision: 0.7057 - lr: 1.0000e-05
# Epoch 7/7
# 350/350 [==============================] - ETA: 0s - loss: 0.0567 - accuracy: 0.9800 - f1_score: 0.9795 - precision: 0.9809
# Epoch 7: val_f1_score did not improve from 0.70295
#
# Epoch 7 Learning Rate : 9.999999747378752e-06
# 350/350 [==============================] - 105s 298ms/step - loss: 0.0567 - accuracy: 0.9800 - f1_score: 0.9795 - precision: 0.9809 - val_loss: 1.7218 - val_accuracy: 0.7019 - val_f1_score: 0.7004 - val_precision: 0.7035 - lr: 1.0000e-05
#
# ==================================================
#  STARTING ITERATION 5 / 5
# ==================================================
# Found 2650 images belonging to 3 classes.
# Predicting on 2650 remaining unlabeled images...
# 83/83 [==============================] - 21s 241ms/step
# Iteration 5: Successfully incorporated 1010 new pseudo-labels.
# Found 12183 images belonging to 3 classes.
# Training model for 7 epochs on updated dataset...
# Epoch 1/7
# 381/381 [==============================] - ETA: 0s - loss: 0.0743 - accuracy: 0.9732 - f1_score: 0.9191 - precision: 0.9212
# Epoch 1: val_f1_score improved from -inf to 0.70275, saving model to EfficientNetB3_SemiSupervised_Final_imbalanced.h5
#
# Epoch 1 Learning Rate : 9.999999747378752e-06
# 381/381 [==============================] - 128s 324ms/step - loss: 0.0743 - accuracy: 0.9732 - f1_score: 0.9191 - precision: 0.9212 - val_loss: 1.7353 - val_accuracy: 0.7032 - val_f1_score: 0.7027 - val_precision: 0.7060 - lr: 1.0000e-05
# Epoch 2/7
# 381/381 [==============================] - ETA: 0s - loss: 0.0725 - accuracy: 0.9741 - f1_score: 0.9739 - precision: 0.9754
# Epoch 2: val_f1_score did not improve from 0.70275
#
# Epoch 2 Learning Rate : 9.999999747378752e-06
# 381/381 [==============================] - 118s 308ms/step - loss: 0.0725 - accuracy: 0.9741 - f1_score: 0.9739 - precision: 0.9754 - val_loss: 1.7158 - val_accuracy: 0.7046 - val_f1_score: 0.7002 - val_precision: 0.7060 - lr: 1.0000e-05
# Epoch 3/7
# 381/381 [==============================] - ETA: 0s - loss: 0.0567 - accuracy: 0.9805 - f1_score: 0.9804 - precision: 0.9810
# Epoch 3: val_f1_score did not improve from 0.70275
#
# Epoch 3 Learning Rate : 9.999999747378752e-06
# 381/381 [==============================] - 112s 292ms/step - loss: 0.0567 - accuracy: 0.9805 - f1_score: 0.9804 - precision: 0.9810 - val_loss: 1.7599 - val_accuracy: 0.7052 - val_f1_score: 0.7022 - val_precision: 0.7079 - lr: 1.0000e-05
# Epoch 4/7
# 381/381 [==============================] - ETA: 0s - loss: 0.0505 - accuracy: 0.9814 - f1_score: 0.9813 - precision: 0.9819
# Epoch 4: val_f1_score improved from 0.70275 to 0.70299, saving model to EfficientNetB3_SemiSupervised_Final_imbalanced.h5
#
# Epoch 4 Learning Rate : 9.999999747378752e-06
# 381/381 [==============================] - 125s 328ms/step - loss: 0.0505 - accuracy: 0.9814 - f1_score: 0.9813 - precision: 0.9819 - val_loss: 1.8523 - val_accuracy: 0.7069 - val_f1_score: 0.7030 - val_precision: 0.7085 - lr: 1.0000e-05
# Epoch 5/7
# 381/381 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9828 - f1_score: 0.9826 - precision: 0.9836
# Epoch 5: val_f1_score did not improve from 0.70299
#
# Epoch 5 Learning Rate : 9.999999747378752e-06
# 381/381 [==============================] - 113s 294ms/step - loss: 0.0511 - accuracy: 0.9828 - f1_score: 0.9826 - precision: 0.9836 - val_loss: 1.8436 - val_accuracy: 0.6978 - val_f1_score: 0.7000 - val_precision: 0.6991 - lr: 1.0000e-05
# Epoch 6/7
# 381/381 [==============================] - ETA: 0s - loss: 0.0505 - accuracy: 0.9832 - f1_score: 0.9830 - precision: 0.9840
# Epoch 6: val_f1_score did not improve from 0.70299
#
# Epoch 6 Learning Rate : 9.999999747378752e-06
# 381/381 [==============================] - 112s 294ms/step - loss: 0.0505 - accuracy: 0.9832 - f1_score: 0.9830 - precision: 0.9840 - val_loss: 1.8792 - val_accuracy: 0.7032 - val_f1_score: 0.6993 - val_precision: 0.7047 - lr: 1.0000e-05
# Epoch 7/7
# 381/381 [==============================] - ETA: 0s - loss: 0.0449 - accuracy: 0.9857 - f1_score: 0.9855 - precision: 0.9863
# Epoch 7: val_f1_score improved from 0.70299 to 0.70488, saving model to EfficientNetB3_SemiSupervised_Final_imbalanced.h5
#
# Epoch 7 Learning Rate : 9.999999747378752e-06
# 381/381 [==============================] - 125s 328ms/step - loss: 0.0449 - accuracy: 0.9857 - f1_score: 0.9855 - precision: 0.9863 - val_loss: 1.9447 - val_accuracy: 0.7066 - val_f1_score: 0.7049 - val_precision: 0.7081 - lr: 1.0000e-05
#
# Iterative Semi-Supervised training loop successfully completed!
# done1

# %%
# ==========================================================
# RELOAD COMBINED TRAINING SET + BEST WEIGHTS AFTER THE SELF-TRAINING LOOP
# ==========================================================
# FIX: this cell previously pointed at paths that don't exist anywhere
# else in the pipeline (semi_supervised_unbalanced/train_labeled/train_unlabeled).
# Standardized to the same base_path and folder names used in Cells 4 and 9.
print("start")
base_path = r"D:\Thesis_folder\Semi_Supervised_ImBalanced"
train_dir = os.path.join(base_path, 'labeled_train')
unlabeled_dir = os.path.join(base_path, 'unlabeled_train')
train_combined_dir = os.path.join(base_path, 'train_combined')

train_combined_generator = train_datagen.flow_from_directory(
    train_combined_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
    )
# 1. Rebuild the model architecture blueprint first
model = get_EfficientNetB3()

# 2. Load the weights directly into the blueprint
model.load_weights("EfficientNetB3_SemiSupervised_Final_imbalanced.h5")

print("Model weights loaded successfully!")
# Out:
# start
# Found 12057 images belonging to 3 classes.
# Model weights loaded successfully!

# %%
# ==========================================================
# PLOT LEARNING CURVES: PHASE 1 (INITIAL TRAINING)
# ==========================================================
print("start")

# Make sure history_initial is available from your Phase 1 model.fit run
if 'history_initial' in locals() or 'history_initial' in globals():
    epochs_range = range(1, len(history_initial.history['loss']) + 1)

    # 1x3 Grid for Loss, F1, and Precision
    plt.figure(figsize=(20, 5))

    # 1. Loss Curve
    plt.subplot(1, 3, 1)
    plt.plot(epochs_range, history_initial.history['loss'], label='Train Loss', color='crimson')
    plt.plot(epochs_range, history_initial.history['val_loss'], label='Val Loss', color='darkorange')

    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)

    # 2. F1-Score Curve
    plt.subplot(1, 3, 2)
    plt.plot(epochs_range, history_initial.history['f1_score'], label='Train F1', color='crimson')
    plt.plot(epochs_range, history_initial.history['val_f1_score'], label='Val F1', color='darkorange')

    plt.xlabel('Epochs')
    plt.ylabel('F1-Score')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)

    # 3. Precision Curve
    plt.subplot(1, 3, 3)
    plt.plot(epochs_range, history_initial.history['precision'], label='Train Precision', color='crimson')
    plt.plot(epochs_range, history_initial.history['val_precision'], label='Val Precision', color='darkorange')
   
    plt.xlabel('Epochs')
    plt.ylabel('Precision')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)

    plt.tight_layout()
    plt.savefig("EfficientNetB3_SemiSupervised_Initial_Learning_Curves_Imbalanced.pdf", format='pdf', bbox_inches='tight')
    plt.show()
else:
    print("Warning: history_initial variable not found. Did Phase 1 execute properly?")

print("done")
# Out:
# start
# done

# %%
# ==========================================================
# PLOT LEARNING CURVES: PHASE 3 (SEMI-SUPERVISED TRAINING)
# ==========================================================
print("start")

# Make sure history_final is available from your Phase 3 model.fit run
if 'history_final' in locals() or 'history_final' in globals():
    epochs_range = range(1, len(history_final.history['loss']) + 1)

    # 1x3 Grid for Loss, F1, and Precision
    plt.figure(figsize=(20, 5))

    # 1. Loss Curve
    plt.subplot(1, 3, 1)
    plt.plot(epochs_range, history_final.history['loss'], label='Combined Train Loss', color='crimson')
    plt.plot(epochs_range, history_final.history['val_loss'], label='Val Loss', color='darkorange')

    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)

    # 2. F1-Score Curve
    plt.subplot(1, 3, 2)
    plt.plot(epochs_range, history_final.history['f1_score'], label='Combined Train F1', color='crimson')
    plt.plot(epochs_range, history_final.history['val_f1_score'], label='Val F1', color='darkorange')
    plt.xlabel('Epochs')
    plt.ylabel('F1-Score')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)

    # 3. Precision Curve
    plt.subplot(1, 3, 3)
    plt.plot(epochs_range, history_final.history['precision'], label='Combined Train Precision', color='crimson')
    plt.plot(epochs_range, history_final.history['val_precision'], label='Val Precision', color='darkorange')

    plt.xlabel('Epochs')
    plt.ylabel('Precision')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)

    plt.tight_layout()
    plt.savefig("EfficientNetB3_SemiSupervised_Final_Learning_Curves_(Imbalanced Dataset).pdf", format='pdf', bbox_inches='tight')
    plt.show()
else:
    print("Warning: history_final variable not found. Did Phase 3 execute properly?")

print("done1")
# Out:
# start
# done1

# %%
# ==========================================================
# FINAL EVALUATION: TRAINING, VALIDATION, AND TEST SETS
# ==========================================================
print("start")

# Load final semi-supervised optimal parameters
model.load_weights("EfficientNetB3_SemiSupervised_Final_imbalanced.h5")

# 1. Evaluate on Training Data (Combined Pseudo-labeled + Labeled)
print("\n--- Evaluating Training Dataset ---")
train_loss, train_acc, train_f1, train_precision, train_recall = model.evaluate(train_combined_generator, verbose=1)
print(f"Final Train Loss: {train_loss:.4f}")
print(f"Final Train Accuracy: {train_acc:.4f}")
print(f"Final Train F1 Score: {train_f1:.4f}")
print(f"Final Train Precision: {train_precision:.4f}")
print(f"Final Train Recall: {train_recall:.4f}") # <-- Added print statement

# 2. Evaluate on Validation Data
print("\n--- Evaluating Validation Dataset ---")
val_loss, val_acc, val_f1, val_precision, val_recall = model.evaluate(val_generator, verbose=1) # <-- Added val_recall
print(f"Final Val Loss: {val_loss:.4f}")
print(f"Final Val Accuracy: {val_acc:.4f}")
print(f"Final Val F1 Score: {val_f1:.4f}")
print(f"Final Val Precision: {val_precision:.4f}")
print(f"Final Val Recall: {val_recall:.4f}") # <-- Added print statement

# 3. Evaluate on Test Data
print("\n--- Evaluating Test Dataset ---")
test_loss, test_acc, test_f1, test_precision, test_recall = model.evaluate(test_generator, verbose=1) # <-- Added test_recall
print(f"Final Test Loss: {test_loss:.4f}")
print(f"Final Test Accuracy: {test_acc:.4f}")
print(f"Final Test F1 Score: {test_f1:.4f}")
print(f"Final Test Precision: {test_precision:.4f}")
print(f"Final Test Recall: {test_recall:.4f}") # <-- Added print statement

print("done1")
# Out:
# start
#
# --- Evaluating Training Dataset ---
# 377/377 [==============================] - 398s 1s/step - loss: 1.1262 - accuracy: 0.8137 - f1_score: 0.7865 - precision: 0.7939 - recall: 0.7591
# Final Train Loss: 1.1262
# Final Train Accuracy: 0.8137
# Final Train F1 Score: 0.7865
# Final Train Precision: 0.7939
# Final Train Recall: 0.7591
#
# --- Evaluating Validation Dataset ---
# 93/93 [==============================] - 22s 238ms/step - loss: 1.9447 - accuracy: 0.7066 - f1_score: 0.7049 - precision: 0.7081 - recall: 0.7052
# Final Val Loss: 1.9447
# Final Val Accuracy: 0.7066
# Final Val F1 Score: 0.7049
# Final Val Precision: 0.7081
# Final Val Recall: 0.7052
#
# --- Evaluating Test Dataset ---
# 92/92 [==============================] - 41s 449ms/step - loss: 1.9991 - accuracy: 0.6938 - f1_score: 0.6886 - precision: 0.6960 - recall: 0.6925
# Final Test Loss: 1.9991
# Final Test Accuracy: 0.6938
# Final Test F1 Score: 0.6886
# Final Test Precision: 0.6960
# Final Test Recall: 0.6925
# done1

# %%
# ==========================================================
# INFERENCE & CLASSIFICATION REPORT
# ==========================================================
print("start")

test_generator.reset()
predictions_test = model.predict(test_generator, verbose=1)
predicted_classes_test = np.argmax(predictions_test, axis=1)
true_classes_test = test_generator.classes
class_names = list(test_generator.class_indices.keys())

print("\nClassification Report:")
print(classification_report(true_classes_test, predicted_classes_test, target_names=class_names))

print("done1")
# Out:
# start
# 92/92 [==============================] - 25s 259ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.57      0.52      0.54       888
#    Malignant       0.73      0.73      0.73      1266
#       Normal       0.75      0.83      0.79       789
#
#     accuracy                           0.69      2943
#    macro avg       0.69      0.69      0.69      2943
# weighted avg       0.69      0.69      0.69      2943
#
# done1

# %%
# ==========================================================
# CONFUSION MATRIX PLOT
# ==========================================================
print("start")

cm = confusion_matrix(true_classes_test, predicted_classes_test)

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=class_names,
    yticklabels=class_names
)

plt.ylabel('True Label', fontsize=14)
plt.xlabel('Predicted Label', fontsize=14)
plt.xticks(rotation=45) # Rotate x-axis labels so they are easier to read
plt.yticks(rotation=0)

plt.tight_layout()
plt.savefig("EfficientNetB3_SemiSupervised_confusion_matrix_test_(Imbalanced Dataset).pdf", format='pdf', bbox_inches='tight')
plt.show()

print("done1")
# Out:
# start
# done1
